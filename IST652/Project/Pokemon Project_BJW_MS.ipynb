# %% [markdown]
# # IST 652 Final Project - Pokemon
# Bing-je Wu, Maggie Southwick

# %% [markdown]
# * Outline
#     + Load the dataset
#     + Explore the datasets
#         1. Pokemon dataset
#             + Renames column names
#             + Dealing with missing values
#             + Data types conversion
#             + Add new features
#         2. PokemonGo dataset
#             + Renames column names
#             + Dealing with missing values
#             + Data types conversion
#             + Add new features
#             + Merge datasets
#         3. Pokemon Moves dataset
#             + Renames column names
#             + Dealing with missing values
#             + Data types conversion
#         4. Pokemon Tweets dataset
#             + Select features
#             + Filter results
#             + Join to Pokemon dataset and prepare for analysis
#     + Research questions

# %% [markdown]
# In this project, we are going to use three csv files and one JSON file from different data source. The first dataset, main dataset, is from the kaggle, https://www.kaggle.com/abcsds/Pokémon. The second dataset is PokemonGO dataset from pokemon database, https://pokemondb.net/go/pokedex. The third dataset is Pokemon moves dataset from the pokemon database as well, https://pokemondb.net/move. The fourth dataset is Tweets that contain Pokemon names, collected from Twitter. We are going to utilize those four datasets to perform our research questions and analysis.

# %% [markdown]
# ## Load the data set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# magic command
# %matplotlib inline    
import seaborn as sns
import statistics
# regular expression for str manipulation
import re 
# work with json formatted files
import json

# %%
df = pd.read_csv('Pokemon.csv')
# print confirmation
print('Read', len(df), 'records from Pokemon csv file.')
# Out:
# Read 800 records from Pokemon csv file.

# %%
go = pd.read_csv('pokemonGo_list.csv')
# print confirmation
print('Read', len(go), 'records from Pokemon Go csv file.')
# Out:
# Read 570 records from Pokemon Go csv file.

# %%
moves = pd.read_csv('pokemon_moves.csv')
# print confirmation
print('Read', len(moves), 'records from Pokemon moves csv file.')
# Out:
# Read 804 records from Pokemon moves csv file.

# %%
with open('pokemon_tweets.json', 'r', encoding='utf8') as jfile:
    tweets = json.load(jfile)
# print confirmation
print('Read', len(tweets), 'records from JSON file.')
# Out:
# Read 613 records from JSON file.

# %% [markdown]
# ## Explore the data set

# %%
# Set the option to see all the columns on jupyter notebook
# https://songhuiming.github.io/pages/2017/04/02/jupyter-and-pandas-display/
pd.set_option('display.max_columns', 500)
pd.options.display.max_rows=999

# %% [markdown]
# ### - Pokemon Dataset -

# %% [markdown]
# #### 1. Renames column names
# Some column names have blanks and some have periods. In order to avoid problems when we do subset, we need to change those column names.

# %%
df.rename(columns={'Type 1':'Type1',
                   'Type 2':'Type2',
                   'Sp. Atk':'Sp_Atk',
                   'Sp. Def':'Sp_Def',}, inplace=True)

# %%
print('Summary of the basic information about this DataFrame and its data: \n')
df.info()
# Out:
# Summary of the basic information about this DataFrame and its data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type1         800 non-null object
# Type2         414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp_Atk        800 non-null int64
# Sp_Def        800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# From the summary of the data set above, we have noticed that there are missing values existing in the data set, specifically in the "Type2" column.

# %%
print('Basic statistics about this DataFrame and its data:')
df.describe()
# Out:
# Basic statistics about this DataFrame and its data:
#                 #      Total          HP      Attack     Defense      Sp_Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#            Sp_Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# #### 2. Dealing with missing values
# There are 386 missing values on Type2 column. The Type2 column provides the infomation of second type.
# Some pokemons have dual types, and some are not. Thus, create a new category, 'no value', to replace the missing value.

# %%
# create a dictionary for filling na values
fill_na = {'Type2':'No value'} 
# assign the the dictionary to replace missing values
df=df.fillna(value=fill_na)
# Check to see if missing values have been resolved
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type1         0
# Type2         0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp_Atk        0
# Sp_Def        0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %% [markdown]
# #### 3. Data types conversion
# There are bool variable and nominal variable need to be converted.
# Convert columns, Generation and Legendary, to str type.
# Use astype() to convert data type with a dictionary as input.
# Reference: https://stackoverflow.com/questions/15891038/change-data-type-of-columns-in-pandas

# %%
df = df.astype({"Generation": str, "Legendary": str})
# Check data type are inplace
df.dtypes
# Out:
# #              int64
# Name          object
# Type1         object
# Type2         object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp_Atk         int64
# Sp_Def         int64
# Speed          int64
# Generation    object
# Legendary     object
# dtype: object

# %%
df
# Out:
#        #                       Name     Type1     Type2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 1      2                    Ivysaur     Grass    Poison    405   60      62
# 2      3                   Venusaur     Grass    Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4      4                 Charmander      Fire  No value    309   39      52
# 5      5                 Charmeleon      Fire  No value    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      7                   Squirtle     Water  No value    314   44      48
# 10     8                  Wartortle     Water  No value    405   59      63
# 11     9                  Blastoise     Water  No value    530   79      83
# 12     9    BlastoiseMega Blastoise     Water  No value    630   79     103
# 13    10                   Caterpie       Bug  No value    195   45      30
# 14    11                    Metapod       Bug  No value    205   50      20
# 15    12                 Butterfree       Bug    Flying    395   60      45
# 16    13                     Weedle       Bug    Poison    195   40      35
# 17    14                     Kakuna       Bug    Poison    205   45      25
# 18    15                   Beedrill       Bug    Poison    395   65      90
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 20    16                     Pidgey    Normal    Flying    251   40      45
# 21    17                  Pidgeotto    Normal    Flying    349   63      60
# 22    18                    Pidgeot    Normal    Flying    479   83      80
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 24    19                    Rattata    Normal  No value    253   30      56
# 25    20                   Raticate    Normal  No value    413   55      81
# 26    21                    Spearow    Normal    Flying    262   40      60
# 27    22                     Fearow    Normal    Flying    442   65      90
# 28    23                      Ekans    Poison  No value    288   35      60
# 29    24                      Arbok    Poison  No value    438   60      85
# 30    25                    Pikachu  Electric  No value    320   35      55
# 31    26                     Raichu  Electric  No value    485   60      90
# 32    27                  Sandshrew    Ground  No value    300   50      75
# 33    28                  Sandslash    Ground  No value    450   75     100
# 34    29                   Nidoran♀    Poison  No value    275   55      47
# 35    30                   Nidorina    Poison  No value    365   70      62
# 36    31                  Nidoqueen    Poison    Ground    505   90      92
# 37    32                   Nidoran♂    Poison  No value    273   46      57
# 38    33                   Nidorino    Poison  No value    365   61      72
# 39    34                   Nidoking    Poison    Ground    505   81     102
# 40    35                   Clefairy     Fairy  No value    323   70      45
# 41    36                   Clefable     Fairy  No value    483   95      70
# 42    37                     Vulpix      Fire  No value    299   38      41
# 43    38                  Ninetales      Fire  No value    505   73      76
# 44    39                 Jigglypuff    Normal     Fairy    270  115      45
# 45    40                 Wigglytuff    Normal     Fairy    435  140      70
# 46    41                      Zubat    Poison    Flying    245   40      45
# 47    42                     Golbat    Poison    Flying    455   75      80
# 48    43                     Oddish     Grass    Poison    320   45      50
# 49    44                      Gloom     Grass    Poison    395   60      65
# 50    45                  Vileplume     Grass    Poison    490   75      80
# 51    46                      Paras       Bug     Grass    285   35      70
# 52    47                   Parasect       Bug     Grass    405   60      95
# 53    48                    Venonat       Bug    Poison    305   60      55
# 54    49                   Venomoth       Bug    Poison    450   70      65
# 55    50                    Diglett    Ground  No value    265   10      55
# 56    51                    Dugtrio    Ground  No value    405   35      80
# 57    52                     Meowth    Normal  No value    290   40      45
# 58    53                    Persian    Normal  No value    440   65      70
# 59    54                    Psyduck     Water  No value    320   50      52
# 60    55                    Golduck     Water  No value    500   80      82
# 61    56                     Mankey  Fighting  No value    305   40      80
# 62    57                   Primeape  Fighting  No value    455   65     105
# 63    58                  Growlithe      Fire  No value    350   55      70
# 64    59                   Arcanine      Fire  No value    555   90     110
# 65    60                    Poliwag     Water  No value    300   40      50
# 66    61                  Poliwhirl     Water  No value    385   65      65
# 67    62                  Poliwrath     Water  Fighting    510   90      95
# 68    63                       Abra   Psychic  No value    310   25      20
# 69    64                    Kadabra   Psychic  No value    400   40      35
# 70    65                   Alakazam   Psychic  No value    500   55      50
# 71    65      AlakazamMega Alakazam   Psychic  No value    590   55      50
# 72    66                     Machop  Fighting  No value    305   70      80
# 73    67                    Machoke  Fighting  No value    405   80     100
# 74    68                    Machamp  Fighting  No value    505   90     130
# 75    69                 Bellsprout     Grass    Poison    300   50      75
# 76    70                 Weepinbell     Grass    Poison    390   65      90
# 77    71                 Victreebel     Grass    Poison    490   80     105
# 78    72                  Tentacool     Water    Poison    335   40      40
# 79    73                 Tentacruel     Water    Poison    515   80      70
# 80    74                    Geodude      Rock    Ground    300   40      80
# 81    75                   Graveler      Rock    Ground    390   55      95
# 82    76                      Golem      Rock    Ground    495   80     120
# 83    77                     Ponyta      Fire  No value    410   50      85
# 84    78                   Rapidash      Fire  No value    500   65     100
# 85    79                   Slowpoke     Water   Psychic    315   90      65
# 86    80                    Slowbro     Water   Psychic    490   95      75
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 88    81                  Magnemite  Electric     Steel    325   25      35
# 89    82                   Magneton  Electric     Steel    465   50      60
# 90    83                 Farfetch'd    Normal    Flying    352   52      65
# 91    84                      Doduo    Normal    Flying    310   35      85
# 92    85                     Dodrio    Normal    Flying    460   60     110
# 93    86                       Seel     Water  No value    325   65      45
# 94    87                    Dewgong     Water       Ice    475   90      70
# 95    88                     Grimer    Poison  No value    325   80      80
# 96    89                        Muk    Poison  No value    500  105     105
# 97    90                   Shellder     Water  No value    305   30      65
# 98    91                   Cloyster     Water       Ice    525   50      95
# 99    92                     Gastly     Ghost    Poison    310   30      35
# 100   93                    Haunter     Ghost    Poison    405   45      50
# 101   94                     Gengar     Ghost    Poison    500   60      65
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 103   95                       Onix      Rock    Ground    385   35      45
# 104   96                    Drowzee   Psychic  No value    328   60      48
# 105   97                      Hypno   Psychic  No value    483   85      73
# 106   98                     Krabby     Water  No value    325   30     105
# 107   99                    Kingler     Water  No value    475   55     130
# 108  100                    Voltorb  Electric  No value    330   40      30
# 109  101                  Electrode  Electric  No value    480   60      50
# 110  102                  Exeggcute     Grass   Psychic    325   60      40
# 111  103                  Exeggutor     Grass   Psychic    520   95      95
# 112  104                     Cubone    Ground  No value    320   50      50
# 113  105                    Marowak    Ground  No value    425   60      80
# 114  106                  Hitmonlee  Fighting  No value    455   50     120
# 115  107                 Hitmonchan  Fighting  No value    455   50     105
# 116  108                  Lickitung    Normal  No value    385   90      55
# 117  109                    Koffing    Poison  No value    340   40      65
# 118  110                    Weezing    Poison  No value    490   65      90
# 119  111                    Rhyhorn    Ground      Rock    345   80      85
# 120  112                     Rhydon    Ground      Rock    485  105     130
# 121  113                    Chansey    Normal  No value    450  250       5
# 122  114                    Tangela     Grass  No value    435   65      55
# 123  115                 Kangaskhan    Normal  No value    490  105      95
# 124  115  KangaskhanMega Kangaskhan    Normal  No value    590  105     125
# 125  116                     Horsea     Water  No value    295   30      40
# 126  117                     Seadra     Water  No value    440   55      65
# 127  118                    Goldeen     Water  No value    320   45      67
# 128  119                    Seaking     Water  No value    450   80      92
# 129  120                     Staryu     Water  No value    340   30      45
# 130  121                    Starmie     Water   Psychic    520   60      75
# 131  122                   Mr. Mime   Psychic     Fairy    460   40      45
# 132  123                    Scyther       Bug    Flying    500   70     110
# 133  124                       Jynx       Ice   Psychic    455   65      50
# 134  125                 Electabuzz  Electric  No value    490   65      83
# 135  126                     Magmar      Fire  No value    495   65      95
# 136  127                     Pinsir       Bug  No value    500   65     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 138  128                     Tauros    Normal  No value    490   75     100
# 139  129                   Magikarp     Water  No value    200   20      10
# 140  130                   Gyarados     Water    Flying    540   95     125
# 141  130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 142  131                     Lapras     Water       Ice    535  130      85
# 143  132                      Ditto    Normal  No value    288   48      48
# 144  133                      Eevee    Normal  No value    325   55      55
# 145  134                   Vaporeon     Water  No value    525  130      65
# 146  135                    Jolteon  Electric  No value    525   65      65
# 147  136                    Flareon      Fire  No value    525   65     130
# 148  137                    Porygon    Normal  No value    395   65      60
# 149  138                    Omanyte      Rock     Water    355   35      40
# 150  139                    Omastar      Rock     Water    495   70      60
# 151  140                     Kabuto      Rock     Water    355   30      80
# 152  141                   Kabutops      Rock     Water    495   60     115
# 153  142                 Aerodactyl      Rock    Flying    515   80     105
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 155  143                    Snorlax    Normal  No value    540  160     110
# 156  144                   Articuno       Ice    Flying    580   90      85
# 157  145                     Zapdos  Electric    Flying    580   90      90
# 158  146                    Moltres      Fire    Flying    580   90     100
# 159  147                    Dratini    Dragon  No value    300   41      64
# 160  148                  Dragonair    Dragon  No value    420   61      84
# 161  149                  Dragonite    Dragon    Flying    600   91     134
# 162  150                     Mewtwo   Psychic  No value    680  106     110
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150        MewtwoMega Mewtwo Y   Psychic  No value    780  106     150
# 165  151                        Mew   Psychic  No value    600  100     100
# 166  152                  Chikorita     Grass  No value    318   45      49
# 167  153                    Bayleef     Grass  No value    405   60      62
# 168  154                   Meganium     Grass  No value    525   80      82
# 169  155                  Cyndaquil      Fire  No value    309   39      52
# 170  156                    Quilava      Fire  No value    405   58      64
# 171  157                 Typhlosion      Fire  No value    534   78      84
# 172  158                   Totodile     Water  No value    314   50      65
# 173  159                   Croconaw     Water  No value    405   65      80
# 174  160                 Feraligatr     Water  No value    530   85     105
# 175  161                    Sentret    Normal  No value    215   35      46
# 176  162                     Furret    Normal  No value    415   85      76
# 177  163                   Hoothoot    Normal    Flying    262   60      30
# 178  164                    Noctowl    Normal    Flying    442  100      50
# 179  165                     Ledyba       Bug    Flying    265   40      20
# 180  166                     Ledian       Bug    Flying    390   55      35
# 181  167                   Spinarak       Bug    Poison    250   40      60
# 182  168                    Ariados       Bug    Poison    390   70      90
# 183  169                     Crobat    Poison    Flying    535   85      90
# 184  170                   Chinchou     Water  Electric    330   75      38
# 185  171                    Lanturn     Water  Electric    460  125      58
# 186  172                      Pichu  Electric  No value    205   20      40
# 187  173                     Cleffa     Fairy  No value    218   50      25
# 188  174                  Igglybuff    Normal     Fairy    210   90      30
# 189  175                     Togepi     Fairy  No value    245   35      20
# 190  176                    Togetic     Fairy    Flying    405   55      40
# 191  177                       Natu   Psychic    Flying    320   40      50
# 192  178                       Xatu   Psychic    Flying    470   65      75
# 193  179                     Mareep  Electric  No value    280   55      40
# 194  180                    Flaaffy  Electric  No value    365   70      55
# 195  181                   Ampharos  Electric  No value    510   90      75
# 196  181      AmpharosMega Ampharos  Electric    Dragon    610   90      95
# 197  182                  Bellossom     Grass  No value    490   75      80
# 198  183                     Marill     Water     Fairy    250   70      20
# 199  184                  Azumarill     Water     Fairy    420  100      50
# 200  185                  Sudowoodo      Rock  No value    410   70     100
# 201  186                   Politoed     Water  No value    500   90      75
# 202  187                     Hoppip     Grass    Flying    250   35      35
# 203  188                   Skiploom     Grass    Flying    340   55      45
# 204  189                   Jumpluff     Grass    Flying    460   75      55
# 205  190                      Aipom    Normal  No value    360   55      70
# 206  191                    Sunkern     Grass  No value    180   30      30
# 207  192                   Sunflora     Grass  No value    425   75      75
# 208  193                      Yanma       Bug    Flying    390   65      65
# 209  194                     Wooper     Water    Ground    210   55      45
# 210  195                   Quagsire     Water    Ground    430   95      85
# 211  196                     Espeon   Psychic  No value    525   65      65
# 212  197                    Umbreon      Dark  No value    525   95      65
# 213  198                    Murkrow      Dark    Flying    405   60      85
# 214  199                   Slowking     Water   Psychic    490   95      75
# 215  200                 Misdreavus     Ghost  No value    435   60      60
# 216  201                      Unown   Psychic  No value    336   48      72
# 217  202                  Wobbuffet   Psychic  No value    405  190      33
# 218  203                  Girafarig    Normal   Psychic    455   70      80
# 219  204                     Pineco       Bug  No value    290   50      65
# 220  205                 Forretress       Bug     Steel    465   75      90
# 221  206                  Dunsparce    Normal  No value    415  100      70
# 222  207                     Gligar    Ground    Flying    430   65      75
# 223  208                    Steelix     Steel    Ground    510   75      85
# 224  208        SteelixMega Steelix     Steel    Ground    610   75     125
# 225  209                   Snubbull     Fairy  No value    300   60      80
# 226  210                   Granbull     Fairy  No value    450   90     120
# 227  211                   Qwilfish     Water    Poison    430   65      95
# 228  212                     Scizor       Bug     Steel    500   70     130
# 229  212          ScizorMega Scizor       Bug     Steel    600   70     150
# 230  213                    Shuckle       Bug      Rock    505   20      10
# 231  214                  Heracross       Bug  Fighting    500   80     125
# 232  214    HeracrossMega Heracross       Bug  Fighting    600   80     185
# 233  215                    Sneasel      Dark       Ice    430   55      95
# 234  216                  Teddiursa    Normal  No value    330   60      80
# 235  217                   Ursaring    Normal  No value    500   90     130
# 236  218                     Slugma      Fire  No value    250   40      40
# 237  219                   Magcargo      Fire      Rock    410   50      50
# 238  220                     Swinub       Ice    Ground    250   50      50
# 239  221                  Piloswine       Ice    Ground    450  100     100
# 240  222                    Corsola     Water      Rock    380   55      55
# 241  223                   Remoraid     Water  No value    300   35      65
# 242  224                  Octillery     Water  No value    480   75     105
# 243  225                   Delibird       Ice    Flying    330   45      55
# 244  226                    Mantine     Water    Flying    465   65      40
# 245  227                   Skarmory     Steel    Flying    465   65      80
# 246  228                   Houndour      Dark      Fire    330   45      60
# 247  229                   Houndoom      Dark      Fire    500   75      90
# 248  229      HoundoomMega Houndoom      Dark      Fire    600   75      90
# 249  230                    Kingdra     Water    Dragon    540   75      95
# 250  231                     Phanpy    Ground  No value    330   90      60
# 251  232                    Donphan    Ground  No value    500   90     120
# 252  233                   Porygon2    Normal  No value    515   85      80
# 253  234                   Stantler    Normal  No value    465   73      95
# 254  235                   Smeargle    Normal  No value    250   55      20
# 255  236                    Tyrogue  Fighting  No value    210   35      35
# 256  237                  Hitmontop  Fighting  No value    455   50      95
# 257  238                   Smoochum       Ice   Psychic    305   45      30
# 258  239                     Elekid  Electric  No value    360   45      63
# 259  240                      Magby      Fire  No value    365   45      75
# 260  241                    Miltank    Normal  No value    490   95      80
# 261  242                    Blissey    Normal  No value    540  255      10
# 262  243                     Raikou  Electric  No value    580   90      85
# 263  244                      Entei      Fire  No value    580  115     115
# 264  245                    Suicune     Water  No value    580  100      75
# 265  246                   Larvitar      Rock    Ground    300   50      64
# 266  247                    Pupitar      Rock    Ground    410   70      84
# 267  248                  Tyranitar      Rock      Dark    600  100     134
# 268  248    TyranitarMega Tyranitar      Rock      Dark    700  100     164
# 269  249                      Lugia   Psychic    Flying    680  106      90
# 270  250                      Ho-oh      Fire    Flying    680  106     130
# 271  251                     Celebi   Psychic     Grass    600  100     100
# 272  252                    Treecko     Grass  No value    310   40      45
# 273  253                    Grovyle     Grass  No value    405   50      65
# 274  254                   Sceptile     Grass  No value    530   70      85
# 275  254      SceptileMega Sceptile     Grass    Dragon    630   70     110
# 276  255                    Torchic      Fire  No value    310   45      60
# 277  256                  Combusken      Fire  Fighting    405   60      85
# 278  257                   Blaziken      Fire  Fighting    530   80     120
# 279  257      BlazikenMega Blaziken      Fire  Fighting    630   80     160
# 280  258                     Mudkip     Water  No value    310   50      70
# 281  259                  Marshtomp     Water    Ground    405   70      85
# 282  260                   Swampert     Water    Ground    535  100     110
# 283  260      SwampertMega Swampert     Water    Ground    635  100     150
# 284  261                  Poochyena      Dark  No value    220   35      55
# 285  262                  Mightyena      Dark  No value    420   70      90
# 286  263                  Zigzagoon    Normal  No value    240   38      30
# 287  264                    Linoone    Normal  No value    420   78      70
# 288  265                    Wurmple       Bug  No value    195   45      45
# 289  266                    Silcoon       Bug  No value    205   50      35
# 290  267                  Beautifly       Bug    Flying    395   60      70
# 291  268                    Cascoon       Bug  No value    205   50      35
# 292  269                     Dustox       Bug    Poison    385   60      50
# 293  270                      Lotad     Water     Grass    220   40      30
# 294  271                     Lombre     Water     Grass    340   60      50
# 295  272                   Ludicolo     Water     Grass    480   80      70
# 296  273                     Seedot     Grass  No value    220   40      40
# 297  274                    Nuzleaf     Grass      Dark    340   70      70
# 298  275                    Shiftry     Grass      Dark    480   90     100
# 299  276                    Taillow    Normal    Flying    270   40      55
# 300  277                    Swellow    Normal    Flying    430   60      85
# 301  278                    Wingull     Water    Flying    270   40      30
# 302  279                   Pelipper     Water    Flying    430   60      50
# 303  280                      Ralts   Psychic     Fairy    198   28      25
# 304  281                     Kirlia   Psychic     Fairy    278   38      35
# 305  282                  Gardevoir   Psychic     Fairy    518   68      65
# 306  282    GardevoirMega Gardevoir   Psychic     Fairy    618   68      85
# 307  283                    Surskit       Bug     Water    269   40      30
# 308  284                 Masquerain       Bug    Flying    414   70      60
# 309  285                  Shroomish     Grass  No value    295   60      40
# 310  286                    Breloom     Grass  Fighting    460   60     130
# 311  287                    Slakoth    Normal  No value    280   60      60
# 312  288                   Vigoroth    Normal  No value    440   80      80
# 313  289                    Slaking    Normal  No value    670  150     160
# 314  290                    Nincada       Bug    Ground    266   31      45
# 315  291                    Ninjask       Bug    Flying    456   61      90
# 316  292                   Shedinja       Bug     Ghost    236    1      90
# 317  293                    Whismur    Normal  No value    240   64      51
# 318  294                    Loudred    Normal  No value    360   84      71
# 319  295                    Exploud    Normal  No value    490  104      91
# 320  296                   Makuhita  Fighting  No value    237   72      60
# 321  297                   Hariyama  Fighting  No value    474  144     120
# 322  298                    Azurill    Normal     Fairy    190   50      20
# 323  299                   Nosepass      Rock  No value    375   30      45
# 324  300                     Skitty    Normal  No value    260   50      45
# 325  301                   Delcatty    Normal  No value    380   70      65
# 326  302                    Sableye      Dark     Ghost    380   50      75
# 327  302        SableyeMega Sableye      Dark     Ghost    480   50      85
# 328  303                     Mawile     Steel     Fairy    380   50      85
# 329  303          MawileMega Mawile     Steel     Fairy    480   50     105
# 330  304                       Aron     Steel      Rock    330   50      70
# 331  305                     Lairon     Steel      Rock    430   60      90
# 332  306                     Aggron     Steel      Rock    530   70     110
# 333  306          AggronMega Aggron     Steel  No value    630   70     140
# 334  307                   Meditite  Fighting   Psychic    280   30      40
# 335  308                   Medicham  Fighting   Psychic    410   60      60
# 336  308      MedichamMega Medicham  Fighting   Psychic    510   60     100
# 337  309                  Electrike  Electric  No value    295   40      45
# 338  310                  Manectric  Electric  No value    475   70      75
# 339  310    ManectricMega Manectric  Electric  No value    575   70      75
# 340  311                     Plusle  Electric  No value    405   60      50
# 341  312                      Minun  Electric  No value    405   60      40
# 342  313                    Volbeat       Bug  No value    400   65      73
# 343  314                   Illumise       Bug  No value    400   65      47
# 344  315                    Roselia     Grass    Poison    400   50      60
# 345  316                     Gulpin    Poison  No value    302   70      43
# 346  317                     Swalot    Poison  No value    467  100      73
# 347  318                   Carvanha     Water      Dark    305   45      90
# 348  319                   Sharpedo     Water      Dark    460   70     120
# 349  319      SharpedoMega Sharpedo     Water      Dark    560   70     140
# 350  320                    Wailmer     Water  No value    400  130      70
# 351  321                    Wailord     Water  No value    500  170      90
# 352  322                      Numel      Fire    Ground    305   60      60
# 353  323                   Camerupt      Fire    Ground    460   70     100
# 354  323      CameruptMega Camerupt      Fire    Ground    560   70     120
# 355  324                    Torkoal      Fire  No value    470   70      85
# 356  325                     Spoink   Psychic  No value    330   60      25
# 357  326                    Grumpig   Psychic  No value    470   80      45
# 358  327                     Spinda    Normal  No value    360   60      60
# 359  328                   Trapinch    Ground  No value    290   45     100
# 360  329                    Vibrava    Ground    Dragon    340   50      70
# 361  330                     Flygon    Ground    Dragon    520   80     100
# 362  331                     Cacnea     Grass  No value    335   50      85
# 363  332                   Cacturne     Grass      Dark    475   70     115
# 364  333                     Swablu    Normal    Flying    310   45      40
# 365  334                    Altaria    Dragon    Flying    490   75      70
# 366  334        AltariaMega Altaria    Dragon     Fairy    590   75     110
# 367  335                   Zangoose    Normal  No value    458   73     115
# 368  336                    Seviper    Poison  No value    458   73     100
# 369  337                   Lunatone      Rock   Psychic    440   70      55
# 370  338                    Solrock      Rock   Psychic    440   70      95
# 371  339                   Barboach     Water    Ground    288   50      48
# 372  340                   Whiscash     Water    Ground    468  110      78
# 373  341                   Corphish     Water  No value    308   43      80
# 374  342                  Crawdaunt     Water      Dark    468   63     120
# 375  343                     Baltoy    Ground   Psychic    300   40      40
# 376  344                    Claydol    Ground   Psychic    500   60      70
# 377  345                     Lileep      Rock     Grass    355   66      41
# 378  346                    Cradily      Rock     Grass    495   86      81
# 379  347                    Anorith      Rock       Bug    355   45      95
# 380  348                    Armaldo      Rock       Bug    495   75     125
# 381  349                     Feebas     Water  No value    200   20      15
# 382  350                    Milotic     Water  No value    540   95      60
# 383  351                   Castform    Normal  No value    420   70      70
# 384  352                    Kecleon    Normal  No value    440   60      90
# 385  353                    Shuppet     Ghost  No value    295   44      75
# 386  354                    Banette     Ghost  No value    455   64     115
# 387  354        BanetteMega Banette     Ghost  No value    555   64     165
# 388  355                    Duskull     Ghost  No value    295   20      40
# 389  356                   Dusclops     Ghost  No value    455   40      70
# 390  357                    Tropius     Grass    Flying    460   99      68
# 391  358                   Chimecho   Psychic  No value    425   65      50
# 392  359                      Absol      Dark  No value    465   65     130
# 393  359            AbsolMega Absol      Dark  No value    565   65     150
# 394  360                     Wynaut   Psychic  No value    260   95      23
# 395  361                    Snorunt       Ice  No value    300   50      50
# 396  362                     Glalie       Ice  No value    480   80      80
# 397  362          GlalieMega Glalie       Ice  No value    580   80     120
# 398  363                     Spheal       Ice     Water    290   70      40
# 399  364                     Sealeo       Ice     Water    410   90      60
# 400  365                    Walrein       Ice     Water    530  110      80
# 401  366                   Clamperl     Water  No value    345   35      64
# 402  367                    Huntail     Water  No value    485   55     104
# 403  368                   Gorebyss     Water  No value    485   55      84
# 404  369                  Relicanth     Water      Rock    485  100      90
# 405  370                    Luvdisc     Water  No value    330   43      30
# 406  371                      Bagon    Dragon  No value    300   45      75
# 407  372                    Shelgon    Dragon  No value    420   65      95
# 408  373                  Salamence    Dragon    Flying    600   95     135
# 409  373    SalamenceMega Salamence    Dragon    Flying    700   95     145
# 410  374                     Beldum     Steel   Psychic    300   40      55
# 411  375                     Metang     Steel   Psychic    420   60      75
# 412  376                  Metagross     Steel   Psychic    600   80     135
# 413  376    MetagrossMega Metagross     Steel   Psychic    700   80     145
# 414  377                   Regirock      Rock  No value    580   80     100
# 415  378                     Regice       Ice  No value    580   80      50
# 416  379                  Registeel     Steel  No value    580   80      75
# 417  380                     Latias    Dragon   Psychic    600   80      80
# 418  380          LatiasMega Latias    Dragon   Psychic    700   80     100
# 419  381                     Latios    Dragon   Psychic    600   80      90
# 420  381          LatiosMega Latios    Dragon   Psychic    700   80     130
# 421  382                     Kyogre     Water  No value    670  100     100
# 422  382        KyogrePrimal Kyogre     Water  No value    770  100     150
# 423  383                    Groudon    Ground  No value    670  100     150
# 424  383      GroudonPrimal Groudon    Ground      Fire    770  100     180
# 425  384                   Rayquaza    Dragon    Flying    680  105     150
# 426  384      RayquazaMega Rayquaza    Dragon    Flying    780  105     180
# 427  385                    Jirachi     Steel   Psychic    600  100     100
# 428  386         DeoxysNormal Forme   Psychic  No value    600   50     150
# 429  386         DeoxysAttack Forme   Psychic  No value    600   50     180
# 430  386        DeoxysDefense Forme   Psychic  No value    600   50      70
# 431  386          DeoxysSpeed Forme   Psychic  No value    600   50      95
# 432  387                    Turtwig     Grass  No value    318   55      68
# 433  388                     Grotle     Grass  No value    405   75      89
# 434  389                   Torterra     Grass    Ground    525   95     109
# 435  390                   Chimchar      Fire  No value    309   44      58
# 436  391                   Monferno      Fire  Fighting    405   64      78
# 437  392                  Infernape      Fire  Fighting    534   76     104
# 438  393                     Piplup     Water  No value    314   53      51
# 439  394                   Prinplup     Water  No value    405   64      66
# 440  395                   Empoleon     Water     Steel    530   84      86
# 441  396                     Starly    Normal    Flying    245   40      55
# 442  397                   Staravia    Normal    Flying    340   55      75
# 443  398                  Staraptor    Normal    Flying    485   85     120
# 444  399                     Bidoof    Normal  No value    250   59      45
# 445  400                    Bibarel    Normal     Water    410   79      85
# 446  401                  Kricketot       Bug  No value    194   37      25
# 447  402                 Kricketune       Bug  No value    384   77      85
# 448  403                      Shinx  Electric  No value    263   45      65
# 449  404                      Luxio  Electric  No value    363   60      85
# 450  405                     Luxray  Electric  No value    523   80     120
# 451  406                      Budew     Grass    Poison    280   40      30
# 452  407                   Roserade     Grass    Poison    515   60      70
# 453  408                   Cranidos      Rock  No value    350   67     125
# 454  409                  Rampardos      Rock  No value    495   97     165
# 455  410                   Shieldon      Rock     Steel    350   30      42
# 456  411                  Bastiodon      Rock     Steel    495   60      52
# 457  412                      Burmy       Bug  No value    224   40      29
# 458  413        WormadamPlant Cloak       Bug     Grass    424   60      59
# 459  413        WormadamSandy Cloak       Bug    Ground    424   60      79
# 460  413        WormadamTrash Cloak       Bug     Steel    424   60      69
# 461  414                     Mothim       Bug    Flying    424   70      94
# 462  415                     Combee       Bug    Flying    244   30      30
# 463  416                  Vespiquen       Bug    Flying    474   70      80
# 464  417                  Pachirisu  Electric  No value    405   60      45
# 465  418                     Buizel     Water  No value    330   55      65
# 466  419                   Floatzel     Water  No value    495   85     105
# 467  420                    Cherubi     Grass  No value    275   45      35
# 468  421                    Cherrim     Grass  No value    450   70      60
# 469  422                    Shellos     Water  No value    325   76      48
# 470  423                  Gastrodon     Water    Ground    475  111      83
# 471  424                    Ambipom    Normal  No value    482   75     100
# 472  425                   Drifloon     Ghost    Flying    348   90      50
# 473  426                   Drifblim     Ghost    Flying    498  150      80
# 474  427                    Buneary    Normal  No value    350   55      66
# 475  428                    Lopunny    Normal  No value    480   65      76
# 476  428        LopunnyMega Lopunny    Normal  Fighting    580   65     136
# 477  429                  Mismagius     Ghost  No value    495   60      60
# 478  430                  Honchkrow      Dark    Flying    505  100     125
# 479  431                    Glameow    Normal  No value    310   49      55
# 480  432                    Purugly    Normal  No value    452   71      82
# 481  433                  Chingling   Psychic  No value    285   45      30
# 482  434                     Stunky    Poison      Dark    329   63      63
# 483  435                   Skuntank    Poison      Dark    479  103      93
# 484  436                    Bronzor     Steel   Psychic    300   57      24
# 485  437                   Bronzong     Steel   Psychic    500   67      89
# 486  438                     Bonsly      Rock  No value    290   50      80
# 487  439                   Mime Jr.   Psychic     Fairy    310   20      25
# 488  440                    Happiny    Normal  No value    220  100       5
# 489  441                     Chatot    Normal    Flying    411   76      65
# 490  442                  Spiritomb     Ghost      Dark    485   50      92
# 491  443                      Gible    Dragon    Ground    300   58      70
# 492  444                     Gabite    Dragon    Ground    410   68      90
# 493  445                   Garchomp    Dragon    Ground    600  108     130
# 494  445      GarchompMega Garchomp    Dragon    Ground    700  108     170
# 495  446                   Munchlax    Normal  No value    390  135      85
# 496  447                      Riolu  Fighting  No value    285   40      70
# 497  448                    Lucario  Fighting     Steel    525   70     110
# 498  448        LucarioMega Lucario  Fighting     Steel    625   70     145
# 499  449                 Hippopotas    Ground  No value    330   68      72
# 500  450                  Hippowdon    Ground  No value    525  108     112
# 501  451                    Skorupi    Poison       Bug    330   40      50
# 502  452                    Drapion    Poison      Dark    500   70      90
# 503  453                   Croagunk    Poison  Fighting    300   48      61
# 504  454                  Toxicroak    Poison  Fighting    490   83     106
# 505  455                  Carnivine     Grass  No value    454   74     100
# 506  456                    Finneon     Water  No value    330   49      49
# 507  457                   Lumineon     Water  No value    460   69      69
# 508  458                    Mantyke     Water    Flying    345   45      20
# 509  459                     Snover     Grass       Ice    334   60      62
# 510  460                  Abomasnow     Grass       Ice    494   90      92
# 511  460    AbomasnowMega Abomasnow     Grass       Ice    594   90     132
# 512  461                    Weavile      Dark       Ice    510   70     120
# 513  462                  Magnezone  Electric     Steel    535   70      70
# 514  463                 Lickilicky    Normal  No value    515  110      85
# 515  464                  Rhyperior    Ground      Rock    535  115     140
# 516  465                  Tangrowth     Grass  No value    535  100     100
# 517  466                 Electivire  Electric  No value    540   75     123
# 518  467                  Magmortar      Fire  No value    540   75      95
# 519  468                   Togekiss     Fairy    Flying    545   85      50
# 520  469                    Yanmega       Bug    Flying    515   86      76
# 521  470                    Leafeon     Grass  No value    525   65     110
# 522  471                    Glaceon       Ice  No value    525   65      60
# 523  472                    Gliscor    Ground    Flying    510   75      95
# 524  473                  Mamoswine       Ice    Ground    530  110     130
# 525  474                  Porygon-Z    Normal  No value    535   85      80
# 526  475                    Gallade   Psychic  Fighting    518   68     125
# 527  475        GalladeMega Gallade   Psychic  Fighting    618   68     165
# 528  476                  Probopass      Rock     Steel    525   60      55
# 529  477                   Dusknoir     Ghost  No value    525   45     100
# 530  478                   Froslass       Ice     Ghost    480   70      80
# 531  479                      Rotom  Electric     Ghost    440   50      50
# 532  479            RotomHeat Rotom  Electric      Fire    520   50      65
# 533  479            RotomWash Rotom  Electric     Water    520   50      65
# 534  479           RotomFrost Rotom  Electric       Ice    520   50      65
# 535  479             RotomFan Rotom  Electric    Flying    520   50      65
# 536  479             RotomMow Rotom  Electric     Grass    520   50      65
# 537  480                       Uxie   Psychic  No value    580   75      75
# 538  481                    Mesprit   Psychic  No value    580   80     105
# 539  482                      Azelf   Psychic  No value    580   75     125
# 540  483                     Dialga     Steel    Dragon    680  100     120
# 541  484                     Palkia     Water    Dragon    680   90     120
# 542  485                    Heatran      Fire     Steel    600   91      90
# 543  486                  Regigigas    Normal  No value    670  110     160
# 544  487      GiratinaAltered Forme     Ghost    Dragon    680  150     100
# 545  487       GiratinaOrigin Forme     Ghost    Dragon    680  150     120
# 546  488                  Cresselia   Psychic  No value    600  120      70
# 547  489                     Phione     Water  No value    480   80      80
# 548  490                    Manaphy     Water  No value    600  100     100
# 549  491                    Darkrai      Dark  No value    600   70      90
# 550  492          ShayminLand Forme     Grass  No value    600  100     100
# 551  492           ShayminSky Forme     Grass    Flying    600  100     103
# 552  493                     Arceus    Normal  No value    720  120     120
# 553  494                    Victini   Psychic      Fire    600  100     100
# 554  495                      Snivy     Grass  No value    308   45      45
# 555  496                    Servine     Grass  No value    413   60      60
# 556  497                  Serperior     Grass  No value    528   75      75
# 557  498                      Tepig      Fire  No value    308   65      63
# 558  499                    Pignite      Fire  Fighting    418   90      93
# 559  500                     Emboar      Fire  Fighting    528  110     123
# 560  501                   Oshawott     Water  No value    308   55      55
# 561  502                     Dewott     Water  No value    413   75      75
# 562  503                   Samurott     Water  No value    528   95     100
# 563  504                     Patrat    Normal  No value    255   45      55
# 564  505                    Watchog    Normal  No value    420   60      85
# 565  506                   Lillipup    Normal  No value    275   45      60
# 566  507                    Herdier    Normal  No value    370   65      80
# 567  508                  Stoutland    Normal  No value    500   85     110
# 568  509                   Purrloin      Dark  No value    281   41      50
# 569  510                    Liepard      Dark  No value    446   64      88
# 570  511                    Pansage     Grass  No value    316   50      53
# 571  512                   Simisage     Grass  No value    498   75      98
# 572  513                    Pansear      Fire  No value    316   50      53
# 573  514                   Simisear      Fire  No value    498   75      98
# 574  515                    Panpour     Water  No value    316   50      53
# 575  516                   Simipour     Water  No value    498   75      98
# 576  517                      Munna   Psychic  No value    292   76      25
# 577  518                   Musharna   Psychic  No value    487  116      55
# 578  519                     Pidove    Normal    Flying    264   50      55
# 579  520                  Tranquill    Normal    Flying    358   62      77
# 580  521                   Unfezant    Normal    Flying    488   80     115
# 581  522                    Blitzle  Electric  No value    295   45      60
# 582  523                  Zebstrika  Electric  No value    497   75     100
# 583  524                 Roggenrola      Rock  No value    280   55      75
# 584  525                    Boldore      Rock  No value    390   70     105
# 585  526                   Gigalith      Rock  No value    515   85     135
# 586  527                     Woobat   Psychic    Flying    313   55      45
# 587  528                    Swoobat   Psychic    Flying    425   67      57
# 588  529                    Drilbur    Ground  No value    328   60      85
# 589  530                  Excadrill    Ground     Steel    508  110     135
# 590  531                     Audino    Normal  No value    445  103      60
# 591  531          AudinoMega Audino    Normal     Fairy    545  103      60
# 592  532                    Timburr  Fighting  No value    305   75      80
# 593  533                    Gurdurr  Fighting  No value    405   85     105
# 594  534                 Conkeldurr  Fighting  No value    505  105     140
# 595  535                    Tympole     Water  No value    294   50      50
# 596  536                  Palpitoad     Water    Ground    384   75      65
# 597  537                 Seismitoad     Water    Ground    509  105      95
# 598  538                      Throh  Fighting  No value    465  120     100
# 599  539                       Sawk  Fighting  No value    465   75     125
# 600  540                   Sewaddle       Bug     Grass    310   45      53
# 601  541                   Swadloon       Bug     Grass    380   55      63
# 602  542                   Leavanny       Bug     Grass    500   75     103
# 603  543                   Venipede       Bug    Poison    260   30      45
# 604  544                 Whirlipede       Bug    Poison    360   40      55
# 605  545                  Scolipede       Bug    Poison    485   60     100
# ...
# 529      135      65     135     45          4     False
# 530       70      80      70    110          4     False
# 531       77      95      77     91          4     False
# 532      107     105     107     86          4     False
# 533      107     105     107     86          4     False
# 534      107     105     107     86          4     False
# 535      107     105     107     86          4     False
# 536      107     105     107     86          4     False
# 537      130      75     130     95          4      True
# 538      105     105     105     80          4      True
# 539       70     125      70    115          4      True
# 540      120     150     100     90          4      True
# 541      100     150     120    100          4      True
# 542      106     130     106     77          4      True
# 543      110      80     110    100          4      True
# 544      120     100     120     90          4      True
# 545      100     120     100     90          4      True
# 546      120      75     130     85          4     False
# 547       80      80      80     80          4     False
# 548      100     100     100    100          4     False
# 549       90     135      90    125          4      True
# 550      100     100     100    100          4      True
# 551       75     120      75    127          4      True
# 552      120     120     120    120          4      True
# 553      100     100     100    100          5      True
# 554       55      45      55     63          5     False
# 555       75      60      75     83          5     False
# 556       95      75      95    113          5     False
# 557       45      45      45     45          5     False
# 558       55      70      55     55          5     False
# 559       65     100      65     65          5     False
# 560       45      63      45     45          5     False
# 561       60      83      60     60          5     False
# 562       85     108      70     70          5     False
# 563       39      35      39     42          5     False
# 564       69      60      69     77          5     False
# 565       45      25      45     55          5     False
# 566       65      35      65     60          5     False
# 567       90      45      90     80          5     False
# 568       37      50      37     66          5     False
# 569       50      88      50    106          5     False
# 570       48      53      48     64          5     False
# 571       63      98      63    101          5     False
# 572       48      53      48     64          5     False
# 573       63      98      63    101          5     False
# 574       48      53      48     64          5     False
# 575       63      98      63    101          5     False
# 576       45      67      55     24          5     False
# 577       85     107      95     29          5     False
# 578       50      36      30     43          5     False
# 579       62      50      42     65          5     False
# 580       80      65      55     93          5     False
# 581       32      50      32     76          5     False
# 582       63      80      63    116          5     False
# 583       85      25      25     15          5     False
# 584      105      50      40     20          5     False
# 585      130      60      80     25          5     False
# 586       43      55      43     72          5     False
# 587       55      77      55    114          5     False
# 588       40      30      45     68          5     False
# 589       60      50      65     88          5     False
# 590       86      60      86     50          5     False
# 591      126      80     126     50          5     False
# 592       55      25      35     35          5     False
# 593       85      40      50     40          5     False
# 594       95      55      65     45          5     False
# 595       40      50      40     64          5     False
# 596       55      65      55     69          5     False
# 597       75      85      75     74          5     False
# 598       85      30      85     45          5     False
# 599       75      30      75     85          5     False
# 600       70      40      60     42          5     False
# 601       90      50      80     42          5     False
# 602       80      70      80     92          5     False
# 603       59      30      39     57          5     False
# 604       99      40      79     47          5     False
# 605       89      55      69    112          5     False
# 606       60      37      50     66          5     False
# 607       85      77      75    116          5     False
# 608       50      70      50     30          5     False
# 609       75     110      75     90          5     False
# 610       65      80      55     98          5     False
# 611       35      35      35     65          5     False
# 612       45      45      45     74          5     False
# 613       80      65      70     92          5     False
# 614       45      15      45     50          5     False
# 615       55      30      55     95          5     False
# 616      105     140     105     55          5     False
# 617       67     106      67     60          5     False
# 618       85      35      35     55          5     False
# 619      125      65      75     45          5     False
# 620       70      35      70     48          5     False
# 621      115      45     115     58          5     False
# 622       80     103      80     97          5     False
# 623       85      55      65     30          5     False
# 624      145      95     105     30          5     False
# 625      103      53      45     22          5     False
# 626      133      83      65     32          5     False
# 627       45      74      45     70          5     False
# 628       65     112      65    110          5     False
# 629       62      40      62     65          5     False
# 630       82      60      82     75          5     False
# 631       40      80      40     65          5     False
# 632       60     120      60    105          5     False
# 633       40      40      40     75          5     False
# 634       60      65      60    115          5     False
# 635       50      55      65     45          5     False
# 636       70      75      85     55          5     False
# 637       95      95     110     65          5     False
# 638       40     105      50     20          5     False
# 639       50     125      60     30          5     False
# 640       75     125      85     30          5     False
# 641       50      44      50     55          5     False
# 642       63      87      63     98          5     False
# 643       50      65      60     44          5     False
# 644       65      80      75     59          5     False
# 645       85     110      95     79          5     False
# 646       50      40      50     75          5     False
# 647       70      60      70     95          5     False
# 648       60      75      60    103          5     False
# 649       45      40      45     60          5     False
# 650      105      60     105     20          5     False
# 651       45      55      55     15          5     False
# 652       70      85      80     30          5     False
# 653       50      65      85     40          5     False
# 654       70      85     105     60          5     False
# 655       80      40      45     65          5     False
# 656       50      57      50     65          5     False
# 657       60      97      60    108          5     False
# 658       91      24      86     10          5     False
# 659      131      54     116     20          5     False
# 660       70      45      60     30          5     False
# 661       95      70      85     50          5     False
# 662      115      70      85     90          5     False
# 663       40      45      40     60          5     False
# 664       70      75      70     40          5     False
# 665       80     105      80     50          5     False
# 666       55      85      55     30          5     False
# 667       75     125      95     40          5     False
# 668       55      65      55     20          5     False
# 669       60      95      60     55          5     False
# 670       90     145      90     80          5     False
# 671       60      30      40     57          5     False
# 672       70      40      50     67          5     False
# 673       90      60      70     97          5     False
# 674       40      60      40     40          5     False
# 675       80      70      80     50          5     False
# 676       30      95     135    105          5     False
# 677       85      40      65     25          5     False
# 678       40     100      60    145          5     False
# 679       84      81      99     32          5     False
# 680       50      55      50     65          5     False
# 681       60      95      60    105          5     False
# 682       90      60      90     48          5     False
# 683       50      35      50     35          5     False
# 684       80      55      80     55          5     False
# 685       70      40      40     60          5     False
# 686      100      60      70     70          5     False
# 687       95      40      95     55          5     False
# 688       50      37      50     60          5     False
# 689       75      57      75     80          5     False
# 690       75      45      65     60          5     False
# 691      105      55      95     80          5     False
# 692       66     105      66     65          5     False
# 693      112      48      48    109          5     False
# 694       50      45      50     38          5     False
# 695       70      65      70     58          5     False
# 696       90     125      90     98          5     False
# 697       55      50      55     60          5     False
# 698       65     135     105    100          5     False
# 699      129      90      72    108          5      True
# 700       90      72      90    108          5      True
# 701       72      90     129    108          5      True
# 702       70     125      80    111          5      True
# 703       80     110      90    121          5      True
# 704       70     125      80    111          5      True
# 705       70     145      80    101          5      True
# 706      100     150     120     90          5      True
# 707      120     120     100     90          5      True
# 708       90     115      80    101          5      True
# 709       90     105      80     91          5      True
# 710       90     130      90     95          5      True
# 711      100     120      90     95          5      True
# 712       90     170     100     95          5      True
# 713       90     129      90    108          5     False
# 714       90     129      90    108          5     False
# 715       77     128     128     90          5     False
# 716       90      77      77    128          5     False
# 717       95     120      95     99          5     False
# 718       65      48      45     38          6     False
# 719       95      56      58     57          6     False
# 720      122      74      75     64          6     False
# 721       40      62      60     60          6     False
# 722       58      90      70     73          6     False
# 723       72     114     100    104          6     False
# 724       40      62      44     71          6     False
# 725       52      83      56     97          6     False
# 726       67     103      71    122          6     False
# 727       38      32      36     57          6     False
# 728       77      50      77     78          6     False
# 729       43      40      38     62          6     False
# 730       55      56      52     84          6     False
# 731       71      74      69    126          6     False
# 732       40      27      25     35          6     False
# 733       60      27      30     29          6     False
# 734       50      90      50     89          6     False
# 735       58      73      54     72          6     False
# 736       72     109      66    106          6     False
# 737       39      61      79     42          6     False
# 738       47      75      98     52          6     False
# 739       68     112     154     75          6     False
# 740       48      62      57     52          6     False
# 741       62      97      81     68          6     False
# 742       62      46      48     43          6     False
# 743       78      69      71     58          6     False
# 744       60      65      90    102          6     False
# 745       54      63      60     68          6     False
# 746       76      83      81    104          6     False
# 747       76      83      81    104          6     False
# 748      100      35      37     28          6     False
# 749      150      45      49     35          6     False
# 750       50     150      50     60          6     False
# 751      150      50     150     60          6     False
# 752       60      63      65     23          6     False
# 753       72      99      89     29          6     False
# 754       66      59      57     49          6     False
# 755       86      85      75     72          6     False
# 756       53      37      46     45          6     False
# 757       88      68      75     73          6     False
# 758       67      39      56     50          6     False
# 759      115      54      86     68          6     False
# 760       60      60      60     30          6     False
# 761       90      97     123     44          6     False
# 762       62      58      63     44          6     False
# 763       88     120      89     59          6     False
# 764       33      61      43     70          6     False
# 765       52     109      94    109          6     False
# 766       77      45      45     48          6     False
# 767      119      69      59     71          6     False
# 768       50      67      63     46          6     False
# 769       72      99      92     58          6     False
# 770       65     110     130     60          6     False
# 771       75      74      63    118          6     False
# 772       57      81      67    101          6     False
# 773      150      50     150     50          6     False
# 774       35      55      75     40          6     False
# 775       53      83     113     60          6     False
# 776       70     110     150     80          6     False
# 777       91      80      87     75          6     False
# 778       48      50      60     38          6     False
# 779       76      65      82     56          6     False
# 780       70      44      55     51          6     False
# 781       70      44      55     56          6     False
# 782       70      44      55     46          6     False
# 783       70      44      55     41          6     False
# 784      122      58      75     84          6     False
# 785      122      58      75     99          6     False
# 786      122      58      75     69          6     False
# 787      122      58      75     54          6     False
# 788       85      32      35     28          6     False
# 789      184      44      46     28          6     False
# 790       35      45      40     55          6     False
# 791       80      97      80    123          6     False
# 792       95     131      98     99          6      True
# 793       95     131      98     99          6      True
# 794      121      81      95     95          6      True
# 795      150     100     150     50          6      True
# 796      110     160     110    110          6      True
# 797       60     150     130     70          6      True
# 798       60     170     130     80          6      True
# 799      120     130      90     70          6      True

# %% [markdown]
# #### 4. Add new features

# %% [markdown]
# Since the data set provides extra information for those pokemon has two types, we want to add a new column for showing the information.
# Reference: https://stackoverflow.com/questions/19913659/pandas-conditional-creation-of-a-series-dataframe-column

# %%
## Quantify 'Type' columns information
# Create a condition list
conditions = [(df.Type2 == 'No value'),
              (df.Type2 != 'No value')]
# Create a choice list
choices=['1','2']
# Set up the default choice, feed in the parameters
df['Types']=np.select(condlist=conditions, choicelist=choices, default=['2'])

# --  alternative -- 
#df['Types']=['1' if x=='No value' else '2' for x in df['Type2']]

# %% [markdown]
# Some pokemon have "mega" in their name, which indicates that they are in an evolved state for a limited amount of time.
# We will add a column to identify these pokemon.
# source: https://bulbapedia.bulbagarden.net/wiki/Mega_Evolution

# %%
# create a condition list
conditions = [(df.Name.str.contains('Mega')),
              # subset the Name column and use str.contains to find the match record
              (df.Name.str.contains('Mega')==False)]

# create a choice list
choices = ['True', 'False']

# set up the default choice, feed in the parameters
df['Mega']=np.select(condlist=conditions, choicelist = choices, default=['False'])

# --  alternative -- 
#df['Mega']=['True' if x==True else 'False' for x in df['Name'].str.contains('Mega')]

# %% [markdown]
# Calculate the total attack values and total defense value for comparison

# %%
df['Total_Atk'] = df.Attack + df.Sp_Atk
df['Total_Def'] = df.Defense + df.Sp_Def

# %%
# Reorder the columns
df=df[['#','Name', 'Types', 'Type1', 'Type2', 'Total', 'Total_Atk', 'Total_Def', 'HP', 'Attack', 
       'Defense', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'Legendary','Mega']]
# Quick look of the cleansed dataset
df.head(10)
# Out:
#    #                       Name Types  Type1     Type2  Total  Total_Atk  \
# 0  1                  Bulbasaur     2  Grass    Poison    318        114
# 1  2                    Ivysaur     2  Grass    Poison    405        142
# 2  3                   Venusaur     2  Grass    Poison    525        182
# 3  3      VenusaurMega Venusaur     2  Grass    Poison    625        222
# 4  4                 Charmander     1   Fire  No value    309        112
# 5  5                 Charmeleon     1   Fire  No value    405        144
# 6  6                  Charizard     2   Fire    Flying    534        193
# 7  6  CharizardMega Charizard X     2   Fire    Dragon    634        260
# 8  6  CharizardMega Charizard Y     2   Fire    Flying    634        263
# 9  7                   Squirtle     1  Water  No value    314         98
#
#    Total_Def  HP  Attack  Defense  Sp_Atk  Sp_Def  Speed Generation Legendary  \
# 0        114  45      49       49      65      65     45          1     False
# 1        143  60      62       63      80      80     60          1     False
# 2        183  80      82       83     100     100     80          1     False
# 3        243  80     100      123     122     120     80          1     False
# 4         93  39      52       43      60      50     65          1     False
# 5        123  58      64       58      80      65     80          1     False
# 6        163  78      84       78     109      85    100          1     False
# 7        196  78     130      111     130      85    100          1     False
# 8        193  78     104       78     159     115    100          1     False
# 9        129  44      48       65      50      64     43          1     False
#
#     Mega
# 0  False
# 1  False
# 2  False
# 3   True
# 4  False
# 5  False
# 6  False
# 7   True
# 8   True
# 9  False

# %% [markdown]
# ### - PokemonGo Dataset -
# Explore the pokemongo dataset and perform some data cleansing process such as resolving missing data, formatting issue, erroneous values, anomalies...etc

# %%
go.describe()
# Out:
#        Unnamed: 0           #      Attack     Defense          HP       Candy
# count  570.000000  570.000000  570.000000  570.000000  570.000000  570.000000
# mean   284.500000  269.628070  167.019298  157.628070  140.285965   28.284211
# std    164.689101  165.194656   46.723860   56.808734   51.286548   45.801128
# min      0.000000    1.000000    1.000000   17.000000   32.000000    0.000000
# 25%    142.250000  125.250000  137.000000  117.000000   98.000000    0.000000
# 50%    284.500000  266.500000  163.000000  156.000000  136.500000    0.000000
# 75%    426.750000  403.750000  190.000000  197.750000  175.000000   50.000000
# max    569.000000  809.000000  496.000000  414.000000  396.000000  400.000000

# %%
go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 12 columns):
# Unnamed: 0      570 non-null int64
# #               570 non-null int64
# Name            570 non-null object
# Type            570 non-null object
# Attack          570 non-null int64
# Defense         570 non-null int64
# HP              570 non-null int64
# Catch_Rate      570 non-null object
# Flee_Rate       570 non-null object
# Candy           570 non-null int64
# Fast_Moves      568 non-null object
# Charge_Moves    568 non-null object
# dtypes: int64(6), object(6)
# memory usage: 53.6+ KB

# %% [markdown]
# From the summary of the data set above, we have noticed that there are missing values existing in the data set, specifically in the "Fast_Moves" column and "Charge_Moves" column.

# %% [markdown]
# #### 1. Renames column names
# The first unnamed column is redundant index column. We should remove the column
# The # column is pokemon index number. To differentiate some of columns from the main dataset, we need to rename 'Type', 'Attack', 'Defense', 'HP'...etc

# %%
# drop the first redundant column
go=go.drop(['Unnamed: 0'],axis=1)

# %%
go.rename(columns={'Type':'Go_Type',
                   'Attack':'Go_Atk',
                   'Defense':'Go_Def',
                   'HP':'Go_HP',}, inplace=True)

# %% [markdown]
# #### 2. Dealing with missing values

# %% [markdown]
# There are two records have missing values. We need to check what are those records and make a decision on how to deal with the missing values.

# %%
go[go['Fast_Moves'].isnull()]
# Out:
#        #      Name     Go_Type  Go_Atk  Go_Def  Go_HP Catch_Rate Flee_Rate  \
# 251  233  Porygon2  ['Normal']     198     198    180         5%        5%
# 253  235  Smeargle  ['Normal']     146      40     83        25%        7%
#
#      Candy Fast_Moves Charge_Moves
# 251    100        NaN          NaN
# 253      0        NaN          NaN

# %% [markdown]
# There are two pokemons do not have Fast moves and charge moves. We decide to keep the records and fill the NA with 'No value'

# %%
fill_na = {'Fast_Moves':'No Value', 'Charge_Moves':'No Value'} # create a dictionary for filling na values
go=go.fillna(value=fill_na)

# %%
# Check if there is a missing value
go.isnull().sum()
# Out:
# #               0
# Name            0
# Go_Type         0
# Go_Atk          0
# Go_Def          0
# Go_HP           0
# Catch_Rate      0
# Flee_Rate       0
# Candy           0
# Fast_Moves      0
# Charge_Moves    0
# dtype: int64

# %% [markdown]
# #### 3. Data types conversion
# To convert 'Catch_Rate' and 'Flee_Rate' to int, we need to remove the '%' sign in the cell.
# A '—' value should be replaced with 0.

# %%
# https://stackoverflow.com/questions/13682044/remove-unwanted-parts-from-strings-in-a-column
go['Catch_Rate'].replace(regex=True,inplace=True,to_replace='%',value='')
go['Catch_Rate'].replace(regex=True,inplace=True,to_replace='—',value='0')
go['Flee_Rate'].replace(regex=True,inplace=True,to_replace='%',value='')

# %%
go = go.astype({'Catch_Rate': float, 'Flee_Rate': float})

# %%
# Check data type
go.dtypes
# Out:
# #                 int64
# Name             object
# Go_Type          object
# Go_Atk            int64
# Go_Def            int64
# Go_HP             int64
# Catch_Rate      float64
# Flee_Rate       float64
# Candy             int64
# Fast_Moves       object
# Charge_Moves     object
# dtype: object

# %% [markdown]
# #### 4. Add new features
# Since the data set provides extra information for those pokemon has different moves, we quantify the information.
# Also, to answer the research question, we want to add all the
# Reference: https://stackoverflow.com/questions/19913659/pandas-conditional-creation-of-a-series-dataframe-column

# %%
# Add 'Go_Total' column to get the total power
go['Go_Total']=go['Go_Atk']+go['Go_Def']+go['Go_HP']

# %%
## Quantify 'Fast_Moves' column
# Create a empty list for 'Fast_Moves_No' column
Fast_Moves_No=[]
# forloop the 'Fast_Moves' column to quantify the information
for i,l in enumerate(go['Fast_Moves']):
    # use regular expression to fill all desired strings to a list
    pattern = re.compile(r"[A-Za-z]+\s?[A-Za-z]+")
    templist = re.findall(pattern, l)
    # count the number of element of the temp list to get the number of moves for each pokemon
    numbers =len(templist)
    # append the number of moves to the 'Fast_Moves_No' list
    Fast_Moves_No.append(numbers)
print(f'{i+1} of records has been updataed !')
# assign 'Fast_Moves_No' list to 'Fast_Moves_No' column
go['Fast_Moves_No'] = Fast_Moves_No
# Out:
# 570 of records has been updataed !

# %%
## Missing values were filled inproperly
go.loc[go.Charge_Moves=='No Value']
# Out:
#        #      Name     Go_Type  Go_Atk  Go_Def  Go_HP  Catch_Rate  Flee_Rate  \
# 251  233  Porygon2  ['Normal']     198     198    180         5.0        5.0
# 253  235  Smeargle  ['Normal']     146      40     83        25.0        7.0
#
#      Candy Fast_Moves Charge_Moves  Go_Total  Fast_Moves_No
# 251    100   No Value     No Value       576              1
# 253      0   No Value     No Value       269              1

# %%
## Adjust the missing values
# chained indexing will produced multiple veiws and it may cuase warning when assign a value to chained index
# use .loc to assing a value to avoid warning in chained indexing
go.loc[go.Fast_Moves=='No Value','Fast_Moves_No']=0 # locate the cells that the row is True and is under 'Fast_Moves_No' column
go.loc[go.Fast_Moves=='No Value']
# Out:
#        #      Name     Go_Type  Go_Atk  Go_Def  Go_HP  Catch_Rate  Flee_Rate  \
# 251  233  Porygon2  ['Normal']     198     198    180         5.0        5.0
# 253  235  Smeargle  ['Normal']     146      40     83        25.0        7.0
#
#      Candy Fast_Moves Charge_Moves  Go_Total  Fast_Moves_No
# 251    100   No Value     No Value       576              0
# 253      0   No Value     No Value       269              0

# %%
## Quantify 'Charge_Moves' column
# Create a empty list for 'Charge_Moves_No' column
Charge_Moves_No=[]
# forloop the 'Charge_Moves' column to quantify the information
for i,l in enumerate(go['Charge_Moves']):
    # use regular expression to fill all desired strings to a list
    pattern = re.compile(r"[A-Za-z]+\s?[A-Za-z]+")
    templist = re.findall(pattern, l)
    # count the number of element of the temp list to get the number of moves for each pokemon
    numbers =len(templist)
    # append the number of moves to the 'Charge_Moves_No' list
    Charge_Moves_No.append(numbers)
print(f'{i+1} of records has been updataed !')
# assign 'Charge_Moves_No' list to 'Charge_Moves_No' column
go['Charge_Moves_No'] = Charge_Moves_No
# Out:
# 570 of records has been updataed !

# %%
## Missing values were filled inproperly
go.loc[go.Charge_Moves=='No Value']
# Out:
#        #      Name     Go_Type  Go_Atk  Go_Def  Go_HP  Catch_Rate  Flee_Rate  \
# 251  233  Porygon2  ['Normal']     198     198    180         5.0        5.0
# 253  235  Smeargle  ['Normal']     146      40     83        25.0        7.0
#
#      Candy Fast_Moves Charge_Moves  Go_Total  Fast_Moves_No  Charge_Moves_No
# 251    100   No Value     No Value       576              0                1
# 253      0   No Value     No Value       269              0                1

# %%
## Adjust the missing values
# chained indexing will produced multiple veiws and it may cuase warning when assign a value to chained index
# use .loc to assing a value to avoid warning in chained indexing
go.loc[go.Charge_Moves=='No Value','Charge_Moves_No']=0 # locate the cells that the row is True and is under 'Fast_Moves_No' column
go.loc[go.Charge_Moves=='No Value']
# Out:
#        #      Name     Go_Type  Go_Atk  Go_Def  Go_HP  Catch_Rate  Flee_Rate  \
# 251  233  Porygon2  ['Normal']     198     198    180         5.0        5.0
# 253  235  Smeargle  ['Normal']     146      40     83        25.0        7.0
#
#      Candy Fast_Moves Charge_Moves  Go_Total  Fast_Moves_No  Charge_Moves_No
# 251    100   No Value     No Value       576              0                0
# 253      0   No Value     No Value       269              0                0

# %%
## Quantify 'Go_Type' column
# Create a empty list for 'Go_Types' column
Go_Types=[]
# forloop the 'Go_Type' column to quantify the information
for i,l in enumerate(go['Go_Type']):
    # use regular expression to fill all desired strings to a list
    pattern = re.compile(r"[A-Za-z]+\s?[A-Za-z]+")
    templist = re.findall(pattern, l)
    # count the number of element of the temp list to get the number of moves for each pokemon
    numbers =len(templist)
    # append the number to the 'Go_Types' list
    Go_Types.append(numbers)
print(f'{i+1} of records has been updataed !')
# assign 'Go_Types' list to 'Go_Types' column
go['Go_Types'] = Go_Types
# Out:
# 570 of records has been updataed !

# %%
# Reorder the columns
go=go[['#','Name', 'Go_Types', 'Go_Type', 'Go_Total', 'Go_Atk', 'Go_Def', 'Go_HP', 'Catch_Rate', 'Flee_Rate',
   'Candy', 'Fast_Moves_No', 'Fast_Moves', 'Charge_Moves_No', 'Charge_Moves']]
# Quick look of the cleansed dataset
go.head(10)
# Out:
#     #        Name  Go_Types              Go_Type  Go_Total  Go_Atk  Go_Def  \
# 0   1   Bulbasaur         2  ['Grass', 'Poison']       357     128     118
# 1   2     Ivysaur         2  ['Grass', 'Poison']       449     155     151
# 2   3    Venusaur         2  ['Grass', 'Poison']       577     190     198
# 3   4  Charmander         1             ['Fire']       327     118     116
# 4   5  Charmeleon         1             ['Fire']       435     151     158
# 5   6   Charizard         2   ['Fire', 'Flying']       582     186     223
# 6   7    Squirtle         1            ['Water']       342     127      94
# 7   8   Wartortle         1            ['Water']       434     153     126
# 8   9   Blastoise         1            ['Water']       566     188     171
# 9  10    Caterpie         1              ['Bug']       238     128      55
#
#    Go_HP  Catch_Rate  Flee_Rate  Candy  Fast_Moves_No  \
# 0    111        20.0       10.0     25              2
# 1    143        10.0        7.0    100              2
# 2    189         5.0        5.0      0              2
# 3     93        20.0       10.0     25              2
# 4    126        10.0        7.0    100              2
# 5    173         5.0        5.0      0              2
# 6    121        20.0       10.0     25              2
# 7    155        10.0        7.0    100              2
# 8    207         5.0        5.0      0              2
# 9     55        50.0       20.0     12              2
#
#                     Fast_Moves  Charge_Moves_No  \
# 0      ['Vine Whip', 'Tackle']                3
# 1  ['Vine Whip', 'Razor Leaf']                3
# 2  ['Vine Whip', 'Razor Leaf']                3
# 3         ['Ember', 'Scratch']                3
# 4       ['Ember', 'Fire Fang']                3
# 5   ['Air Slash', 'Fire Spin']                3
# 6         ['Tackle', 'Bubble']                3
# 7        ['Bite', 'Water Gun']                3
# 8        ['Bite', 'Water Gun']                4
# 9       ['Bug Bite', 'Tackle']                1
#
#                                         Charge_Moves
# 0         ['Seed Bomb', 'Sludge Bomb', 'Power Whip']
# 1        ['Sludge Bomb', 'Solar Beam', 'Power Whip']
# 2    ['Petal Blizzard', 'Sludge Bomb', 'Solar Beam']
# 3    ['Flamethrower', 'Flame Charge', 'Flame Burst']
# 4      ['Flamethrower', 'Flame Burst', 'Fire Punch']
# 5          ['Dragon Claw', 'Fire Blast', 'Overheat']
# 6           ['Aqua Jet', 'Aqua Tail', 'Water Pulse']
# 7             ['Ice Beam', 'Aqua Jet', 'Hydro Pump']
# 8  ['Flash Cannon', 'Ice Beam', 'Hydro Pump', 'Sk...
# 9                                       ['Struggle']

# %% [markdown]
# #### 5. Merge datasets

# %% [markdown]
# Since we want to compare two platform of pokemon status, we use inner join and to compare pokemons exist in both two platforms. The condition of join is based on the index number column, '#', and pokemon name column, 'Name'.
# Reference:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html
# https://datacarpentry.org/python-ecology-lesson/05-merging-data/

# %%
dfm = df.merge(go, left_on=['#','Name'], right_on=['#','Name'], suffixes=('_left', '_right'))
dfm
# Out:
#        #        Name Types     Type1     Type2  Total  Total_Atk  Total_Def  \
# 0      1   Bulbasaur     2     Grass    Poison    318        114        114
# 1      2     Ivysaur     2     Grass    Poison    405        142        143
# 2      3    Venusaur     2     Grass    Poison    525        182        183
# 3      4  Charmander     1      Fire  No value    309        112         93
# 4      5  Charmeleon     1      Fire  No value    405        144        123
# 5      6   Charizard     2      Fire    Flying    534        193        163
# 6      7    Squirtle     1     Water  No value    314         98        129
# 7      8   Wartortle     1     Water  No value    405        128        160
# 8      9   Blastoise     1     Water  No value    530        168        205
# 9     10    Caterpie     1       Bug  No value    195         50         55
# 10    11     Metapod     1       Bug  No value    205         45         80
# 11    12  Butterfree     2       Bug    Flying    395        135        130
# 12    13      Weedle     2       Bug    Poison    195         55         50
# 13    14      Kakuna     2       Bug    Poison    205         50         75
# 14    15    Beedrill     2       Bug    Poison    395        135        120
# 15    16      Pidgey     2    Normal    Flying    251         80         75
# 16    17   Pidgeotto     2    Normal    Flying    349        110        105
# 17    18     Pidgeot     2    Normal    Flying    479        150        145
# 18    19     Rattata     1    Normal  No value    253         81         70
# 19    20    Raticate     1    Normal  No value    413        131        130
# 20    21     Spearow     2    Normal    Flying    262         91         61
# 21    22      Fearow     2    Normal    Flying    442        151        126
# 22    23       Ekans     1    Poison  No value    288        100         98
# 23    24       Arbok     1    Poison  No value    438        150        148
# 24    25     Pikachu     1  Electric  No value    320        105         90
# 25    26      Raichu     1  Electric  No value    485        180        135
# 26    27   Sandshrew     1    Ground  No value    300         95        115
# 27    28   Sandslash     1    Ground  No value    450        145        165
# 28    29    Nidoran♀     1    Poison  No value    275         87         92
# 29    30    Nidorina     1    Poison  No value    365        117        122
# 30    31   Nidoqueen     2    Poison    Ground    505        167        172
# 31    32    Nidoran♂     1    Poison  No value    273         97         80
# 32    33    Nidorino     1    Poison  No value    365        127        112
# 33    34    Nidoking     2    Poison    Ground    505        187        152
# 34    35    Clefairy     1     Fairy  No value    323        105        113
# 35    36    Clefable     1     Fairy  No value    483        165        163
# 36    37      Vulpix     1      Fire  No value    299         91        105
# 37    38   Ninetales     1      Fire  No value    505        157        175
# 38    39  Jigglypuff     2    Normal     Fairy    270         90         45
# 39    40  Wigglytuff     2    Normal     Fairy    435        155         95
# 40    41       Zubat     2    Poison    Flying    245         75         75
# 41    42      Golbat     2    Poison    Flying    455        145        145
# 42    43      Oddish     2     Grass    Poison    320        125        120
# 43    44       Gloom     2     Grass    Poison    395        150        145
# 44    45   Vileplume     2     Grass    Poison    490        190        175
# 45    46       Paras     2       Bug     Grass    285        115        110
# 46    47    Parasect     2       Bug     Grass    405        155        160
# 47    48     Venonat     2       Bug    Poison    305         95        105
# 48    49    Venomoth     2       Bug    Poison    450        155        135
# 49    50     Diglett     1    Ground  No value    265         90         70
# 50    51     Dugtrio     1    Ground  No value    405        130        120
# 51    52      Meowth     1    Normal  No value    290         85         75
# 52    53     Persian     1    Normal  No value    440        135        125
# 53    54     Psyduck     1     Water  No value    320        117         98
# 54    55     Golduck     1     Water  No value    500        177        158
# 55    56      Mankey     1  Fighting  No value    305        115         80
# 56    57    Primeape     1  Fighting  No value    455        165        130
# 57    58   Growlithe     1      Fire  No value    350        140         95
# 58    59    Arcanine     1      Fire  No value    555        210        160
# 59    60     Poliwag     1     Water  No value    300         90         80
# 60    61   Poliwhirl     1     Water  No value    385        115        115
# 61    62   Poliwrath     2     Water  Fighting    510        165        185
# 62    63        Abra     1   Psychic  No value    310        125         70
# 63    64     Kadabra     1   Psychic  No value    400        155        100
# 64    65    Alakazam     1   Psychic  No value    500        185        140
# 65    66      Machop     1  Fighting  No value    305        115         85
# 66    67     Machoke     1  Fighting  No value    405        150        130
# 67    68     Machamp     1  Fighting  No value    505        195        165
# 68    69  Bellsprout     2     Grass    Poison    300        145         65
# 69    70  Weepinbell     2     Grass    Poison    390        175         95
# 70    71  Victreebel     2     Grass    Poison    490        205        135
# 71    72   Tentacool     2     Water    Poison    335         90        135
# 72    73  Tentacruel     2     Water    Poison    515        150        185
# 73    74     Geodude     2      Rock    Ground    300        110        130
# 74    75    Graveler     2      Rock    Ground    390        140        160
# 75    76       Golem     2      Rock    Ground    495        175        195
# 76    77      Ponyta     1      Fire  No value    410        150        120
# 77    78    Rapidash     1      Fire  No value    500        180        150
# 78    79    Slowpoke     2     Water   Psychic    315        105        105
# 79    80     Slowbro     2     Water   Psychic    490        175        190
# 80    81   Magnemite     2  Electric     Steel    325        130        125
# 81    82    Magneton     2  Electric     Steel    465        180        165
# 82    83  Farfetch'd     2    Normal    Flying    352        123        117
# 83    84       Doduo     2    Normal    Flying    310        120         80
# 84    85      Dodrio     2    Normal    Flying    460        170        130
# 85    86        Seel     1     Water  No value    325         90        125
# 86    87     Dewgong     2     Water       Ice    475        140        175
# 87    88      Grimer     1    Poison  No value    325        120        100
# 88    89         Muk     1    Poison  No value    500        170        175
# 89    90    Shellder     1     Water  No value    305        110        125
# 90    91    Cloyster     2     Water       Ice    525        180        225
# 91    92      Gastly     2     Ghost    Poison    310        135         65
# 92    93     Haunter     2     Ghost    Poison    405        165        100
# 93    94      Gengar     2     Ghost    Poison    500        195        135
# 94    95        Onix     2      Rock    Ground    385         75        205
# 95    96     Drowzee     1   Psychic  No value    328         91        135
# 96    97       Hypno     1   Psychic  No value    483        146        185
# 97    98      Krabby     1     Water  No value    325        130        115
# 98    99     Kingler     1     Water  No value    475        180        165
# 99   100     Voltorb     1  Electric  No value    330         85        105
# 100  101   Electrode     1  Electric  No value    480        130        150
# 101  102   Exeggcute     2     Grass   Psychic    325        100        125
# 102  103   Exeggutor     2     Grass   Psychic    520        220        150
# 103  104      Cubone     1    Ground  No value    320         90        145
# 104  105     Marowak     1    Ground  No value    425        130        190
# 105  106   Hitmonlee     1  Fighting  No value    455        155        163
# 106  107  Hitmonchan     1  Fighting  No value    455        140        189
# 107  108   Lickitung     1    Normal  No value    385        115        150
# 108  109     Koffing     1    Poison  No value    340        125        140
# 109  110     Weezing     1    Poison  No value    490        175        190
# 110  111     Rhyhorn     2    Ground      Rock    345        115        125
# 111  112      Rhydon     2    Ground      Rock    485        175        165
# 112  113     Chansey     1    Normal  No value    450         40        110
# 113  114     Tangela     1     Grass  No value    435        155        155
# 114  115  Kangaskhan     1    Normal  No value    490        135        160
# 115  116      Horsea     1     Water  No value    295        110         95
# 116  117      Seadra     1     Water  No value    440        160        140
# 117  118     Goldeen     1     Water  No value    320        102        110
# 118  119     Seaking     1     Water  No value    450        157        145
# 119  120      Staryu     1     Water  No value    340        115        110
# 120  121     Starmie     2     Water   Psychic    520        175        170
# 121  122    Mr. Mime     2   Psychic     Fairy    460        145        185
# 122  123     Scyther     2       Bug    Flying    500        165        160
# 123  124        Jynx     2       Ice   Psychic    455        165        130
# 124  125  Electabuzz     1  Electric  No value    490        178        142
# 125  126      Magmar     1      Fire  No value    495        195        142
# 126  127      Pinsir     1       Bug  No value    500        180        170
# 127  128      Tauros     1    Normal  No value    490        140        165
# 128  129    Magikarp     1     Water  No value    200         25         75
# 129  130    Gyarados     2     Water    Flying    540        185        179
# 130  131      Lapras     2     Water       Ice    535        170        175
# 131  132       Ditto     1    Normal  No value    288         96         96
# 132  133       Eevee     1    Normal  No value    325        100        115
# 133  134    Vaporeon     1     Water  No value    525        175        155
# 134  135     Jolteon     1  Electric  No value    525        175        155
# 135  136     Flareon     1      Fire  No value    525        225        170
# 136  137     Porygon     1    Normal  No value    395        145        145
# 137  138     Omanyte     2      Rock     Water    355        130        155
# 138  139     Omastar     2      Rock     Water    495        175        195
# 139  140      Kabuto     2      Rock     Water    355        135        135
# 140  141    Kabutops     2      Rock     Water    495        180        175
# 141  142  Aerodactyl     2      Rock    Flying    515        165        140
# 142  143     Snorlax     1    Normal  No value    540        175        175
# 143  144    Articuno     2       Ice    Flying    580        180        225
# 144  145      Zapdos     2  Electric    Flying    580        215        175
# 145  146     Moltres     2      Fire    Flying    580        225        175
# 146  147     Dratini     1    Dragon  No value    300        114         95
# 147  148   Dragonair     1    Dragon  No value    420        154        135
# 148  149   Dragonite     2    Dragon    Flying    600        234        195
# 149  150      Mewtwo     1   Psychic  No value    680        264        180
# 150  151         Mew     1   Psychic  No value    600        200        200
# 151  152   Chikorita     1     Grass  No value    318         98        130
# 152  153     Bayleef     1     Grass  No value    405        125        160
# 153  154    Meganium     1     Grass  No value    525        165        200
# 154  155   Cyndaquil     1      Fire  No value    309        112         93
# 155  156     Quilava     1      Fire  No value    405        144        123
# 156  157  Typhlosion     1      Fire  No value    534        193        163
# 157  158    Totodile     1     Water  No value    314        109        112
# 158  159    Croconaw     1     Water  No value    405        139        143
# 159  160  Feraligatr     1     Water  No value    530        184        183
# 160  161     Sentret     1    Normal  No value    215         81         79
# 161  162      Furret     1    Normal  No value    415        121        119
# 162  163    Hoothoot     2    Normal    Flying    262         66         86
# 163  164     Noctowl     2    Normal    Flying    442        126        146
# 164  165      Ledyba     2       Bug    Flying    265         60        110
# 165  166      Ledian     2       Bug    Flying    390         90        160
# 166  167    Spinarak     2       Bug    Poison    250        100         80
# 167  168     Ariados     2       Bug    Poison    390        150        130
# 168  169      Crobat     2    Poison    Flying    535        160        160
# 169  170    Chinchou     2     Water  Electric    330         94         94
# 170  171     Lanturn     2     Water  Electric    460        134        134
# 171  172       Pichu     1  Electric  No value    205         75         50
# 172  173      Cleffa     1     Fairy  No value    218         70         83
# 173  174   Igglybuff     2    Normal     Fairy    210         70         35
# 174  175      Togepi     1     Fairy  No value    245         60        130
# 175  176     Togetic     2     Fairy    Flying    405        120        190
# 176  177        Natu     2   Psychic    Flying    320        120         90
# 177  178        Xatu     2   Psychic    Flying    470        170        140
# 178  179      Mareep     1  Electric  No value    280        105         85
# 179  180     Flaaffy     1  Electric  No value    365        135        115
# 180  181    Ampharos     1  Electric  No value    510        190        175
# 181  182   Bellossom     1     Grass  No value    490        170        195
# 182  183      Marill     2     Water     Fairy    250         40        100
# 183  184   Azumarill     2     Water     Fairy    420        110        160
# 184  185   Sudowoodo     1      Rock  No value    410        130        180
# 185  186    Politoed     1     Water  No value    500        165        175
# 186  187      Hoppip     2     Grass    Flying    250         70         95
# 187  188    Skiploom     2     Grass    Flying    340         90        115
# 188  189    Jumpluff     2     Grass    Flying    460        110        165
# 189  190       Aipom     1    Normal  No value    360        110        110
# 190  191     Sunkern     1     Grass  No value    180         60         60
# 191  192    Sunflora     1     Grass  No value    425        180        140
# 192  193       Yanma     2       Bug    Flying    390        140         90
# 193  194      Wooper     2     Water    Ground    210         70         70
# 194  195    Quagsire     2     Water    Ground    430        150        150
# 195  196      Espeon     1   Psychic  No value    525        195        155
# 196  197     Umbreon     1      Dark  No value    525        125        240
# 197  198     Murkrow     2      Dark    Flying    405        170         84
# 198  199    Slowking     2     Water   Psychic    490        175        190
# 199  200  Misdreavus     1     Ghost  No value    435        145        145
# 200  201       Unown     1   Psychic  No value    336        144         96
# 201  202   Wobbuffet     1   Psychic  No value    405         66        116
# 202  203   Girafarig     2    Normal   Psychic    455        170        130
# 203  204      Pineco     1       Bug  No value    290        100        125
# 204  205  Forretress     2       Bug     Steel    465        150        200
# 205  206   Dunsparce     1    Normal  No value    415        135        135
# 206  207      Gligar     2    Ground    Flying    430        110        170
# 207  208     Steelix     2     Steel    Ground    510        140        265
# 208  209    Snubbull     1     Fairy  No value    300        120         90
# 209  210    Granbull     1     Fairy  No value    450        180        135
# 210  211    Qwilfish     2     Water    Poison    430        150        130
# 211  212      Scizor     2       Bug     Steel    500        185        180
# 212  213     Shuckle     2       Bug      Rock    505         20        460
# 213  214   Heracross     2       Bug  Fighting    500        165        170
# 214  215     Sneasel     2      Dark       Ice    430        130        130
# 215  216   Teddiursa     1    Normal  No value    330        130        100
# 216  217    Ursaring     1    Normal  No value    500        205        150
# 217  218      Slugma     1      Fire  No value    250        110         80
# 218  219    Magcargo     2      Fire      Rock    410        130        200
# 219  220      Swinub     2       Ice    Ground    250         80         70
# 220  221   Piloswine     2       Ice    Ground    450        160        140
# 221  222     Corsola     2     Water      Rock    380        120        170
# 222  223    Remoraid     1     Water  No value    300        130         70
# 223  224   Octillery     1     Water  No value    480        210        150
# 224  225    Delibird     2       Ice    Flying    330        120         90
# 225  226     Mantine     2     Water    Flying    465        120        210
# 226  227    Skarmory     2     Steel    Flying    465        120        210
# 227  228    Houndour     2      Dark      Fire    330        140         80
# 228  229    Houndoom     2      Dark      Fire    500        200        130
# 229  230     Kingdra     2     Water    Dragon    540        190        190
# 230  231      Phanpy     1    Ground  No value    330        100        100
# 231  232     Donphan     1    Ground  No value    500        180        180
# 232  233    Porygon2     1    Normal  No value    515        185        185
# 233  234    Stantler     1    Normal  No value    465        180        127
# 234  235    Smeargle     1    Normal  No value    250         40         80
# 235  236     Tyrogue     1  Fighting  No value    210         70         70
# 236  237   Hitmontop     1  Fighting  No value    455        130        205
# 237  238    Smoochum     2       Ice   Psychic    305        115         80
# 238  239      Elekid     1  Electric  No value    360        128         92
# 239  240       Magby     1      Fire  No value    365        145         92
# 240  241     Miltank     1    Normal  No value    490        120        175
# 241  242     Blissey     1    Normal  No value    540         85        145
# 242  243      Raikou     1  Electric  No value    580        200        175
# 243  244       Entei     1      Fire  No value    580        205        160
# 244  245     Suicune     1     Water  No value    580        165        230
# 245  246    Larvitar     2      Rock    Ground    300        109        100
# 246  247     Pupitar     2      Rock    Ground    410        149        140
# 247  248   Tyranitar     2      Rock      Dark    600        229        210
# 248  249       Lugia     2   Psychic    Flying    680        180        284
# 249  250       Ho-oh     2      Fire    Flying    680        240        244
# 250  251      Celebi     2   Psychic     Grass    600        200        200
# 251  252     Treecko     1     Grass  No value    310        110         90
# 252  253     Grovyle     1     Grass  No value    405        150        110
# 253  254    Sceptile     1     Grass  No value    530        190        150
# 254  255     Torchic     1      Fire  No value    310        130         90
# 255  256   Combusken     2      Fire  Fighting    405        170        120
# 256  257    Blaziken     2      Fire  Fighting    530        230        140
# 257  258      Mudkip     1     Water  No value    310        120        100
# 258  259   Marshtomp     2     Water    Ground    405        145        140
# 259  260    Swampert     2     Water    Ground    535        195        180
# 260  261   Poochyena     1      Dark  No value    220         85         65
# 261  262   Mightyena     1      Dark  No value    420        150        130
# 262  263   Zigzagoon     1    Normal  No value    240         60         82
# 263  264     Linoone     1    Normal  No value    420        120        122
# 264  265     Wurmple     1       Bug  No value    195         65         65
# 265  266     Silcoon     1       Bug  No value    205         60         80
# 266  267   Beautifly     2       Bug    Flying    395        170        100
# 267  268     Cascoon     1       Bug  No value    205         60         80
# 268  269      Dustox     2       Bug    Poison    385        100        160
# 269  270       Lotad     2     Water     Grass    220         70         80
# 270  271      Lombre     2     Water     Grass    340        110        120
# 271  272    Ludicolo     2     Water     Grass    480        160        170
# 272  273      Seedot     1     Grass  No value    220         70         80
# 273  274     Nuzleaf     2     Grass      Dark    340        130         80
# 274  275     Shiftry     2     Grass      Dark    480        190        120
# 275  276     Taillow     2    Normal    Flying    270         85         60
# 276  277     Swellow     2    Normal    Flying    430        135        110
# 277  278     Wingull     2     Water    Flying    270         85         60
# 278  279    Pelipper     2     Water    Flying    430        135        170
# 279  280       Ralts     2   Psychic     Fairy    198         70         60
# 280  281      Kirlia     2   Psychic     Fairy    278        100         90
# 281  282   Gardevoir     2   Psychic     Fairy    518        190        180
# 282  283     Surskit     2       Bug     Water    269         80         84
# 283  284  Masquerain     2       Bug    Flying    414        140        144
# 284  285   Shroomish     1     Grass  No value    295         80        120
# 285  286     Breloom     2     Grass  Fighting    460        190        140
# 286  287     Slakoth     1    Normal  No value    280         95         95
# 287  288    Vigoroth     1    Normal  No value    440        135        135
# 288  289     Slaking     1    Normal  No value    670        255        165
# 289  290     Nincada     2       Bug    Ground    266         75        120
# 290  291     Ninjask     2       Bug    Flying    456        140         95
# 291  292    Shedinja     2       Bug     Ghost    236        120         75
# 292  293     Whismur     1    Normal  No value    240        102         46
# 293  294     Loudred     1    Normal  No value    360        142         86
# 294  295     Exploud     1    Normal  No value    490        182        136
# 295  296    Makuhita     1  Fighting  No value    237         80         60
# 296  297    Hariyama     1  Fighting  No value    474        160        120
# 297  298     Azurill     2    Normal     Fairy    190         40         80
# 298  299    Nosepass     1      Rock  No value    375         90        225
# 299  300      Skitty     1    Normal  No value    260         80         80
# 300  301    Delcatty     1    Normal  No value    380        120        120
# 301  302     Sableye     2      Dark     Ghost    380        140        140
# 302  303      Mawile     2     Steel     Fairy    380        140        140
# 303  304        Aron     2     Steel      Rock    330        110        140
# 304  305      Lairon     2     Steel      Rock    430        140        190
# 305  306      Aggron     2     Steel      Rock    530        170        240
# 306  307    Meditite     2  Fighting   Psychic    280         80        110
# 307  308    Medicham     2  Fighting   Psychic    410        120        150
# 308  309   Electrike     1  Electric  No value    295        110         80
# 309  310   Manectric     1  Electric  No value    475        180        120
# 310  311      Plusle     1  Electric  No value    405        135        115
# 311  312       Minun     1  Electric  No value    405        115        135
# 312  313     Volbeat     1       Bug  No value    400        120        130
# 313  314    Illumise     1       Bug  No value    400        120        130
# 314  315     Roselia     2     Grass    Poison    400        160        125
# 315  316      Gulpin     1    Poison  No value    302         86        106
# 316  317      Swalot     1    Poison  No value    467        146        166
# 317  318    Carvanha     2     Water      Dark    305        155         40
# 318  319    Sharpedo     2     Water      Dark    460        215         80
# 319  320     Wailmer     1     Water  No value    400        140         70
# 320  321     Wailord     1     Water  No value    500        180         90
# 321  322       Numel     2      Fire    Ground    305        125         85
# 322  323    Camerupt     2      Fire    Ground    460        205        145
# 323  324     Torkoal     1      Fire  No value    470        170        210
# 324  325      Spoink     1   Psychic  No value    330         95        115
# 325  326     Grumpig     1   Psychic  No value    470        135        175
# 326  327      Spinda     1    Normal  No value    360        120        120
# 327  328    Trapinch     1    Ground  No value    290        145         90
# 328  329     Vibrava     2    Ground    Dragon    340        120        100
# 329  330      Flygon     2    Ground    Dragon    520        180        160
# 330  331      Cacnea     1     Grass  No value    335        170         80
# 331  332    Cacturne     2     Grass      Dark    475        230        120
# 332  333      Swablu     2    Normal    Flying    310         80        135
# 333  334     Altaria     2    Dragon    Flying    490        140        195
# 334  335    Zangoose     1    Normal  No value    458        175        120
# 335  336     Seviper     1    Poison  No value    458        200        120
# 336  337    Lunatone     2      Rock   Psychic    440        150        150
# 337  338     Solrock     2      Rock   Psychic    440        150        150
# 338  339    Barboach     2     Water    Ground    288         94         84
# 339  340    Whiscash     2     Water    Ground    468        154        144
# 340  341    Corphish     1     Water  No value    308        130        100
# 341  342   Crawdaunt     2     Water      Dark    468        210        140
# 342  343      Baltoy     2    Ground   Psychic    300         80        125
# 343  344     Claydol     2    Ground   Psychic    500        140        225
# 344  345      Lileep     2      Rock     Grass    355        102        164
# 345  346     Cradily     2      Rock     Grass    495        162        204
# 346  347     Anorith     2      Rock       Bug    355        135        100
# 347  348     Armaldo     2      Rock       Bug    495        195        180
# 348  349      Feebas     1     Water  No value    200         25         75
# 349  350     Milotic     1     Water  No value    540        160        204
# 350  351    Castform     1    Normal  No value    420        140        140
# 351  353     Shuppet     1     Ghost  No value    295        138         68
# 352  354     Banette     1     Ghost  No value    455        198        128
# 353  355     Duskull     1     Ghost  No value    295         70        180
# 354  356    Dusclops     1     Ghost  No value    455        130        260
# 355  357     Tropius     2     Grass    Flying    460        140        170
# 356  358    Chimecho     1   Psychic  No value    425        145        150
# 357  359       Absol     1      Dark  No value    465        205        120
# 358  360      Wynaut     1   Psychic  No value    260         46         96
# 359  361     Snorunt     1       Ice  No value    300        100        100
# 360  362      Glalie     1       Ice  No value    480        160        160
# 361  363      Spheal     2       Ice     Water    290         95        100
# 362  364      Sealeo     2       Ice     Water    410        135        140
# 363  365     Walrein     2       Ice     Water    530        175        180
# 364  366    Clamperl     1     Water  No value    345        138        140
# 365  367     Huntail     1     Water  No value    485        198        180
# 366  368    Gorebyss     1     Water  No value    485        198        180
# 367  369   Relicanth     2     Water      Rock    485        135        195
# 368  370     Luvdisc     1     Water  No value    330         70        120
# 369  371       Bagon     1    Dragon  No value    300        115         90
# 370  372     Shelgon     1    Dragon  No value    420        155        150
# 371  373   Salamence     2    Dragon    Flying    600        245        160
# 372  374      Beldum     2     Steel   Psychic    300         90        140
# 373  375      Metang     2     Steel   Psychic    420        130        180
# 374  376   Metagross     2     Steel   Psychic    600        230        220
# 375  377    Regirock     1      Rock  No value    580        150        300
# 376  378      Regice     1       Ice  No value    580        150        300
# 377  379   Registeel     1     Steel  No value    580        150        300
# 378  380      Latias     2    Dragon   Psychic    600        190        220
# 379  381      Latios     2    Dragon   Psychic    600        220        190
# 380  382      Kyogre     1     Water  No value    670        250        230
# 381  383     Groudon     1    Ground  No value    670        250        230
# 382  384    Rayquaza     2    Dragon    Flying    680        300        180
# 383  385     Jirachi     2     Steel   Psychic    600        200        200
# 384  387     Turtwig     1     Grass  No value    318        113        119
# 385  388      Grotle     1     Grass  No value    405        144        150
# 386  389    Torterra     2     Grass    Ground    525        184        190
# 387  390    Chimchar     1      Fire  No value    309        116         88
# 388  391    Monferno     2      Fire  Fighting    405        156        104
# 389  392   Infernape     2      Fire  Fighting    534        208        142
# 390  393      Piplup     1     Water  No value    314        112        109
# 391  394    Prinplup     1     Water  No value    405        147        144
# 392  395    Empoleon     2     Water     Steel    530        197        189
# 393  396      Starly     2    Normal    Flying    245         85         60
# 394  397    Staravia     2    Normal    Flying    340        115         90
# 395  398   Staraptor     2    Normal    Flying    485        170        130
# 396  399      Bidoof     1    Normal  No value    250         80         80
# 397  400     Bibarel     2    Normal     Water    410        140        120
# 398  401   Kricketot     1       Bug  No value    194         50         82
# 399  402  Kricketune     1       Bug  No value    384        140        102
# 400  403       Shinx     1  Electric  No value    263        105         68
# 401  404       Luxio     1  Electric  No value    363        145         98
# 402  405      Luxray     1  Electric  No value    523        215        158
# 403  406       Budew     2     Grass    Poison    280         80        105
# 404  407    Roserade     2     Grass    Poison    515        195        170
# 405  408    Cranidos     1      Rock  No value    350        155         70
# 406  409   Rampardos     1      Rock  No value    495        230        110
# 407  410    Shieldon     2      Rock     Steel    350         84        206
# 408  411   Bastiodon     2      Rock     Steel    495         99        306
# 409  414      Mothim     2       Bug    Flying    424        188        100
# 410  415      Combee     2       Bug    Flying    244         60         84
# 411  416   Vespiquen     2       Bug    Flying    474        160        204
# 412  417   Pachirisu     1  Electric  No value    405         90        160
# 413  418      Buizel     1     Water  No value    330        125         65
# 414  419    Floatzel     1     Water  No value    495        190        105
# 415  420     Cherubi     1     Grass  No value    275         97         98
# 416  424     Ambipom     1    Normal  No value    482        160        132
# 417  425    Drifloon     2     Ghost    Flying    348        110         78
# 418  426    Drifblim     2     Ghost    Flying    498        170         98
# 419  427     Buneary     1    Normal  No value    350        110        100
# 420  428     Lopunny     1    Normal  No value    480        130        180
# 421  429   Mismagius     1     Ghost  No value    495        165        165
# 422  430   Honchkrow     2      Dark    Flying    505        230        104
# 423  431     Glameow     1    Normal  No value    310         97         79
# 424  432     Purugly     1    Normal  No value    452        146        123
# 425  433   Chingling     1   Psychic  No value    285         95        100
# 426  434      Stunky     2    Poison      Dark    329        104         88
# 427  435    Skuntank     2    Poison      Dark    479        164        128
# 428  436     Bronzor     2     Steel   Psychic    300         48        172
# 429  437    Bronzong     2     Steel   Psychic    500        168        232
# 430  438      Bonsly     1      Rock  No value    290         90        140
# 431  439    Mime Jr.     2   Psychic     Fairy    310         95        135
# 432  440     Happiny     1    Normal  No value    220         20         70
# 433  441      Chatot     2    Normal    Flying    411        157         87
# 434  442   Spiritomb     2     Ghost      Dark    485        184        216
# 435  443       Gible     2    Dragon    Ground    300        110         90
# 436  444      Gabite     2    Dragon    Ground    410        140        120
# 437  445    Garchomp     2    Dragon    Ground    600        210        180
# 438  446    Munchlax     1    Normal  No value    390        125        125
# 439  447       Riolu     1  Fighting  No value    285        105         80
# 440  448     Lucario     2  Fighting     Steel    525        225        140
# 441  449  Hippopotas     1    Ground  No value    330        110        120
# 442  450   Hippowdon     1    Ground  No value    525        180        190
# 443  451     Skorupi     2    Poison       Bug    330         80        145
# 444  452     Drapion     2    Poison      Dark    500        150        185
# 445  453    Croagunk     2    Poison  Fighting    300        122         80
# 446  454   Toxicroak     2    Poison  Fighting    490        192        130
# 447  455   Carnivine     1     Grass  No value    454        190        144
# 448  456     Finneon     1     Water  No value    330         98        117
# 449  457    Lumineon     1     Water  No value    460        138        162
# 450  458     Mantyke     2     Water    Flying    345         80        170
# 451  459      Snover     2     Grass       Ice    334        124        110
# 452  460   Abomasnow     2     Grass       Ice    494        184        160
# 453  461     Weavile     2      Dark       Ice    510        165        150
# 454  462   Magnezone     2  Electric     Steel    535        200        205
# 455  463  Lickilicky     1    Normal  No value    515        165        190
# 456  464   Rhyperior     2    Ground      Rock    535        195        185
# 457  465   Tangrowth     1     Grass  No value    535        210        175
# 458  466  Electivire     1  Electric  No value    540        218        152
# 459  467   Magmortar     1      Fire  No value    540        220        162
# 460  468    Togekiss     2     Fairy    Flying    545        170        210
# 461  469     Yanmega     2       Bug    Flying    515        192        142
# 462  470     Leafeon     1     Grass  No value    525        170        195
# 463  471     Glaceon     1       Ice  No value    525        190        205
# 464  472     Gliscor     2    Ground    Flying    510        140        200
# 465  473   Mamoswine     2       Ice    Ground    530        200        140
# 466  474   Porygon-Z     1    Normal  No value    535        215        145
# 467  475     Gallade     2   Psychic  Fighting    518        190        180
# 468  476   Probopass     2      Rock     Steel    525        130        295
# 469  477    Dusknoir     1     Ghost  No value    525        165        270
# 470  478    Froslass     2       Ice     Ghost    480        160        140
# 471  480        Uxie     1   Psychic  No value    580        150        260
# 472  481     Mesprit     1   Psychic  No value    580        210        210
# 473  482       Azelf     1   Psychic  No value    580        250        140
# 474  483      Dialga     2     Steel    Dragon    680        270        220
# 475  484      Palkia     2     Water    Dragon    680        270        220
# 476  485     Heatran     2      Fire     Steel    600        220        212
# 477  486   Regigigas     1    Normal  No value    670        240        220
# 478  488   Cresselia     1   Psychic  No value    600        145        250
# 479  491     Darkrai     1      Dark  No value    600        225        180
# 480  495       Snivy     1     Grass  No value    308         90        110
# 481  496     Servine     1     Grass  No value    413        120        150
# 482  497   Serperior     1     Grass  No value    528        150        190
# 483  498       Tepig     1      Fire  No value    308        108         90
# 484  499     Pignite     2      Fire  Fighting    418        163        110
# 485  500      Emboar     2      Fire  Fighting    528        223        130
# 486  501    Oshawott     1     Water  No value    308        118         90
# 487  502      Dewott     1     Water  No value    413        158        120
# 488  503    Samurott     1     Water  No value    528        208        155
# 489  504      Patrat     1    Normal  No value    255         90         78
# 490  505     Watchog     1    Normal  No value    420        145        138
# 491  506    Lillipup     1    Normal  No value    275         85         90
# 492  507     Herdier     1    Normal  No value    370        115        130
# 493  508   Stoutland     1    Normal  No value    500        155        180
# 494  509    Purrloin     1      Dark  No value    281        100         74
# 495  510     Liepard     1      Dark  No value    446        176        100
# 496  511     Pansage     1     Grass  No value    316        106         96
# 497  512    Simisage     1     Grass  No value    498        196        126
# 498  513     Pansear     1      Fire  No value    316        106         96
# 499  514    Simisear     1      Fire  No value    498        196        126
# 500  515     Panpour     1     Water  No value    316        106         96
# 501  516    Simipour     1     Water  No value    498        196        126
# 502  519      Pidove     2    Normal    Flying    264         91         80
# 503  520   Tranquill     2    Normal    Flying    358        127        104
# 504  521    Unfezant     2    Normal    Flying    488        180        135
# 505  522     Blitzle     1  Electric  No value    295        110         64
# 506  523   Zebstrika     1  Electric  No value    497        180        126
# 507  529     Drilbur     1    Ground  No value    328        115         85
# 508  530   Excadrill     2    Ground     Steel    508        185        125
# 509  562      Yamask     1     Ghost  No value    303         85        150
# 510  563  Cofagrigus     1     Ghost  No value    483        145        250
# 511  590     Foongus     2     Grass    Poison    294        110        100
# 512  591   Amoonguss     2     Grass    Poison    464        170        150
# 513  597   Ferroseed     2     Grass     Steel    305         74        177
# 514  598  Ferrothorn     2     Grass     Steel    489        148        247
# 515  599       Klink     1     Steel  No value    300        100        130
# 516  600       Klang     1     Steel  No value    440        150        180
# 517  601   Klinklang     1     Steel  No value    520        170        200
# 518  607     Litwick     2     Ghost      Fire    275         95        110
# 519  608     Lampent     2     Ghost      Fire    370        135        120
# 520  609  Chandelure     2     Ghost      Fire    520        200        180
# 521  622      Golett     2    Ground     Ghost    303        109        100
# 522  623      Golurk     2    Ground     Ghost    483        179        160
# 523  631     Heatmor     1      Fire  No value    484        202        132
# 524  632      Durant     2       Bug     Steel    484        157        160
# 525  633       Deino     2      Dark    Dragon    300        110        100
# 526  634    Zweilous     2      Dark    Dragon    420        150        140
# 527  635   Hydreigon     2      Dark    Dragon    600        230        180
#
#       HP  Attack  Defense  Sp_Atk  Sp_Def  Speed Generation Legendary   Mega  \
# 0     45      49       49      65      65     45          1     False  False
# 1     60      62       63      80      80     60          1     False  False
# 2     80      82       83     100     100     80          1     False  False
# 3     39      52       43      60      50     65          1     False  False
# 4     58      64       58      80      65     80          1     False  False
# 5     78      84       78     109      85    100          1     False  False
# 6     44      48       65      50      64     43          1     False  False
# 7     59      63       80      65      80     58          1     False  False
# 8     79      83      100      85     105     78          1     False  False
# 9     45      30       35      20      20     45          1     False  False
# 10    50      20       55      25      25     30          1     False  False
# 11    60      45       50      90      80     70          1     False  False
# 12    40      35       30      20      20     50          1     False  False
# 13    45      25       50      25      25     35          1     False  False
# 14    65      90       40      45      80     75          1     False  False
# 15    40      45       40      35      35     56          1     False  False
# 16    63      60       55      50      50     71          1     False  False
# 17    83      80       75      70      70    101          1     False  False
# 18    30      56       35      25      35     72          1     False  False
# 19    55      81       60      50      70     97          1     False  False
# 20    40      60       30      31      31     70          1     False  False
# 21    65      90       65      61      61    100          1     False  False
# 22    35      60       44      40      54     55          1     False  False
# 23    60      85       69      65      79     80          1     False  False
# 24    35      55       40      50      50     90          1     False  False
# 25    60      90       55      90      80    110          1     False  False
# 26    50      75       85      20      30     40          1     False  False
# 27    75     100      110      45      55     65          1     False  False
# 28    55      47       52      40      40     41          1     False  False
# 29    70      62       67      55      55     56          1     False  False
# 30    90      92       87      75      85     76          1     False  False
# 31    46      57       40      40      40     50          1     False  False
# 32    61      72       57      55      55     65          1     False  False
# 33    81     102       77      85      75     85          1     False  False
# 34    70      45       48      60      65     35          1     False  False
# 35    95      70       73      95      90     60          1     False  False
# 36    38      41       40      50      65     65          1     False  False
# 37    73      76       75      81     100    100          1     False  False
# 38   115      45       20      45      25     20          1     False  False
# 39   140      70       45      85      50     45          1     False  False
# 40    40      45       35      30      40     55          1     False  False
# 41    75      80       70      65      75     90          1     False  False
# 42    45      50       55      75      65     30          1     False  False
# 43    60      65       70      85      75     40          1     False  False
# 44    75      80       85     110      90     50          1     False  False
# 45    35      70       55      45      55     25          1     False  False
# 46    60      95       80      60      80     30          1     False  False
# 47    60      55       50      40      55     45          1     False  False
# 48    70      65       60      90      75     90          1     False  False
# 49    10      55       25      35      45     95          1     False  False
# 50    35      80       50      50      70    120          1     False  False
# 51    40      45       35      40      40     90          1     False  False
# 52    65      70       60      65      65    115          1     False  False
# 53    50      52       48      65      50     55          1     False  False
# 54    80      82       78      95      80     85          1     False  False
# 55    40      80       35      35      45     70          1     False  False
# 56    65     105       60      60      70     95          1     False  False
# 57    55      70       45      70      50     60          1     False  False
# 58    90     110       80     100      80     95          1     False  False
# 59    40      50       40      40      40     90          1     False  False
# 60    65      65       65      50      50     90          1     False  False
# 61    90      95       95      70      90     70          1     False  False
# 62    25      20       15     105      55     90          1     False  False
# 63    40      35       30     120      70    105          1     False  False
# 64    55      50       45     135      95    120          1     False  False
# 65    70      80       50      35      35     35          1     False  False
# 66    80     100       70      50      60     45          1     False  False
# 67    90     130       80      65      85     55          1     False  False
# 68    50      75       35      70      30     40          1     False  False
# 69    65      90       50      85      45     55          1     False  False
# 70    80     105       65     100      70     70          1     False  False
# 71    40      40       35      50     100     70          1     False  False
# 72    80      70       65      80     120    100          1     False  False
# 73    40      80      100      30      30     20          1     False  False
# 74    55      95      115      45      45     35          1     False  False
# 75    80     120      130      55      65     45          1     False  False
# ...
# 248       ['Hydro Pump', 'Sky Attack', 'Future Sight']
# 249         ['Fire Blast', 'Solar Beam', 'Brave Bird']
# 250        ['Hyper Beam', 'Dazzling Gleam', 'Psychic']
# 251        ['Aerial Ace', 'Grass Knot', 'Energy Ball']
# 252         ['Aerial Ace', 'Leaf Blade', 'Grass Knot']
# 253  ['Earthquake', 'Aerial Ace', 'Dragon Claw', 'L...
# 254      ['Flamethrower', 'Rock Tomb', 'Flame Charge']
# 255     ['Flamethrower', 'Rock Slide', 'Flame Charge']
# 256  ['Focus Blast', 'Brave Bird', 'Overheat', 'Bla...
# 257                         ['Sludge', 'Dig', 'Stomp']
# 258                     ['Sludge', 'Mud Bomb', 'Surf']
# 259  ['Earthquake', 'Sludge Wave', 'Surf', 'Muddy W...
# 260                   ['Dig', 'Poison Fang', 'Crunch']
# 261            ['Poison Fang', 'Play Rough', 'Crunch']
# 262               ['Dig', 'Thunderbolt', 'Grass Knot']
# 263                   ['Dig', 'Thunder', 'Grass Knot']
# 264                                       ['Struggle']
# 265                                       ['Struggle']
# 266          ['Bug Buzz', 'Air Cutter', 'Silver Wind']
# 267                                       ['Struggle']
# 268         ['Bug Buzz', 'Sludge Bomb', 'Silver Wind']
# 269                     ['Bubble Beam', 'Energy Ball']
# 270          ['Ice Beam', 'Bubble Beam', 'Grass Knot']
# 271  ['Ice Beam', 'Blizzard', 'Hydro Pump', 'Solar ...
# 272         ['Grass Knot', 'Energy Ball', 'Foul Play']
# 273          ['Leaf Blade', 'Grass Knot', 'Foul Play']
# 274  ['Leaf Blade', 'Hurricane', 'Foul Play', 'Leaf...
# 275                                     ['Aerial Ace']
# 276         ['Aerial Ace', 'Brave Bird', 'Sky Attack']
# 277          ['Ice Beam', 'Water Pulse', 'Air Cutter']
# 278            ['Blizzard', 'Hydro Pump', 'Hurricane']
# 279    ['Psyshock', 'Shadow Sneak', 'Disarming Voice']
# 280     ['Shadow Sneak', 'Disarming Voice', 'Psychic']
# 281       ['Shadow Ball', 'Dazzling Gleam', 'Psychic']
# 282         ['Bubble Beam', 'Aqua Jet', 'Signal Beam']
# 283      ['Ominous Wind', 'Air Cutter', 'Silver Wind']
# 284         ['Seed Bomb', 'Grass Knot', 'Energy Ball']
# 285      ['Seed Bomb', 'Sludge Bomb', 'Dynamic Punch']
# 286        ['Night Slash', 'Brick Break', 'Body Slam']
# 287           ['Bulldoze', 'Brick Break', 'Body Slam']
# 288         ['Hyper Beam', 'Earthquake', 'Play Rough']
# 289          ['Aerial Ace', 'Bug Buzz', 'Night Slash']
# 290          ['Aerial Ace', 'Bug Buzz', 'Shadow Ball']
# 291              ['Dig', 'Aerial Ace', 'Shadow Sneak']
# 292       ['Flamethrower', 'Disarming Voice', 'Stomp']
# 293       ['Flamethrower', 'Disarming Voice', 'Stomp']
# 294        ['Disarming Voice', 'Fire Blast', 'Crunch']
# 295          ['Cross Chop', 'Low Sweep', 'Heavy Slam']
# 296    ['Close Combat', 'Dynamic Punch', 'Heavy Slam']
# 297           ['Ice Beam', 'Bubble Beam', 'Body Slam']
# 298        ['Rock Slide', 'Thunderbolt', 'Rock Blast']
# 299          ['Dig', 'Disarming Voice', 'Wild Charge']
# 300   ['Disarming Voice', 'Play Rough', 'Wild Charge']
# 301         ['Power Gem', 'Shadow Sneak', 'Foul Play']
# 302  ['Vice Grip', 'Iron Head', 'Play Rough', 'Powe...
# 303            ['Rock Tomb', 'Iron Head', 'Body Slam']
# 304          ['Rock Slide', 'Body Slam', 'Heavy Slam']
# 305            ['Stone Edge', 'Thunder', 'Heavy Slam']
# 306             ['Ice Punch', 'Low Sweep', 'Psyshock']
# 307  ['Ice Punch', 'Psychic', 'Dynamic Punch', 'Pow...
# 308              ['Discharge', 'Thunderbolt', 'Swift']
# 309          ['Thunder', 'Flame Burst', 'Wild Charge']
# 310              ['Discharge', 'Thunderbolt', 'Swift']
# 311              ['Discharge', 'Thunderbolt', 'Swift']
# 312         ['Bug Buzz', 'Thunderbolt', 'Signal Beam']
# 313      ['Bug Buzz', 'Dazzling Gleam', 'Silver Wind']
# 314  ['Petal Blizzard', 'Dazzling Gleam', 'Sludge B...
# 315                ['Sludge', 'Ice Beam', 'Gunk Shot']
# 316  ['Ice Beam', 'Sludge Bomb', 'Gunk Shot', 'Acid...
# 317              ['Poison Fang', 'Aqua Jet', 'Crunch']
# 318            ['Poison Fang', 'Hydro Pump', 'Crunch']
# 319         ['Water Pulse', 'Body Slam', 'Heavy Slam']
# 320                 ['Hyper Beam', 'Blizzard', 'Surf']
# 321                 ['Heat Wave', 'Bulldoze', 'Stomp']
# 322  ['Earthquake', 'Solar Beam', 'Overheat', 'Eart...
# 323           ['Earthquake', 'Solar Beam', 'Overheat']
# 324          ['Psybeam', 'Shadow Ball', 'Mirror Coat']
# 325          ['Shadow Ball', 'Psychic', 'Mirror Coat']
# 326                   ['Dig', 'Rock Tomb', 'Icy Wind']
# 327                     ['Dig', 'Sand Tomb', 'Crunch']
# 328              ['Bug Buzz', 'Bulldoze', 'Sand Tomb']
# 329        ['Earthquake', 'Stone Edge', 'Dragon Claw']
# 330         ['Seed Bomb', 'Brick Break', 'Grass Knot']
# 331      ['Dark Pulse', 'Dynamic Punch', 'Grass Knot']
# 332      ['Ice Beam', 'Aerial Ace', 'Disarming Voice']
# 333   ['Dragon Pulse', 'Dazzling Gleam', 'Sky Attack']
# 334             ['Dig', 'Night Slash', 'Close Combat']
# 335                  ['Wrap', 'Poison Fang', 'Crunch']
# 336             ['Rock Slide', 'Moonblast', 'Psychic']
# 337            ['Rock Slide', 'Psychic', 'Solar Beam']
# 338              ['Ice Beam', 'Aqua Tail', 'Mud Bomb']
# 339            ['Blizzard', 'Mud Bomb', 'Water Pulse']
# 340           ['Vice Grip', 'Bubble Beam', 'Aqua Jet']
# 341  ['Vice Grip', 'Night Slash', 'Bubble Beam', 'C...
# 342                    ['Dig', 'Psybeam', 'Gyro Ball']
# 343  ['Earthquake', 'Psychic', 'Gyro Ball', 'Earth ...
# 344     ['Ancient Power', 'Grass Knot', 'Mirror Coat']
# 345           ['Stone Edge', 'Bulldoze', 'Grass Knot']
# 346      ['Aqua Jet', 'Ancient Power', 'Cross Poison']
# 347      ['Cross Poison', 'Water Pulse', 'Rock Blast']
# 348                                    ['Mirror Coat']
# 349                 ['Hyper Beam', 'Blizzard', 'Surf']
# 350                       ['Hurricane', 'Energy Ball']
# 351    ['Shadow Sneak', 'Ominous Wind', 'Night Shade']
# 352       ['Shadow Ball', 'Thunder', 'Dazzling Gleam']
# 353    ['Shadow Sneak', 'Ominous Wind', 'Night Shade']
# 354        ['Ice Punch', 'Shadow Punch', 'Fire Punch']
# 355              ['Aerial Ace', 'Leaf Blade', 'Stomp']
# 356         ['Psyshock', 'Shadow Ball', 'Energy Ball']
# 357              ['Dark Pulse', 'Megahorn', 'Thunder']
# 358                                    ['Mirror Coat']
# 359           ['Shadow Ball', 'Icy Wind', 'Avalanche']
# 360          ['Shadow Ball', 'Avalanche', 'Gyro Ball']
# 361        ['Water Pulse', 'Body Slam', 'Aurora Beam']
# 362        ['Water Pulse', 'Body Slam', 'Aurora Beam']
# 363          ['Earthquake', 'Blizzard', 'Water Pulse']
# 364           ['Ice Beam', 'Water Pulse', 'Body Slam']
# 365                ['Ice Beam', 'Aqua Tail', 'Crunch']
# 366        ['Draining Kiss', 'Water Pulse', 'Psychic']
# 367       ['Aqua Tail', 'Ancient Power', 'Hydro Pump']
# 368       ['Aqua Jet', 'Draining Kiss', 'Water Pulse']
# 369              ['Flamethrower', 'Twister', 'Crunch']
# 370        ['Flamethrower', 'Twister', 'Dragon Pulse']
# 371       ['Fire Blast', 'Hydro Pump', 'Draco Meteor']
# 372                                       ['Struggle']
# 373               ['Psyshock', 'Psychic', 'Gyro Ball']
# 374          ['Earthquake', 'Flash Cannon', 'Psychic']
# 375        ['Stone Edge', 'Focus Blast', 'Zap Cannon']
# 376          ['Earthquake', 'Blizzard', 'Focus Blast']
# 377      ['Hyper Beam', 'Flash Cannon', 'Focus Blast']
# 378                  ['Thunder', 'Psychic', 'Outrage']
# 379           ['Dragon Claw', 'Psychic', 'Solar Beam']
# 380              ['Blizzard', 'Thunder', 'Hydro Pump']
# 381         ['Earthquake', 'Fire Blast', 'Solar Beam']
# 382         ['Aerial Ace', 'Ancient Power', 'Outrage']
# 383       ['Dazzling Gleam', 'Psychic', 'Doom Desire']
# 384          ['Seed Bomb', 'Body Slam', 'Energy Ball']
# 385         ['Solar Beam', 'Body Slam', 'Energy Ball']
# 386         ['Earthquake', 'Stone Edge', 'Solar Beam']
# 387    ['Flame Wheel', 'Flamethrower', 'Flame Charge']
# 388       ['Flame Wheel', 'Flamethrower', 'Low Sweep']
# 389     ['Flamethrower', 'Solar Beam', 'Close Combat']
# 390          ['Drill Peck', 'Bubble Beam', 'Icy Wind']
# 391          ['Bubble Beam', 'Hydro Pump', 'Icy Wind']
# 392         ['Flash Cannon', 'Blizzard', 'Hydro Pump']
# 393                       ['Aerial Ace', 'Brave Bird']
# 394          ['Heat Wave', 'Aerial Ace', 'Brave Bird']
# 395        ['Heat Wave', 'Close Combat', 'Brave Bird']
# 396             ['Hyper Fang', 'Grass Knot', 'Crunch']
# 397               ['Hyper Beam', 'Hyper Fang', 'Surf']
# 398                                       ['Struggle']
# 399         ['Aerial Ace', 'Bug Buzz', 'X', 'Scissor']
# 400              ['Discharge', 'Thunderbolt', 'Swift']
# 401           ['Thunderbolt', 'Wild Charge', 'Crunch']
# 402            ['Hyper Beam', 'Wild Charge', 'Crunch']
# 403                      ['Grass Knot', 'Energy Ball']
# 404  ['Dazzling Gleam', 'Sludge Bomb', 'Solar Beam'...
# 405         ['Ancient Power', 'Rock Tomb', 'Bulldoze']
# 406          ['Flamethrower', 'Rock Slide', 'Outrage']
# 407       ['Ancient Power', 'Rock Tomb', 'Heavy Slam']
# 408     ['Flamethrower', 'Stone Edge', 'Flash Cannon']
# 409              ['Psybeam', 'Aerial Ace', 'Bug Buzz']
# 410                                       ['Bug Buzz']
# 411          ['Bug Buzz', 'Power Gem', 'X', 'Scissor']
# 412        ['Thunder Punch', 'Thunder', 'Thunderbolt']
# 413               ['Aqua Jet', 'Water Pulse', 'Swift']
# 414                ['Aqua Jet', 'Hydro Pump', 'Swift']
# 415  ['Petal Blizzard', 'Seed Bomb', 'Dazzling Gleam']
# 416          ['Hyper Beam', 'Aerial Ace', 'Low Sweep']
# 417        ['Ominous Wind', 'Shadow Ball', 'Icy Wind']
# 418        ['Ominous Wind', 'Shadow Ball', 'Icy Wind']
# 419                            ['Fire Punch', 'Swift']
# 420        ['Hyper Beam', 'Fire Punch', 'Focus Blast']
# 421    ['Dark Pulse', 'Shadow Ball', 'Dazzling Gleam']
# 422  ['Dark Pulse', 'Psychic', 'Brave Bird', 'Sky A...
# 423        ['Aerial Ace', 'Thunderbolt', 'Play Rough']
# 424            ['Aerial Ace', 'Thunder', 'Play Rough']
# 425                ['Wrap', 'Psyshock', 'Shadow Ball']
# 426          ['Flamethrower', 'Sludge Bomb', 'Crunch']
# 427          ['Flamethrower', 'Sludge Bomb', 'Crunch']
# 428            ['Psyshock', 'Gyro Ball', 'Heavy Slam']
# 429  ['Flash Cannon', 'Psyshock', 'Bulldoze', 'Psyc...
# 430          ['Earthquake', 'Rock Tomb', 'Rock Slide']
# 431                 ['Psybeam', 'Psyshock', 'Psychic']
# 432                                        ['Psychic']
# 433         ['Heat Wave', 'Sky Attack', 'Night Shade']
# 434    ['Shadow Sneak', 'Ominous Wind', 'Shadow Ball']
# 435                    ['Dig', 'Twister', 'Body Slam']
# 436                 ['Flamethrower', 'Dig', 'Twister']
# 437            ['Earthquake', 'Fire Blast', 'Outrage']
# 438             ['Gunk Shot', 'Bulldoze', 'Body Slam']
# 439         ['Cross Chop', 'Low Sweep', 'Brick Break']
# 440  ['Flash Cannon', 'Shadow Ball', 'Close Combat'...
# 441                  ['Dig', 'Rock Tomb', 'Body Slam']
# 442  ['Earthquake', 'Stone Edge', 'Body Slam', 'Ear...
# 443       ['Aqua Tail', 'Cross Poison', 'Sludge Bomb']
# 444             ['Aqua Tail', 'Sludge Bomb', 'Crunch']
# 445        ['Low Sweep', 'Sludge Bomb', 'Brick Break']
# 446       ['Sludge Bomb', 'Mud Bomb', 'Dynamic Punch']
# 447            ['Power Whip', 'Energy Ball', 'Crunch']
# 448         ['Ice Beam', 'Water Pulse', 'Silver Wind']
# 449         ['Blizzard', 'Water Pulse', 'Silver Wind']
# 450          ['Ice Beam', 'Aerial Ace', 'Water Pulse']
# 451               ['Ice Beam', 'Stomp', 'Energy Ball']
# 452             ['Blizzard', 'Energy Ball', 'Outrage']
# 453          ['Focus Blast', 'Avalanche', 'Foul Play']
# 454      ['Flash Cannon', 'Wild Charge', 'Zap Cannon']
# 455         ['Hyper Beam', 'Earthquake', 'Solar Beam']
# 456  ['Earthquake', 'Stone Edge', 'Surf', 'Skull Ba...
# 457     ['Ancient Power', 'Sludge Bomb', 'Solar Beam']
# 458  ['Ice Punch', 'Thunder Punch', 'Thunder', 'Wil...
# 459  ['Fire Blast', 'Psychic', 'Fire Punch', 'Brick...
# 460  ['Flamethrower', 'Aerial Ace', 'Ancient Power'...
# 461        ['Aerial Ace', 'Bug Buzz', 'Ancient Power']
# 462        ['Solar Beam', 'Leaf Blade', 'Energy Ball']
# 463              ['Ice Beam', 'Icy Wind', 'Avalanche']
# 464        ['Earthquake', 'Aerial Ace', 'Night Slash']
# 465            ['Stone Edge', 'Bulldoze', 'Avalanche']
# 466  ['Hyper Beam', 'Blizzard', 'Solar Beam', 'Zap ...
# 467          ['Psychic', 'Leaf Blade', 'Close Combat']
# 468       ['Rock Slide', 'Magnet Bomb', 'Thunderbolt']
# 469          ['Dark Pulse', 'Ominous Wind', 'Psychic']
# 470             ['Shadow Ball', 'Avalanche', 'Crunch']
# 471               ['Thunder', 'Swift', 'Future Sight']
# 472              ['Blizzard', 'Swift', 'Future Sight']
# 473            ['Fire Blast', 'Swift', 'Future Sight']
# 474           ['Iron Head', 'Thunder', 'Draco Meteor']
# 475       ['Fire Blast', 'Hydro Pump', 'Draco Meteor']
# 476          ['Stone Edge', 'Iron Head', 'Fire Blast']
# 477          ['Stone Edge', 'Avalanche', 'Heavy Slam']
# 478       ['Moonblast', 'Aurora Beam', 'Future Sight']
# 479       ['Dark Pulse', 'Shadow Ball', 'Focus Blast']
# 480               ['Wrap', 'Seed Bomb', 'Energy Ball']
# 481             ['Wrap', 'Grass Knot', 'Leaf Tornado']
# 482       ['Aerial Ace', 'Grass Knot', 'Leaf Tornado']
# 483      ['Flamethrower', 'Flame Charge', 'Body Slam']
# 484      ['Flamethrower', 'Rock Tomb', 'Flame Charge']
# 485         ['Heat Wave', 'Rock Slide', 'Focus Blast']
# 486        ['Night Slash', 'Aqua Tail', 'Water Pulse']
# 487       ['Aqua Tail', 'X', 'Scissor', 'Water Pulse']
# 488             ['Megahorn', 'Blizzard', 'Hydro Pump']
# 489                ['Dig', 'Hyper Fang', 'Grass Knot']
# 490             ['Hyper Fang', 'Grass Knot', 'Crunch']
# 491                ['Dig', 'Rock Tomb', 'Thunderbolt']
# 492               ['Dig', 'Thunderbolt', 'Play Rough']
# 493            ['Play Rough', 'Wild Charge', 'Crunch']
# 494        ['Dark Pulse', 'Night Slash', 'Play Rough']
# 495          ['Dark Pulse', 'Play Rough', 'Gunk Shot']
# 496             ['Seed Bomb', 'Energy Ball', 'Crunch']
# 497             ['Solar Beam', 'Grass Knot', 'Crunch']
# 498          ['Flame Charge', 'Flame Burst', 'Crunch']
# 499           ['Flamethrower', 'Fire Blast', 'Crunch']
# 500                  ['Water Pulse', 'Crunch', 'Surf']
# 501                   ['Hydro Pump', 'Crunch', 'Surf']
# 502          ['Heat Wave', 'Aerial Ace', 'Air Cutter']
# 503          ['Heat Wave', 'Aerial Ace', 'Sky Attack']
# 504          ['Hyper Beam', 'Heat Wave', 'Sky Attack']
# 505       ['Discharge', 'Thunderbolt', 'Flame Charge']
# 506       ['Discharge', 'Flame Charge', 'Wild Charge']
# 507                  ['Dig', 'Drill Run', 'Rock Tomb']
# 508  ['Earthquake', 'Drill Run', 'Rock Slide', 'Iro...
# 509      ['Dark Pulse', 'Ominous Wind', 'Shadow Ball']
# 510           ['Dark Pulse', 'Shadow Ball', 'Psychic']
# 511         ['Body Slam', 'Grass Knot', 'Energy Ball']
# 512         ['Sludge Bomb', 'Grass Knot', 'Foul Play']
# 513         ['Flash Cannon', 'Iron Head', 'Gyro Ball']
# 514  ['Flash Cannon', 'Thunder', 'Power Whip', 'Aci...
# 515           ['Vice Grip', 'Discharge', 'Zap Cannon']
# 516         ['Vice Grip', 'Thunderbolt', 'Zap Cannon']
# 517       ['Hyper Beam', 'Flash Cannon', 'Zap Cannon']
# 518       ['Heat Wave', 'Flame Charge', 'Flame Burst']
# 519        ['Heat Wave', 'Flame Burst', 'Energy Ball']
# 520         ['Shadow Ball', 'Overheat', 'Energy Ball']
# 521     ['Shadow Punch', 'Brick Break', 'Night Shade']
# 522   ['Shadow Punch', 'Dynamic Punch', 'Earth Power']
# 523  ['Flamethrower', 'Thunder Punch', 'Power', 'Up...
# 524        ['Stone Edge', 'Iron Head', 'X', 'Scissor']
# 525            ['Dragon Pulse', 'Body Slam', 'Crunch']
# 526        ['Dark Pulse', 'Dragon Pulse', 'Body Slam']
# 527     ['Dark Pulse', 'Flash Cannon', 'Dragon Pulse']

# %% [markdown]
# ### - Pokemon Moves Dataset -

# %%
moves.describe()
# Out:
#                 Name    Type Cat. Power Acc.   PP    TM                Effect  \
# count            804     804   63   804  804  804   100                   773
# unique           804      18    1    36   12   11   100                   512
# top     Techno Blast  Normal    —     —  100   10  TM32  May cause flinching.
# freq               1     189   63   354  365  226     1                    20
#
#        Prob. (%)
# count        627
# unique         8
# top            —
# freq         479

# %%
moves.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 9 columns):
# Name         804 non-null object
# Type         804 non-null object
# Cat.         63 non-null object
# Power        804 non-null object
# Acc.         804 non-null object
# PP           804 non-null object
# TM           100 non-null object
# Effect       773 non-null object
# Prob. (%)    627 non-null object
# dtypes: object(9)
# memory usage: 56.7+ KB

# %% [markdown]
# #### 1. Renames column names

# %%
## Rename columns for ease of reference
moves=moves.rename(
    columns = {
        "Name":"Move", 
        "Acc.":"Accuracy", 
        "TM":"TechMachine", 
        "Prob. (%)":"Prob"})
moves
# Out:
#                             Move      Type Cat. Power Accuracy  PP  \
# 0    10,000,000 Volt Thunderbolt  Electric  NaN   195        —   1
# 1                         Absorb     Grass  NaN    20      100  25
# 2                     Accelerock      Rock  NaN    40      100  20
# 3                           Acid    Poison  NaN    40      100  30
# 4                     Acid Armor    Poison  NaN     —        —  20
# 5                  Acid Downpour    Poison    —     —        —   1
# 6                     Acid Spray    Poison  NaN    40      100  20
# 7                     Acrobatics    Flying  NaN    55      100  15
# 8                    Acupressure    Normal  NaN     —        —  30
# 9                     Aerial Ace    Flying  NaN    60        ∞  20
# 10                     Aeroblast    Flying  NaN   100       95   5
# 11                     After You    Normal  NaN     —        —  15
# 12                       Agility   Psychic  NaN     —        —  30
# 13                    Air Cutter    Flying  NaN    60       95  25
# 14                     Air Slash    Flying  NaN    75       95  20
# 15             All-Out Pummeling  Fighting    —     —        —   1
# 16                   Ally Switch   Psychic  NaN     —        —  15
# 17                       Amnesia   Psychic  NaN     —        —  20
# 18                   Anchor Shot     Steel  NaN    80      100  20
# 19                 Ancient Power      Rock  NaN    60      100   5
# 20                    Apple Acid     Grass  NaN    80      100  10
# 21                      Aqua Jet     Water  NaN    40      100  20
# 22                     Aqua Ring     Water  NaN     —        —  20
# 23                     Aqua Tail     Water  NaN    90       90  10
# 24                    Arm Thrust  Fighting  NaN    15      100  20
# 25                  Aromatherapy     Grass  NaN     —        —   5
# 26                 Aromatic Mist     Fairy  NaN     —        —  20
# 27                        Assist    Normal  NaN     —        —  20
# 28                     Assurance      Dark  NaN    60      100  10
# 29                      Astonish     Ghost  NaN    30      100  15
# 30                  Attack Order       Bug  NaN    90      100  15
# 31                       Attract    Normal  NaN     —      100  15
# 32                   Aura Sphere  Fighting  NaN    80        ∞  20
# 33                    Aura Wheel  Electric  NaN   110      100  10
# 34                   Aurora Beam       Ice  NaN    65      100  20
# 35                   Aurora Veil       Ice  NaN     —        —  20
# 36                    Autotomize     Steel  NaN     —        —  15
# 37                     Avalanche       Ice  NaN    60      100  10
# 38                Baby-Doll Eyes     Fairy  NaN     —      100  30
# 39                     Baddy Bad      Dark  NaN    90      100  15
# 40                Baneful Bunker    Poison  NaN     —        —  10
# 41                       Barrage    Normal  NaN    15       85  20
# 42                       Barrier   Psychic  NaN     —        —  20
# 43                    Baton Pass    Normal  NaN     —        —  40
# 44                    Beak Blast    Flying  NaN   100      100  15
# 45                       Beat Up      Dark  NaN     —      100  30
# 46                 Behemoth Bash     Steel  NaN   100      100   5
# 47                Behemoth Blade     Steel  NaN   100      100   5
# 48                         Belch    Poison  NaN   120       90  10
# 49                    Belly Drum    Normal  NaN     —        —  10
# 50                        Bestow    Normal  NaN     —        —  15
# 51                          Bide    Normal  NaN     —        —  10
# 52                          Bind    Normal  NaN    15       85  20
# 53                          Bite      Dark  NaN    60      100  25
# 54            Black Hole Eclipse      Dark    —     —        —   1
# 55                    Blast Burn      Fire  NaN   150       90   5
# 56                    Blaze Kick      Fire  NaN    85       90  10
# 57                      Blizzard       Ice  NaN   110       70   5
# 58                         Block    Normal  NaN     —        —   5
# 59                    Bloom Doom     Grass    —     —        —   1
# 60                    Blue Flare      Fire  NaN   130       85   5
# 61                    Body Press  Fighting  NaN    80      100  10
# 62                     Body Slam    Normal  NaN    85      100  15
# 63                     Bolt Beak  Electric  NaN    85      100  10
# 64                   Bolt Strike  Electric  NaN   130       85   5
# 65                     Bone Club    Ground  NaN    65       85  20
# 66                     Bone Rush    Ground  NaN    25       90  10
# 67                    Bonemerang    Ground  NaN    50       90  10
# 68                     Boomburst    Normal  NaN   140      100  10
# 69                        Bounce    Flying  NaN    85       85   5
# 70                 Bouncy Bubble     Water  NaN    90      100  15
# 71                   Branch Poke     Grass  NaN    40      100  40
# 72                    Brave Bird    Flying  NaN   120      100  15
# 73                Breaking Swipe    Dragon  NaN    60      100  15
# 74               Breakneck Blitz    Normal    —     —        —   1
# 75                   Brick Break  Fighting  NaN    75      100  15
# 76                         Brine     Water  NaN    65      100  10
# 77                  Brutal Swing      Dark  NaN    60      100  20
# 78                        Bubble     Water  NaN    40      100  30
# 79                   Bubble Beam     Water  NaN    65      100  20
# 80                      Bug Bite       Bug  NaN    60      100  20
# 81                      Bug Buzz       Bug  NaN    90      100  10
# 82                       Bulk Up  Fighting  NaN     —        —  20
# 83                      Bulldoze    Ground  NaN    60      100  20
# 84                  Bullet Punch     Steel  NaN    40      100  30
# 85                   Bullet Seed     Grass  NaN    25      100  30
# 86                       Burn Up      Fire  NaN   130      100   5
# 87                    Buzzy Buzz  Electric  NaN    90      100  15
# 88                     Calm Mind   Psychic  NaN     —        —  20
# 89                    Camouflage    Normal  NaN     —        —  20
# 90                     Captivate    Normal  NaN     —      100  20
# 91                  Catastropika  Electric  NaN   210        —   1
# 92                     Celebrate    Normal  NaN     —        —  40
# 93                        Charge  Electric  NaN     —        —  20
# 94                   Charge Beam  Electric  NaN    50       90  10
# 95                         Charm     Fairy  NaN     —      100  20
# 96                       Chatter    Flying  NaN    65      100  20
# 97                     Chip Away    Normal  NaN    70      100  20
# 98                  Circle Throw  Fighting  NaN    60       90  10
# 99                         Clamp     Water  NaN    35       85  10
# 100              Clanging Scales    Dragon  NaN   110      100   5
# 101              Clangorous Soul    Dragon  NaN     —      100   5
# 102         Clangorous Soulblaze    Dragon  NaN   185        —   1
# 103                   Clear Smog    Poison  NaN    50        —  15
# 104                 Close Combat  Fighting  NaN   120      100   5
# 105                         Coil    Poison  NaN     —        —  20
# 106                  Comet Punch    Normal  NaN    18       85  15
# 107                      Confide    Normal  NaN     —        —  20
# 108                  Confuse Ray     Ghost  NaN     —      100  10
# 109                    Confusion   Psychic  NaN    50      100  25
# 110                    Constrict    Normal  NaN    10      100  35
# 111            Continental Crush      Rock    —     —        —   1
# 112                   Conversion    Normal  NaN     —        —  30
# 113                 Conversion 2    Normal  NaN     —        —  30
# 114                      Copycat    Normal  NaN     —        —  20
# 115                Core Enforcer    Dragon  NaN   100      100  10
# 116              Corkscrew Crash     Steel    —     —        —   1
# 117                 Cosmic Power   Psychic  NaN     —        —  20
# 118                 Cotton Guard     Grass  NaN     —        —  10
# 119                 Cotton Spore     Grass  NaN     —      100  40
# 120                      Counter  Fighting  NaN     —      100  20
# 121                 Court Change    Normal  NaN     —      100  10
# 122                        Covet    Normal  NaN    60      100  25
# 123                   Crabhammer     Water  NaN   100       90  10
# 124                Crafty Shield     Fairy  NaN     —        —  10
# 125                   Cross Chop  Fighting  NaN   100       80   5
# 126                 Cross Poison    Poison  NaN    70      100  20
# 127                       Crunch      Dark  NaN    80      100  15
# 128                   Crush Claw    Normal  NaN    75       95  10
# 129                   Crush Grip    Normal  NaN     —      100   5
# 130                        Curse     Ghost  NaN     —        —  10
# 131                          Cut    Normal  NaN    50       95  30
# 132                   Dark Pulse      Dark  NaN    80      100  15
# 133                    Dark Void      Dark  NaN     —       50  10
# 134               Darkest Lariat      Dark  NaN    85      100  10
# 135               Dazzling Gleam     Fairy  NaN    80      100  10
# 136                     Decorate     Fairy  NaN     —        —  15
# 137                 Defend Order       Bug  NaN     —        —  10
# 138                 Defense Curl    Normal  NaN     —        —  40
# 139                        Defog    Flying  NaN     —        —  15
# 140                 Destiny Bond     Ghost  NaN     —        —   5
# 141                       Detect  Fighting  NaN     —        —   5
# 142            Devastating Drake    Dragon    —     —        —   1
# 143                Diamond Storm      Rock  NaN   100       95   5
# 144                          Dig    Ground  NaN    80      100  10
# 145                      Disable    Normal  NaN     —      100  20
# 146              Disarming Voice     Fairy  NaN    40        ∞  15
# 147                    Discharge  Electric  NaN    80      100  15
# 148                         Dive     Water  NaN    80      100  10
# 149                  Dizzy Punch    Normal  NaN    70      100  10
# 150                  Doom Desire     Steel  NaN   140      100   5
# 151                   Double Hit    Normal  NaN    35       90  10
# 152             Double Iron Bash     Steel  NaN    60      100   5
# 153                  Double Kick  Fighting  NaN    30      100  30
# 154                  Double Slap    Normal  NaN    15       85  10
# 155                  Double Team    Normal  NaN     —        —  15
# 156                  Double-Edge    Normal  NaN   120      100  15
# 157                 Draco Meteor    Dragon  NaN   130       90   5
# 158                Dragon Ascent    Flying  NaN   120      100   5
# 159                Dragon Breath    Dragon  NaN    60      100  20
# 160                  Dragon Claw    Dragon  NaN    80      100  15
# 161                 Dragon Dance    Dragon  NaN     —        —  20
# 162                 Dragon Darts    Dragon  NaN    50      100  10
# 163                Dragon Hammer    Dragon  NaN    90      100  15
# 164                 Dragon Pulse    Dragon  NaN    85      100  10
# 165                  Dragon Rage    Dragon  NaN     —      100  10
# 166                  Dragon Rush    Dragon  NaN   100       75  10
# 167                  Dragon Tail    Dragon  NaN    60       90  10
# 168                  Drain Punch  Fighting  NaN    75      100  10
# 169                Draining Kiss     Fairy  NaN    50      100  10
# 170                  Dream Eater   Psychic  NaN   100      100  15
# 171                   Drill Peck    Flying  NaN    80      100  20
# 172                    Drill Run    Ground  NaN    80       95  10
# 173                 Drum Beating     Grass  NaN    80      100  10
# 174                    Dual Chop    Dragon  NaN    40       90  15
# 175               Dynamax Cannon    Dragon  NaN   100      100   5
# 176                Dynamic Punch  Fighting  NaN   100       50   5
# 177                  Earth Power    Ground  NaN    90      100  10
# 178                   Earthquake    Ground  NaN   100      100  10
# 179                 Echoed Voice    Normal  NaN    40      100  15
# 180                Eerie Impulse  Electric  NaN     —      100  15
# 181                     Egg Bomb    Normal  NaN   100       75  10
# 182             Electric Terrain  Electric  NaN     —        —  10
# 183                    Electrify  Electric  NaN     —        —  20
# 184                 Electro Ball  Electric  NaN     —      100  10
# 185                   Electroweb  Electric  NaN    55       95  15
# 186                      Embargo      Dark  NaN     —      100  15
# 187                        Ember      Fire  NaN    40      100  25
# 188                       Encore    Normal  NaN     —      100   5
# 189                     Endeavor    Normal  NaN     —      100   5
# 190                       Endure    Normal  NaN     —        —  10
# 191                  Energy Ball     Grass  NaN    90      100  10
# 192                  Entrainment    Normal  NaN     —      100  15
# 193                     Eruption      Fire  NaN   150      100   5
# 194                   Eternabeam    Dragon  NaN   160       90   6
# 195                    Explosion    Normal  NaN   250      100   5
# 196                 Extrasensory   Psychic  NaN    80      100  20
# 197             Extreme Evoboost    Normal  NaN     —        —   1
# 198                Extreme Speed    Normal  NaN    80      100   5
# 199                       Facade    Normal  NaN    70      100  20
# 200                   Fairy Lock     Fairy  NaN     —        —  10
# 201                   Fairy Wind     Fairy  NaN    40      100  30
# 202                     Fake Out    Normal  NaN    40      100  10
# 203                   Fake Tears      Dark  NaN     —      100  20
# 204              False Surrender      Dark  NaN    80        ∞  10
# 205                  False Swipe    Normal  NaN    40      100  40
# 206                Feather Dance    Flying  NaN     —      100  15
# 207                        Feint    Normal  NaN    30      100  10
# 208                 Feint Attack      Dark  NaN    60        ∞  20
# 209                 Fell Stinger       Bug  NaN    50      100  25
# 210                  Fiery Dance      Fire  NaN    80      100  10
# 211                 Final Gambit  Fighting  NaN     —      100   5
# 212                   Fire Blast      Fire  NaN   110       85   5
# 213                    Fire Fang      Fire  NaN    65       95  15
# 214                    Fire Lash      Fire  NaN    80      100  15
# 215                  Fire Pledge      Fire  NaN    80      100  10
# 216                   Fire Punch      Fire  NaN    75      100  15
# 217                    Fire Spin      Fire  NaN    35       85  15
# 218             First Impression       Bug  NaN    90      100  10
# 219                Fishious Rend     Water  NaN    85      100  10
# 220                      Fissure    Ground  NaN     —        —   5
# 221                        Flail    Normal  NaN     —      100  15
# 222                  Flame Burst      Fire  NaN    70      100  15
# 223                 Flame Charge      Fire  NaN    50      100  20
# 224                  Flame Wheel      Fire  NaN    60      100  25
# 225                 Flamethrower      Fire  NaN    90      100  15
# 226                  Flare Blitz      Fire  NaN   120      100  15
# 227                        Flash    Normal  NaN     —      100  20
# 228                 Flash Cannon     Steel  NaN    80      100  10
# 229                      Flatter      Dark  NaN     —      100  15
# 230                 Fleur Cannon     Fairy  NaN   130       90   5
# 231                        Fling      Dark  NaN     —      100  10
# 232                  Floaty Fall    Flying  NaN    90       95  15
# 233               Floral Healing     Fairy  NaN     —        —  10
# 234                Flower Shield     Fairy  NaN     —        —  10
# 235                          Fly    Flying  NaN    90       95  15
# 236                 Flying Press  Fighting  NaN   100       95  10
# 237                  Focus Blast  Fighting  NaN   120       70   5
# 238                 Focus Energy    Normal  NaN     —        —  30
# 239                  Focus Punch  Fighting  NaN   150      100  20
# 240                    Follow Me    Normal  NaN     —        —  20
# 241                   Force Palm  Fighting  NaN    60      100  10
# 242                    Foresight    Normal  NaN     —        —  40
# 243               Forest's Curse     Grass  NaN     —      100  20
# 244                    Foul Play      Dark  NaN    95      100  15
# 245                 Freeze Shock       Ice  NaN   140       90   5
# 246                   Freeze-Dry       Ice  NaN    70      100  20
# 247                 Freezy Frost       Ice  NaN    90      100  15
# 248                 Frenzy Plant     Grass  NaN   150       90   5
# 249                 Frost Breath       Ice  NaN    60       90  10
# 250                  Frustration    Normal  NaN     —      100  20
# 251                  Fury Attack    Normal  NaN    15       85  20
# 252                  Fury Cutter       Bug  NaN    40       95  20
# 253                  Fury Swipes    Normal  NaN    18       80  15
# 254                  Fusion Bolt  Electric  NaN   100      100   5
# 255                 Fusion Flare      Fire  NaN   100      100   5
# 256                 Future Sight   Psychic  NaN   120      100  10
# 257               G-Max Befuddle       Bug    —     —        —   —
# 258             G-Max Centiferno      Fire    —     —        —   —
# 259             G-Max Chi Strike  Fighting    —     —        —   —
# 260                 G-Max Cuddle    Normal    —     —        —   —
# 261              G-Max Depletion    Dragon    —     —        —   —
# 262                 G-Max Finale     Fairy    —     —        —   —
# 263             G-Max Foam Burst     Water    —     —        —   —
# 264              G-Max Gold Rush    Normal    —     —        —   —
# 265               G-Max Gravitas   Psychic    —     —        —   —
# 266                G-Max Malodor    Poison    —     —        —   —
# 267               G-Max Meltdown     Steel    —     —        —   —
# 268              G-Max Replenish    Normal    —     —        —   —
# 269              G-Max Resonance       Ice    —     —        —   —
# 270              G-Max Sandblast    Ground    —     —        —   —
# 271                  G-Max Smite     Fairy    —     —        —   —
# 272                 G-Max Snooze      Dark    —     —        —   —
# 273             G-Max Steelsurge     Steel    —     —        —   —
# 274             G-Max Stonesurge     Water    —     —        —   —
# 275             G-Max Stun Shock  Electric    —     —        —   —
# 276              G-Max Sweetness     Grass    —     —        —   —
# 277               G-Max Tartness     Grass    —     —        —   —
# 278                 G-Max Terror     Ghost    —     —        —   —
# 279              G-Max Volcalith      Rock    —     —        —   —
# 280             G-Max Volt Crash  Electric    —     —        —   —
# 281               G-Max Wildfire      Fire    —     —        —   —
# 282              G-Max Wind Rage    Flying    —     —        —   —
# 283                  Gastro Acid    Poison  NaN     —      100  10
# 284                   Gear Grind     Steel  NaN    50       85  15
# 285                      Gear Up     Steel  NaN     —        —  20
# 286            Genesis Supernova   Psychic  NaN   185        —   1
# 287                     Geomancy     Fairy  NaN     —        —  10
# 288                   Giga Drain     Grass  NaN    75      100  10
# 289                  Giga Impact    Normal  NaN   150       90   5
# 290               Gigavolt Havoc  Electric    —     —        —   1
# 291                     Glaciate       Ice  NaN    65       95  10
# 292                        Glare    Normal  NaN     —      100  30
# 293                  Glitzy Glow   Psychic  NaN    90      100  15
# 294                   Grass Knot     Grass  NaN     —      100  20
# 295                 Grass Pledge     Grass  NaN    80      100  10
# 296                Grass Whistle     Grass  NaN     —       55  15
# 297               Grassy Terrain     Grass  NaN     —        —  10
# 298                   Grav Apple     Grass  NaN    80      100  10
# 299                      Gravity   Psychic  NaN     —        —   5
# 300                        Growl    Normal  NaN     —      100  40
# 301                       Growth    Normal  NaN     —        —  40
# 302                       Grudge     Ghost  NaN     —        —   5
# 303                  Guard Split   Psychic  NaN     —        —  10
# 304                   Guard Swap   Psychic  NaN     —        —  10
# 305            Guardian of Alola     Fairy  NaN     —        —   1
# 306                   Guillotine    Normal  NaN     —        —   5
# 307                    Gunk Shot    Poison  NaN   120       80   5
# 308                         Gust    Flying  NaN    40      100  35
# 309                    Gyro Ball     Steel  NaN     —      100   5
# 310                         Hail       Ice  NaN     —        —  10
# 311                   Hammer Arm  Fighting  NaN   100       90  10
# 312                   Happy Hour    Normal  NaN     —        —  30
# 313                       Harden    Normal  NaN     —        —  30
# 314                         Haze       Ice  NaN     —        —  30
# 315                  Head Charge    Normal  NaN   120      100  15
# 316                   Head Smash      Rock  NaN   150       80   5
# 317                     Headbutt    Normal  NaN    70      100  15
# 318                    Heal Bell    Normal  NaN     —        —   5
# 319                   Heal Block   Psychic  NaN     —        —  15
# 320                   Heal Order       Bug  NaN     —        —  10
# 321                   Heal Pulse   Psychic  NaN     —        —  10
# 322                 Healing Wish   Psychic  NaN     —        —  10
# 323                  Heart Stamp   Psychic  NaN    60      100  25
# 324                   Heart Swap   Psychic  NaN     —        —  10
# 325                   Heat Crash      Fire  NaN     —      100  10
# 326                    Heat Wave      Fire  NaN    95       90  10
# 327                   Heavy Slam     Steel  NaN     —      100  10
# 328                 Helping Hand    Normal  NaN     —        —  20
# 329                          Hex     Ghost  NaN    65      100  10
# 330                 Hidden Power    Normal  NaN    60      100  15
# 331              High Horsepower    Ground  NaN    95       95  10
# 332               High Jump Kick  Fighting  NaN   130       90  10
# 333                    Hold Back    Normal  NaN    40      100  40
# 334                   Hold Hands    Normal  NaN     —        —  40
# 335                   Hone Claws      Dark  NaN     —        —  15
# 336                  Horn Attack    Normal  NaN    65      100  25
# 337                   Horn Drill    Normal  NaN     —        —   5
# 338                   Horn Leech     Grass  NaN    75      100  10
# 339                         Howl    Normal  NaN     —        —  40
# 340                    Hurricane    Flying  NaN   110       70  10
# 341                 Hydro Cannon     Water  NaN   150       90   5
# 342                   Hydro Pump     Water  NaN   110       80   5
# 343                 Hydro Vortex     Water    —     —        —   1
# 344                   Hyper Beam    Normal  NaN   150       90   5
# 345                   Hyper Fang    Normal  NaN    80       90  15
# 346                  Hyper Voice    Normal  NaN    90      100  10
# 347              Hyperspace Fury      Dark  NaN   100        ∞   5
# 348              Hyperspace Hole   Psychic  NaN    80        ∞   5
# 349                     Hypnosis   Psychic  NaN     —       60  20
# 350                     Ice Ball       Ice  NaN    30       90  20
# 351                     Ice Beam       Ice  NaN    90      100  10
# 352                     Ice Burn       Ice  NaN   140       90   5
# 353                     Ice Fang       Ice  NaN    65       95  15
# 354                   Ice Hammer       Ice  NaN   100       90  10
# 355                    Ice Punch       Ice  NaN    75      100  15
# 356                    Ice Shard       Ice  NaN    40      100  30
# 357                 Icicle Crash       Ice  NaN    85       90  10
# 358                 Icicle Spear       Ice  NaN    25      100  30
# 359                     Icy Wind       Ice  NaN    55       95  15
# 360                     Imprison   Psychic  NaN     —        —  10
# 361                   Incinerate      Fire  NaN    60      100  15
# 362                      Inferno      Fire  NaN   100       50   5
# 363            Inferno Overdrive      Fire    —     —        —   1
# 364                  Infestation       Bug  NaN    20      100  20
# 365                      Ingrain     Grass  NaN     —        —  20
# 366                     Instruct   Psychic  NaN     —        —  15
# 367                   Ion Deluge  Electric  NaN     —        —  25
# 368                 Iron Defense     Steel  NaN     —        —  15
# 369                    Iron Head     Steel  NaN    80      100  15
# 370                    Iron Tail     Steel  NaN   100       75  15
# 371                     Jaw Lock      Dark  NaN    80      100  10
# 372                     Judgment    Normal  NaN   100      100  10
# 373                    Jump Kick  Fighting  NaN   100       95  10
# 374                  Karate Chop  Fighting  NaN    50      100  25
# 375                      Kinesis   Psychic  NaN     —       80  15
# 376                King's Shield     Steel  NaN     —        —  10
# 377                    Knock Off      Dark  NaN    65      100  20
# 378                 Land's Wrath    Ground  NaN    90      100  10
# 379                  Laser Focus    Normal  NaN     —        —  30
# 380                  Last Resort    Normal  NaN   140      100   5
# 381                   Lava Plume      Fire  NaN    80      100  15
# 382                   Leaf Blade     Grass  NaN    90      100  15
# 383                   Leaf Storm     Grass  NaN   130       90   5
# 384                 Leaf Tornado     Grass  NaN    65       90  10
# 385                      Leafage     Grass  NaN    40      100  40
# 386                   Leech Life       Bug  NaN    80      100  10
# 387                   Leech Seed     Grass  NaN     —       90  10
# 388                         Leer    Normal  NaN     —      100  30
# 389        Let's Snuggle Forever     Fairy  NaN   190        —   1
# 390                         Lick     Ghost  NaN    30      100  30
# 391                     Life Dew     Water  NaN     —        —  10
# 392                Light of Ruin     Fairy  NaN   140       90   5
# 393                 Light Screen   Psychic  NaN     —        —  30
# 394     Light That Burns the Sky   Psychic  NaN   200        —   1
# 395                  Liquidation     Water  NaN    85      100  10
# 396                      Lock-On    Normal  NaN     —        —   5
# 397                  Lovely Kiss    Normal  NaN     —       75  10
# 398                     Low Kick  Fighting  NaN     —      100  20
# 399                    Low Sweep  Fighting  NaN    65      100  20
# 400                  Lucky Chant    Normal  NaN     —        —  30
# 401                  Lunar Dance   Psychic  NaN     —        —  10
# 402                        Lunge       Bug  NaN    80      100  15
# 403                 Luster Purge   Psychic  NaN    70      100   5
# 404                   Mach Punch  Fighting  NaN    40      100  30
# 405                   Magic Coat   Psychic  NaN     —        —  15
# 406                 Magic Powder   Psychic  NaN     —      100  20
# 407                   Magic Room   Psychic  NaN     —        —  10
# 408                 Magical Leaf     Grass  NaN    60        ∞  20
# 409                  Magma Storm      Fire  NaN   100       75   5
# 410                  Magnet Bomb     Steel  NaN    60        ∞  20
# 411                  Magnet Rise  Electric  NaN     —        —  10
# 412                Magnetic Flux  Electric  NaN     —        —  20
# 413                    Magnitude    Ground  NaN     —      100  30
# 414          Malicious Moonsault      Dark  NaN   180        —   1
# 415                    Mat Block  Fighting  NaN     —        —  10
# 416                Max Airstream    Flying    —     —        —   —
# 417                 Max Darkness      Dark    —     —        —   —
# 418                    Max Flare      Fire    —     —        —   —
# 419                Max Flutterby       Bug    —     —        —   —
# 420                   Max Geyser     Water    —     —        —   —
# 421                    Max Guard    Normal    —     —        —   —
# 422                Max Hailstorm       Ice    —     —        —   —
# 423                  Max Knuckle  Fighting    —     —        —   —
# 424                Max Lightning  Electric    —     —        —   —
# 425                Max Mindstorm   Psychic    —     —        —   —
# 426                     Max Ooze    Poison    —     —        —   —
# 427               Max Overgrowth     Grass    —     —        —   —
# 428                 Max Phantasm     Ghost    —     —        —   —
# 429                    Max Quake    Ground    —     —        —   —
# 430                 Max Rockfall      Rock    —     —        —   —
# 431                 Max Starfall     Fairy    —     —        —   —
# 432               Max Steelspike     Steel    —     —        —   —
# 433                   Max Strike    Normal    —     —        —   —
# 434                 Max Wyrmwind    Dragon    —     —        —   —
# 435                     Me First    Normal  NaN     —        —  20
# 436                    Mean Look    Normal  NaN     —        —   5
# 437                     Meditate   Psychic  NaN     —        —  40
# 438                   Mega Drain     Grass  NaN    40      100  15
# 439                    Mega Kick    Normal  NaN   120       75   5
# 440                   Mega Punch    Normal  NaN    80       85  20
# 441                     Megahorn       Bug  NaN   120       85  10
# 442                      Memento      Dark  NaN     —      100  10
# 443  Menacing Moonraze Maelstrom     Ghost  NaN   200        —   1
# 444                  Metal Burst     Steel  NaN     —      100  10
# 445                   Metal Claw     Steel  NaN    50       95  35
# 446                  Metal Sound     Steel  NaN     —       85  40
# 447               Meteor Assault  Fighting  NaN   150      100   5
# 448                  Meteor Mash     Steel  NaN    90       90  10
# 449                    Metronome    Normal  NaN     —        —  10
# 450                   Milk Drink    Normal  NaN     —        —  10
# 451                        Mimic    Normal  NaN     —        —  10
# 452                   Mind Blown      Fire  NaN   150      100   5
# 453                  Mind Reader    Normal  NaN     —        —   5
# 454                     Minimize    Normal  NaN     —        —  10
# 455                  Miracle Eye   Psychic  NaN     —        —  40
# 456                  Mirror Coat   Psychic  NaN     —      100  20
# 457                  Mirror Move    Flying  NaN     —        —  20
# 458                  Mirror Shot     Steel  NaN    65       85  10
# 459                         Mist       Ice  NaN     —        —  30
# 460                    Mist Ball   Psychic  NaN    70      100   5
# 461                Misty Terrain     Fairy  NaN     —        —  10
# 462                    Moonblast     Fairy  NaN    95      100  15
# 463               Moongeist Beam     Ghost  NaN   100      100   5
# 464                    Moonlight     Fairy  NaN     —        —   5
# 465                  Morning Sun    Normal  NaN     —        —   5
# 466                     Mud Bomb    Ground  NaN    65       85  10
# 467                     Mud Shot    Ground  NaN    55       95  15
# 468                    Mud Sport    Ground  NaN     —        —  15
# 469                     Mud-Slap    Ground  NaN    20      100  10
# 470                  Muddy Water     Water  NaN    90       85  10
# 471                 Multi-Attack    Normal  NaN    90      100  10
# 472                Mystical Fire      Fire  NaN    75      100  10
# 473                   Nasty Plot      Dark  NaN     —        —  20
# 474                 Natural Gift    Normal  NaN     —      100  15
# 475                 Nature Power    Normal  NaN     —        —  20
# 476             Nature's Madness     Fairy  NaN     —       90  10
# 477                   Needle Arm     Grass  NaN    60      100  15
# 478       Never-Ending Nightmare     Ghost    —     —        —   1
# 479                   Night Daze      Dark  NaN    85       95  10
# 480                  Night Shade     Ghost  NaN     —      100  15
# 481                  Night Slash      Dark  NaN    70      100  15
# 482                    Nightmare     Ghost  NaN     —      100  15
# 483                   No Retreat  Fighting  NaN     —        —   5
# 484                   Noble Roar    Normal  NaN     —      100  30
# 485                       Nuzzle  Electric  NaN    20      100  20
# 486                Oblivion Wing    Flying  NaN    80      100  10
# 487                     Obstruct      Dark  NaN     —      100  10
# 488             Oceanic Operetta     Water  NaN   195        —   1
# 489                    Octazooka     Water  NaN    65       85  10
# 490                     Octolock  Fighting  NaN     —      100  15
# 491                  Odor Sleuth    Normal  NaN     —        —  40
# 492                 Ominous Wind     Ghost  NaN    60      100   5
# 493                 Origin Pulse     Water  NaN   110       85  10
# 494                      Outrage    Dragon  NaN   120      100  10
# 495                    Overdrive  Electric  NaN    80      100  10
# 496                     Overheat      Fire  NaN   130       90   5
# 497                   Pain Split    Normal  NaN     —        —  20
# 498             Parabolic Charge  Electric  NaN    65      100  20
# 499                 Parting Shot      Dark  NaN     —      100  20
# 500                      Pay Day    Normal  NaN    40      100  20
# 501                      Payback      Dark  NaN    50      100  10
# 502                         Peck    Flying  NaN    35      100  35
# 503                  Perish Song    Normal  NaN     —        —   5
# 504               Petal Blizzard     Grass  NaN    90      100  15
# 505                  Petal Dance     Grass  NaN   120      100  10
# 506                Phantom Force     Ghost  NaN    90      100  10
# 507                Photon Geyser   Psychic  NaN   100      100   5
# 508                   Pika Papow  Electric  NaN     —        ∞  20
# 509                  Pin Missile       Bug  NaN    25       95  20
# 510                 Plasma Fists  Electric  NaN   100      100  15
# 511                    Play Nice    Normal  NaN     —        —  20
# 512                   Play Rough     Fairy  NaN    90       90  10
# 513                        Pluck    Flying  NaN    60      100  20
# 514                  Poison Fang    Poison  NaN    50      100  15
# 515                   Poison Gas    Poison  NaN     —       90  40
# 516                   Poison Jab    Poison  NaN    80      100  20
# 517                Poison Powder    Poison  NaN     —       75  35
# 518                 Poison Sting    Poison  NaN    15      100  35
# 519                  Poison Tail    Poison  NaN    50      100  25
# 520                  Pollen Puff       Bug  NaN    90      100  15
# 521                        Pound    Normal  NaN    40      100  35
# 522                       Powder       Bug  NaN     —      100  20
# 523                  Powder Snow       Ice  NaN    40      100  25
# 524                    Power Gem      Rock  NaN    80      100  20
# 525                  Power Split   Psychic  NaN     —        —  10
# 526                   Power Swap   Psychic  NaN     —        —  10
# 527                  Power Trick   Psychic  NaN     —        —  10
# 528                   Power Trip      Dark  NaN    20      100  10
# 529                   Power Whip     Grass  NaN   120       85  10
# 530               Power-Up Punch  Fighting  NaN    40      100  10
# 531             Precipice Blades    Ground  NaN   120       85  10
# 532                      Present    Normal  NaN     —       90  15
# 533              Prismatic Laser   Psychic  NaN   160      100  10
# 534                      Protect    Normal  NaN     —        —  10
# 535                      Psybeam   Psychic  NaN    65      100  20
# 536                     Psych Up    Normal  NaN     —        —  10
# 537                      Psychic   Psychic  NaN    90      100  10
# 538                Psychic Fangs   Psychic  NaN    85      100  10
# 539              Psychic Terrain   Psychic  NaN     —        —  10
# 540                 Psycho Boost   Psychic  NaN   140       90   5
# 541                   Psycho Cut   Psychic  NaN    70      100  20
# 542                 Psycho Shift   Psychic  NaN     —       90  10
# 543                     Psyshock   Psychic  NaN    80      100  10
# 544                    Psystrike   Psychic  NaN   100      100  10
# 545                      Psywave   Psychic  NaN     —       80  15
# 546          Pulverizing Pancake    Normal  NaN   210        —   1
# 547                   Punishment      Dark  NaN     —      100   5
# 548                       Purify    Poison  NaN     —        —  20
# 549                      Pursuit      Dark  NaN    40      100  20
# 550                    Pyro Ball      Fire  NaN   120       90   5
# 551                        Quash      Dark  NaN     —      100  15
# 552                 Quick Attack    Normal  NaN    40      100  30
# 553                  Quick Guard  Fighting  NaN     —        —  15
# 554                 Quiver Dance       Bug  NaN     —        —  20
# 555                         Rage    Normal  NaN    20      100  20
# 556                  Rage Powder       Bug  NaN     —        —  20
# 557                   Rain Dance     Water  NaN     —        —   5
# 558                   Rapid Spin    Normal  NaN    20      100  40
# 559                   Razor Leaf     Grass  NaN    55       95  25
# 560                  Razor Shell     Water  NaN    75       95  10
# 561                   Razor Wind    Normal  NaN    80      100  10
# 562                      Recover    Normal  NaN     —        —  10
# 563                      Recycle    Normal  NaN     —        —  10
# 564                      Reflect   Psychic  NaN     —        —  20
# 565                 Reflect Type    Normal  NaN     —        —  15
# 566                      Refresh    Normal  NaN     —        —  20
# 567                   Relic Song    Normal  NaN    75      100  10
# 568                         Rest   Psychic  NaN     —        —  10
# 569                    Retaliate    Normal  NaN    70      100   5
# 570                       Return    Normal  NaN     —      100  20
# 571             Revelation Dance    Normal  NaN    90      100  15
# 572                      Revenge  Fighting  NaN    60      100  10
# 573                     Reversal  Fighting  NaN     —      100  15
# 574                         Roar    Normal  NaN     —        —  20
# 575                 Roar of Time    Dragon  NaN   150       90   5
# 576                   Rock Blast      Rock  NaN    25       90  10
# 577                   Rock Climb    Normal  NaN    90       85  20
# 578                  Rock Polish      Rock  NaN     —        —  20
# 579                   Rock Slide      Rock  NaN    75       90  10
# 580                   Rock Smash  Fighting  NaN    40      100  15
# 581                   Rock Throw      Rock  NaN    50       90  15
# 582                    Rock Tomb      Rock  NaN    60       95  15
# 583                 Rock Wrecker      Rock  NaN   150       90   5
# 584                    Role Play   Psychic  NaN     —        —  15
# 585                 Rolling Kick  Fighting  NaN    60       85  15
# 586                      Rollout      Rock  NaN    30       90  20
# 587                        Roost    Flying  NaN     —        —  10
# 588                   Rototiller    Ground  NaN     —        —  10
# 589                        Round    Normal  NaN    60      100  15
# 590                  Sacred Fire      Fire  NaN   100       95   5
# 591                 Sacred Sword  Fighting  NaN    90      100  20
# 592                    Safeguard    Normal  NaN     —        —  25
# 593                  Sand Attack    Ground  NaN     —      100  15
# 594                    Sand Tomb    Ground  NaN    35       85  15
# 595                    Sandstorm      Rock  NaN     —        —  10
# 596                   Sappy Seed     Grass  NaN    90      100  15
# 597              Savage Spin-Out       Bug    —     —        —   1
# 598                        Scald     Water  NaN    80      100  15
# 599                   Scary Face    Normal  NaN     —      100  10
# 600                      Scratch    Normal  NaN    40      100  35
# 601                      Screech    Normal  NaN     —       85  40
# 602                 Searing Shot      Fire  NaN   100      100   5
# 603        Searing Sunraze Smash     Steel  NaN   200        —   1
# 604                 Secret Power    Normal  NaN    70      100  20
# 605                 Secret Sword  Fighting  NaN    85      100  10
# 606                    Seed Bomb     Grass  NaN    80      100  15
# 607                   Seed Flare     Grass  NaN   120       85   5
# 608                 Seismic Toss  Fighting  NaN     —      100  20
# 609                Self-Destruct    Normal  NaN   200      100   5
# 610                  Shadow Ball     Ghost  NaN    80      100  15
# 611                  Shadow Bone     Ghost  NaN    85      100  10
# 612                  Shadow Claw     Ghost  NaN    70      100  15
# 613                 Shadow Force     Ghost  NaN   120      100   5
# 614                 Shadow Punch     Ghost  NaN    60        ∞  20
# 615                 Shadow Sneak     Ghost  NaN    40      100  30
# 616                      Sharpen    Normal  NaN     —        —  30
# 617             Shattered Psyche   Psychic    —     —        —   1
# 618                   Sheer Cold       Ice  NaN     —        —   5
# 619                  Shell Smash    Normal  NaN     —        —  15
# 620                   Shell Trap      Fire  NaN   150      100   5
# 621                   Shift Gear     Steel  NaN     —        —  10
# 622                   Shock Wave  Electric  NaN    60        ∞  20
# 623                     Shore Up    Ground  NaN     —        —  10
# 624                  Signal Beam       Bug  NaN    75      100  15
# 625                  Silver Wind       Bug  NaN    60      100   5
# 626                  Simple Beam    Normal  NaN     —      100  15
# 627                         Sing    Normal  NaN     —       55  15
# 628          Sinister Arrow Raid     Ghost  NaN   180        —   1
# 629                 Sizzly Slide      Fire  NaN    90      100  15
# 630                       Sketch    Normal  NaN     —        —   1
# 631                   Skill Swap   Psychic  NaN     —        —  10
# 632                   Skull Bash    Normal  NaN   130      100  10
# 633                   Sky Attack    Flying  NaN   140       90   5
# 634                     Sky Drop    Flying  NaN    60      100  10
# 635                 Sky Uppercut  Fighting  NaN    85       90  15
# 636                    Slack Off    Normal  NaN     —        —  10
# 637                         Slam    Normal  NaN    80       75  20
# 638                        Slash    Normal  NaN    70      100  20
# 639                 Sleep Powder     Grass  NaN     —       75  15
# 640                   Sleep Talk    Normal  NaN     —        —  10
# 641                       Sludge    Poison  NaN    65      100  20
# 642                  Sludge Bomb    Poison  NaN    90      100  10
# 643                  Sludge Wave    Poison  NaN    95      100  10
# 644                   Smack Down      Rock  NaN    50      100  15
# 645                 Smart Strike     Steel  NaN    70        —  10
# 646               Smelling Salts    Normal  NaN    70      100  10
# 647                         Smog    Poison  NaN    30       70  20
# 648                  Smokescreen    Normal  NaN     —      100  20
# 649                    Snap Trap     Grass  NaN    35      100  15
# 650                        Snarl      Dark  NaN    55       95  15
# 651                       Snatch      Dark  NaN     —        —  10
# 652                   Snipe Shot     Water  NaN    80      100  15
# 653                        Snore    Normal  NaN    50      100  15
# 654                         Soak     Water  NaN     —      100  20
# 655                  Soft-Boiled    Normal  NaN     —        —  10
# 656                   Solar Beam     Grass  NaN   120      100  10
# 657                  Solar Blade     Grass  NaN   125      100  10
# 658                   Sonic Boom    Normal  NaN     —       90  20
# 659  Soul-Stealing 7-Star Strike     Ghost  NaN   195        —   1
# 660                 Spacial Rend    Dragon  NaN   100       95   5
# 661                        Spark  Electric  NaN    65      100  20
# 662               Sparkling Aria     Water  NaN    90      100  10
# 663                Sparkly Swirl     Fairy  NaN    90      100  15
# 664               Spectral Thief     Ghost  NaN    90      100  10
# 665                   Speed Swap   Psychic  NaN     —        —  10
# 666                   Spider Web       Bug  NaN     —        —  10
# 667                 Spike Cannon    Normal  NaN    20      100  15
# 668                       Spikes    Ground  NaN     —        —  20
# 669                 Spiky Shield     Grass  NaN     —        —  10
# 670                 Spirit Break     Fairy  NaN    75      100  15
# 671               Spirit Shackle     Ghost  NaN    80      100  10
# 672                      Spit Up    Normal  NaN     —      100  10
# 673                        Spite     Ghost  NaN     —      100  10
# 674                       Splash    Normal  NaN     —        —  40
# 675       Splintered Stormshards      Rock  NaN   190        —   1
# 676               Splishy Splash     Water  NaN    90      100  15
# 677                        Spore     Grass  NaN     —      100  15
# 678                    Spotlight    Normal  NaN     —        —  15
# 679                 Stealth Rock      Rock  NaN     —        —  20
# 680               Steam Eruption     Water  NaN   110       95   5
# 681                  Steamroller       Bug  NaN    65      100  20
# 682                   Steel Beam     Steel  NaN   140       95   5
# 683                   Steel Wing     Steel  NaN    70       90  25
# ...
# 588         NaN   Raises Attack and Special Attack of Grass-types.    —
# 589        TM48  Power increases if teammates use it in the sam...    —
# 590         NaN                                 May burn opponent.   50
# 591         NaN                   Ignores opponent's stat changes.    —
# 592        TM20  The user's party is protected from status cond...    —
# 593         NaN                        Lowers opponent's Accuracy.    —
# 594         NaN       Traps opponent, damaging them for 4-5 turns.    —
# 595        TM37                   Creates a sandstorm for 5 turns.    —
# 596         NaN                 Drains HP from opponent each turn.  100
# 597         NaN                                   Bug type Z-Move.  NaN
# 598        TM55                                 May burn opponent.   30
# 599         NaN                   Sharply lowers opponent's Speed.    —
# 600         NaN                                                NaN    —
# 601         NaN                 Sharply lowers opponent's Defense.    —
# 602         NaN                                 May burn opponent.   30
# 603         NaN                         Solgaleo-exclusive Z-Move.  NaN
# 604         NaN      Effects of the attack vary with the location.   30
# 605         NaN  Inflicts damage based on the target's Defense,...    —
# 606         NaN                                                NaN    —
# 607         NaN              May lower opponent's Special Defense.   40
# 608         NaN             Inflicts damage equal to user's level.    —
# 609         NaN                                       User faints.    —
# 610        TM30              May lower opponent's Special Defense.   20
# 611         NaN  The user attacks by beating the target with a ...  NaN
# 612        TM65                           High critical hit ratio.    —
# 613         NaN  Disappears on first turn, attacks on second. C...    —
# 614         NaN                  Ignores Accuracy and Evasiveness.    —
# 615         NaN                                User attacks first.    —
# 616         NaN                              Raises user's Attack.    —
# 617         NaN                               Psychic type Z-Move.  NaN
# 618         NaN                            One-Hit-KO, if it hits.    —
# 619         NaN  Sharply raises user's Attack, Special Attack a...    —
# 620         NaN  Deals more damage to opponent if hit by a Phys...  NaN
# 621         NaN     Raises user's Attack and sharply raises Speed.    —
# 622         NaN                  Ignores Accuracy and Evasiveness.    —
# 623         NaN  The user regains up to half of its max HP. It ...  NaN
# 624         NaN                              May confuse opponent.   10
# 625         NaN               May raise all stats of user at once.   10
# 626         NaN                Changes target's ability to Simple.    —
# 627         NaN                            Puts opponent to sleep.  100
# 628         NaN                        Decidueye-exclusive Z-Move.  NaN
# 629         NaN                                Burns the opponent.  NaN
# 630         NaN       Permanently copies the opponent's last move.    —
# 631         NaN        The user swaps Abilities with the opponent.    —
# 632         NaN   Raises Defense on first turn, attacks on second.  100
# 633         NaN  Charges on first turn, attacks on second. May ...   30
# 634        TM58  Takes opponent into the air on first turn, dro...    —
# 635         NaN                Hits the opponent, even during Fly.    —
# 636         NaN                     User recovers half its max HP.    —
# 637         NaN                                                NaN    —
# 638         NaN                           High critical hit ratio.    —
# 639         NaN                            Puts opponent to sleep.    —
# 640        TM88  User performs one of its own moves while sleep...    —
# 641         NaN                               May poison opponent.   30
# 642        TM36                               May poison opponent.   30
# 643        TM34                               May poison opponent.   10
# 644        TM23  Makes Flying-type Pokémon vulnerable to Ground...    —
# 645        TM67  The user stabs the target with a sharp horn. T...  NaN
# 646         NaN  Power doubles if opponent is paralyzed, but cu...    —
# 647         NaN                               May poison opponent.   40
# 648         NaN                        Lowers opponent's Accuracy.    —
# 649         NaN  Snares the target in a snap trap for four to f...  NaN
# 650        TM95                  Lowers opponent's Special Attack.  100
# 651         NaN    Steals the effects of the opponent's next move.    —
# 652         NaN    Ignores moves and abilities that draw in moves.  NaN
# 653         NaN   Can only be used if asleep. May cause flinching.   30
# 654         NaN                Changes the target's type to water.    —
# 655         NaN                     User recovers half its max HP.    —
# 656        TM22          Charges on first turn, attacks on second.    —
# 657         NaN          Charges on first turn, attacks on second.  NaN
# 658         NaN                             Always inflicts 20 HP.    —
# 659         NaN                        Marshadow-exclusive Z-Move.  NaN
# 660         NaN                           High critical hit ratio.    —
# 661         NaN                             May paralyze opponent.   30
# 662         NaN                     Heals the burns of its target.  NaN
# 663         NaN    Cures all status problems in the party Pokémon.  NaN
# 664         NaN  The user hides in the target's shadow, steals ...  NaN
# 665         NaN    The user exchanges Speed stats with the target.  NaN
# 666         NaN                     Opponent cannot escape/switch.    —
# 667         NaN                        Hits 2-5 times in one turn.    —
# 668         NaN      Hurts opponents when they switch into battle.    —
# 669         NaN  Protects the user and inflicts damage on contact.    —
# 670         NaN                  Lowers opponent's Special Attack.  NaN
# 671         NaN          Prevents the opponent from switching out.  NaN
# 672         NaN  Power depends on how many times the user perfo...    —
# 673         NaN             The opponent's last move loses 2-5 PP.    —
# 674         NaN                               Doesn't do ANYTHING.    —
# 675         NaN                         Lycanroc-exclusive Z-Move.  NaN
# 676         NaN                             May paralyze opponent.   30
# 677         NaN                            Puts opponent to sleep.  100
# 678         NaN  The user shines a spotlight on the target so t...  NaN
# 679         NaN            Damages opponent switching into battle.    —
# 680         NaN                                 May burn opponent.   30
# 681         NaN                               May cause flinching.   30
# 682         NaN                          User loses 50% of its HP.  NaN
# 683        TM51                          May raise user's Defense.   10
# 684         NaN  Lowers opponent's Speed when switching into ba...    —
# 685         NaN    Stores energy for use with Spit Up and Swallow.    —
# 686         NaN      Alolan Raichu-exclusive Electric type Z-Move.  NaN
# 687         NaN                               May cause flinching.   30
# 688         NaN  Driven by frustration, the user attacks the ta...  NaN
# 689        TM71                           High critical hit ratio.    —
# 690         NaN  Power increases when user's stats have been ra...    —
# 691         NaN                  Always results in a critical hit.    —
# 692         NaN                              May confuse opponent.  NaN
# 693         NaN                                                NaN    —
# 694         NaN  The user restores its HP by the same amount as...  NaN
# 695         NaN                   Sharply lowers opponent's Speed.    —
# 696         NaN  Only usable when all PP are gone. Hurts the user.    —
# 697         NaN                  Lowers opponent's Special Attack.  100
# 698         NaN  The user eats its held Berry, then sharply rai...  NaN
# 699         NaN                                Paralyzes opponent.    —
# 700         NaN                       User receives recoil damage.    —
# 701        TM90        Uses HP to creates a decoy that takes hits.    —
# 702         NaN                                   Ice type Z-Move.  NaN
# 703         NaN  User attacks first, but only works if opponent...    —
# 704        TM11                        Makes it sunny for 5 turns.    —
# 705         NaN                      Ignores the target's ability.  NaN
# 706         NaN        Always takes off half of the opponent's HP.    —
# 707         NaN                  Lowers user's Attack and Defense.    —
# 708         NaN                                 Confuses opponent.    —
# 709         NaN                                Flying type Z-Move.  NaN
# 710        TM94                         Hits all adjacent Pokémon.    —
# 711        TM87  Opponent becomes confused, but its Attack is s...    —
# 712         NaN  The more times the user has performed Stockpil...    —
# 713         NaN                                 Confuses opponent.    —
# 714         NaN                     Lowers opponent's Evasiveness.    —
# 715         NaN                  Ignores Accuracy and Evasiveness.    —
# 716         NaN                Swaps held items with the opponent.    —
# 717        TM75                      Sharply raises user's Attack.    —
# 718         NaN  Hits any Pokémon that shares a type with the u...    —
# 719         NaN  User recovers HP. Amount varies with the weather.    —
# 720         NaN                                                NaN    —
# 721         NaN          Drastically raises user's Special Attack.    —
# 722         NaN                        Hits 2-5 times in one turn.    —
# 723         NaN                         Lowers opponent's Defense.    —
# 724         NaN                         Doubles Speed for 4 turns.    —
# 725         NaN                       User receives recoil damage.    —
# 726         NaN  Lowers the opponent's Speed and makes them wea...  NaN
# 727        TM12           Opponent can only use moves that attack.    —
# 728         NaN  The user gets teary eyed to make the target lo...  NaN
# 729         NaN  Forces all Pokémon on the field to eat their b...  NaN
# 730         NaN              Type depends on the Drive being held.    —
# 731         NaN                                Ground type Z-Move.  NaN
# 732         NaN                              Confuses all Pokémon.    —
# 733         NaN  Ignores opponent's Evasiveness for three turns...    —
# 734         NaN  Allows user to flee wild battles; also warps p...    —
# 735        TM46                  Also steals opponent's held item.    —
# 736         NaN  Makes Flying-type Pokémon vulnerable to Ground...    —
# 737         NaN                    Opponent cannot flee or switch.    —
# 738         NaN  User attacks for 2-3 turns but then becomes co...    —
# 739         NaN         Prevents use of sound moves for two turns.  NaN
# 740        TM25                             May paralyze opponent.   30
# 741         NaN      May cause flinching and/or paralyze opponent.   10
# 742         NaN                             May paralyze opponent.   10
# 743         NaN                             May paralyze opponent.   10
# 744        TM73                                Paralyzes opponent.  100
# 745        TM24                             May paralyze opponent.   10
# 746         NaN              Lowers opponent's Attack and Defense.    —
# 747         NaN                 Reverses stat changes of opponent.    —
# 748        TM41        Opponent cannot use the same move in a row.    —
# 749        TM06                            Badly poisons opponent.    —
# 750         NaN    Poisons opponents when they switch into battle.    —
# 751         NaN  The user shoots poisonous threads to poison th...  NaN
# 752         NaN  User takes on the form and attacks of the oppo...    —
# 753         NaN             May paralyze, burn or freeze opponent.   20
# 754         NaN                Swaps held items with the opponent.    —
# 755        TM92  Slower Pokémon move first in the turn for 5 tu...    —
# 756         NaN                       Adds Ghost type to opponent.    —
# 757         NaN       Hits thrice in one turn at increasing power.    —
# 758         NaN                          Lowers opponent's Attack.  NaN
# 759         NaN            The lower the PP, the higher the power.    —
# 760         NaN       Hits twice in one turn. May poison opponent.   20
# 761         NaN                                 Fairy type Z-Move.  NaN
# 762         NaN  May cause flinching. Hits Pokémon using Fly/Bo...   20
# 763        TM89     User switches out immediately after attacking.    —
# 764         NaN       User attacks for 3 turns and prevents sleep.    —
# 765         NaN  Lowers user's Defense, Special Defense and Speed.  100
# 766         NaN                                User attacks first.    —
# 767         NaN    Power increases when player's bond is stronger.  NaN
# 768         NaN  Lowers poisoned opponent's Special Attack and ...    —
# 769        TM09  Inflicts double damage if the target is poisoned.    —
# 770         NaN                                                NaN    —
# 771         NaN                                                NaN    —
# 772         NaN  User attacks last, but ignores Accuracy and Ev...    —
# 773        TM72              User must switch out after attacking.    —
# 774         NaN  User receives recoil damage. May paralyze oppo...   10
# 775         NaN  Power doubles if opponent is asleep, but wakes...    —
# 776         NaN                                                NaN    —
# 777         NaN  Added effects appear if preceded by Fire Pledg...    —
# 778         NaN                              May confuse opponent.   20
# 779         NaN                        Hits 2-5 times in one turn.    —
# 780         NaN              Weakens the power of Fire-type moves.    —
# 781         NaN  The higher the user's HP, the higher the damag...    —
# 782        TM98                               May cause flinching.   20
# 783         NaN    Move's power and type changes with the weather.    —
# 784         NaN       Traps opponent, damaging them for 4-5 turns.    —
# 785         NaN  In battles, the opponent switches. In the wild...    —
# 786         NaN  Protects the user's team from multi-target att...    —
# 787        TM93                       User receives recoil damage.    —
# 788        TM61                                    Burns opponent.  100
# 789         NaN                                                NaN    —
# 790         NaN        The user recovers HP in the following turn.    —
# 791         NaN                             Raises user's Defense.    —
# 792         NaN  Swaps every Pokémon's Defense and Special Defe...    —
# 793         NaN                       User receives recoil damage.    —
# 794        TM01           Raises user's Attack and Special Attack.    —
# 795         NaN        Changes the opponent's Ability to Insomnia.    —
# 796         NaN       Traps opponent, damaging them for 4-5 turns.    —
# 797         NaN  The higher the opponent's HP, the higher the d...    —
# 798        TM81                                                NaN    —
# 799         NaN           Puts opponent to sleep in the next turn.    —
# 800         NaN                                Paralyzes opponent.  100
# 801         NaN                               May cause flinching.   20
# 802         NaN  A strong electric blast crashes down on the ta...  NaN
# 803         NaN                           High critical-hit ratio.  NaN

# %% [markdown]
# #### 2. Dealing with missing values

# %%
## Category column did not read in correctly. 
# Tried to read in alt text of image but I just could not make it happen :( 
# Remove it from analysis since it is not needed to answer research question.
moves=moves.drop('Cat.', axis=1)
moves.head()
# Out:
#                           Move      Type Power Accuracy  PP TechMachine  \
# 0  10,000,000 Volt Thunderbolt  Electric   195        —   1         NaN
# 1                       Absorb     Grass    20      100  25         NaN
# 2                   Accelerock      Rock    40      100  20         NaN
# 3                         Acid    Poison    40      100  30         NaN
# 4                   Acid Armor    Poison     —        —  20         NaN
#
#                                              Effect Prob
# 0                         Pikachu-exclusive Z-Move.  NaN
# 1  User recovers half the HP inflicted on opponent.    —
# 2                               User attacks first.  NaN
# 3             May lower opponent's Special Defense.   10
# 4                    Sharply raises user's Defense.    —

# %%
# replace all instances of '—' in Power, Accuracy and PP with zero
moves = moves.replace({'Power':'—', 'Accuracy':'—', 'PP':'—'},0)
print(moves.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 8 columns):
# Move           804 non-null object
# Type           804 non-null object
# Power          804 non-null object
# Accuracy       804 non-null object
# PP             804 non-null object
# TechMachine    100 non-null object
# Effect         773 non-null object
# Prob           627 non-null object
# dtypes: object(8)
# memory usage: 50.4+ KB
# None

# %% [markdown]
# #### 3. Data types conversion

# %%
## Accuracy is shown as an object when it should be a number. Observe a strange character in several observations
print(moves['Accuracy'][9])
# Out:
# ∞

# %%
# convert infinity symbol to infinity numeric
# https://stackoverflow.com/questions/5438745/is-it-possible-to-set-a-number-to-nan-or-infinity
moves['Accuracy'] = moves['Accuracy'].replace({'∞': float('Inf')}, regex=True)
moves.head()
# Out:
#                           Move      Type Power Accuracy  PP TechMachine  \
# 0  10,000,000 Volt Thunderbolt  Electric   195        0   1         NaN
# 1                       Absorb     Grass    20      100  25         NaN
# 2                   Accelerock      Rock    40      100  20         NaN
# 3                         Acid    Poison    40      100  30         NaN
# 4                   Acid Armor    Poison     0        0  20         NaN
#
#                                              Effect Prob
# 0                         Pikachu-exclusive Z-Move.  NaN
# 1  User recovers half the HP inflicted on opponent.    —
# 2                               User attacks first.  NaN
# 3             May lower opponent's Special Defense.   10
# 4                    Sharply raises user's Defense.    —

# %%
# observe data types
print('starting data types:\n', moves.info())
# Probability should be a number as well. Replace '-' with blank
# https://stackoverflow.com/questions/13682044/remove-unwanted-parts-from-strings-in-a-column
moves['Prob'].replace(regex=True,inplace=True,to_replace='—',value='')
# convert prob to numeric
# https://datatofish.com/convert-string-to-float-dataframe/
moves['Prob'] = pd.to_numeric(moves['Prob'], errors = 'coerce')
# observe data types
print('result data types:\n', moves.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 8 columns):
# Move           804 non-null object
# Type           804 non-null object
# Power          804 non-null object
# Accuracy       804 non-null object
# PP             804 non-null object
# TechMachine    100 non-null object
# Effect         773 non-null object
# Prob           627 non-null object
# dtypes: object(8)
# memory usage: 50.4+ KB
# starting data types:
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 8 columns):
# Move           804 non-null object
# Type           804 non-null object
# Power          804 non-null object
# Accuracy       804 non-null object
# PP             804 non-null object
# TechMachine    100 non-null object
# Effect         773 non-null object
# Prob           148 non-null float64
# dtypes: float64(1), object(7)
# memory usage: 50.4+ KB
# result data types:
#  None

# %%
# convert remaining fields to numeric
moves['Power'] = moves['Power'].astype(float)
moves['Accuracy'] = moves['Accuracy'].astype(float)
moves['PP']=moves['PP'].astype(float)
moves['TechMachine']=moves['TechMachine'].astype(str)
moves['Prob']=moves['Prob'].astype(float)
moves.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 8 columns):
# Move           804 non-null object
# Type           804 non-null object
# Power          804 non-null float64
# Accuracy       804 non-null float64
# PP             804 non-null float64
# TechMachine    804 non-null object
# Effect         773 non-null object
# Prob           148 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 50.4+ KB

# %%
# make sure conversion worked
moves.info() # observe data type, should be float64 for Prob
moves['Prob'].mean() # test out mathematical function on converted column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 8 columns):
# Move           804 non-null object
# Type           804 non-null object
# Power          804 non-null float64
# Accuracy       804 non-null float64
# PP             804 non-null float64
# TechMachine    804 non-null object
# Effect         773 non-null object
# Prob           148 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 50.4+ KB
# 38.17567567567568

# %% [markdown]
# ### - Pokemon Tweets Dataset -

# %% [markdown]
# #### 0. Observe Dataset

# %%
# print confirmation
print('Read', len(tweets), 'records from JSON file.\nPreview of first Tweet:')
print(tweets[1])
# Observe that hashtags are stored as nested lists within the entities field
# It also appears that users tweet about more than one pokemon at once. Keep this duplication in mind during analysis
# Out:
# Read 613 records from JSON file.
# Preview of first Tweet:
# {'created_at': 'Mon Dec 02 01:02:49 +0000 2019', 'id': 1201305685209812992, 'id_str': '1201305685209812992', 'text': 'RT @HelloMagMoe: @#精灵宝可梦 : 哦，fushigidane，fushigisou ... Satosh ...\n \n#Anime #Anipoke #Ash #Bulbasaur #Ivysaur #Pokémon\n \nhttps://t.co/nDVw1…', 'truncated': False, 'entities': {'hashtags': [{'text': '精灵宝可梦', 'indices': [18, 24]}, {'text': 'Anime', 'indices': [69, 75]}, {'text': 'Anipoke', 'indices': [76, 84]}, {'text': 'Ash', 'indices': [85, 89]}, {'text': 'Bulbasaur', 'indices': [90, 100]}, {'text': 'Ivysaur', 'indices': [101, 109]}, {'text': 'Pokémon', 'indices': [110, 118]}], 'symbols': [], 'user_mentions': [{'screen_name': 'HelloMagMoe', 'name': 'MAGMOE', 'id': 3383764209, 'id_str': '3383764209', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'et', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 765671863565418496, 'id_str': '765671863565418496', 'name': 'Jonatan Santiago Hdz', 'screen_name': 'jonnhysantihdz', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 33, 'friends_count': 252, 'listed_count': 0, 'created_at': 'Tue Aug 16 22:09:32 +0000 2016', 'favourites_count': 27937, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2605, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1140815118940430336/6Z5q3FXW_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1140815118940430336/6Z5q3FXW_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/765671863565418496/1478995198', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Dec 01 05:10:02 +0000 2019', 'id': 1201005512843616256, 'id_str': '1201005512843616256', 'text': '@#精灵宝可梦 : 哦，fushigidane，fushigisou ... Satosh ...\n \n#Anime #Anipoke #Ash #Bulbasaur #Ivysaur #Pokémon… https://t.co/GiKac7ym4p', 'truncated': True, 'entities': {'hashtags': [{'text': '精灵宝可梦', 'indices': [1, 7]}, {'text': 'Anime', 'indices': [52, 58]}, {'text': 'Anipoke', 'indices': [59, 67]}, {'text': 'Ash', 'indices': [68, 72]}, {'text': 'Bulbasaur', 'indices': [73, 83]}, {'text': 'Ivysaur', 'indices': [84, 92]}, {'text': 'Pokémon', 'indices': [93, 101]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/GiKac7ym4p', 'expanded_url': 'https://twitter.com/i/web/status/1201005512843616256', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [103, 126]}]}, 'metadata': {'iso_language_code': 'et', 'result_type': 'recent'}, 'source': '<a href="http://mag.moe" rel="nofollow">Mag.Moe</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3383764209, 'id_str': '3383764209', 'name': 'MAGMOE', 'screen_name': 'HelloMagMoe', 'location': '', 'description': '#萌 #卖萌', 'url': 'https://t.co/Ei1MU7KusP', 'entities': {'url': {'urls': [{'url': 'https://t.co/Ei1MU7KusP', 'expanded_url': 'http://mag.moe/', 'display_url': 'mag.moe', 'indic ...

# %%
# show a list of keys for a tweet
tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %% [markdown]
# #### 1. Select Features

# %%
# Iterate through tweets and store hashtag text in a list
# create empty hashtag list
hashes = []
# store text of each hashtag, nested within entities | hashtag, in the hashes list
for tweet in tweets:
    txts=tweet['entities']['hashtags']
    for index in range(len(txts)):
        hashes.append(txts[index]['text'])
# print results
print('The following terms were mentioned in a hashtag in our tweets collection.')
for hash in hashes:
    print(hash)
# Out:
# The following terms were mentioned in a hashtag in our tweets collection.
# 精灵宝可梦
# Anime
# Anipoke
# Ash
# Bulbasaur
# Ivysaur
# Pokémon
# Dragonite
# Pokédex
# Pokémon
# PokémonGO
# PurifiedPokémon
# Snorlax
# Venusaur
# pokemon
# pikachu
# snorlax
# squirtle
# charmander
# pokeball
# animelove
# animefans
# bulbasaur
# charmeleon
# pokemon
# trogdor
# copic
# copicmarker
# Pokemon
# Charizard
# pokemon
# pikachu
# snorlax
# squirtle
# charmander
# pokeball
# animelove
# animefans
# bulbasaur
# pokemon
# pikachu
# snorlax
# squirtle
# charmander
# pokeball
# animelove
# animefans
# bulbasaur
# pokeomcollector
# pokemon
# pokemoncards
# pokemontcg
# DrawEveryPokemon
# caterpie
# metapod
# butterfree
# pokemon
# illustration
# nintendo
# DrawEveryPokemon
# caterpie
# metapod
# butterfree
# pokemon
# illustration
# nintendo
# DrawEveryPokemon
# caterpie
# metapod
# butterfree
# pokemon
# illustration
# nintendo
# PCODex
# Pidgey
# PCODex
# Pidgeotto
# ラキューでポケモン
# ラキュー
# ポケモン
# Pokémon
# LaQ
# ピジョット
# Pidgeot
# TeamSkull
# Rattata
# Pokémon
# gottacatchemall
# Fearow
# オニドリル
# ポケモン
# ポケモンAR写真家さんと繋がりたい
# ポケモンGO
# ポケモンGOAR写真
# ポケモンウォッチャー
# GoSnapshot
# PokeDex
# Ekans
# Facts
# Pokemon
# Slytherin
# Orochimaru
# Arbok
# AladV
# pikachu
# pikachuamigurumi
# detallesmagicoscr
# knittingtoys
# knittersofinstagram
# pokemon
# pikachu
# snorlax
# squirtle
# charmander
# pokeball
# animelove
# animefans
# bulbasaur
# pokemon
# pokemonpixelart
# pixelart
# sprite
# pixelartist
# sandshrew
# mousepokemon
# Pokemon
# Sandslash
# shiny
# nidoran
# pokemon
# pokemongo
# art
# fanart
# pokemon
# nidorina
# shinynidoqueen
# shinynidoking
# nidoqueen
# nidoking
# pokemon
# pokemongo
# shiny
# nidoran
# pokemon
# pokemongo
# Inktober
# Pokemon
# Gengar
# Nidorino
# christmas
# pokemon
# OC
# Clefable
# Pokemon
# Vulpix
# art
# Alola
# Alola
# Ninetales
# Pokemon
# Gymleader
# Pokemocracy
# Pokemon
# Jigglypuff
# pokemon
# pokemonfanart
# concretepot
# concrete
# あみぐるみ
# ハンドメイド
# 白くま
# くま
# カップケーキ
# GLOOM
# Foto
# Edited
# InstantaneaDeGo
# Fiesta
# PokemonGo
# SemanasAtras
# Love
# InstaPic
# shehnaz
# Paras
# parasect
# mushrooms
# pokemongo
# photography
# chesnaught
# venonat
# smoochum
# ポケモンGO写真で一言
# ポケモンGO
# ポケットモンスター
# Meowth
# Pokemon
# pokemonSwSh
# Cats
# psyduck
# PokemonGO
# Pokemon
# Ducklett
# Psyduck
# Pokemon
# Rillaboom
# PokemonSwordShield
# Infernape
# Ambipom
# Passimian
# Pokemon
# Rillaboom
# PokemonSwordShield
# Infernape
# Ambipom
# Passimian
# pokemonswordshield
# pokemon
# growlithe
# fire
# doggo
# Pokemon
# Arcanine
# pokemon
# pokemonswsh
# doodles
# poliwhirl
# poliwrath
# DesignerCon2019
# copic
# pokemon
# poliwrath
# abra
# DubaiFerry
# alakazam
# terrakion
# myart
# PokemonSwordShield
# SwordAndShield
# pokemon
# PokkenTournamentDX
# NintendoSwitch
# CloseCombatNJ
# Hype
# Monitors
# Machamp
# Bellsprout
# APokemonADay
# Weepinbell
# APokemonADay
# Cacturne
# Exeggutor
# Victreebel
# Pokemon
# MaxOutMonday
# maxed
# hundo
# tentacool
# tentacruel
# darkrai
# MaxOutMonday
# maxed
# hundo
# tentacool
# tentacruel
# darkrai
# pokemon
# pokemutation
# edj
# edjimenezart
# pikachu
# gengar
# geodude
# pokemon
# dailychallenge
# pixelart
# pixelpokedex
# pokedex
# pokemon
# graveler
# ゴローン
# golone
# golem
# pokemon
# ponyta
# Meltan
# PokemonLetsGo
# Pokemon
# Slowpoke
# Anime
# PokemonGo
# NestMigration
# Magnemite
# Shinycheck
# magneton
# shiny
# pokemongo
# pokemon
# Pokémon
# Doduo
# UnsolvedMysteries
# NewSong
# pokemon
# pokemongo
# pokemonfigure
# pokemonactionfigure
# pokedex
# pokeafc
# pokemontrainer
# pokemoncenter
# pokemonfan
# pokemon
# pokemongo
# pokemonfigure
# pokemonactionfigure
# pokedex
# pokeafc
# pokemontrainer
# pokemoncenter
# pokemonfan
# Pokemon
# PokemonGo
# KantoRegion
# ซีเฉิง
# readAwrite
# Muk
# Mukkuk
# ซีเฉิง
# Pokemon
# Cloyster
# Anime
# pokemoncenter
# pokémon
# gastly
# haunter
# pokémonfit
# ゴース
# ゴースト
# haunter
# Pokemon
# Gengar
# Anime
# pokemon
# yugiho
# crossover
# voiceover
# onix
# blueeyeswhitedragon
# pokemon
# pokemongo
# drowzee
# psychic
# genone
# dark
# galaxy
# cute
# etsy
# smallbusiness
# pokemon
# Festivaldelaamistad
# PokemonGo
# luckypokemon
# shinx
# Electrode
# top10
# edm
# dancemusic
# ポケモンGO写真で一言
# ポケモンGO
# ポケットモンスター
# Cacturne
# Exeggutor
# Victreebel
# Pokemon
# YoshisCraftedWorld
# Cosplay
# Cubone
# Yoshi
# Pokemon
# pokemon
# cubone
# marowak
# hitmonlee
# OG
# thehat
# fedora
# workerbee
# suitup
# dayfive
# PokemonGO
# pokemon
# GO
# purified
# nightmares
# lickitung
# Marill
# Pikablu
# Snubbull
# PokemonSwordandShield
# arbok
# weezing
# Rhydon
# ShimmyTypePokemon
# PokemonSwordShield
# art
# digital
# digitalartwork
# digitalart
# pokemon
# pokemonart
# pokemonedit
# artedit
# edit
# artwork
# tangela
# pokemon
# kangaskhan
# kickstarter
# pokemon
# terrarium
# Lapras
# NavyDay
# Seaking
# Helicopters
# GatewayofIndia
# Mumbai
# Staryu
# white
# boy
# baseball
# pokemon
# pokemoncards
# vans
# skateboard
# NestMigration
# Shinycheck
# Scyther
# pokemongo
# PokemonSwordandShield
# jynx
# Narutoshippuden
# magmar
# pokemon
# PokemonGo
# pinsir
# PokemonGo
# tauros
# desocupada
# Magikarp
# gyarados
# pokemon
# pokemongo
# pokemon
# カイリュー
# カビゴン
# ラプラス
# 捕獲
# dragonite
# lapras
# snorlax
# pokemon
# eevee
# Eeveelution
# Charms
# Eeveelution
# Charms
# Eeveelution
# Charms
# Corsola
# Cyndaquil
# Porygon
# Pokemon
# Omanyte
# Omastar
# Kabuto
# Anime
# Pokemon
# Omanyte
# Omastar
# Kabuto
# Anime
# kabuto
# 天の道を征き総てを司る男
# pokemon
# pokemonpodcast
# pokemontv
# Pokemon
# Nintendo
# GameFreak
# Aerodactyl
# プテラ
# Dracozolt
# パッチラゴン
# Arctozolt
# パッチルドン
# gigantimax
# snorlax
# 松戸駅西口
# フリーザー
# Articuno
# ポケモン
# ポケモンGO
# ポケモンGOAR
# ポケモンGOAR写真
# GOスナップショット
# Pokemon
# shiny
# Zapdos
# shiny
# moltres
# PokemonGO
# pikachu
# pokemon
# keychain
# YellowMonster
# ハクリュー
# Dragonair
# GOsnapshot
# 祝AR勢歓喜のAR写真大会
# ポケモンGO奇跡の一枚
# pokemongo
# pokemon
# カイリュー
# カビゴン
# ラプラス
# 捕獲
# dragonite
# lapras
# snorlax
# MewGulf
# mew
# gulf
# มิวกลัฟ
# Chikorita
# Shiny
# PokemonGo
# Pokemon
# bayleef
# shedinja
# pokemonart
# Thanksgiving
# Typhlosion
# Flygon
# Quilava
# 感謝祭
# バクフーン
# SuperSmashBros
# Jigglypuff
# Typhlosion
# Haunter
# Miniature
# NewProfilePic
# totodile
# pokemon
# pokemon
# croconaw
# riptide
# feraligatr
# pokemon
# artistsontwitter
# Frostymon2019
# pokemon
# sentret
# furret
# snow
# frostymon
# Odemon
# Spinarak
# Pokemon
# crobat
# Pokemon
# chinchou
# lanturn
# johto
# Drilbur
# Pelipper
# Lanturn
# PokemonSwordShield
# NintendoSwitch
# Pokemon
# Bonsly
# Cleffa
# Riolu
# Charizard
# pinata
# fanart
# pichu
# pokemon
# cleffa
# igglybuff
# johto
# togepi
# togetic
# pokemon
# johto
# togepi
# togetic
# pokemon
# johto
# NATUのトークルームとツイーとの前に入れてくれると
# NATUのトークルーム
# NATU
# Pokemon
# fakemon
# pokemonfusion
# pokemonfanart
# xatu
# vespiquen
# SwordAndShield
# flaaffy
# pokemon
# art
# fanart
# Pokemon
# PokemonCenter
# Ampharos
# HarikenFest
# Bellossom
# pokémon
# Marill
# Pikablu
# Snubbull
# Azumarill
# PokemonSwordandShield
# sudowoodo
# ポケモンGO
# PokemonGO
# ニョロトノ
# Politoed
# pokemon
# pokemonart
# art
# digitalart
# hoppip
# procreate
# shiny
# 色違い
# Aipom
# エイパム
# huevember2019
# pokemon
# swadloon
# sunkern
# FDA
# CBD
# advertising
# Greed
# conciouscapitalism
# Shiny
# Yanma
# wooper
# pokemon
# watercolor
# wooper
# sentret
# Eeveelution
# Charms
# crochet
# Hat
# crochethat
# Handmade
# Umbreon
# PokemonGo
# shiny
# murkrow
# Unown
# wynaut
# wobbuffet
# PokemonShield
# pokemon
# PokemonSwordandShield
# girafarig
# pokemon
# gligar
# gliscor
# swordandshieldteam
# pokemon
# pokemonswordshield
# pokemonteam
# Marill
# Pikablu
# Snubbull
# PokemonSwordandShield
# qwilfish
# PokemonSwordAndShield
# Sneasel
# shinypokemon
# letsplay
# Abgeordnetenhaus
# Berlin
# Teddiursa
# AGH
# GOsnapshot
# UrsaMajor
# Ursaring
# Pokemon
# AllHail
# pokemon
# magcargo
# PokemonGOCommunityDay
# piloswine
# pokemongo
# revenge
# solo
# pokemonSwSh
# corsola
# PokemonGo
# Remoraid
# Octillery
# delibird
# pokemon
# pokemongijinka
# pokemoncosplay
# mantine
# PokemonSwordShield
# pokemon
# ArtistOnTwitter
# weavile
# elekid
# skarmory
# Houndour
# Kingdra
# Pokemon
# pokemonfusion
# combusken
# phanpy
# pokemonfanart
# Donphan
# Porygon2
# Stantler
# shinynidoking
# tyrogue
# chesnaught
# venonat
# smoochum
# pokemon
# ArtistOnTwitter
# weavile
# elekid
# skarmory
# pokemongo
# ポケGO
# ポケモン
# GOsnapshot
# Pokemon
# Pokemorph
# Furry
# Miltank
# Pokegirl
# pokemon
# pikachu
# detectivepikachu
# animation
# blissey
# anime
# raikou
# FateGrandOrder
# Suicune
# Entei
# Raikou
# japan
# dbz
# Suicune
# Pokemon
# Pokemon
# Larvitar
# art
# nerd
# tattoo
# inkednerd
# triceramon
# tyranitar
# combomon
# pokemon
# digimon
# pokemonart
# digimonart
# pokemonfanart
# digimonfanart
# dinosaur
# PokemonGo
# Celebi
# pokemon
# treecko
# art
# doodle
# sceptile
# combusken
# Mudkip
# Marshtomp
# ヌマクロー
# day259
# swampert
# Pokemon
# Pokemon
# stickers
# PokemonGO
# Poochyena
# Mightyena
# galarzigzagoon
# veemon
# combomon
# zigzagoon
# pokemon
# digimon
# pokemonart
# digimonart
# pokemonfanart
# digimonfanart
# Zigzagoon
# Linoone
# Obstagoon
# pokemon
# nuzlocke
# omegaruby
# pokemon
# nuzlocke
# omegaruby
# silcoon
# pokemon
# nuzlocke
# omegaruby
# beautifly
# Lotad
# PokemonGo
# LOmbre
# DédeineVolkLeonovitch
# pokemon
# monpoke
# pikachu
# ludicolo
# ポケモン
# モンポケ
# ピカチュウ
# ルンパッパ
# pokémongo
# pokemongo
# ポケモンGO
# GOsnapshot
# Seedot
# タネボー
# 川口市
# 川口西公園
# pokemon
# nuzlocke
# omegaruby
# taillow
# キャモメ
# メノクラゲ
# ポケモンGO
# PokemonGO
# 色違い
# shiny
# Wingull
# Drilbur
# Pelipper
# Lanturn
# PokemonSwordShield
# NintendoSwitch
# Ralts
# Gardevoir
# PokemonEspadaEscudo
# Hatterene
# Gardevoir
# Pokemon
# Ludicolo
# Ducklett
# Surskit
# art
# Masquerain
# pokemon
# pokemonruby
# breloom
# nintendods
# nintendo
# gameboyadvance
# videogames
# nostalgia
# vintage
# ヤルキモノ
# vigoroth
# pokemon
# pokemongo
# ポケモン
# ポケモンGO
# whismur
# pokemon
# pokemon
# pokemonfanart
# losersclub
# pokemon
# itchapter1
# itfanart
# richietozier
# eddiekaspbrak
# chatot
# 個体値98
# ソーナノ
# ポケモンGO
# PokemonGO
# マクノシタ
# Makuhita
# ゴクリン
# Gulpin
# Regigigas
# ShinyPokemon
# PokemonGO
# shiny
# azurill
# 7kegg
# babypokemon
# pokemon
# Festivaldelaamistad
# PokemonGo
# luckypokemon
# shinx
# cofagrigus
# veemon
# skitty
# duskull
# infernape
# scraggy
# larvesta
# sableye
# Pokemon
# pokemon
# mawile
# steel
# fairy
# ARON
# 뉴이스트
# NUEST
# Meditite
# Taillow
# PokemonArt
# PokemonADay
# DailyPokemon
# Pokemon
# FanArt
# DigitalArt
# meditate
# pmd
# sylveon
# gardevoir
# gengar
# medicham
# braixen
# PokemonSwordSheild
# Pokemon
# Manectric
# Spiritomb
# art
# Christmas
# Christmas
# Volbeat
# RoyalArena
# ラウクレ
# Roselia
# 個体値98
# ソーナノ
# ポケモンGO
# PokemonGO
# マクノシタ
# Makuhita
# ゴクリン
# Gulpin
# combomon
# digimon
# pokemon
# digimonfanart
# pokemonfanart
# pokemonsaphire
# pokemon
# PokemonSwordShield
# wailmer
# pokemon
# pokemonfanart
# popplio
# wailord
# filipino
# PokemonSwordShield
# DanielRazon
# shehulk
# DeibisuNoSekai
# KimikoGlenn
# Torkoal
# Pokemon
# PokemonSword
# PokemonShield
# PokemonSwordandShield
# PokemonSwordShield
# Inktober2019
# PokemonGo
# Grumpig
# pokemon
# pokemongo
# pokemongoar
# pokemongoarplus
# statueoflibertymeme
# statueoflibertythen
# statueoflibertynow
# statueoflibertythenandnow
# trapinch
# shinytrapinch
# Trapinch
# Vibrava
# Flygon
# Pokemon
# PokemonSwordShield
# pokemon
# PokemonSwordandShield
# PokemonSwordShield
# grimmsnarl
# toxicitoxicitry
# Cacnea
# PokemonSwordShield
# NintendoSwitch
# Cacturne
# Exeggutor
# Victreebel
# Pokemon
# Pokemon
# Drakloak
# Swablu
# Altaria
# Terrakium
# pokemon
# seviper
# pokemon
# seviper
# eclipse
# Pokémon
# Lunatone
# Solrock
# eclipse
# Pokémon
# Lunatone
# Solrock
# corphish
# pokemon
# splash
# feebas
# Milotic
# Shiny
# PokemonGo
# ShinyHype
# shinycastform
# castform
# illumi
# illumizoldyck
# hisoka
# hisokamorow
# hisokamorou
# hxh
# hunterxhunter
# pokemon
# zoroark
# Allister
# PokemonShieldExclusive
# Nintendo
# Pokémon
# Chimecho
# pokemon
# pokemonart
# absol
# art
# digitalart
# procreate
# wynaut
# wobbuffet
# PokemonShield
# pokemon
# Shield
# Snorunt
# PokemonShield
# shinyhunting
# Pokemon
# Glalie
# Anime
# spheal
# pokemon
# MAPpositivity
# map
# maps
# nomap
# nomaps
# antimap
# Pokemon
# CDMX
# Metro
# bagon
# diable
# eevee
# cute
# pokemon
# salamence
# flareon
# sylveon
# umbreon
# eeveelutions
# PokemonGOCommunityDay
# pokemon
# pokemoncard
# pokemoncardopening
# regigigas
# regice
# registeel
# regirock
# regigigas
# regice
# registeel
# regirock
# combomon
# registeel
# boltmon
# digimon
# pokemon
# digimonart
# pokemonart
# Pokemon
# Latias
# Latios
# Block
# spam
# Pokemon
# Latias
# Latios
# Block
# spam
# Ford
# FocusRS
# FordPerformance
# iPhone
# nitrousblue
# Kyogre
# blue
# ETS
# Titan7
# TeamSFS
# Evasive
# stance
# Gosnapshot
# グラードン
# Groudon
# 関越自動車道高坂SA
# PokemonSwordandShield
# rayquaza
# PokemonGo
# Jirachi
# Pokemon
# PokemonGo
# Lillipup
# Buneary
# Murkrow
# Turtwig
# PokemonGo
# Grotle
# Torterra
# Pokemon
# Torterra
# art
# swordandshield
# monferno
# fuego
# lucha
# pokemonraro
# pokédex
# Infernape
# Pokemon
# Procreate
# OC
# cole
# colewilliams
# diaper
# pamp
# pokemon
# penguin
# piplup
# colepiplup
# pokemon
# pokemonfanart
# popplio
# piplup
# prinplup
# pkmnart
# white
# boy
# baseball
# pokemon
# pokemoncards
# vans
# skateboard
# Mew
# PokemonRanch
# pokemon
# breloom
# bibarel
# krookodile
# PokemonGo
# GOsnapshot
# コロトック
# Kricketune
# 好きなようにGOしよう
# ポケモンAR写真家さんと繋がりたい
# コリンク
# Shinx
# kredit
# Daihatsu
# Terios
# Xenia
# Ayla
# Luxio
# GranMax
# Sirion
# luxray
# pokemon
# mech
# Harmony16
# pokemon
# budew
# animation
# roserade
# snivy
# pokemon
# pokemon
# Festivaldelaamistad
# PokemonGo
# luckypokemon
# shinx
# burmy
# pokemon
# ゲームウィズARコンテスト
# GOsnapshot
# ガーメイル
# Mothim
# 好きなようにGOしよう
# ポケモンGO写真で一言
# Vespiquen
# PokemonGo
# pokemongo
# pachirisu
# Buizel
# art
# drawing
# pokemon
# buizel
# floatzel
# Pokemon
# kawaii
# cherubi
# art
# pokemon
# PokemonEpeeBouclier
# PokemonSwordShield
# トリトドン
# ポケモン
# Gastrodon
# Pokemon
# ポケモンイラスト
# Pokemon
# Rillaboom
# PokemonSwordShield
# Infernape
# Ambipom
# Passimian
# PokemonSwordShield
# Drifloon
# pokemon
# pokemonsword
# pokemonshield
# vanilluxe
# PokemonSwordShield
# Pokemondiamondandpearl
# Pokemon
# sfw
# Furry
# Pokemon
# Lopunny
# gargomon
# mismagius
# PokemonSwordShield
# Corviknight
# Honchkrow
# glameow
# pokemon
# art
# drawing
# pmd
# Pokemon
# Christmas
# stunky
# 807daysofpokemon
# skuntank
# pokemon
# pokemonswordshield
# pokemon
# pokemonswordshield
# Bonsly
# Hundo
# Shundo
# Happiny
# Pokemon
# PokemonADay
# PokedexChallenge
# pokemon
# pokemonfanart
# Spiritomb
# Pokemon
# PokemonADay
# PokedexChallenge
# ポケモンGO
# ポケモンGO写真
# ポケモンAR写真
# pokemongo
# SternAR
# 好きなようにGOしよう
# フカマル
# Garchomp
# Pokemon
# PokemonADay
# PokedexChallenge
# Munchlax
# Pokemon
# PokemonADay
# PokedexChallenge
# Christmas
# pokemon
# riolu
# pokemon
# pokemonpulls
# pokemoncommunity
# ptcgo
# ptcg
# Pokemon
# Pokemookie
# Pokemonmookie
# PokemonSwordShield
# PokemonDiamond
# PokemonPearl
# PokemonPlatinum
# PokemonGo
# Pokemon
# Pokemookie
# Pokemonmookie
# PokemonSwordShield
# PokemonDiamond
# PokemonPearl
# PokemonPlatinum
# PokemonGo
# PokemonSwordShield
# NintendoSwitch
# Skorupi
# Noibat
# Diglett
# croagunk
# PokemonSwordandShield
# Toxicroak
# PokemonSwordShield
# NintendoSwitch
# sunflora
# carnivine
# fusion
# wip
# Finneon
# ケイコウオ
# Pokemon
# GOsnapshot
# PokemonGO
# PokemonGOBR
# Pokenerd
# PokemonPhotography
# PokemonPhoto
# Swampert
# Salamence
# Lumineon
# Stoutland
# PokémonGO
# PokemonGO
# Pokémon
# Pokemon
# PokemonSwordShield
# NintendoSwitch
# shiny
# mantyke
# PokeMeet
# pokemon
# abomasnow
# PokemonSwordShield
# NintendoSwitch
# pokemon
# ArtistOnTwitter
# weavile
# elekid
# skarmory
# 好きなようにgoしよう
# ポケモンGO
# GOsnapshot
# ベロベルト
# lickilicky
# hundo
# electivire
# pokemon
# togekiss
# ポケモンGO
# PokémonGO
# PokemonGOARplus
# PokemonGOAR
# ポケモンAR写真
# GOsnapshot
# メガヤンマ
# Yanmega
# leafeon
# commission
# commissionopen
# ksp
# Eeveelution
# Charms
# pokemon
# gligar
# gliscor
# traditionalart
# pokemon
# pokken
# tekken
# pokkentournament2
# dusknoir
# pokemon
# mech
# そうだ京都行こう
# GOsnapshot
# froslass
# 永観堂
# pokemon
# inteleon
# rotom
# art
# pokemon
# pokemonart
# uxie
# DEX
# Candy
# Mesprit
# Pokémon
# ポケモン
# Azelf
# アグノム
# 3D
# PokemonGO
# TeamValor
# Dialga
# talo
# sortudo
# lucky
# PokémonGo
# TeamValor
# GDCxPokemon
# lanwangji
# lanzhan
# hanguangjun
# Pokemon
# MaxOutMonday
# maxed
# hundo
# tentacool
# tentacruel
# darkrai
# pokecembervdt
# pokecembervdt
# 渋谷
# 忠犬ハチ公
# ビクティニてぃにてぃに
# ビクティニ
# victini
# pokemon
# servine
# snake
# serperier
# snivy
# autumn
# leaves
# pokemon
# servine
# snake
# serperier
# snivy
# autumn
# leaves
# serperior
# pokemon
# pokemon
# froakie
# tepig
# psmd
# Registro
# Pignite
# Salvaje
# PokemonGo
# pokemon
# emboar
# starterpokemon
# samurott
# Scyther
# Patrat
# Grimer
# PokemonGo
# Tranquill
# Watchog
# Rampardos
# Herdier
# PokémonGO
# PokemonGO
# Pokémon
# Pokemon
# Pokemon
# PokemonGo
# Lillipup
# Buneary
# Murkrow
# Turtwig
# Tranquill
# Watchog
# Rampardos
# Herdier
# PokémonGO
# PokemonGO
# Pokémon
# Pokemon
# Swampert
# Salamence
# Lumineon
# Stoutland
# PokémonGO
# PokemonGO
# Pokémon
# Pokemon
# pokemon
# swordandshield
# nickit
# purrloin
# Centiskorch
# Liepard
# Pokemon
# pansage
# tsareena
# Pokemon
# Rillaboom
# PokemonSwordShield
# Infernape
# Ambipom
# Passimian
# Pokemon
# Pansear
# art
# DnD
# Pokemon
# Magic
# Item
# Pansear
# Simisear
# simple
# luckyPanpour
# Panpour
# DnD
# Pokemon
# MagicItem
# Panpour
# Simipour
# simple
# pokemon
# musharna
# DnD
# Pokemon
# MagicItem
# Pidove
# Tranquill
# Unfezant
# stupifying
# vacation
# Dubrovnik
# picture
# pictureperfect
# boats
# relax
# zen
# calm
# tranquill
# Unfezant
# DnD
# Pokemon
# MagicItem
# Blitzle
# Zebstrika
# electrify
# DnD
# Pokemon
# MagicItem
# Roggenrola
# Boldore
# Gigalith
# DnD
# Pokemon
# MagicItem
# Roggenrola
# Boldore
# Gigalith
# DnD
# Pokemon
# MagicItem
# Roggenrola
# Boldore
# Gigalith
# PokemonSwordandShield
# PokemonGO
# woobat
# pokemon
# pokemonswordandshield
# モグリュー
# Drilbur
# pokemon
# pokemongo
# ポケモン
# ポケモンGO
# 好きなポケモン4匹晒すと好みがわかる
# ポケモン
# pokemonart
# イエッサン
# メガタブンネ
# ラティアス
# ニャオニクス
# meowstic
# indeedee
# audino
# latias
# TimBurr
# BillDing
# JimNasium
# RayStrack
# tympole
# PokemonSwordShield
# NintendoSwitch
# Shiny
# Palpitoad
# pokemon
# Electrode
# Ampharos
# Throh
# Cotton
# Heatmor
# Hypno
# art
# rapidash
# sawk
# cinderace
# corviknight
# PokemonSwordShield
# NintendoSwitch
# huevember2019
# pokemon
# swadloon
# sunkern
# Banette
# Scolipede
# Cutiefly
# Gengar
# Pokemon
# PokemonSwordSheild
# cottonee
# eldegoss
# wooloo
# Chandelure
# Sableye
# Whimsicott
# Joltik
# LilPetti
# Linkara
# Pokemon
# Petilil
# Pokemon
# Sandile
# Anime
# krookodile
# pokemon
# fanart
# roughsketch
# doodle
# artist
# pokemon
# PokemonSwordSheild
# darumaka
# PokemonSwordShield
# NintendoSwitch
# Ribombee
# Joltik
# Combee
# Dwebble
# infernape
# scraggy
# larvesta
# sableye
# Pokemon
# pokemon
# pkmn
# scrafty
# digitalart
# pokemonart
# darkfighting
# commission
# シンボラー
# Sigilyph
# pokemon
# clay
# clayart
# pokemongo
# nintendo
# YouTube
# cofagrigus
# veemon
# skitty
# duskull
# J9
# pokesona
# pokemon
# arche
# archeops
# dinopokemon
# dino
# raptor
# birb
# bird
# Garbodor
# PokemonSwordShield
# NintendoSwitch
# illumi
# illumizoldyck
# hisoka
# hisokamorow
# hisokamorou
# hxh
# hunterxhunter
# pokemon
# zoroark
# ribombee
# espeon
# minccino
# pokemon
# pokemonoc
# pokemoncharacter
# espeonoc
# ribombeeoc
# Gothita
# Pokemon
# pokken
# Pokemon
# PokemonSwordShield
# PokemonSwordandShield
# Hop
# Marnie
# Bede
# Sobble
# Morpeko
# Solosis
# PokemonSwordandShield
# PokemonSwordShield
# Bede
# Duosion
# Pokemon
# Ducklett
# Psyduck
# Vanillite
# PokemonSwordShield
# NintendoSwitch
# pokemon
# vanillish
# pokemonshield
# pokemon
# drawing
# pokedex
# digitalart
# vanilluxe
# Deerling
# pokemon
# googlyeyes
# escavalier
# PokemonGO
# Foongus
# suvivorseries
# pokemon
# googlyeyes
# amoonguss
# PokemonSwordShield
# Duskull
# Frillish
# pokemon
# googlyeyes
# jellicent
# pokemon
# googlyeyes
# alomomola
# Pokémon
# PokemonSwordandShield
# pokemon
# pokemontcg
# pokemoncards
# steamseige
# galvantula
# unova
# pokemon
# googlyeyes
# ferroseed
# pokemon
# ferrothorn
# colorpalette
# klink
# Dakar
# HariRaya
# klang
# BeritaSukanCaltex
# johor
# AI
# chomp
# gameday
# beerfestival
# adidas
# nike
# LV
# gucci
# Hate
# Klink
# BanjoKazooieNutsAndBolts
# Nintendo
# Heliolisk
# Galvantula
# Eelektross
# Pokemon
# PlayPokemon
# decktestingwKids
# litwick
# lampent
# chandelure
# pokemon
# pokemongo
# Unova
# litwick
# lampent
# chandelure
# pokemon
# pokemongo
# Unova
# Fortnite
# SaveTheWorld
# Pokemon
# Chandelure
# PS4share
# PokemonSwordShield
# NintendoSwitch
# shiny
# axew
# Shinyaxew
# huevember
# pokemon
# stantler
# fraxure
# Axew
# cubchoo
# pokemon
# PokemonSwordSheild
# pangoro
# beartic
# stunfisk
# pokemon
# pokemonswordshield
# galar
# pokeball
# digitaldrawing
# digital_art
# digitalart
# pokemon
# gallade
# mienfoo
# digitalart
# draw
# drawing
# mienshao
# pokemon
# PokemonSwordShield
# golett
# pokemon
# PokemonSwordandShield
# cinderace
# golurk
# jangmo
# lucario
# anime
# oc
# pokemonswordshield
# nintendoswitch
# pawniard
# bisharp
# pokemonswordshield
# nintendoswitch
# pawniard
# bisharp
# Pokemon
# Bouffalant
# art
# Gothita
# Braviary
# RedBasculin
# PokemonSwordShield
# NintendoSwitch
# vullaby
# pokemon
# Electrode
# Ampharos
# Throh
# Cotton
# Heatmor
# Hypno
# art
# Reba
# Durant
# pokemon
# trainersona
# gymleadersona
# deino
# solochi
# zweilous
# raichu
# pokefusion
# pokemon
# ポケモン剣盾
# サザンドラ
# ギルガルド
# Hydreigon
# Aegislash
# infernape
# scraggy
# larvesta
# sableye
# Pokemon
# Terrakion
# ExpassGym
# Boosted
# Potenciado
# pokemon
# pokemonblack
# pokepark
# reshiram
# reshirampokemon
# dragon
# drawing
# draw
# lol
# pokemon
# pokemonswordshield
# kyurem
# Genesect
# Gboost
# Pokemon
# PokemonSS
# VGC2020
# SwordAndShield
# myart
# art
# draw
# drawing
# pokemon
# pokemonx
# pokemony
# pokemongo
# chesnaught
# chespin
# myart
# art
# draw
# drawing
# pokemon
# pokemonx
# pokemony
# pokemongo
# chesnaught
# chespin
# chesnaught
# venonat
# smoochum
# BritEve
# Britney
# Braixen
# Eve
# Eevee
# Pokémon
# Nintendo
# delphox
# braixen
# Pokemon
# Froakie
# Anime
# frokie
# frogadier
# pokemonfanart
# animedallas
# Commission
# incineroar
# greninja
# sketch
# mud
# pond
# Bunnelby
# Scorbunny
# PokemonSwordShield
# NintendoSwitch
# Diggersby
# PokemonSwordShield
# NintendoSwitch
# fletchling
# pokemon
# talonflame
# bringbackthenationaldex
# dexit
# Pokemon
# Litleo
# Anime
# beverlymarsh
# itchapter2
# Inktober
# Inktober2019
# Pokémon
# AZ
# Floette
# Florges
# Pokemon
# pokemon
# pokemonfanart
# skiddo
# gogoat
# pancham
# PokemonSwordSheild
# pangoro
# beartic
# pokemon
# dragonair
# furfrou
# Espurr
# PokemonSwordShield
# NintendoSwitch
# suprisetradesunday
# pokemon
# honedge
# spritzee
# Fanart
# PokemonEpeeBouclier
# PokemonSwordShield
# Aromatisse
# pkmn
# kuhnpuff
# slurpuff
# furryart
# fatfur
# belly
# pokemon
# inkay
# splatoon
# nintendo
# crossover
# inkling
# borrasca
# pluges
# Pokemon
# Dragalge
# art
# WIP
# helioptile
# Heliolisk
# Galvantula
# Eelektross
# Pokemon
# pokemon
# pokemonfanart
# tyrunt
# balgoras
# aceocard
# kakaokarte
# copicmarkers
# copics
# Sylveon
# PokemonSwordShield
# NintendoSwitch
# pinlucha
# pincurchin
# hawlucha
# PokemonSwordShield
# NintendoSwitch
# june
# erisolsprite
# shera
# dedenne
# carbink
# pokemon
# goodra
# phantump
# shinyphantump
# pokemon
# ShinyPokemon
# traditionalart
# Bergmite
# Avalugg
# PokemonSwordShield
# NintendoSwitch
# Pokemon
# avalugg
# TeslaCyberTruck
# noibat
# absol
# pokemon
# artistsontwitter
# pokemon
# pokemonoc
# noivern
# Xerneas
# yveltal
# gijinka
# diancie
# pokemon
# artistsontwitter
# Pokemon
# Volcanion
# art

# %% [markdown]
# #### 3. Filter Results

# %% [markdown]
# There are many other hashtags besides just our pokemon names. This makes sense, but we will need to narrow it down to just our population of interest.

# %%
# Store Pokemon names in a list
# create empty list
name_list = []
# iterate through list of Pokemon and store names
for index, row in df.iterrows():
    name_list.append(row['Name'])

# confirm that all records were read in correctly
len(name_list)
# print confirmation
print('Stored', len(name_list), "pokemon names in a list.")
# Out:
# Stored 800 pokemon names in a list.

# %%
## Since Mega Pokemon have names with an abnormal format, and are varients of other Pokemon names,
# our query filtered out these Pokemon added hashtag to pokemon name to use as search term

# narrow down our criteria further. 
# create list of pokemon names that have no variations (i.e. types or forms) without hashtags
plain_name=[]
exclude_name = []
for name in name_list:
    name.strip()  ## Remove extraneous white space
    if ' ' in name:  # do not include names with spaces since these cannot be tweeted verbatim (tweets do not allow spaces)
        exclude_name.append(name)
        continue
    plain_name.append(name)
# observe head of resulting list
exclude_name[:5]
print('The following {:d} Pokemon will be removed from the dataset:'.format(len(exclude_name)))
for name in exclude_name:
    print(name)
# Out:
# The following 95 Pokemon will be removed from the dataset:
# VenusaurMega Venusaur
# CharizardMega Charizard X
# CharizardMega Charizard Y
# BlastoiseMega Blastoise
# BeedrillMega Beedrill
# PidgeotMega Pidgeot
# AlakazamMega Alakazam
# SlowbroMega Slowbro
# GengarMega Gengar
# KangaskhanMega Kangaskhan
# Mr. Mime
# PinsirMega Pinsir
# GyaradosMega Gyarados
# AerodactylMega Aerodactyl
# MewtwoMega Mewtwo X
# MewtwoMega Mewtwo Y
# AmpharosMega Ampharos
# SteelixMega Steelix
# ScizorMega Scizor
# HeracrossMega Heracross
# HoundoomMega Houndoom
# TyranitarMega Tyranitar
# SceptileMega Sceptile
# BlazikenMega Blaziken
# SwampertMega Swampert
# GardevoirMega Gardevoir
# SableyeMega Sableye
# MawileMega Mawile
# AggronMega Aggron
# MedichamMega Medicham
# ManectricMega Manectric
# SharpedoMega Sharpedo
# CameruptMega Camerupt
# AltariaMega Altaria
# BanetteMega Banette
# AbsolMega Absol
# GlalieMega Glalie
# SalamenceMega Salamence
# MetagrossMega Metagross
# LatiasMega Latias
# LatiosMega Latios
# KyogrePrimal Kyogre
# GroudonPrimal Groudon
# RayquazaMega Rayquaza
# DeoxysNormal Forme
# DeoxysAttack Forme
# DeoxysDefense Forme
# DeoxysSpeed Forme
# WormadamPlant Cloak
# WormadamSandy Cloak
# WormadamTrash Cloak
# LopunnyMega Lopunny
# Mime Jr.
# GarchompMega Garchomp
# LucarioMega Lucario
# AbomasnowMega Abomasnow
# GalladeMega Gallade
# RotomHeat Rotom
# RotomWash Rotom
# RotomFrost Rotom
# RotomFan Rotom
# RotomMow Rotom
# GiratinaAltered Forme
# GiratinaOrigin Forme
# ShayminLand Forme
# ShayminSky Forme
# AudinoMega Audino
# DarmanitanStandard Mode
# DarmanitanZen Mode
# TornadusIncarnate Forme
# TornadusTherian Forme
# ThundurusIncarnate Forme
# ThundurusTherian Forme
# LandorusIncarnate Forme
# LandorusTherian Forme
# KyuremBlack Kyurem
# KyuremWhite Kyurem
# KeldeoOrdinary Forme
# KeldeoResolute Forme
# MeloettaAria Forme
# MeloettaPirouette Forme
# AegislashBlade Forme
# AegislashShield Forme
# PumpkabooAverage Size
# PumpkabooSmall Size
# PumpkabooLarge Size
# PumpkabooSuper Size
# GourgeistAverage Size
# GourgeistSmall Size
# GourgeistLarge Size
# GourgeistSuper Size
# Zygarde50% Forme
# DiancieMega Diancie
# HoopaHoopa Confined
# HoopaHoopa Unbound

# %%
# Store names of pokemon that were referenced in a tweet and are in our list of Pokemon
hash_name = []
for hash in hashes:
    if hash in plain_name:
        hash_name.append(hash)
print(len(hash_name), 'hashtags reference Pokemon named in original list of Pokemon')
# Out:
# 318 hashtags reference Pokemon named in original list of Pokemon

# %%
## Sort through our original list of pokemon and see who is included in the tweets and who is not
included = []
missing = []
for poke in plain_name:    # iterate through our original list of non-Mega pokemon
    if poke in hash_name:   # if a pokemon from original list is included in list of hashtags, add it to "included" list
        if poke in included:  # de-duplicate: if pokemon name already included in list, do not add it again
            continue
        included.append(poke) # 
    else:
        if poke in missing:   # de-duplicate: if pokemon name already included in list, do not add it again
            continue
        missing.append(poke)  # if a pokemon from original list is NOT included in list of hashtags, add it to "missing" list

# print summary statements
print(len(included), 'pokemon have been tweeted about.')
print(len(missing), 'pokemon have not been tweeted about.')
# Out:
# 238 pokemon have been tweeted about.
# 467 pokemon have not been tweeted about.

# %%
# create dictionary to count the number of times relevant Pokemon have been referenced in tweets
dict = {}
for poke in hash_name:
    if poke in dict:
        dict[poke] += 1
    else:
        dict[poke]=1
print (sorted(dict.items(), key = lambda item: item[1], reverse = True))
# Out:
# [('Infernape', 5), ('Ambipom', 4), ('Gengar', 3), ('Ducklett', 3), ('Cacturne', 3), ('Exeggutor', 3), ('Victreebel', 3), ('Electrode', 3), ('Marill', 3), ('Snubbull', 3), ('Drilbur', 3), ('Ampharos', 3), ('Tranquill', 3), ('Roggenrola', 3), ('Boldore', 3), ('Gigalith', 3), ('Charizard', 2), ('Jigglypuff', 2), ('Psyduck', 2), ('Scyther', 2), ('Omanyte', 2), ('Omastar', 2), ('Kabuto', 2), ('Typhlosion', 2), ('Flygon', 2), ('Pelipper', 2), ('Lanturn', 2), ('Bonsly', 2), ('Suicune', 2), ('Gardevoir', 2), ('Makuhita', 2), ('Gulpin', 2), ('Spiritomb', 2), ('Lunatone', 2), ('Solrock', 2), ('Latias', 2), ('Latios', 2), ('Lillipup', 2), ('Buneary', 2), ('Murkrow', 2), ('Turtwig', 2), ('Torterra', 2), ('Swampert', 2), ('Salamence', 2), ('Lumineon', 2), ('Stoutland', 2), ('Watchog', 2), ('Rampardos', 2), ('Herdier', 2), ('Pansear', 2), ('Panpour', 2), ('Unfezant', 2), ('Throh', 2), ('Heatmor', 2), ('Hypno', 2), ('Chandelure', 2), ('Joltik', 2), ('Gothita', 2), ('Heliolisk', 2), ('Galvantula', 2), ('Eelektross', 2), ('Bulbasaur', 1), ('Ivysaur', 1), ('Dragonite', 1), ('Snorlax', 1), ('Venusaur', 1), ('Pidgey', 1), ('Pidgeotto', 1), ('Pidgeot', 1), ('Rattata', 1), ('Fearow', 1), ('Ekans', 1), ('Arbok', 1), ('Sandslash', 1), ('Nidorino', 1), ('Clefable', 1), ('Vulpix', 1), ('Ninetales', 1), ('Paras', 1), ('Meowth', 1), ('Arcanine', 1), ('Machamp', 1), ('Bellsprout', 1), ('Weepinbell', 1), ('Slowpoke', 1), ('Magnemite', 1), ('Doduo', 1), ('Muk', 1), ('Cloyster', 1), ('Cubone', 1), ('Rhydon', 1), ('Lapras', 1), ('Seaking', 1), ('Staryu', 1), ('Magikarp', 1), ('Corsola', 1), ('Cyndaquil', 1), ('Porygon', 1), ('Aerodactyl', 1), ('Articuno', 1), ('Zapdos', 1), ('Dragonair', 1), ('Chikorita', 1), ('Quilava', 1), ('Haunter', 1), ('Spinarak', 1), ('Cleffa', 1), ('Riolu', 1), ('Bellossom', 1), ('Azumarill', 1), ('Politoed', 1), ('Aipom', 1), ('Yanma', 1), ('Umbreon', 1), ('Unown', 1), ('Sneasel', 1), ('Teddiursa', 1), ('Ursaring', 1), ('Remoraid', 1), ('Octillery', 1), ('Houndour', 1), ('Kingdra', 1), ('Donphan', 1), ('Porygon2', 1), ('Stantler', 1), ('Miltank', 1), ('Entei', 1), ('Raikou', 1), ('Larvitar', 1), ('Celebi', 1), ('Mudkip', 1), ('Marshtomp', 1), ('Poochyena', 1), ('Mightyena', 1), ('Zigzagoon', 1), ('Linoone', 1), ('Lotad', 1), ('Seedot', 1), ('Wingull', 1), ('Ralts', 1), ('Ludicolo', 1), ('Surskit', 1), ('Masquerain', 1), ('Regigigas', 1), ('Meditite', 1), ('Taillow', 1), ('Manectric', 1), ('Volbeat', 1), ('Roselia', 1), ('Torkoal', 1), ('Grumpig', 1), ('Trapinch', 1), ('Vibrava', 1), ('Cacnea', 1), ('Swablu', 1), ('Altaria', 1), ('Milotic', 1), ('Chimecho', 1), ('Snorunt', 1), ('Glalie', 1), ('Kyogre', 1), ('Groudon', 1), ('Jirachi', 1), ('Grotle', 1), ('Mew', 1), ('Kricketune', 1), ('Shinx', 1), ('Luxio', 1), ('Mothim', 1), ('Vespiquen', 1), ('Buizel', 1), ('Gastrodon', 1), ('Drifloon', 1), ('Lopunny', 1), ('Honchkrow', 1), ('Happiny', 1), ('Garchomp', 1), ('Munchlax', 1), ('Skorupi', 1), ('Noibat', 1), ('Diglett', 1), ('Toxicroak', 1), ('Finneon', 1), ('Yanmega', 1), ('Mesprit', 1), ('Azelf', 1), ('Dialga', 1), ('Pignite', 1), ('Patrat', 1), ('Grimer', 1), ('Liepard', 1), ('Simisear', 1), ('Simipour', 1), ('Pidove', 1), ('Blitzle', 1), ('Zebstrika', 1), ('Palpitoad', 1), ('Banette', 1), ('Scolipede', 1), ('Sableye', 1), ('Whimsicott', 1), ('Petilil', 1), ('Sandile', 1), ('Combee', 1), ('Dwebble', 1), ('Sigilyph', 1), ('Garbodor', 1), ('Solosis', 1), ('Duosion', 1), ('Vanillite', 1), ('Deerling', 1), ('Foongus', 1), ('Duskull', 1), ('Frillish', 1), ('Klink', 1), ('Axew', 1), ('Bouffalant', 1), ('Braviary', 1), ('Durant', 1), ('Hydreigon', 1), ('Terrakion', 1), ('Genesect', 1), ('Braixen', 1), ('Eevee', 1), ('Froakie', 1), ('Bunnelby', 1), ('Diggersby', 1), ('Litleo', 1), ('Floette', 1), ('Florges', 1), ('Espurr', 1), ('Aromatisse', 1), ('Dragalge', 1), ('Sylveon', 1), ('Bergmite', 1), ('Avalugg', 1), ('Xerneas', 1), ('Volcanion', 1)]

# %%
# observe list of Popular Pokemon
print('Popular Pokemon\nThe following Pokemon were tweeted about in the last 7 days:\n')
for pokemon in included:
    print(pokemon)
# observe list of unpopular pokemon
print('\nUnpopularPokemon\nThe following Pokemon were NOT tweeted about in the last 7 days:\n')
for pokemon in missing: 
    print(pokemon)
# Out:
# Popular Pokemon
# The following Pokemon were tweeted about in the last 7 days:
#
# Bulbasaur
# Ivysaur
# Venusaur
# Charizard
# Pidgey
# Pidgeotto
# Pidgeot
# Rattata
# Fearow
# Ekans
# Arbok
# Sandslash
# Nidorino
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Paras
# Diglett
# Meowth
# Psyduck
# Arcanine
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Slowpoke
# Magnemite
# Doduo
# Grimer
# Muk
# Cloyster
# Haunter
# Gengar
# Hypno
# Electrode
# Exeggutor
# Cubone
# Rhydon
# Seaking
# Staryu
# Scyther
# Magikarp
# Lapras
# Eevee
# Porygon
# Omanyte
# Omastar
# Kabuto
# Aerodactyl
# Snorlax
# Articuno
# Zapdos
# Dragonair
# Dragonite
# Mew
# Chikorita
# Cyndaquil
# Quilava
# Typhlosion
# Spinarak
# Lanturn
# Cleffa
# Ampharos
# Bellossom
# Marill
# Azumarill
# Politoed
# Aipom
# Yanma
# Umbreon
# Murkrow
# Unown
# Snubbull
# Sneasel
# Teddiursa
# Ursaring
# Corsola
# Remoraid
# Octillery
# Houndour
# Kingdra
# Donphan
# Porygon2
# Stantler
# Miltank
# Raikou
# Entei
# Suicune
# Larvitar
# Celebi
# Mudkip
# Marshtomp
# Swampert
# Poochyena
# Mightyena
# Zigzagoon
# Linoone
# Lotad
# Ludicolo
# Seedot
# Taillow
# Wingull
# Pelipper
# Ralts
# Gardevoir
# Surskit
# Masquerain
# Makuhita
# Sableye
# Meditite
# Manectric
# Volbeat
# Roselia
# Gulpin
# Torkoal
# Grumpig
# Trapinch
# Vibrava
# Flygon
# Cacnea
# Cacturne
# Swablu
# Altaria
# Lunatone
# Solrock
# Milotic
# Banette
# Duskull
# Chimecho
# Snorunt
# Glalie
# Salamence
# Latias
# Latios
# Kyogre
# Groudon
# Jirachi
# Turtwig
# Grotle
# Torterra
# Infernape
# Kricketune
# Shinx
# Luxio
# Rampardos
# Mothim
# Combee
# Vespiquen
# Buizel
# Gastrodon
# Ambipom
# Drifloon
# Buneary
# Lopunny
# Honchkrow
# Bonsly
# Happiny
# Spiritomb
# Garchomp
# Munchlax
# Riolu
# Skorupi
# Toxicroak
# Finneon
# Lumineon
# Yanmega
# Mesprit
# Azelf
# Dialga
# Regigigas
# Pignite
# Patrat
# Watchog
# Lillipup
# Herdier
# Stoutland
# Liepard
# Pansear
# Simisear
# Panpour
# Simipour
# Pidove
# Tranquill
# Unfezant
# Blitzle
# Zebstrika
# Roggenrola
# Boldore
# Gigalith
# Drilbur
# Palpitoad
# Throh
# Scolipede
# Whimsicott
# Petilil
# Sandile
# Dwebble
# Sigilyph
# Garbodor
# Gothita
# Solosis
# Duosion
# Ducklett
# Vanillite
# Deerling
# Foongus
# Frillish
# Joltik
# Galvantula
# Klink
# Eelektross
# Chandelure
# Axew
# Bouffalant
# Braviary
# Heatmor
# Durant
# Hydreigon
# Terrakion
# Genesect
# Braixen
# Froakie
# Bunnelby
# Diggersby
# Litleo
# Floette
# Florges
# Espurr
# Aromatisse
# Dragalge
# Heliolisk
# Sylveon
# Bergmite
# Avalugg
# Noibat
# Xerneas
# Volcanion
#
# UnpopularPokemon
# The following Pokemon were NOT tweeted about in the last 7 days:
#
# Charmander
# Charmeleon
# Squirtle
# Wartortle
# Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# Raticate
# Spearow
# Pikachu
# Raichu
# Sandshrew
# Nidoran♀
# Nidorina
# Nidoqueen
# Nidoran♂
# Nidoking
# Clefairy
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Parasect
# Venonat
# Venomoth
# Dugtrio
# Persian
# Golduck
# Mankey
# Primeape
# Growlithe
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# Machop
# Machoke
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# Ponyta
# Rapidash
# Slowbro
# Magneton
# Farfetch'd
# Dodrio
# Seel
# Dewgong
# Shellder
# Gastly
# Onix
# Drowzee
# Krabby
# Kingler
# Voltorb
# Exeggcute
# Marowak
# Hitmonlee
# Hitmonchan
# Lickitung
# Koffing
# Weezing
# Rhyhorn
# Chansey
# Tangela
# Kangaskhan
# Horsea
# Seadra
# Goldeen
# Starmie
# Jynx
# Electabuzz
# Magmar
# Pinsir
# Tauros
# Gyarados
# Ditto
# Vaporeon
# Jolteon
# Flareon
# Kabutops
# Moltres
# Dratini
# Mewtwo
# Bayleef
# Meganium
# Totodile
# Croconaw
# Feraligatr
# Sentret
# Furret
# Hoothoot
# Noctowl
# Ledyba
# Ledian
# Ariados
# Crobat
# Chinchou
# Pichu
# Igglybuff
# Togepi
# Togetic
# Natu
# Xatu
# Mareep
# Flaaffy
# Sudowoodo
# Hoppip
# Skiploom
# Jumpluff
# Sunkern
# Sunflora
# Wooper
# Quagsire
# Espeon
# Slowking
# Misdreavus
# Wobbuffet
# Girafarig
# Pineco
# Forretress
# Dunsparce
# Gligar
# Steelix
# Granbull
# Qwilfish
# Scizor
# Shuckle
# Heracross
# Slugma
# Magcargo
# Swinub
# Piloswine
# Delibird
# Mantine
# Skarmory
# Houndoom
# Phanpy
# Smeargle
# Tyrogue
# Hitmontop
# Smoochum
# Elekid
# Magby
# Blissey
# Pupitar
# Tyranitar
# Lugia
# Ho-oh
# Treecko
# Grovyle
# Sceptile
# Torchic
# Combusken
# Blaziken
# Wurmple
# Silcoon
# Beautifly
# Cascoon
# Dustox
# Lombre
# Nuzleaf
# Shiftry
# Swellow
# Kirlia
# Shroomish
# Breloom
# Slakoth
# Vigoroth
# Slaking
# Nincada
# Ninjask
# Shedinja
# Whismur
# Loudred
# Exploud
# Hariyama
# Azurill
# Nosepass
# Skitty
# Delcatty
# Mawile
# Aron
# Lairon
# Aggron
# Medicham
# Electrike
# Plusle
# Minun
# Illumise
# Swalot
# Carvanha
# Sharpedo
# Wailmer
# Wailord
# Numel
# Camerupt
# Spoink
# Spinda
# Zangoose
# Seviper
# Barboach
# Whiscash
# Corphish
# Crawdaunt
# Baltoy
# Claydol
# Lileep
# Cradily
# Anorith
# Armaldo
# Feebas
# Castform
# Kecleon
# Shuppet
# Dusclops
# Tropius
# Absol
# Wynaut
# Spheal
# Sealeo
# Walrein
# Clamperl
# Huntail
# Gorebyss
# Relicanth
# Luvdisc
# Bagon
# Shelgon
# Beldum
# Metang
# Metagross
# Regirock
# Regice
# Registeel
# Rayquaza
# Chimchar
# Monferno
# Piplup
# Prinplup
# Empoleon
# Starly
# Staravia
# Staraptor
# Bidoof
# Bibarel
# Kricketot
# Luxray
# Budew
# Roserade
# Cranidos
# Shieldon
# Bastiodon
# Burmy
# Pachirisu
# Floatzel
# Cherubi
# Cherrim
# Shellos
# Drifblim
# Mismagius
# Glameow
# Purugly
# Chingling
# Stunky
# Skuntank
# Bronzor
# Bronzong
# Chatot
# Gible
# Gabite
# Lucario
# Hippopotas
# Hippowdon
# Drapion
# Croagunk
# Carnivine
# Mantyke
# Snover
# Abomasnow
# Weavile
# Magnezone
# Lickilicky
# Rhyperior
# Tangrowth
# Electivire
# Magmortar
# Togekiss
# Leafeon
# Glaceon
# Gliscor
# Mamoswine
# Porygon-Z
# Gallade
# Probopass
# Dusknoir
# Froslass
# Rotom
# Uxie
# Palkia
# Heatran
# Cresselia
# Phione
# Manaphy
# Darkrai
# Arceus
# Victini
# Snivy
# Servine
# Serperior
# Tepig
# Emboar
# Oshawott
# Dewott
# Samurott
# Purrloin
# Pansage
# Simisage
# Munna
# Musharna
# Woobat
# Swoobat
# Excadrill
# Audino
# Timburr
# Gurdurr
# Conkeldurr
# Tympole
# Seismitoad
# Sawk
# Sewaddle
# Swadloon
# Leavanny
# Venipede
# Whirlipede
# Cottonee
# Lilligant
# Basculin
# Krokorok
# Krookodile
# Darumaka
# Maractus
# Crustle
# Scraggy
# Scrafty
# Yamask
# Cofagrigus
# Tirtouga
# Carracosta
# Archen
# Archeops
# Trubbish
# Zorua
# Zoroark
# Minccino
# Cinccino
# Gothorita
# Gothitelle
# Reuniclus
# Swanna
# Vanillish
# Vanilluxe
# Sawsbuck
# Emolga
# Karrablast
# Escavalier
# Amoonguss
# Jellicent
# Alomomola
# Ferroseed
# Ferrothorn
# Klang
# Klinklang
# Tynamo
# Eelektrik
# Elgyem
# Beheeyem
# Litwick
# Lampent
# Fraxure
# Haxorus
# Cubchoo
# Beartic
# Cryogonal
# Shelmet
# Accelgor
# Stunfisk
# Mienfoo
# Mienshao
# Druddigon
# Golett
# Golurk
# Pawniard
# Bisharp
# Rufflet
# Vullaby
# Mandibuzz
# Deino
# Zweilous
# Larvesta
# Volcarona
# Cobalion
# Virizion
# Reshiram
# Zekrom
# Kyurem
# Chespin
# Quilladin
# Chesnaught
# Fennekin
# Delphox
# Frogadier
# Greninja
# Fletchling
# Fletchinder
# Talonflame
# Scatterbug
# Spewpa
# Vivillon
# Pyroar
# Flabébé
# Skiddo
# Gogoat
# Pancham
# Pangoro
# Furfrou
# MeowsticMale
# MeowsticFemale
# Honedge
# Doublade
# Spritzee
# Swirlix
# Slurpuff
# Inkay
# Malamar
# Binacle
# Barbaracle
# Skrelp
# Clauncher
# Clawitzer
# Helioptile
# Tyrunt
# Tyrantrum
# Amaura
# Aurorus
# Hawlucha
# Dedenne
# Carbink
# Goomy
# Sliggoo
# Goodra
# Klefki
# Phantump
# Trevenant
# Noivern
# Yveltal
# Diancie

# %%
# calculate the percentage of popular pokemon
pct_pop = 100*(len(included) / (len(included) + len(missing)))
print('{:.1f}% of non-Mega Pokemon from our Original Pokemon Data Set are popular. That is to say, they have been mentioned in a twitter hashtag at least once in the last 7 days.'.format(pct_pop))
# Out:
# 33.8% of non-Mega Pokemon from our Original Pokemon Data Set are popular. That is to say, they have been mentioned in a twitter hashtag at least once in the last 7 days.

# %% [markdown]
# #### 4. Join to Pokemon Dataset

# %%
# filter out excluded names
# https://stackoverflow.com/questions/12096252/use-a-list-of-values-to-select-rows-from-a-pandas-dataframe
pokemonDF = df[~df['Name'].isin(exclude_name)].copy()
print('The original datset contains {:d} pokemon. This analysis will focus on {:d} non-variant Pokemon.'.format(len(df), len(pokemonDF)))
# Out:
# The original datset contains 800 pokemon. This analysis will focus on 705 non-variant Pokemon.

# %%
len(pokemonDF)
# Out:
# 705

# %%
# ADD POPULARITY IND TO POKEMON DATASET: 
# If pokemon name is in the "included" list (i.e. was tweeted about), then Popular == TRUE
# create a condition list 
conditions = [(pokemonDF.Name.isin(included)==True),
              # subset the Name column and use str.contains to find the match record
              (pokemonDF.Name.isin(included)==False)]

# create a choice list
choices = ['True', 'False']

# Add Popular Ind: set up the default choice, feed in the parameters
pokemonDF['Popular']=np.select(condlist=conditions, choicelist = choices, default=['False'])

# %%
pokemonDF.head()
# Out:
#    #        Name Types  Type1     Type2  Total  Total_Atk  Total_Def  HP  \
# 0  1   Bulbasaur     2  Grass    Poison    318        114        114  45
# 1  2     Ivysaur     2  Grass    Poison    405        142        143  60
# 2  3    Venusaur     2  Grass    Poison    525        182        183  80
# 4  4  Charmander     1   Fire  No value    309        112         93  39
# 5  5  Charmeleon     1   Fire  No value    405        144        123  58
#
#    Attack  Defense  Sp_Atk  Sp_Def  Speed Generation Legendary   Mega Popular
# 0      49       49      65      65     45          1     False  False    True
# 1      62       63      80      80     60          1     False  False    True
# 2      82       83     100     100     80          1     False  False    True
# 4      52       43      60      50     65          1     False  False   False
# 5      64       58      80      65     80          1     False  False   False

# %%
#### This block of code is redundent
# Rename Type columns for ease of analysis
#pokemonDF['Type2'] = pokemonDF['Type 2']

# %%
## create a duplicated list of Pokemon type: if a pokemon is dual type, it will have a record for each type


type1 = pokemonDF[['Name', 'Type1', 'Popular', 'Total']]
# rename column from type 1 to type
type1 = type1.rename(columns={"Type1":"type"})

# Create 1 list to store all Pokemon's Type 1
# https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-6fcd0170be9c
# extract name and type1
type1 = pokemonDF[['Name', 'Type1', 'Popular', 'Total']]
# rename column from type1 to type
type1 = type1.rename(columns={"Type1":"Type"})
# Create another list to store secondary type for each Pokemon
# filter out all Pokemon that do not have a secondary type
type2 = pokemonDF[pokemonDF.Type2 !=""]
# store name and secondary type of resulting dataset
type2 = type2[['Name', 'Type2', 'Popular', 'Total']]
# rename column from type2 to type, to conform to our other list
type2 = type2.rename(columns={"Type2":"Type"})
# perform a union query, or concatenate the two lists
#http://www.datasciencemadesimple.com/union-and-union-all-in-pandas-dataframe-in-python-2/
types = pd.concat([type1, type2], sort=True)
types
# Out:
#            Name Popular  Total      Type
# 0     Bulbasaur    True    318     Grass
# 1       Ivysaur    True    405     Grass
# 2      Venusaur    True    525     Grass
# 4    Charmander   False    309      Fire
# 5    Charmeleon   False    405      Fire
# ..          ...     ...    ...       ...
# 791     Noivern   False    535    Dragon
# 792     Xerneas    True    680  No value
# 793     Yveltal   False    680    Flying
# 795     Diancie   False    600     Fairy
# 799   Volcanion    True    600     Water
#
# [1410 rows x 4 columns]

# %% [markdown]
# ## Research questions

# %% [markdown]
# ### 1. How a legendary Pokemon was enhanced by the Mega Evaluation?

# %%
#pip install plotnine

# %%
# ggplot2 package in python
import plotnine as p9
from plotnine import *

# %% [markdown]
# Because the pokemongo dataset does not contain mega and legnedary information, for this research question, we use the main dataset to perform analysis. And to know how a pokemon is effected by Mega evaluation and Legendary attribute, we need to find those pokemon that are legendary and able to have Mega evaluation.

# %%
# Get the pokedex of the pokemon that has Mega attribute and legendary attribute
df[(df['Legendary']=='True')&(df['Mega']=='True')][0:]
# Out:
#        #                   Name Types    Type1     Type2  Total  Total_Atk  \
# 163  150    MewtwoMega Mewtwo X     2  Psychic  Fighting    780        344
# 164  150    MewtwoMega Mewtwo Y     1  Psychic  No value    780        344
# 418  380      LatiasMega Latias     2   Dragon   Psychic    700        240
# 420  381      LatiosMega Latios     2   Dragon   Psychic    700        290
# 426  384  RayquazaMega Rayquaza     2   Dragon    Flying    780        360
# 796  719    DiancieMega Diancie     2     Rock     Fairy    700        320
#
#      Total_Def   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed Generation  \
# 163        200  106     190      100     154     100    130          1
# 164        190  106     150       70     194     120    140          1
# 418        270   80     100      120     140     150    110          3
# 420        220   80     130      100     160     120    110          3
# 426        200  105     180      100     180     100    115          3
# 796        220   50     160      110     160     110    110          6
#
#     Legendary  Mega
# 163      True  True
# 164      True  True
# 418      True  True
# 420      True  True
# 426      True  True
# 796      True  True

# %% [markdown]
# We have five pokemons, Mewtwo(#150), Latias(#380), Latios(#381), Rayquaza(#384) and Diancie(#719), that have both Mega and Lengendary attributes.

# %%
# Subset the pokemon that has Legendary attribute
LegP = df[(df['#']==150)|(df['#']==380)|(df['#']==381)|(df['#']==384)|(df['#']==719)].copy()
LegP
# Out:
#        #                   Name Types    Type1     Type2  Total  Total_Atk  \
# 162  150                 Mewtwo     1  Psychic  No value    680        264
# 163  150    MewtwoMega Mewtwo X     2  Psychic  Fighting    780        344
# 164  150    MewtwoMega Mewtwo Y     1  Psychic  No value    780        344
# 417  380                 Latias     2   Dragon   Psychic    600        190
# 418  380      LatiasMega Latias     2   Dragon   Psychic    700        240
# 419  381                 Latios     2   Dragon   Psychic    600        220
# 420  381      LatiosMega Latios     2   Dragon   Psychic    700        290
# 425  384               Rayquaza     2   Dragon    Flying    680        300
# 426  384  RayquazaMega Rayquaza     2   Dragon    Flying    780        360
# 795  719                Diancie     2     Rock     Fairy    600        200
# 796  719    DiancieMega Diancie     2     Rock     Fairy    700        320
#
#      Total_Def   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed Generation  \
# 162        180  106     110       90     154      90    130          1
# 163        200  106     190      100     154     100    130          1
# 164        190  106     150       70     194     120    140          1
# 417        220   80      80       90     110     130    110          3
# 418        270   80     100      120     140     150    110          3
# 419        190   80      90       80     130     110    110          3
# 420        220   80     130      100     160     120    110          3
# 425        180  105     150       90     150      90     95          3
# 426        200  105     180      100     180     100    115          3
# 795        300   50     100      150     100     150     50          6
# 796        220   50     160      110     160     110    110          6
#
#     Legendary   Mega
# 162      True  False
# 163      True   True
# 164      True   True
# 417      True  False
# 418      True   True
# 419      True  False
# 420      True   True
# 425      True  False
# 426      True   True
# 795      True  False
# 796      True   True

# %% [markdown]
# ##### Visualize the comparison

# %%
## Mega and Legendary Comparison - Total Power
(ggplot(LegP)                                                       # defining what data to use
 + aes(y='Name', x='Total',color='Mega', shape='Legendary')    # defining what variable to use
 + geom_point(alpha=0.5)                                          # defining the type of plot to use
 + labs(title='Total Power Comparison: Mega vs Legendary',
        y='Pokémon Name', x='Total Power') 
 + theme_minimal()
)
# Out:
# <ggplot: (125415267995)>

# %%
## Mega and Legendary Comparison - Total Attack
(ggplot(LegP)                                                       # defining what data to use
 + aes(y='Name', x='Total_Atk',color='Mega', shape='Legendary')    # defining what variable to use
 + geom_point(alpha=0.5)                                          # defining the type of plot to use
 + labs(title='Total Attack Comparison: Mega vs Legendary',
        y='Pokémon Name', x='Total Attack') 
 + theme_minimal()
)
# Out:
# <ggplot: (125412296915)>

# %%
## Mega and Legendary Comparison - Total Defense
(ggplot(LegP)                                                       # defining what data to use
 + aes(y='Name', x='Total_Def',color='Mega', shape='Legendary')    # defining what variable to use
 + geom_point(alpha=0.5)                                          # defining the type of plot to use
 + labs(title='Total Defense Comparison: Mega vs Legendary',
        y='Pokémon Name', x='Total Defense') 
 + theme_minimal()
)
# Out:
# <ggplot: (125415701389)>

# %%
plt.figure(figsize=(6,8))
sns.scatterplot(x=LegP['Total'], y=LegP['Name'] ,hue=LegP['Mega'], size=LegP['Mega'])

# %% [markdown]
# Because Mewtwo(#150) is a special Pokemon, it has two type of mega forms, Mega Mewtwo X and Mega Mewtwo Y, in Mega Evaluation.
# So, we wiil do the analysis on Mewtwo(#150) later and see how the Mega Evalution effect on others.

# %%
# Exclude Mewtwo(#150) for analysis on others
LegP[(LegP['#']!=150)]
# Out:
#        #                   Name Types   Type1    Type2  Total  Total_Atk  \
# 417  380                 Latias     2  Dragon  Psychic    600        190
# 418  380      LatiasMega Latias     2  Dragon  Psychic    700        240
# 419  381                 Latios     2  Dragon  Psychic    600        220
# 420  381      LatiosMega Latios     2  Dragon  Psychic    700        290
# 425  384               Rayquaza     2  Dragon   Flying    680        300
# 426  384  RayquazaMega Rayquaza     2  Dragon   Flying    780        360
# 795  719                Diancie     2    Rock    Fairy    600        200
# 796  719    DiancieMega Diancie     2    Rock    Fairy    700        320
#
#      Total_Def   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed Generation  \
# 417        220   80      80       90     110     130    110          3
# 418        270   80     100      120     140     150    110          3
# 419        190   80      90       80     130     110    110          3
# 420        220   80     130      100     160     120    110          3
# 425        180  105     150       90     150      90     95          3
# 426        200  105     180      100     180     100    115          3
# 795        300   50     100      150     100     150     50          6
# 796        220   50     160      110     160     110    110          6
#
#     Legendary   Mega
# 417      True  False
# 418      True   True
# 419      True  False
# 420      True   True
# 425      True  False
# 426      True   True
# 795      True  False
# 796      True   True

# %%
# Subset the Mewtwo(#150) for analysis
LegP[(LegP['#']==150)]
# Out:
#        #                 Name Types    Type1     Type2  Total  Total_Atk  \
# 162  150               Mewtwo     1  Psychic  No value    680        264
# 163  150  MewtwoMega Mewtwo X     2  Psychic  Fighting    780        344
# 164  150  MewtwoMega Mewtwo Y     1  Psychic  No value    780        344
#
#      Total_Def   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed Generation  \
# 162        180  106     110       90     154      90    130          1
# 163        200  106     190      100     154     100    130          1
# 164        190  106     150       70     194     120    140          1
#
#     Legendary   Mega
# 162      True  False
# 163      True   True
# 164      True   True

# %% [markdown]
# #### Total Power Comparison:

# %%
lastPdex=0
for i in LegP[(LegP['#']!=150)].iterrows():
    if i[1]['#']==lastPdex:
        difference = i[1]['Total'] - lastPower
        print('Pokédex No.{} {:20s} withot Mega Evaluation has {} total power'.format(lastPdex, lastPname, lastPower))
        print('Pokédex No.{} {:20s} with Mega Evaluation has {} total power'.format(i[1]['#'], i[1]['Name'], i[1]['Total']))
        print("The total power has been increased by {}\n".format(difference))
    else:
        lastPdex=i[1]['#']
        lastPname=i[1]['Name']
        lastPower=i[1]['Total']
# Out:
# Pokédex No.380 Latias               withot Mega Evaluation has 600 total power
# Pokédex No.380 LatiasMega Latias    with Mega Evaluation has 700 total power
# The total power has been increased by 100
#
# Pokédex No.381 Latios               withot Mega Evaluation has 600 total power
# Pokédex No.381 LatiosMega Latios    with Mega Evaluation has 700 total power
# The total power has been increased by 100
#
# Pokédex No.384 Rayquaza             withot Mega Evaluation has 680 total power
# Pokédex No.384 RayquazaMega Rayquaza with Mega Evaluation has 780 total power
# The total power has been increased by 100
#
# Pokédex No.719 Diancie              withot Mega Evaluation has 600 total power
# Pokédex No.719 DiancieMega Diancie  with Mega Evaluation has 700 total power
# The total power has been increased by 100

# %% [markdown]
# Four pokemons, Latias(#380), Latios(#381), Rayquaza(#384) and Diancie(#719) have increase 100 total power by having Mega Evaluation.
# Now we are ready to analyze the status of Mewtwo(#150).

# %%
MGvalue1=0 #780
MGvalue2=0 #780
megaformindex1=0  #163
megaformindex2=0  #164
for i in LegP[(LegP['#']==150)].iterrows():
    if i[1]['Mega']=='True':
        print('Pokédex No.{} {:20s} with Mega Evaluation has {} total power'.format(i[1]['#'], i[1]['Name'], i[1]['Total']))
        if i[0]==megaformindex1 or megaformindex1>megaformindex2:
            megaformindex2=i[0]
            if i[1]['Total_Def'] > MGvalue2:
                MGvalue2 = i[1]['Total'] 
        else:
            megaformindex1=i[0]
            if i[1]['Total_Def'] > MGvalue1:
                MGvalue1 = i[1]['Total']
    else:
        print('Pokédex No.{} {:20s} without Mega Evaluation has {} total power\n'.format(i[1]['#'], i[1]['Name'], i[1]['Total']))
        lowestvalue=i[1]['Total']
    if megaformindex1>0 and megaformindex2==0:
        print("The total power has been increased by {}\n".format(MGvalue1 - lowestvalue))
    elif megaformindex2>0:
        print("The total power has been increased by {}\n".format(MGvalue2 - lowestvalue))
# Out:
# Pokédex No.150 Mewtwo               without Mega Evaluation has 680 total power
#
# Pokédex No.150 MewtwoMega Mewtwo X  with Mega Evaluation has 780 total power
# The total power has been increased by 100
#
# Pokédex No.150 MewtwoMega Mewtwo Y  with Mega Evaluation has 780 total power
# The total power has been increased by 100

# %% [markdown]
# Mewtwo(#150) has been increased by 100 total power as other four pokemons, Latias(#380), Latios(#381), Rayquaza(#384) and Diancie(#719).

# %% [markdown]
# #### Total Attack Comparison:

# %%
lastPdex=0
for i in LegP[(LegP['#']!=150)].iterrows():
    if i[1]['#']==lastPdex:
        difference = i[1]['Total_Atk'] - lastAtk
        print('Pokédex No.{} {:20s} without Mega Evaluation has {} total attack'.format(lastPdex, lastPname, lastAtk))
        print('Pokédex No.{} {:20s} with Mega Evaluation has {} total attack'.format(i[1]['#'], i[1]['Name'], i[1]['Total_Atk']))
        print("The total attack has been increased by {}\n".format(difference))
    else:
        lastPdex=i[1]['#']
        lastPname=i[1]['Name']
        lastAtk=i[1]['Total_Atk']
# Out:
# Pokédex No.380 Latias               without Mega Evaluation has 190 total attack
# Pokédex No.380 LatiasMega Latias    with Mega Evaluation has 240 total attack
# The total attack has been increased by 50
#
# Pokédex No.381 Latios               without Mega Evaluation has 220 total attack
# Pokédex No.381 LatiosMega Latios    with Mega Evaluation has 290 total attack
# The total attack has been increased by 70
#
# Pokédex No.384 Rayquaza             without Mega Evaluation has 300 total attack
# Pokédex No.384 RayquazaMega Rayquaza with Mega Evaluation has 360 total attack
# The total attack has been increased by 60
#
# Pokédex No.719 Diancie              without Mega Evaluation has 200 total attack
# Pokédex No.719 DiancieMega Diancie  with Mega Evaluation has 320 total attack
# The total attack has been increased by 120

# %% [markdown]
# Diancie(#719) has been increased the most by 120 total attack and Latias(#380) has been increased the least by 50 total attack.

# %%
MGvalue1=0 #344
MGvalue2=0 #344
megaformindex1=0  #163
megaformindex2=0  #164
for i in LegP[(LegP['#']==150)].iterrows():
    if i[1]['Mega']=='True':
        print('Pokédex No.{} {:20s} with Mega Evaluation has {} total attack'.format(i[1]['#'], i[1]['Name'], i[1]['Total_Atk']))
        if i[0]==megaformindex1 or megaformindex1>megaformindex2:
            megaformindex2=i[0]
            if i[1]['Total_Def'] > MGvalue2:
                MGvalue2 = i[1]['Total_Atk'] 
        else:
            megaformindex1=i[0]
            if i[1]['Total_Def'] > MGvalue1:
                MGvalue1 = i[1]['Total_Atk']
    else:
        print('Pokédex No.{} {:20s} without Mega Evaluation has {} total attack\n'.format(i[1]['#'], i[1]['Name'], i[1]['Total_Atk']))
        lowestvalue=i[1]['Total_Atk']
    if megaformindex1>0 and megaformindex2==0:
        print("The total attack has been increased by {}\n".format(MGvalue1 - lowestvalue))
    elif megaformindex2>0:
        print("The total attack has been increased by {}\n".format(MGvalue2 - lowestvalue))
# Out:
# Pokédex No.150 Mewtwo               without Mega Evaluation has 264 total attack
#
# Pokédex No.150 MewtwoMega Mewtwo X  with Mega Evaluation has 344 total attack
# The total attack has been increased by 80
#
# Pokédex No.150 MewtwoMega Mewtwo Y  with Mega Evaluation has 344 total attack
# The total attack has been increased by 80

# %% [markdown]
# Mewtwo(#150) has been increased by 80 total attack. Overall, Diancie(#719) is the most enhanced pokemon on total attack.

# %% [markdown]
# #### Total Defense Comparison:

# %%
lastPdex=0
for i in LegP[(LegP['#']!=150)].iterrows():
    if i[1]['#']==lastPdex:
        difference = i[1]['Total_Def'] - lastDef
        print('Pokédex No.{} {:20s} without Mega Evaluation has {} total defense'.format(lastPdex, lastPname, lastDef))
        print('Pokédex No.{} {:20s} with Mega Evaluation has {} total defense'.format(i[1]['#'], i[1]['Name'], i[1]['Total_Def']))
        print("The total defense has been increased by {}\n".format(difference))
    else:
        lastPdex=i[1]['#']
        lastPname=i[1]['Name']
        lastDef=i[1]['Total_Def']
# Out:
# Pokédex No.380 Latias               without Mega Evaluation has 220 total defense
# Pokédex No.380 LatiasMega Latias    with Mega Evaluation has 270 total defense
# The total defense has been increased by 50
#
# Pokédex No.381 Latios               without Mega Evaluation has 190 total defense
# Pokédex No.381 LatiosMega Latios    with Mega Evaluation has 220 total defense
# The total defense has been increased by 30
#
# Pokédex No.384 Rayquaza             without Mega Evaluation has 180 total defense
# Pokédex No.384 RayquazaMega Rayquaza with Mega Evaluation has 200 total defense
# The total defense has been increased by 20
#
# Pokédex No.719 Diancie              without Mega Evaluation has 300 total defense
# Pokédex No.719 DiancieMega Diancie  with Mega Evaluation has 220 total defense
# The total defense has been increased by -80

# %% [markdown]
# Diancie(#719) has been decreased the most by 80 total defense and Latias(#380) has been increased the most by 50 total defense.

# %%
MGvalue1=0 #200
MGvalue2=0 #190
megaformindex1=0  #163
megaformindex2=0  #164
for i in LegP[(LegP['#']==150)].iterrows():
    if i[1]['Mega']=='True':
        print('Pokédex No.{} {:20s} with Mega Evaluation has {} total defense'.format(i[1]['#'], i[1]['Name'], i[1]['Total_Def']))
        if i[0]==megaformindex1 or megaformindex1>megaformindex2:
            megaformindex2=i[0]
            if i[1]['Total_Def'] > MGvalue2:
                MGvalue2 = i[1]['Total_Def'] 
        else:
            megaformindex1=i[0]
            if i[1]['Total_Def'] > MGvalue1:
                MGvalue1 = i[1]['Total_Def']
    else:
        print('Pokédex No.{} {:20s} without Mega Evaluation has {} total defense\n'.format(i[1]['#'], i[1]['Name'], i[1]['Total_Def']))
        lowestvalue=i[1]['Total_Def']
    if megaformindex1>0 and megaformindex2==0:
        print("The total defense has been increased by {}\n".format(MGvalue1 - lowestvalue))
    elif megaformindex2>0:
        print("The total defense has been increased by {}\n".format(MGvalue2 - lowestvalue))
# Out:
# Pokédex No.150 Mewtwo               without Mega Evaluation has 180 total defense
#
# Pokédex No.150 MewtwoMega Mewtwo X  with Mega Evaluation has 200 total defense
# The total defense has been increased by 20
#
# Pokédex No.150 MewtwoMega Mewtwo Y  with Mega Evaluation has 190 total defense
# The total defense has been increased by 10

# %% [markdown]
# Mega Mewtwo X got 20 total defense increased and Mega Mewtwo Y got 10 total defense increased.

# %% [markdown]
# In summary, Diancie(#719) got boosted for 120 total attack power and got reduced for 80 total defense power.
# Mewtwo(#150) got 10 total defense power higher in Mega Mewtwo X form than Mega Mewtwo Y form.
# Overall, pokemon got enhanced the same amount of power in total.

# %% [markdown]
# ### 2. Is there any difference in a Pokémon’s power or skill between the two platforms? How are they different?

# %%
# adding .copy() to avoid SettingWithCopyWarning
# reference: https://stackoverflow.com/questions/38835483/confusion-re-pandas-copy-of-slice-of-dataframe-warning
GO = dfm[['#','Name','Go_Types','Go_Total', 'Go_Atk', 'Go_Def', 'Generation']].copy()
Switch = dfm[['#','Name','Types','Total','Total_Atk', 'Total_Def', 'Generation']].copy()
GO.rename(columns={'Go_Types':'Types',
                   'Go_Total':'Total',
                   'Go_Atk':'Total_Atk',
                   'Go_Def':'Total_Def'}, inplace=True)
GO.loc[:,'Platform']='PokemonGO'
Switch.loc[:,'Platform']='Games'

# %%
pokemon = pd.concat([GO,Switch])

# %%
pokemon
# Out:
#        #        Name Types  Total  Total_Atk  Total_Def Generation   Platform
# 0      1   Bulbasaur     2    357        128        118          1  PokemonGO
# 1      2     Ivysaur     2    449        155        151          1  PokemonGO
# 2      3    Venusaur     2    577        190        198          1  PokemonGO
# 3      4  Charmander     1    327        118        116          1  PokemonGO
# 4      5  Charmeleon     1    435        151        158          1  PokemonGO
# ..   ...         ...   ...    ...        ...        ...        ...        ...
# 523  631     Heatmor     1    484        202        132          5      Games
# 524  632      Durant     2    484        157        160          5      Games
# 525  633       Deino     2    300        110        100          5      Games
# 526  634    Zweilous     2    420        150        140          5      Games
# 527  635   Hydreigon     2    600        230        180          5      Games
#
# [1056 rows x 8 columns]

# %% [markdown]
# #### Total Power Comparison for two platforms

# %%
## Total Power Comparison
(ggplot(pokemon)         # defining what data to use
 + aes(x='#', y='Total',color='Generation')    # defining what variable to use
 + geom_jitter(alpha=0.5) # defining the type of plot to use
 + labs(title='Total Power Comparison: Games vs. PokemonGo',
        x='Pokédex Number', y='Total Power')
 + facet_wrap(' ~ Platform', nrow = 1)  # facet by platform
 + theme_minimal()
)
# Out:
# <ggplot: (125415720740)>

# %% [markdown]
# Surprisingly, PokemonGO platform has the pokemon, Blissey, with total power as high as 794.

# %%
# find the pokemon that has total power over 750
pokemon[pokemon['Total']>750]
# Out:
#        #     Name Types  Total  Total_Atk  Total_Def Generation   Platform
# 241  242  Blissey     1    794        496        129          2  PokemonGO

# %% [markdown]
# In the console games plantform, the pokemon, Blissey, has the total power only 540.

# %%
# find the pokedex number of 242
pokemon[pokemon['#']==242]
# Out:
#        #     Name Types  Total  Total_Atk  Total_Def Generation   Platform
# 241  242  Blissey     1    794        496        129          2  PokemonGO
# 241  242  Blissey     1    540         85        145          2      Games

# %% [markdown]
# #### Total Attack Comparison for two platforms

# %%
## Total Attack Comparison
(ggplot(pokemon)         # defining what data to use
 + aes(x='#', y='Total_Atk',color='Generation')    # defining what variable to use
 + geom_jitter(alpha=0.5) # defining the type of plot to use
 + labs(title='Total Attack Comparison: Games vs. PokemonGo',
        x='Pokédex Number', y='Total Power')
 + facet_wrap(' ~ Platform', nrow = 1)  # facet by platform
 + theme_minimal()
)
# Out:
# <ggplot: (-9223371911439049570)>

# %% [markdown]
# Here we see the pokemon, Blissey, again, showing the high value of total attack.

# %%
# find the pokemon that has total attack over 490
pokemon[pokemon['Total_Atk']>490]
# Out:
#        #     Name Types  Total  Total_Atk  Total_Def Generation   Platform
# 241  242  Blissey     1    794        496        129          2  PokemonGO

# %% [markdown]
# The status for both pokemons, Chansey and Blissey, are low in console games platform.

# %%
# find the pokedex number of 242 and 113
pokemon[(pokemon['#']==242)]
# Out:
#        #     Name Types  Total  Total_Atk  Total_Def Generation   Platform
# 241  242  Blissey     1    794        496        129          2  PokemonGO
# 241  242  Blissey     1    540         85        145          2      Games

# %% [markdown]
# #### Total Defense Comparison for two platforms

# %%
## Total Defense Comparison
(ggplot(pokemon)         # defining what data to use
 + aes(x='#', y='Total_Def',color='Generation')    # defining what variable to use
 + geom_jitter(alpha=0.5) # defining the type of plot to use
 + labs(title='Total Defense Comparison: Games vs. PokemonGo',
        x='Pokédex Number', y='Total Power')
 + facet_wrap(' ~ Platform', nrow = 1)  # facet by platform
 + theme_minimal()
)
# Out:
# <ggplot: (125415534824)>

# %% [markdown]
# The pokemon, Shuckle, has the highest total defense value among two platforms.

# %%
# find the pokemon that has total Defense over 400
pokemon[pokemon['Total_Def']>400]
# Out:
#        #     Name Types  Total  Total_Atk  Total_Def Generation Platform
# 212  213  Shuckle     2    505         20        460          2    Games

# %% [markdown]
# In the PokemonGO, the pokemon has the low value of total defense of 17.

# %%
# find the pokedex number of 213
pokemon[(pokemon['#']==213)]
# Out:
#        #     Name Types  Total  Total_Atk  Total_Def Generation   Platform
# 212  213  Shuckle     2    498         85         17          2  PokemonGO
# 212  213  Shuckle     2    505         20        460          2      Games

# %% [markdown]
# ### 3. Which Pokémon types have the most powerful moves? When combined with powers related to Pokémon themselves (i.e. HP, speed etc.?) which Pokémon are the strongest?

# %% [markdown]
# ##### Part 1:
# Which Pokémon types have the most powerful moves?
#
# ##### Part 2:
# When combined with powers related to Pokémon themselves (i.e. HP, speed etc?) which Pokémon are the strongest?

# %%
# Create aggregated data set comparing average measures by type
compare = moves.groupby(by = "Type").mean()
compare
# Out:
#               Power   Accuracy         PP       Prob
# Type
# Bug       40.645161  66.774194  15.354839  30.000000
# Dark      38.750000        inf  13.454545  42.000000
# Dragon    72.800000  76.800000   9.120000  23.333333
# Electric  61.428571        inf  12.595238  48.666667
# Fairy     37.000000        inf  10.433333  20.000000
# Fighting  55.306122        inf  12.775510  60.000000
# Fire      80.750000  82.500000   9.400000  40.526316
# Flying    58.103448        inf  15.379310  41.666667
# Ghost     56.250000        inf  10.142857  22.500000
# Grass     48.431373        inf  14.137255  51.666667
# Ground    45.892857  68.035714  11.285714  58.333333
# Ice       52.037037  66.481481  13.925926  37.500000
# Normal    28.153439        inf  16.740741  39.333333
# Poison    33.793103  65.344828  16.931034  31.666667
# Psychic   33.059701        inf  13.402985  23.750000
# Rock      52.727273  59.090909  10.318182  47.500000
# Steel     52.343750        inf  11.937500  18.750000
# Water     62.682927  72.317073  12.243902  28.000000

# %%
# Identify top 3 Types for Power, Accuracy and PP
comparePower = compare.sort_values('Power', ascending = False)
compareAccuracy = compare.sort_values('Accuracy', ascending = False)
comparePP = compare.sort_values('PP', ascending = False)
# Iterate through rows in resulting data frame to print results
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
print('Top 3 Types with Powerful Moves:')       # print header
i=0                                          # initiate counter
for index, row in comparePower.iterrows():   # iterate through rows to print results
    i+=1
    if i > 3: 
        break
    print('{:d}. {:s}: {:.1f} average'.format(i, index, row['Power']))

print('\nTop 3 Types with Accurate Moves:')
i=0
for index, row in compareAccuracy.iterrows():
    i+=1
    if i > 3:
        break
    print('{:d}. {:s}: {:.1f} average'.format(i, index, row['Accuracy']))
    
print('\nTop 3 Types with PP Moves:')
i=0
for index, row in comparePP.iterrows():
    i+=1
    if i > 3: 
        break
    print('{:d}. {:s}: {:.1f} average'.format(i, index, row['PP']))
# Out:
# Top 3 Types with Powerful Moves:
# 1. Fire: 80.8 average
# 2. Dragon: 72.8 average
# 3. Water: 62.7 average
#
# Top 3 Types with Accurate Moves:
# 1. Grass: inf average
# 2. Normal: inf average
# 3. Electric: inf average
#
# Top 3 Types with PP Moves:
# 1. Poison: 16.9 average
# 2. Normal: 16.7 average
# 3. Flying: 15.4 average

# %% [markdown]
# ##### Outside research
# Are "Power" and "PP" the same thing?
#
# Answer: No, they are different.
# PP is an abbreviation of Power Points. Power Points measure the number of times a move can be used. The higher the PP, the more times you can use the move. PP are essential for attacking, supporting, stalling, recovering, and defending.
#
# Source: https://pokemon.fandom.com/wiki/PP

# %%
# How many pokemon types have an average accuracy of infinity?
i=0
for index, row in compare.iterrows():
    if row['Accuracy']==float('inf'):
        i+=1
print(i, 'Pokemon Type Moves have an average accuracy of infinity.')

# Count the type that has the most moves with infinite accuracy
infMoves = []      # create empty list to store pokemon move types with infinite accuracy
for index, row in moves.iterrows():  # iterate through dataframe
    if row['Accuracy']==float('inf'):  # if accuracy is infinite, add type to list
        infMoves.append(row['Type'])
# observe results
for type in infMoves:
    print(type)
# Out:
# 10 Pokemon Type Moves have an average accuracy of infinity.
# Flying
# Fighting
# Fairy
# Dark
# Dark
# Dark
# Psychic
# Grass
# Steel
# Electric
# Ghost
# Electric
# Normal
# Normal
# Normal
# Fighting

# %%
# use dictionary to count number of occurences
# https://stackoverflow.com/questions/3496518/using-a-dictionary-to-count-the-items-in-a-list
infDict = {}
for type in infMoves:
    infDict[type] = infDict.get(type,0) + 1
    
# print types of pokemon with more than 1 move with infinite accuracy
for key, value in infDict.items():
    if value > 1:
        print('{:s} Pokemon: {:d} moves with infinite accuracy'.format(key, value))
# Out:
# Fighting Pokemon: 2 moves with infinite accuracy
# Dark Pokemon: 3 moves with infinite accuracy
# Electric Pokemon: 2 moves with infinite accuracy
# Normal Pokemon: 3 moves with infinite accuracy

# %%
# Try Median as measure of center
compareMed = moves.groupby(by = "Type").median()
compareMedAccuracy = compareMed.sort_values('Accuracy', ascending = False)

# print results
print('\nTop 3 Types with Accurate Moves (Median):')
i=0
for index, row in compareMedAccuracy.iterrows():
    i+=1
    if i > 3:
        break
    print('{:d}. {:s}: {:.1f} average'.format(i, index, row['Accuracy']))
# Out:
# Top 3 Types with Accurate Moves (Median):
# 1. Bug: 100.0 average
# 2. Fighting: 100.0 average
# 3. Dark: 100.0 average

# %%
# Combine average power, pp and probability by type with median accuracy
compareMean = moves.groupby(by = "Type").mean() # calculate mean for all measures
compareMedian = moves.groupby(by="Type").median() # calculate median for all measures
compareMean = compareMean[['Power', 'PP', 'Prob']] # select features which will be measured with mean
compareMedian = compareMedian[['Accuracy']] # select features which will be measured with median
compareMix = compareMean.join(compareMedian) # join datasets
compareMix
# Out:
#               Power         PP       Prob  Accuracy
# Type
# Bug       40.645161  15.354839  30.000000     100.0
# Dark      38.750000  13.454545  42.000000     100.0
# Dragon    72.800000   9.120000  23.333333     100.0
# Electric  61.428571  12.595238  48.666667     100.0
# Fairy     37.000000  10.433333  20.000000      37.5
# Fighting  55.306122  12.775510  60.000000     100.0
# Fire      80.750000   9.400000  40.526316     100.0
# Flying    58.103448  15.379310  41.666667      95.0
# Ghost     56.250000  10.142857  22.500000     100.0
# Grass     48.431373  14.137255  51.666667     100.0
# Ground    45.892857  11.285714  58.333333      92.5
# Ice       52.037037  13.925926  37.500000      90.0
# Normal    28.153439  16.740741  39.333333      85.0
# Poison    33.793103  16.931034  31.666667      90.0
# Psychic   33.059701  13.402985  23.750000       0.0
# Rock      52.727273  10.318182  47.500000      90.0
# Steel     52.343750  11.937500  18.750000      90.0
# Water     62.682927  12.243902  28.000000      95.0

# %%
# Identify top 3 Types for Power, Accuracy and PP
comparePower = compareMix.sort_values('Power', ascending = False)
compareAccuracy = compareMix.sort_values('Accuracy', ascending = False)
comparePP = compareMix.sort_values('PP', ascending = False)

# Iterate through rows in resulting data frame to print results
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
print('Top 3 Types with Powerful Moves:')       # print header
i=0                                          # initiate counter
for index, row in comparePower.iterrows():   # iterate through rows to print results
    i+=1
    if i > 3: 
        break
    print('{:d}. {:s}: {:.1f} average'.format(i, index, row['Power']))
    
print('\nTop 3 Types with PP Moves:')
i=0
for index, row in comparePP.iterrows():
    i+=1
    if i > 3: 
        break
    print('{:d}. {:s}: {:.1f} average'.format(i, index, row['PP']))
    
print('\nTop Types with Accurate Moves:')
i=0
for index, row in compareAccuracy.iterrows():
    if row['Accuracy'] == 100:
        i+=1
        print('{:d}. {:s}: {:.1f} median'.format(i,index, row['Accuracy']))
# Out:
# Top 3 Types with Powerful Moves:
# 1. Fire: 80.8 average
# 2. Dragon: 72.8 average
# 3. Water: 62.7 average
#
# Top 3 Types with PP Moves:
# 1. Poison: 16.9 average
# 2. Normal: 16.7 average
# 3. Flying: 15.4 average
#
# Top Types with Accurate Moves:
# 1. Bug: 100.0 median
# 2. Fighting: 100.0 median
# 3. Dark: 100.0 median
# 4. Ghost: 100.0 median
# 5. Fire: 100.0 median
# 6. Grass: 100.0 median
# 7. Electric: 100.0 median
# 8. Dragon: 100.0 median

# %% [markdown]
# #### Question 3 Part II:
# When combined with powers related to Pokémon themselves (i.e. HP, speed etc?) which Pokémon are the strongest?

# %%
# read in pokemon dataset for quick analysis. reuse code from prior section 
import pandas as pd
pokemon = pd.read_csv('Pokemon.csv')
pokemon = pokemon.drop(['#'], axis=1) #drop the duplicate column
pokemon.rename(columns={'Type 1':'Type1',
                   'Type 2':'Type2',
                   'Sp. Atk':'Sp_Atk',
                   'Sp. Def':'Sp_Def',}, inplace=True)
fill_na = {'Type2':'No value'} # create a dictionary for filling na values
pokemon=pokemon.fillna(value=fill_na)
print('Number of null values in dataframe:\n', pokemon.isnull().sum())
pokemon
# Out:
# Number of null values in dataframe:
#  Name          0
# Type1         0
# Type2         0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp_Atk        0
# Sp_Def        0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64
#                           Name     Type1     Type2  Total   HP  Attack  \
# 0                    Bulbasaur     Grass    Poison    318   45      49
# 1                      Ivysaur     Grass    Poison    405   60      62
# 2                     Venusaur     Grass    Poison    525   80      82
# 3        VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4                   Charmander      Fire  No value    309   39      52
# 5                   Charmeleon      Fire  No value    405   58      64
# 6                    Charizard      Fire    Flying    534   78      84
# 7    CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8    CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9                     Squirtle     Water  No value    314   44      48
# 10                   Wartortle     Water  No value    405   59      63
# 11                   Blastoise     Water  No value    530   79      83
# 12     BlastoiseMega Blastoise     Water  No value    630   79     103
# 13                    Caterpie       Bug  No value    195   45      30
# 14                     Metapod       Bug  No value    205   50      20
# 15                  Butterfree       Bug    Flying    395   60      45
# 16                      Weedle       Bug    Poison    195   40      35
# 17                      Kakuna       Bug    Poison    205   45      25
# 18                    Beedrill       Bug    Poison    395   65      90
# 19       BeedrillMega Beedrill       Bug    Poison    495   65     150
# 20                      Pidgey    Normal    Flying    251   40      45
# 21                   Pidgeotto    Normal    Flying    349   63      60
# 22                     Pidgeot    Normal    Flying    479   83      80
# 23         PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 24                     Rattata    Normal  No value    253   30      56
# 25                    Raticate    Normal  No value    413   55      81
# 26                     Spearow    Normal    Flying    262   40      60
# 27                      Fearow    Normal    Flying    442   65      90
# 28                       Ekans    Poison  No value    288   35      60
# 29                       Arbok    Poison  No value    438   60      85
# 30                     Pikachu  Electric  No value    320   35      55
# 31                      Raichu  Electric  No value    485   60      90
# 32                   Sandshrew    Ground  No value    300   50      75
# 33                   Sandslash    Ground  No value    450   75     100
# 34                    Nidoran♀    Poison  No value    275   55      47
# 35                    Nidorina    Poison  No value    365   70      62
# 36                   Nidoqueen    Poison    Ground    505   90      92
# 37                    Nidoran♂    Poison  No value    273   46      57
# 38                    Nidorino    Poison  No value    365   61      72
# 39                    Nidoking    Poison    Ground    505   81     102
# 40                    Clefairy     Fairy  No value    323   70      45
# 41                    Clefable     Fairy  No value    483   95      70
# 42                      Vulpix      Fire  No value    299   38      41
# 43                   Ninetales      Fire  No value    505   73      76
# 44                  Jigglypuff    Normal     Fairy    270  115      45
# 45                  Wigglytuff    Normal     Fairy    435  140      70
# 46                       Zubat    Poison    Flying    245   40      45
# 47                      Golbat    Poison    Flying    455   75      80
# 48                      Oddish     Grass    Poison    320   45      50
# 49                       Gloom     Grass    Poison    395   60      65
# 50                   Vileplume     Grass    Poison    490   75      80
# 51                       Paras       Bug     Grass    285   35      70
# 52                    Parasect       Bug     Grass    405   60      95
# 53                     Venonat       Bug    Poison    305   60      55
# 54                    Venomoth       Bug    Poison    450   70      65
# 55                     Diglett    Ground  No value    265   10      55
# 56                     Dugtrio    Ground  No value    405   35      80
# 57                      Meowth    Normal  No value    290   40      45
# 58                     Persian    Normal  No value    440   65      70
# 59                     Psyduck     Water  No value    320   50      52
# 60                     Golduck     Water  No value    500   80      82
# 61                      Mankey  Fighting  No value    305   40      80
# 62                    Primeape  Fighting  No value    455   65     105
# 63                   Growlithe      Fire  No value    350   55      70
# 64                    Arcanine      Fire  No value    555   90     110
# 65                     Poliwag     Water  No value    300   40      50
# 66                   Poliwhirl     Water  No value    385   65      65
# 67                   Poliwrath     Water  Fighting    510   90      95
# 68                        Abra   Psychic  No value    310   25      20
# 69                     Kadabra   Psychic  No value    400   40      35
# 70                    Alakazam   Psychic  No value    500   55      50
# 71       AlakazamMega Alakazam   Psychic  No value    590   55      50
# 72                      Machop  Fighting  No value    305   70      80
# 73                     Machoke  Fighting  No value    405   80     100
# 74                     Machamp  Fighting  No value    505   90     130
# 75                  Bellsprout     Grass    Poison    300   50      75
# 76                  Weepinbell     Grass    Poison    390   65      90
# 77                  Victreebel     Grass    Poison    490   80     105
# 78                   Tentacool     Water    Poison    335   40      40
# 79                  Tentacruel     Water    Poison    515   80      70
# 80                     Geodude      Rock    Ground    300   40      80
# 81                    Graveler      Rock    Ground    390   55      95
# 82                       Golem      Rock    Ground    495   80     120
# 83                      Ponyta      Fire  No value    410   50      85
# 84                    Rapidash      Fire  No value    500   65     100
# 85                    Slowpoke     Water   Psychic    315   90      65
# 86                     Slowbro     Water   Psychic    490   95      75
# 87         SlowbroMega Slowbro     Water   Psychic    590   95      75
# 88                   Magnemite  Electric     Steel    325   25      35
# 89                    Magneton  Electric     Steel    465   50      60
# 90                  Farfetch'd    Normal    Flying    352   52      65
# 91                       Doduo    Normal    Flying    310   35      85
# 92                      Dodrio    Normal    Flying    460   60     110
# 93                        Seel     Water  No value    325   65      45
# 94                     Dewgong     Water       Ice    475   90      70
# 95                      Grimer    Poison  No value    325   80      80
# 96                         Muk    Poison  No value    500  105     105
# 97                    Shellder     Water  No value    305   30      65
# 98                    Cloyster     Water       Ice    525   50      95
# 99                      Gastly     Ghost    Poison    310   30      35
# 100                    Haunter     Ghost    Poison    405   45      50
# 101                     Gengar     Ghost    Poison    500   60      65
# 102          GengarMega Gengar     Ghost    Poison    600   60      65
# 103                       Onix      Rock    Ground    385   35      45
# 104                    Drowzee   Psychic  No value    328   60      48
# 105                      Hypno   Psychic  No value    483   85      73
# 106                     Krabby     Water  No value    325   30     105
# 107                    Kingler     Water  No value    475   55     130
# 108                    Voltorb  Electric  No value    330   40      30
# 109                  Electrode  Electric  No value    480   60      50
# 110                  Exeggcute     Grass   Psychic    325   60      40
# 111                  Exeggutor     Grass   Psychic    520   95      95
# 112                     Cubone    Ground  No value    320   50      50
# 113                    Marowak    Ground  No value    425   60      80
# 114                  Hitmonlee  Fighting  No value    455   50     120
# 115                 Hitmonchan  Fighting  No value    455   50     105
# 116                  Lickitung    Normal  No value    385   90      55
# 117                    Koffing    Poison  No value    340   40      65
# 118                    Weezing    Poison  No value    490   65      90
# 119                    Rhyhorn    Ground      Rock    345   80      85
# 120                     Rhydon    Ground      Rock    485  105     130
# 121                    Chansey    Normal  No value    450  250       5
# 122                    Tangela     Grass  No value    435   65      55
# 123                 Kangaskhan    Normal  No value    490  105      95
# 124  KangaskhanMega Kangaskhan    Normal  No value    590  105     125
# 125                     Horsea     Water  No value    295   30      40
# 126                     Seadra     Water  No value    440   55      65
# 127                    Goldeen     Water  No value    320   45      67
# 128                    Seaking     Water  No value    450   80      92
# 129                     Staryu     Water  No value    340   30      45
# 130                    Starmie     Water   Psychic    520   60      75
# 131                   Mr. Mime   Psychic     Fairy    460   40      45
# 132                    Scyther       Bug    Flying    500   70     110
# 133                       Jynx       Ice   Psychic    455   65      50
# 134                 Electabuzz  Electric  No value    490   65      83
# 135                     Magmar      Fire  No value    495   65      95
# 136                     Pinsir       Bug  No value    500   65     125
# 137          PinsirMega Pinsir       Bug    Flying    600   65     155
# 138                     Tauros    Normal  No value    490   75     100
# 139                   Magikarp     Water  No value    200   20      10
# 140                   Gyarados     Water    Flying    540   95     125
# 141      GyaradosMega Gyarados     Water      Dark    640   95     155
# 142                     Lapras     Water       Ice    535  130      85
# 143                      Ditto    Normal  No value    288   48      48
# 144                      Eevee    Normal  No value    325   55      55
# 145                   Vaporeon     Water  No value    525  130      65
# 146                    Jolteon  Electric  No value    525   65      65
# 147                    Flareon      Fire  No value    525   65     130
# 148                    Porygon    Normal  No value    395   65      60
# 149                    Omanyte      Rock     Water    355   35      40
# 150                    Omastar      Rock     Water    495   70      60
# 151                     Kabuto      Rock     Water    355   30      80
# 152                   Kabutops      Rock     Water    495   60     115
# 153                 Aerodactyl      Rock    Flying    515   80     105
# 154  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 155                    Snorlax    Normal  No value    540  160     110
# 156                   Articuno       Ice    Flying    580   90      85
# 157                     Zapdos  Electric    Flying    580   90      90
# 158                    Moltres      Fire    Flying    580   90     100
# 159                    Dratini    Dragon  No value    300   41      64
# 160                  Dragonair    Dragon  No value    420   61      84
# 161                  Dragonite    Dragon    Flying    600   91     134
# 162                     Mewtwo   Psychic  No value    680  106     110
# 163        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164        MewtwoMega Mewtwo Y   Psychic  No value    780  106     150
# 165                        Mew   Psychic  No value    600  100     100
# 166                  Chikorita     Grass  No value    318   45      49
# 167                    Bayleef     Grass  No value    405   60      62
# 168                   Meganium     Grass  No value    525   80      82
# 169                  Cyndaquil      Fire  No value    309   39      52
# 170                    Quilava      Fire  No value    405   58      64
# 171                 Typhlosion      Fire  No value    534   78      84
# 172                   Totodile     Water  No value    314   50      65
# 173                   Croconaw     Water  No value    405   65      80
# 174                 Feraligatr     Water  No value    530   85     105
# 175                    Sentret    Normal  No value    215   35      46
# 176                     Furret    Normal  No value    415   85      76
# 177                   Hoothoot    Normal    Flying    262   60      30
# 178                    Noctowl    Normal    Flying    442  100      50
# 179                     Ledyba       Bug    Flying    265   40      20
# 180                     Ledian       Bug    Flying    390   55      35
# 181                   Spinarak       Bug    Poison    250   40      60
# 182                    Ariados       Bug    Poison    390   70      90
# 183                     Crobat    Poison    Flying    535   85      90
# 184                   Chinchou     Water  Electric    330   75      38
# 185                    Lanturn     Water  Electric    460  125      58
# 186                      Pichu  Electric  No value    205   20      40
# 187                     Cleffa     Fairy  No value    218   50      25
# 188                  Igglybuff    Normal     Fairy    210   90      30
# 189                     Togepi     Fairy  No value    245   35      20
# 190                    Togetic     Fairy    Flying    405   55      40
# 191                       Natu   Psychic    Flying    320   40      50
# 192                       Xatu   Psychic    Flying    470   65      75
# 193                     Mareep  Electric  No value    280   55      40
# 194                    Flaaffy  Electric  No value    365   70      55
# 195                   Ampharos  Electric  No value    510   90      75
# 196      AmpharosMega Ampharos  Electric    Dragon    610   90      95
# 197                  Bellossom     Grass  No value    490   75      80
# 198                     Marill     Water     Fairy    250   70      20
# 199                  Azumarill     Water     Fairy    420  100      50
# 200                  Sudowoodo      Rock  No value    410   70     100
# 201                   Politoed     Water  No value    500   90      75
# 202                     Hoppip     Grass    Flying    250   35      35
# 203                   Skiploom     Grass    Flying    340   55      45
# 204                   Jumpluff     Grass    Flying    460   75      55
# 205                      Aipom    Normal  No value    360   55      70
# 206                    Sunkern     Grass  No value    180   30      30
# 207                   Sunflora     Grass  No value    425   75      75
# 208                      Yanma       Bug    Flying    390   65      65
# 209                     Wooper     Water    Ground    210   55      45
# 210                   Quagsire     Water    Ground    430   95      85
# 211                     Espeon   Psychic  No value    525   65      65
# 212                    Umbreon      Dark  No value    525   95      65
# 213                    Murkrow      Dark    Flying    405   60      85
# 214                   Slowking     Water   Psychic    490   95      75
# 215                 Misdreavus     Ghost  No value    435   60      60
# 216                      Unown   Psychic  No value    336   48      72
# 217                  Wobbuffet   Psychic  No value    405  190      33
# 218                  Girafarig    Normal   Psychic    455   70      80
# 219                     Pineco       Bug  No value    290   50      65
# 220                 Forretress       Bug     Steel    465   75      90
# 221                  Dunsparce    Normal  No value    415  100      70
# 222                     Gligar    Ground    Flying    430   65      75
# 223                    Steelix     Steel    Ground    510   75      85
# 224        SteelixMega Steelix     Steel    Ground    610   75     125
# 225                   Snubbull     Fairy  No value    300   60      80
# 226                   Granbull     Fairy  No value    450   90     120
# 227                   Qwilfish     Water    Poison    430   65      95
# 228                     Scizor       Bug     Steel    500   70     130
# 229          ScizorMega Scizor       Bug     Steel    600   70     150
# 230                    Shuckle       Bug      Rock    505   20      10
# 231                  Heracross       Bug  Fighting    500   80     125
# 232    HeracrossMega Heracross       Bug  Fighting    600   80     185
# 233                    Sneasel      Dark       Ice    430   55      95
# 234                  Teddiursa    Normal  No value    330   60      80
# 235                   Ursaring    Normal  No value    500   90     130
# 236                     Slugma      Fire  No value    250   40      40
# 237                   Magcargo      Fire      Rock    410   50      50
# 238                     Swinub       Ice    Ground    250   50      50
# 239                  Piloswine       Ice    Ground    450  100     100
# 240                    Corsola     Water      Rock    380   55      55
# 241                   Remoraid     Water  No value    300   35      65
# 242                  Octillery     Water  No value    480   75     105
# 243                   Delibird       Ice    Flying    330   45      55
# 244                    Mantine     Water    Flying    465   65      40
# 245                   Skarmory     Steel    Flying    465   65      80
# 246                   Houndour      Dark      Fire    330   45      60
# 247                   Houndoom      Dark      Fire    500   75      90
# 248      HoundoomMega Houndoom      Dark      Fire    600   75      90
# 249                    Kingdra     Water    Dragon    540   75      95
# 250                     Phanpy    Ground  No value    330   90      60
# 251                    Donphan    Ground  No value    500   90     120
# 252                   Porygon2    Normal  No value    515   85      80
# 253                   Stantler    Normal  No value    465   73      95
# 254                   Smeargle    Normal  No value    250   55      20
# 255                    Tyrogue  Fighting  No value    210   35      35
# 256                  Hitmontop  Fighting  No value    455   50      95
# 257                   Smoochum       Ice   Psychic    305   45      30
# 258                     Elekid  Electric  No value    360   45      63
# 259                      Magby      Fire  No value    365   45      75
# 260                    Miltank    Normal  No value    490   95      80
# 261                    Blissey    Normal  No value    540  255      10
# 262                     Raikou  Electric  No value    580   90      85
# 263                      Entei      Fire  No value    580  115     115
# 264                    Suicune     Water  No value    580  100      75
# 265                   Larvitar      Rock    Ground    300   50      64
# 266                    Pupitar      Rock    Ground    410   70      84
# 267                  Tyranitar      Rock      Dark    600  100     134
# 268    TyranitarMega Tyranitar      Rock      Dark    700  100     164
# 269                      Lugia   Psychic    Flying    680  106      90
# 270                      Ho-oh      Fire    Flying    680  106     130
# 271                     Celebi   Psychic     Grass    600  100     100
# 272                    Treecko     Grass  No value    310   40      45
# 273                    Grovyle     Grass  No value    405   50      65
# 274                   Sceptile     Grass  No value    530   70      85
# 275      SceptileMega Sceptile     Grass    Dragon    630   70     110
# 276                    Torchic      Fire  No value    310   45      60
# 277                  Combusken      Fire  Fighting    405   60      85
# 278                   Blaziken      Fire  Fighting    530   80     120
# 279      BlazikenMega Blaziken      Fire  Fighting    630   80     160
# 280                     Mudkip     Water  No value    310   50      70
# 281                  Marshtomp     Water    Ground    405   70      85
# 282                   Swampert     Water    Ground    535  100     110
# 283      SwampertMega Swampert     Water    Ground    635  100     150
# 284                  Poochyena      Dark  No value    220   35      55
# 285                  Mightyena      Dark  No value    420   70      90
# 286                  Zigzagoon    Normal  No value    240   38      30
# 287                    Linoone    Normal  No value    420   78      70
# 288                    Wurmple       Bug  No value    195   45      45
# 289                    Silcoon       Bug  No value    205   50      35
# 290                  Beautifly       Bug    Flying    395   60      70
# 291                    Cascoon       Bug  No value    205   50      35
# 292                     Dustox       Bug    Poison    385   60      50
# 293                      Lotad     Water     Grass    220   40      30
# 294                     Lombre     Water     Grass    340   60      50
# 295                   Ludicolo     Water     Grass    480   80      70
# 296                     Seedot     Grass  No value    220   40      40
# 297                    Nuzleaf     Grass      Dark    340   70      70
# 298                    Shiftry     Grass      Dark    480   90     100
# 299                    Taillow    Normal    Flying    270   40      55
# 300                    Swellow    Normal    Flying    430   60      85
# 301                    Wingull     Water    Flying    270   40      30
# 302                   Pelipper     Water    Flying    430   60      50
# 303                      Ralts   Psychic     Fairy    198   28      25
# 304                     Kirlia   Psychic     Fairy    278   38      35
# 305                  Gardevoir   Psychic     Fairy    518   68      65
# 306    GardevoirMega Gardevoir   Psychic     Fairy    618   68      85
# 307                    Surskit       Bug     Water    269   40      30
# 308                 Masquerain       Bug    Flying    414   70      60
# 309                  Shroomish     Grass  No value    295   60      40
# 310                    Breloom     Grass  Fighting    460   60     130
# 311                    Slakoth    Normal  No value    280   60      60
# 312                   Vigoroth    Normal  No value    440   80      80
# 313                    Slaking    Normal  No value    670  150     160
# 314                    Nincada       Bug    Ground    266   31      45
# 315                    Ninjask       Bug    Flying    456   61      90
# 316                   Shedinja       Bug     Ghost    236    1      90
# 317                    Whismur    Normal  No value    240   64      51
# 318                    Loudred    Normal  No value    360   84      71
# 319                    Exploud    Normal  No value    490  104      91
# 320                   Makuhita  Fighting  No value    237   72      60
# 321                   Hariyama  Fighting  No value    474  144     120
# 322                    Azurill    Normal     Fairy    190   50      20
# 323                   Nosepass      Rock  No value    375   30      45
# 324                     Skitty    Normal  No value    260   50      45
# 325                   Delcatty    Normal  No value    380   70      65
# 326                    Sableye      Dark     Ghost    380   50      75
# 327        SableyeMega Sableye      Dark     Ghost    480   50      85
# 328                     Mawile     Steel     Fairy    380   50      85
# 329          MawileMega Mawile     Steel     Fairy    480   50     105
# 330                       Aron     Steel      Rock    330   50      70
# 331                     Lairon     Steel      Rock    430   60      90
# 332                     Aggron     Steel      Rock    530   70     110
# 333          AggronMega Aggron     Steel  No value    630   70     140
# 334                   Meditite  Fighting   Psychic    280   30      40
# 335                   Medicham  Fighting   Psychic    410   60      60
# 336      MedichamMega Medicham  Fighting   Psychic    510   60     100
# 337                  Electrike  Electric  No value    295   40      45
# 338                  Manectric  Electric  No value    475   70      75
# 339    ManectricMega Manectric  Electric  No value    575   70      75
# 340                     Plusle  Electric  No value    405   60      50
# 341                      Minun  Electric  No value    405   60      40
# 342                    Volbeat       Bug  No value    400   65      73
# 343                   Illumise       Bug  No value    400   65      47
# 344                    Roselia     Grass    Poison    400   50      60
# 345                     Gulpin    Poison  No value    302   70      43
# 346                     Swalot    Poison  No value    467  100      73
# 347                   Carvanha     Water      Dark    305   45      90
# 348                   Sharpedo     Water      Dark    460   70     120
# 349      SharpedoMega Sharpedo     Water      Dark    560   70     140
# 350                    Wailmer     Water  No value    400  130      70
# 351                    Wailord     Water  No value    500  170      90
# 352                      Numel      Fire    Ground    305   60      60
# 353                   Camerupt      Fire    Ground    460   70     100
# 354      CameruptMega Camerupt      Fire    Ground    560   70     120
# 355                    Torkoal      Fire  No value    470   70      85
# 356                     Spoink   Psychic  No value    330   60      25
# 357                    Grumpig   Psychic  No value    470   80      45
# 358                     Spinda    Normal  No value    360   60      60
# 359                   Trapinch    Ground  No value    290   45     100
# 360                    Vibrava    Ground    Dragon    340   50      70
# 361                     Flygon    Ground    Dragon    520   80     100
# 362                     Cacnea     Grass  No value    335   50      85
# 363                   Cacturne     Grass      Dark    475   70     115
# 364                     Swablu    Normal    Flying    310   45      40
# 365                    Altaria    Dragon    Flying    490   75      70
# 366        AltariaMega Altaria    Dragon     Fairy    590   75     110
# 367                   Zangoose    Normal  No value    458   73     115
# 368                    Seviper    Poison  No value    458   73     100
# 369                   Lunatone      Rock   Psychic    440   70      55
# 370                    Solrock      Rock   Psychic    440   70      95
# 371                   Barboach     Water    Ground    288   50      48
# 372                   Whiscash     Water    Ground    468  110      78
# 373                   Corphish     Water  No value    308   43      80
# 374                  Crawdaunt     Water      Dark    468   63     120
# 375                     Baltoy    Ground   Psychic    300   40      40
# 376                    Claydol    Ground   Psychic    500   60      70
# 377                     Lileep      Rock     Grass    355   66      41
# 378                    Cradily      Rock     Grass    495   86      81
# 379                    Anorith      Rock       Bug    355   45      95
# 380                    Armaldo      Rock       Bug    495   75     125
# 381                     Feebas     Water  No value    200   20      15
# 382                    Milotic     Water  No value    540   95      60
# 383                   Castform    Normal  No value    420   70      70
# 384                    Kecleon    Normal  No value    440   60      90
# 385                    Shuppet     Ghost  No value    295   44      75
# 386                    Banette     Ghost  No value    455   64     115
# 387        BanetteMega Banette     Ghost  No value    555   64     165
# 388                    Duskull     Ghost  No value    295   20      40
# 389                   Dusclops     Ghost  No value    455   40      70
# 390                    Tropius     Grass    Flying    460   99      68
# 391                   Chimecho   Psychic  No value    425   65      50
# 392                      Absol      Dark  No value    465   65     130
# 393            AbsolMega Absol      Dark  No value    565   65     150
# 394                     Wynaut   Psychic  No value    260   95      23
# 395                    Snorunt       Ice  No value    300   50      50
# 396                     Glalie       Ice  No value    480   80      80
# 397          GlalieMega Glalie       Ice  No value    580   80     120
# 398                     Spheal       Ice     Water    290   70      40
# 399                     Sealeo       Ice     Water    410   90      60
# 400                    Walrein       Ice     Water    530  110      80
# 401                   Clamperl     Water  No value    345   35      64
# 402                    Huntail     Water  No value    485   55     104
# 403                   Gorebyss     Water  No value    485   55      84
# 404                  Relicanth     Water      Rock    485  100      90
# 405                    Luvdisc     Water  No value    330   43      30
# 406                      Bagon    Dragon  No value    300   45      75
# 407                    Shelgon    Dragon  No value    420   65      95
# 408                  Salamence    Dragon    Flying    600   95     135
# 409    SalamenceMega Salamence    Dragon    Flying    700   95     145
# 410                     Beldum     Steel   Psychic    300   40      55
# 411                     Metang     Steel   Psychic    420   60      75
# 412                  Metagross     Steel   Psychic    600   80     135
# 413    MetagrossMega Metagross     Steel   Psychic    700   80     145
# 414                   Regirock      Rock  No value    580   80     100
# 415                     Regice       Ice  No value    580   80      50
# 416                  Registeel     Steel  No value    580   80      75
# 417                     Latias    Dragon   Psychic    600   80      80
# 418          LatiasMega Latias    Dragon   Psychic    700   80     100
# 419                     Latios    Dragon   Psychic    600   80      90
# 420          LatiosMega Latios    Dragon   Psychic    700   80     130
# 421                     Kyogre     Water  No value    670  100     100
# 422        KyogrePrimal Kyogre     Water  No value    770  100     150
# 423                    Groudon    Ground  No value    670  100     150
# 424      GroudonPrimal Groudon    Ground      Fire    770  100     180
# 425                   Rayquaza    Dragon    Flying    680  105     150
# 426      RayquazaMega Rayquaza    Dragon    Flying    780  105     180
# 427                    Jirachi     Steel   Psychic    600  100     100
# 428         DeoxysNormal Forme   Psychic  No value    600   50     150
# 429         DeoxysAttack Forme   Psychic  No value    600   50     180
# 430        DeoxysDefense Forme   Psychic  No value    600   50      70
# 431          DeoxysSpeed Forme   Psychic  No value    600   50      95
# 432                    Turtwig     Grass  No value    318   55      68
# 433                     Grotle     Grass  No value    405   75      89
# 434                   Torterra     Grass    Ground    525   95     109
# 435                   Chimchar      Fire  No value    309   44      58
# 436                   Monferno      Fire  Fighting    405   64      78
# 437                  Infernape      Fire  Fighting    534   76     104
# 438                     Piplup     Water  No value    314   53      51
# 439                   Prinplup     Water  No value    405   64      66
# 440                   Empoleon     Water     Steel    530   84      86
# 441                     Starly    Normal    Flying    245   40      55
# 442                   Staravia    Normal    Flying    340   55      75
# 443                  Staraptor    Normal    Flying    485   85     120
# 444                     Bidoof    Normal  No value    250   59      45
# 445                    Bibarel    Normal     Water    410   79      85
# 446                  Kricketot       Bug  No value    194   37      25
# 447                 Kricketune       Bug  No value    384   77      85
# 448                      Shinx  Electric  No value    263   45      65
# 449                      Luxio  Electric  No value    363   60      85
# 450                     Luxray  Electric  No value    523   80     120
# 451                      Budew     Grass    Poison    280   40      30
# 452                   Roserade     Grass    Poison    515   60      70
# 453                   Cranidos      Rock  No value    350   67     125
# 454                  Rampardos      Rock  No value    495   97     165
# 455                   Shieldon      Rock     Steel    350   30      42
# 456                  Bastiodon      Rock     Steel    495   60      52
# 457                      Burmy       Bug  No value    224   40      29
# 458        WormadamPlant Cloak       Bug     Grass    424   60      59
# 459        WormadamSandy Cloak       Bug    Ground    424   60      79
# 460        WormadamTrash Cloak       Bug     Steel    424   60      69
# 461                     Mothim       Bug    Flying    424   70      94
# 462                     Combee       Bug    Flying    244   30      30
# 463                  Vespiquen       Bug    Flying    474   70      80
# 464                  Pachirisu  Electric  No value    405   60      45
# 465                     Buizel     Water  No value    330   55      65
# 466                   Floatzel     Water  No value    495   85     105
# 467                    Cherubi     Grass  No value    275   45      35
# 468                    Cherrim     Grass  No value    450   70      60
# 469                    Shellos     Water  No value    325   76      48
# 470                  Gastrodon     Water    Ground    475  111      83
# 471                    Ambipom    Normal  No value    482   75     100
# 472                   Drifloon     Ghost    Flying    348   90      50
# 473                   Drifblim     Ghost    Flying    498  150      80
# 474                    Buneary    Normal  No value    350   55      66
# 475                    Lopunny    Normal  No value    480   65      76
# 476        LopunnyMega Lopunny    Normal  Fighting    580   65     136
# 477                  Mismagius     Ghost  No value    495   60      60
# 478                  Honchkrow      Dark    Flying    505  100     125
# 479                    Glameow    Normal  No value    310   49      55
# 480                    Purugly    Normal  No value    452   71      82
# 481                  Chingling   Psychic  No value    285   45      30
# 482                     Stunky    Poison      Dark    329   63      63
# 483                   Skuntank    Poison      Dark    479  103      93
# 484                    Bronzor     Steel   Psychic    300   57      24
# 485                   Bronzong     Steel   Psychic    500   67      89
# 486                     Bonsly      Rock  No value    290   50      80
# 487                   Mime Jr.   Psychic     Fairy    310   20      25
# 488                    Happiny    Normal  No value    220  100       5
# 489                     Chatot    Normal    Flying    411   76      65
# 490                  Spiritomb     Ghost      Dark    485   50      92
# 491                      Gible    Dragon    Ground    300   58      70
# 492                     Gabite    Dragon    Ground    410   68      90
# 493                   Garchomp    Dragon    Ground    600  108     130
# 494      GarchompMega Garchomp    Dragon    Ground    700  108     170
# 495                   Munchlax    Normal  No value    390  135      85
# 496                      Riolu  Fighting  No value    285   40      70
# 497                    Lucario  Fighting     Steel    525   70     110
# 498        LucarioMega Lucario  Fighting     Steel    625   70     145
# 499                 Hippopotas    Ground  No value    330   68      72
# 500                  Hippowdon    Ground  No value    525  108     112
# 501                    Skorupi    Poison       Bug    330   40      50
# 502                    Drapion    Poison      Dark    500   70      90
# 503                   Croagunk    Poison  Fighting    300   48      61
# 504                  Toxicroak    Poison  Fighting    490   83     106
# 505                  Carnivine     Grass  No value    454   74     100
# 506                    Finneon     Water  No value    330   49      49
# 507                   Lumineon     Water  No value    460   69      69
# 508                    Mantyke     Water    Flying    345   45      20
# 509                     Snover     Grass       Ice    334   60      62
# 510                  Abomasnow     Grass       Ice    494   90      92
# 511    AbomasnowMega Abomasnow     Grass       Ice    594   90     132
# 512                    Weavile      Dark       Ice    510   70     120
# 513                  Magnezone  Electric     Steel    535   70      70
# 514                 Lickilicky    Normal  No value    515  110      85
# 515                  Rhyperior    Ground      Rock    535  115     140
# 516                  Tangrowth     Grass  No value    535  100     100
# 517                 Electivire  Electric  No value    540   75     123
# 518                  Magmortar      Fire  No value    540   75      95
# 519                   Togekiss     Fairy    Flying    545   85      50
# 520                    Yanmega       Bug    Flying    515   86      76
# 521                    Leafeon     Grass  No value    525   65     110
# 522                    Glaceon       Ice  No value    525   65      60
# 523                    Gliscor    Ground    Flying    510   75      95
# 524                  Mamoswine       Ice    Ground    530  110     130
# 525                  Porygon-Z    Normal  No value    535   85      80
# 526                    Gallade   Psychic  Fighting    518   68     125
# 527        GalladeMega Gallade   Psychic  Fighting    618   68     165
# 528                  Probopass      Rock     Steel    525   60      55
# 529                   Dusknoir     Ghost  No value    525   45     100
# 530                   Froslass       Ice     Ghost    480   70      80
# 531                      Rotom  Electric     Ghost    440   50      50
# 532            RotomHeat Rotom  Electric      Fire    520   50      65
# 533            RotomWash Rotom  Electric     Water    520   50      65
# 534           RotomFrost Rotom  Electric       Ice    520   50      65
# 535             RotomFan Rotom  Electric    Flying    520   50      65
# 536             RotomMow Rotom  Electric     Grass    520   50      65
# 537                       Uxie   Psychic  No value    580   75      75
# 538                    Mesprit   Psychic  No value    580   80     105
# 539                      Azelf   Psychic  No value    580   75     125
# 540                     Dialga     Steel    Dragon    680  100     120
# 541                     Palkia     Water    Dragon    680   90     120
# 542                    Heatran      Fire     Steel    600   91      90
# 543                  Regigigas    Normal  No value    670  110     160
# 544      GiratinaAltered Forme     Ghost    Dragon    680  150     100
# 545       GiratinaOrigin Forme     Ghost    Dragon    680  150     120
# 546                  Cresselia   Psychic  No value    600  120      70
# 547                     Phione     Water  No value    480   80      80
# 548                    Manaphy     Water  No value    600  100     100
# 549                    Darkrai      Dark  No value    600   70      90
# 550          ShayminLand Forme     Grass  No value    600  100     100
# 551           ShayminSky Forme     Grass    Flying    600  100     103
# 552                     Arceus    Normal  No value    720  120     120
# 553                    Victini   Psychic      Fire    600  100     100
# 554                      Snivy     Grass  No value    308   45      45
# 555                    Servine     Grass  No value    413   60      60
# 556                  Serperior     Grass  No value    528   75      75
# 557                      Tepig      Fire  No value    308   65      63
# 558                    Pignite      Fire  Fighting    418   90      93
# 559                     Emboar      Fire  Fighting    528  110     123
# 560                   Oshawott     Water  No value    308   55      55
# 561                     Dewott     Water  No value    413   75      75
# 562                   Samurott     Water  No value    528   95     100
# 563                     Patrat    Normal  No value    255   45      55
# 564                    Watchog    Normal  No value    420   60      85
# 565                   Lillipup    Normal  No value    275   45      60
# 566                    Herdier    Normal  No value    370   65      80
# 567                  Stoutland    Normal  No value    500   85     110
# 568                   Purrloin      Dark  No value    281   41      50
# 569                    Liepard      Dark  No value    446   64      88
# 570                    Pansage     Grass  No value    316   50      53
# 571                   Simisage     Grass  No value    498   75      98
# 572                    Pansear      Fire  No value    316   50      53
# 573                   Simisear      Fire  No value    498   75      98
# 574                    Panpour     Water  No value    316   50      53
# 575                   Simipour     Water  No value    498   75      98
# 576                      Munna   Psychic  No value    292   76      25
# 577                   Musharna   Psychic  No value    487  116      55
# 578                     Pidove    Normal    Flying    264   50      55
# 579                  Tranquill    Normal    Flying    358   62      77
# 580                   Unfezant    Normal    Flying    488   80     115
# 581                    Blitzle  Electric  No value    295   45      60
# 582                  Zebstrika  Electric  No value    497   75     100
# 583                 Roggenrola      Rock  No value    280   55      75
# 584                    Boldore      Rock  No value    390   70     105
# 585                   Gigalith      Rock  No value    515   85     135
# 586                     Woobat   Psychic    Flying    313   55      45
# 587                    Swoobat   Psychic    Flying    425   67      57
# 588                    Drilbur    Ground  No value    328   60      85
# 589                  Excadrill    Ground     Steel    508  110     135
# 590                     Audino    Normal  No value    445  103      60
# 591          AudinoMega Audino    Normal     Fairy    545  103      60
# 592                    Timburr  Fighting  No value    305   75      80
# 593                    Gurdurr  Fighting  No value    405   85     105
# 594                 Conkeldurr  Fighting  No value    505  105     140
# 595                    Tympole     Water  No value    294   50      50
# 596                  Palpitoad     Water    Ground    384   75      65
# 597                 Seismitoad     Water    Ground    509  105      95
# 598                      Throh  Fighting  No value    465  120     100
# 599                       Sawk  Fighting  No value    465   75     125
# 600                   Sewaddle       Bug     Grass    310   45      53
# 601                   Swadloon       Bug     Grass    380   55      63
# 602                   Leavanny       Bug     Grass    500   75     103
# 603                   Venipede       Bug    Poison    260   30      45
# 604                 Whirlipede       Bug    Poison    360   40      55
# 605                  Scolipede       Bug    Poison    485   60     100
# 606                   Cottonee     Grass     Fairy    280   40      27
# 607                 Whimsicott     Grass     Fairy    480   60      67
# 608                    Petilil     Grass  No value    280   45      35
# 609                  Lilligant     Grass  No value    480   70      60
# 610                   Basculin     Water  No value    460   70      92
# 611                    Sandile    Ground      Dark    292   50      72
# 612                   Krokorok    Ground      Dark    351   60      82
# 613                 Krookodile    Ground      Dark    519   95     117
# 614                   Darumaka      Fire  No value    315   70      90
# 615    DarmanitanStandard Mode      Fire  No value    480  105     140
# 616         DarmanitanZen Mode      Fire   Psychic    540  105      30
# 617                   Maractus     Grass  No value    461   75      86
# 618                    Dwebble       Bug      Rock    325   50      65
# 619                    Crustle       Bug      Rock    475   70      95
# 620                    Scraggy      Dark  Fighting    348   50      75
# 621                    Scrafty      Dark  Fighting    488   65      90
# 622                   Sigilyph   Psychic    Flying    490   72      58
# 623                     Yamask     Ghost  No value    303   38      30
# 624                 Cofagrigus     Ghost  No value    483   58      50
# 625                   Tirtouga     Water      Rock    355   54      78
# 626                 Carracosta     Water      Rock    495   74     108
# 627                     Archen      Rock    Flying    401   55     112
# 628                   Archeops      Rock    Flying    567   75     140
# 629                   Trubbish    Poison  No value    329   50      50
# 630                   Garbodor    Poison  No value    474   80      95
# 631                      Zorua      Dark  No value    330   40      65
# 632                    Zoroark      Dark  No value    510   60     105
# 633                   Minccino    Normal  No value    300   55      50
# 634                   Cinccino    Normal  No value    470   75      95
# 635                    Gothita   Psychic  No value    290   45      30
# 636                  Gothorita   Psychic  No value    390   60      45
# 637                 Gothitelle   Psychic  No value    490   70      55
# 638                    Solosis   Psychic  No value    290   45      30
# 639                    Duosion   Psychic  No value    370   65      40
# 640                  Reuniclus   Psychic  No value    490  110      65
# 641                   Ducklett     Water    Flying    305   62      44
# 642                     Swanna     Water    Flying    473   75      87
# 643                  Vanillite       Ice  No value    305   36      50
# ...
# 538      105     105     105     80           4       True
# 539       70     125      70    115           4       True
# 540      120     150     100     90           4       True
# 541      100     150     120    100           4       True
# 542      106     130     106     77           4       True
# 543      110      80     110    100           4       True
# 544      120     100     120     90           4       True
# 545      100     120     100     90           4       True
# 546      120      75     130     85           4      False
# 547       80      80      80     80           4      False
# 548      100     100     100    100           4      False
# 549       90     135      90    125           4       True
# 550      100     100     100    100           4       True
# 551       75     120      75    127           4       True
# 552      120     120     120    120           4       True
# 553      100     100     100    100           5       True
# 554       55      45      55     63           5      False
# 555       75      60      75     83           5      False
# 556       95      75      95    113           5      False
# 557       45      45      45     45           5      False
# 558       55      70      55     55           5      False
# 559       65     100      65     65           5      False
# 560       45      63      45     45           5      False
# 561       60      83      60     60           5      False
# 562       85     108      70     70           5      False
# 563       39      35      39     42           5      False
# 564       69      60      69     77           5      False
# 565       45      25      45     55           5      False
# 566       65      35      65     60           5      False
# 567       90      45      90     80           5      False
# 568       37      50      37     66           5      False
# 569       50      88      50    106           5      False
# 570       48      53      48     64           5      False
# 571       63      98      63    101           5      False
# 572       48      53      48     64           5      False
# 573       63      98      63    101           5      False
# 574       48      53      48     64           5      False
# 575       63      98      63    101           5      False
# 576       45      67      55     24           5      False
# 577       85     107      95     29           5      False
# 578       50      36      30     43           5      False
# 579       62      50      42     65           5      False
# 580       80      65      55     93           5      False
# 581       32      50      32     76           5      False
# 582       63      80      63    116           5      False
# 583       85      25      25     15           5      False
# 584      105      50      40     20           5      False
# 585      130      60      80     25           5      False
# 586       43      55      43     72           5      False
# 587       55      77      55    114           5      False
# 588       40      30      45     68           5      False
# 589       60      50      65     88           5      False
# 590       86      60      86     50           5      False
# 591      126      80     126     50           5      False
# 592       55      25      35     35           5      False
# 593       85      40      50     40           5      False
# 594       95      55      65     45           5      False
# 595       40      50      40     64           5      False
# 596       55      65      55     69           5      False
# 597       75      85      75     74           5      False
# 598       85      30      85     45           5      False
# 599       75      30      75     85           5      False
# 600       70      40      60     42           5      False
# 601       90      50      80     42           5      False
# 602       80      70      80     92           5      False
# 603       59      30      39     57           5      False
# 604       99      40      79     47           5      False
# 605       89      55      69    112           5      False
# 606       60      37      50     66           5      False
# 607       85      77      75    116           5      False
# 608       50      70      50     30           5      False
# 609       75     110      75     90           5      False
# 610       65      80      55     98           5      False
# 611       35      35      35     65           5      False
# 612       45      45      45     74           5      False
# 613       80      65      70     92           5      False
# 614       45      15      45     50           5      False
# 615       55      30      55     95           5      False
# 616      105     140     105     55           5      False
# 617       67     106      67     60           5      False
# 618       85      35      35     55           5      False
# 619      125      65      75     45           5      False
# 620       70      35      70     48           5      False
# 621      115      45     115     58           5      False
# 622       80     103      80     97           5      False
# 623       85      55      65     30           5      False
# 624      145      95     105     30           5      False
# 625      103      53      45     22           5      False
# 626      133      83      65     32           5      False
# 627       45      74      45     70           5      False
# 628       65     112      65    110           5      False
# 629       62      40      62     65           5      False
# 630       82      60      82     75           5      False
# 631       40      80      40     65           5      False
# 632       60     120      60    105           5      False
# 633       40      40      40     75           5      False
# 634       60      65      60    115           5      False
# 635       50      55      65     45           5      False
# 636       70      75      85     55           5      False
# 637       95      95     110     65           5      False
# 638       40     105      50     20           5      False
# 639       50     125      60     30           5      False
# 640       75     125      85     30           5      False
# 641       50      44      50     55           5      False
# 642       63      87      63     98           5      False
# 643       50      65      60     44           5      False
# 644       65      80      75     59           5      False
# 645       85     110      95     79           5      False
# 646       50      40      50     75           5      False
# 647       70      60      70     95           5      False
# 648       60      75      60    103           5      False
# 649       45      40      45     60           5      False
# 650      105      60     105     20           5      False
# 651       45      55      55     15           5      False
# 652       70      85      80     30           5      False
# 653       50      65      85     40           5      False
# 654       70      85     105     60           5      False
# 655       80      40      45     65           5      False
# 656       50      57      50     65           5      False
# 657       60      97      60    108           5      False
# 658       91      24      86     10           5      False
# 659      131      54     116     20           5      False
# 660       70      45      60     30           5      False
# 661       95      70      85     50           5      False
# 662      115      70      85     90           5      False
# 663       40      45      40     60           5      False
# 664       70      75      70     40           5      False
# 665       80     105      80     50           5      False
# 666       55      85      55     30           5      False
# 667       75     125      95     40           5      False
# 668       55      65      55     20           5      False
# 669       60      95      60     55           5      False
# 670       90     145      90     80           5      False
# 671       60      30      40     57           5      False
# 672       70      40      50     67           5      False
# 673       90      60      70     97           5      False
# 674       40      60      40     40           5      False
# 675       80      70      80     50           5      False
# 676       30      95     135    105           5      False
# 677       85      40      65     25           5      False
# 678       40     100      60    145           5      False
# 679       84      81      99     32           5      False
# 680       50      55      50     65           5      False
# 681       60      95      60    105           5      False
# 682       90      60      90     48           5      False
# 683       50      35      50     35           5      False
# 684       80      55      80     55           5      False
# 685       70      40      40     60           5      False
# 686      100      60      70     70           5      False
# 687       95      40      95     55           5      False
# 688       50      37      50     60           5      False
# 689       75      57      75     80           5      False
# 690       75      45      65     60           5      False
# 691      105      55      95     80           5      False
# 692       66     105      66     65           5      False
# 693      112      48      48    109           5      False
# 694       50      45      50     38           5      False
# 695       70      65      70     58           5      False
# 696       90     125      90     98           5      False
# 697       55      50      55     60           5      False
# 698       65     135     105    100           5      False
# 699      129      90      72    108           5       True
# 700       90      72      90    108           5       True
# 701       72      90     129    108           5       True
# 702       70     125      80    111           5       True
# 703       80     110      90    121           5       True
# 704       70     125      80    111           5       True
# 705       70     145      80    101           5       True
# 706      100     150     120     90           5       True
# 707      120     120     100     90           5       True
# 708       90     115      80    101           5       True
# 709       90     105      80     91           5       True
# 710       90     130      90     95           5       True
# 711      100     120      90     95           5       True
# 712       90     170     100     95           5       True
# 713       90     129      90    108           5      False
# 714       90     129      90    108           5      False
# 715       77     128     128     90           5      False
# 716       90      77      77    128           5      False
# 717       95     120      95     99           5      False
# 718       65      48      45     38           6      False
# 719       95      56      58     57           6      False
# 720      122      74      75     64           6      False
# 721       40      62      60     60           6      False
# 722       58      90      70     73           6      False
# 723       72     114     100    104           6      False
# 724       40      62      44     71           6      False
# 725       52      83      56     97           6      False
# 726       67     103      71    122           6      False
# 727       38      32      36     57           6      False
# 728       77      50      77     78           6      False
# 729       43      40      38     62           6      False
# 730       55      56      52     84           6      False
# 731       71      74      69    126           6      False
# 732       40      27      25     35           6      False
# 733       60      27      30     29           6      False
# 734       50      90      50     89           6      False
# 735       58      73      54     72           6      False
# 736       72     109      66    106           6      False
# 737       39      61      79     42           6      False
# 738       47      75      98     52           6      False
# 739       68     112     154     75           6      False
# 740       48      62      57     52           6      False
# 741       62      97      81     68           6      False
# 742       62      46      48     43           6      False
# 743       78      69      71     58           6      False
# 744       60      65      90    102           6      False
# 745       54      63      60     68           6      False
# 746       76      83      81    104           6      False
# 747       76      83      81    104           6      False
# 748      100      35      37     28           6      False
# 749      150      45      49     35           6      False
# 750       50     150      50     60           6      False
# 751      150      50     150     60           6      False
# 752       60      63      65     23           6      False
# 753       72      99      89     29           6      False
# 754       66      59      57     49           6      False
# 755       86      85      75     72           6      False
# 756       53      37      46     45           6      False
# 757       88      68      75     73           6      False
# 758       67      39      56     50           6      False
# 759      115      54      86     68           6      False
# 760       60      60      60     30           6      False
# 761       90      97     123     44           6      False
# 762       62      58      63     44           6      False
# 763       88     120      89     59           6      False
# 764       33      61      43     70           6      False
# 765       52     109      94    109           6      False
# 766       77      45      45     48           6      False
# 767      119      69      59     71           6      False
# 768       50      67      63     46           6      False
# 769       72      99      92     58           6      False
# 770       65     110     130     60           6      False
# 771       75      74      63    118           6      False
# 772       57      81      67    101           6      False
# 773      150      50     150     50           6      False
# 774       35      55      75     40           6      False
# 775       53      83     113     60           6      False
# 776       70     110     150     80           6      False
# 777       91      80      87     75           6      False
# 778       48      50      60     38           6      False
# 779       76      65      82     56           6      False
# 780       70      44      55     51           6      False
# 781       70      44      55     56           6      False
# 782       70      44      55     46           6      False
# 783       70      44      55     41           6      False
# 784      122      58      75     84           6      False
# 785      122      58      75     99           6      False
# 786      122      58      75     69           6      False
# 787      122      58      75     54           6      False
# 788       85      32      35     28           6      False
# 789      184      44      46     28           6      False
# 790       35      45      40     55           6      False
# 791       80      97      80    123           6      False
# 792       95     131      98     99           6       True
# 793       95     131      98     99           6       True
# 794      121      81      95     95           6       True
# 795      150     100     150     50           6       True
# 796      110     160     110    110           6       True
# 797       60     150     130     70           6       True
# 798       60     170     130     80           6       True
# 799      120     130      90     70           6       True

# %%
# Group by type and summarise with average
pokeGroup = pokemon.groupby("Type1").mean()

# Use "Total" for comparison since it compares total power
pokeGroup = pokeGroup.sort_values('Total', ascending = False)
# rank by total points
# http://www.datasciencemadesimple.com/rank-dataframe-python-pandas-min-max-dense-rank-group/
pokeGroup['total_ranked']=pokeGroup['Total'].rank(ascending=0)
pokeGroup
# Out:
#                Total         HP      Attack     Defense     Sp_Atk     Sp_Def  \
# Type1
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Steel     487.703704  65.222222   92.703704  126.370370  67.518519  80.629630
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Psychic   475.947368  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Rock      453.750000  65.363636   92.863636  100.795455  63.340909  75.477273
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Electric  443.409091  59.795455   69.090909   66.295455  90.022727  73.704545
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Ice       433.458333  72.000000   72.750000   71.416667  77.541667  76.291667
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Fairy     413.176471  74.117647   61.529412   65.705882  78.529412  84.705882
# Normal    401.683673  77.275510   73.469388   59.846939  55.816327  63.724490
# Poison    399.142857  67.250000   74.678571   68.821429  60.428571  64.392857
# Bug       378.927536  56.884058   70.971014   70.724638  53.869565  64.797101
#
#                Speed  Generation  Legendary  total_ranked
# Type1
# Dragon     83.031250    3.875000   0.375000           1.0
# Steel      55.259259    3.851852   0.148148           2.0
# Flying    102.500000    5.500000   0.500000           3.0
# Psychic    81.491228    3.385965   0.245614           4.0
# Fire       74.442308    3.211538   0.096154           5.0
# Rock       55.909091    3.454545   0.090909           6.0
# Dark       76.161290    4.032258   0.064516           7.0
# Electric   84.500000    3.272727   0.090909           8.0
# Ghost      64.343750    4.187500   0.062500           9.0
# Ground     63.906250    3.156250   0.125000          10.0
# Ice        63.458333    3.541667   0.083333          11.0
# Water      65.964286    2.857143   0.035714          12.0
# Grass      61.928571    3.357143   0.042857          13.0
# Fighting   66.074074    3.370370   0.000000          14.0
# Fairy      48.588235    4.117647   0.058824          15.0
# Normal     71.551020    3.051020   0.020408          16.0
# Poison     63.571429    2.535714   0.000000          17.0
# Bug        61.681159    3.217391   0.000000          18.0

# %%
# Join moves dataset and Pokemon dataset
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html
full = compareMix.join(pokeGroup)
full = full.sort_values('Total')
full
# Out:
#               Power         PP       Prob  Accuracy       Total         HP  \
# Type
# Bug       40.645161  15.354839  30.000000     100.0  378.927536  56.884058
# Poison    33.793103  16.931034  31.666667      90.0  399.142857  67.250000
# Normal    28.153439  16.740741  39.333333      85.0  401.683673  77.275510
# Fairy     37.000000  10.433333  20.000000      37.5  413.176471  74.117647
# Fighting  55.306122  12.775510  60.000000     100.0  416.444444  69.851852
# Grass     48.431373  14.137255  51.666667     100.0  421.142857  67.271429
# Water     62.682927  12.243902  28.000000      95.0  430.455357  72.062500
# Ice       52.037037  13.925926  37.500000      90.0  433.458333  72.000000
# Ground    45.892857  11.285714  58.333333      92.5  437.500000  73.781250
# Ghost     56.250000  10.142857  22.500000     100.0  439.562500  64.437500
# Electric  61.428571  12.595238  48.666667     100.0  443.409091  59.795455
# Dark      38.750000  13.454545  42.000000     100.0  445.741935  66.806452
# Rock      52.727273  10.318182  47.500000      90.0  453.750000  65.363636
# Fire      80.750000   9.400000  40.526316     100.0  458.076923  69.903846
# Psychic   33.059701  13.402985  23.750000       0.0  475.947368  70.631579
# Flying    58.103448  15.379310  41.666667      95.0  485.000000  70.750000
# Steel     52.343750  11.937500  18.750000      90.0  487.703704  65.222222
# Dragon    72.800000   9.120000  23.333333     100.0  550.531250  83.312500
#
#               Attack     Defense     Sp_Atk     Sp_Def       Speed  \
# Type
# Bug        70.971014   70.724638  53.869565  64.797101   61.681159
# Poison     74.678571   68.821429  60.428571  64.392857   63.571429
# Normal     73.469388   59.846939  55.816327  63.724490   71.551020
# Fairy      61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting   96.777778   65.925926  53.111111  64.703704   66.074074
# Grass      73.214286   70.800000  77.500000  70.428571   61.928571
# Water      74.151786   72.946429  74.812500  70.517857   65.964286
# Ice        72.750000   71.416667  77.541667  76.291667   63.458333
# Ground     95.750000   84.843750  56.468750  62.750000   63.906250
# Ghost      73.781250   81.187500  79.343750  76.468750   64.343750
# Electric   69.090909   66.295455  90.022727  73.704545   84.500000
# Dark       88.387097   70.225806  74.645161  69.516129   76.161290
# Rock       92.863636  100.795455  63.340909  75.477273   55.909091
# Fire       84.769231   67.769231  88.980769  72.211538   74.442308
# Psychic    71.456140   67.684211  98.403509  86.280702   81.491228
# Flying     78.750000   66.250000  94.250000  72.500000  102.500000
# Steel      92.703704  126.370370  67.518519  80.629630   55.259259
# Dragon    112.125000   86.375000  96.843750  88.843750   83.031250
#
#           Generation  Legendary  total_ranked
# Type
# Bug         3.217391   0.000000          18.0
# Poison      2.535714   0.000000          17.0
# Normal      3.051020   0.020408          16.0
# Fairy       4.117647   0.058824          15.0
# Fighting    3.370370   0.000000          14.0
# Grass       3.357143   0.042857          13.0
# Water       2.857143   0.035714          12.0
# Ice         3.541667   0.083333          11.0
# Ground      3.156250   0.125000          10.0
# Ghost       4.187500   0.062500           9.0
# Electric    3.272727   0.090909           8.0
# Dark        4.032258   0.064516           7.0
# Rock        3.454545   0.090909           6.0
# Fire        3.211538   0.096154           5.0
# Psychic     3.385965   0.245614           4.0
# Flying      5.500000   0.500000           3.0
# Steel       3.851852   0.148148           2.0
# Dragon      3.875000   0.375000           1.0

# %%
# Create subset dataframes that are sorted for printing results
fullPower = full.sort_values('Power', ascending = False)
fullAcc = full.sort_values('total_ranked', ascending = True)
fullPP = full.sort_values('PP', ascending = False)
# Iterate through rows in resulting data frame to print results
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
print('Top 3 Types with Powerful Moves:')       # print header
i=0                                          # initiate counter
for index, row in fullPower.iterrows():   # iterate through rows to print results
    i+=1
    if i > 3: 
        break
    print('{:d}. {:s}: {:.1f} mean. \n\tOverall strength rank of Pokemon Type: {:.0f} of 18.'.format(i, index, row['Power'], row['total_ranked']))
    
print('\nTop 3 Types with PP Moves:')
i=0
for index, row in fullPP.iterrows():
    i+=1
    if i > 3: 
        break
    print('{:d}. {:s}: {:.1f} mean.\n\tOverall strength rank of Pokemon Type: {:.0f} of 18.'.format(i, index, row['PP'], row['total_ranked']))


print('\nTop Types with Accurate Moves:')
i=0
for index, row in fullAcc.iterrows():
    if row['Accuracy'] == 100:
        i+=1
        print('{:d}. {:s}: {:.1f} median.\n\tOverall strength rank of Pokemon Type: {:.0f} of 18.'.format(i,index, row['Accuracy'], row['total_ranked']))
# Out:
# Top 3 Types with Powerful Moves:
# 1. Fire: 80.8 mean.
# 	Overall strength rank of Pokemon Type: 5 of 18.
# 2. Dragon: 72.8 mean.
# 	Overall strength rank of Pokemon Type: 1 of 18.
# 3. Water: 62.7 mean.
# 	Overall strength rank of Pokemon Type: 12 of 18.
#
# Top 3 Types with PP Moves:
# 1. Poison: 16.9 mean.
# 	Overall strength rank of Pokemon Type: 17 of 18.
# 2. Normal: 16.7 mean.
# 	Overall strength rank of Pokemon Type: 16 of 18.
# 3. Flying: 15.4 mean.
# 	Overall strength rank of Pokemon Type: 3 of 18.
#
# Top Types with Accurate Moves:
# 1. Dragon: 100.0 median.
# 	Overall strength rank of Pokemon Type: 1 of 18.
# 2. Fire: 100.0 median.
# 	Overall strength rank of Pokemon Type: 5 of 18.
# 3. Dark: 100.0 median.
# 	Overall strength rank of Pokemon Type: 7 of 18.
# 4. Electric: 100.0 median.
# 	Overall strength rank of Pokemon Type: 8 of 18.
# 5. Ghost: 100.0 median.
# 	Overall strength rank of Pokemon Type: 9 of 18.
# 6. Grass: 100.0 median.
# 	Overall strength rank of Pokemon Type: 13 of 18.
# 7. Fighting: 100.0 median.
# 	Overall strength rank of Pokemon Type: 14 of 18.
# 8. Bug: 100.0 median.
# 	Overall strength rank of Pokemon Type: 18 of 18.

# %% [markdown]
# It looks like the pokemon types with the most powerful moves on average tend to be the pokemon
# types that are the weakest on their own.
# there are 2 exceptions: Dragon: 2nd most powerful moves and #1 total inherent
# Flying is 3rd PP and 3rd overall

# %%
# Plot results
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
# Color code ranking: assign colors to top and bottom 6. 
# https://datatofish.com/if-condition-in-pandas-dataframe/
full.loc[full.total_ranked<=6, 'color']='red'  # most powerful
full.loc[full.total_ranked>6, 'color']='blue'  # middle
full.loc[full.total_ranked>=12, 'color']='gold' # least powerful
full
# Out:
#               Power         PP       Prob  Accuracy       Total         HP  \
# Type
# Bug       40.645161  15.354839  30.000000     100.0  378.927536  56.884058
# Poison    33.793103  16.931034  31.666667      90.0  399.142857  67.250000
# Normal    28.153439  16.740741  39.333333      85.0  401.683673  77.275510
# Fairy     37.000000  10.433333  20.000000      37.5  413.176471  74.117647
# Fighting  55.306122  12.775510  60.000000     100.0  416.444444  69.851852
# Grass     48.431373  14.137255  51.666667     100.0  421.142857  67.271429
# Water     62.682927  12.243902  28.000000      95.0  430.455357  72.062500
# Ice       52.037037  13.925926  37.500000      90.0  433.458333  72.000000
# Ground    45.892857  11.285714  58.333333      92.5  437.500000  73.781250
# Ghost     56.250000  10.142857  22.500000     100.0  439.562500  64.437500
# Electric  61.428571  12.595238  48.666667     100.0  443.409091  59.795455
# Dark      38.750000  13.454545  42.000000     100.0  445.741935  66.806452
# Rock      52.727273  10.318182  47.500000      90.0  453.750000  65.363636
# Fire      80.750000   9.400000  40.526316     100.0  458.076923  69.903846
# Psychic   33.059701  13.402985  23.750000       0.0  475.947368  70.631579
# Flying    58.103448  15.379310  41.666667      95.0  485.000000  70.750000
# Steel     52.343750  11.937500  18.750000      90.0  487.703704  65.222222
# Dragon    72.800000   9.120000  23.333333     100.0  550.531250  83.312500
#
#               Attack     Defense     Sp_Atk     Sp_Def       Speed  \
# Type
# Bug        70.971014   70.724638  53.869565  64.797101   61.681159
# Poison     74.678571   68.821429  60.428571  64.392857   63.571429
# Normal     73.469388   59.846939  55.816327  63.724490   71.551020
# Fairy      61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting   96.777778   65.925926  53.111111  64.703704   66.074074
# Grass      73.214286   70.800000  77.500000  70.428571   61.928571
# Water      74.151786   72.946429  74.812500  70.517857   65.964286
# Ice        72.750000   71.416667  77.541667  76.291667   63.458333
# Ground     95.750000   84.843750  56.468750  62.750000   63.906250
# Ghost      73.781250   81.187500  79.343750  76.468750   64.343750
# Electric   69.090909   66.295455  90.022727  73.704545   84.500000
# Dark       88.387097   70.225806  74.645161  69.516129   76.161290
# Rock       92.863636  100.795455  63.340909  75.477273   55.909091
# Fire       84.769231   67.769231  88.980769  72.211538   74.442308
# Psychic    71.456140   67.684211  98.403509  86.280702   81.491228
# Flying     78.750000   66.250000  94.250000  72.500000  102.500000
# Steel      92.703704  126.370370  67.518519  80.629630   55.259259
# Dragon    112.125000   86.375000  96.843750  88.843750   83.031250
#
#           Generation  Legendary  total_ranked color
# Type
# Bug         3.217391   0.000000          18.0  gold
# Poison      2.535714   0.000000          17.0  gold
# Normal      3.051020   0.020408          16.0  gold
# Fairy       4.117647   0.058824          15.0  gold
# Fighting    3.370370   0.000000          14.0  gold
# Grass       3.357143   0.042857          13.0  gold
# Water       2.857143   0.035714          12.0  gold
# Ice         3.541667   0.083333          11.0  blue
# Ground      3.156250   0.125000          10.0  blue
# Ghost       4.187500   0.062500           9.0  blue
# Electric    3.272727   0.090909           8.0  blue
# Dark        4.032258   0.064516           7.0  blue
# Rock        3.454545   0.090909           6.0   red
# Fire        3.211538   0.096154           5.0   red
# Psychic     3.385965   0.245614           4.0   red
# Flying      5.500000   0.500000           3.0   red
# Steel       3.851852   0.148148           2.0   red
# Dragon      3.875000   0.375000           1.0   red

# %%
# Plot Pokemon Power before moves
plt.barh(full.index.values, full['Total'], color = full['color'])
plt.xlabel("Average Total Power")
plt.ylabel("Pokemon Type")
plt.title("Pokemon Power Before Moves");

# %%
# Plot power of POkemon moves by type
fullPowerD = full.sort_values('Power', ascending = True)
plt.barh(fullPowerD.index.values, fullPowerD['Power'], color = fullPowerD['color'])
plt.xlabel("Average Power of Moves")
plt.ylabel("Pokemon Type")
plt.title("Pokemon Powerful Moves");

# %%
# Plot accuracy of moves by type
fullAcc = full.sort_values('Accuracy', ascending = True)
plt.barh(fullAcc.index.values, fullAcc['Accuracy'], color = fullAcc['color'])
plt.xlabel("Median Accuracy of Moves")
plt.ylabel("Pokemon Type")
plt.title("Pokemon Accurate Moves");

# %%
# Plot PP of moves by type
fullPP = full.sort_values('PP', ascending = True)
plt.barh(fullPP.index.values, fullPP['PP'], color = fullPP['color'])
plt.xlabel("Average Power of Moves")
plt.ylabel("Pokemon Type")
plt.title("Pokemon Power Point Moves");

# %% [markdown]
# ### 4. Which Pokémon are most popular, as measured by mentions on social media platforms? (might drop this question)
#
# Given the query limitations of the free version of the Twitter API, this will be measured in a binary manner: if a Pokemon was mentioned in a hashtag on Twitter in the last 7 days, it will be considered popular.

# %%
# calculate the percentage of popular pokemon
pct_pop = 100*(len(included) / (len(included) + len(missing)))
print('{:.1f}% of non-Mega Pokemon from our Original Pokemon Data Set are popular. That is to say, they have been mentioned in a twitter hashtag at least once in the last 7 days.'.format(pct_pop))
# Out:
# 33.8% of non-Mega Pokemon from our Original Pokemon Data Set are popular. That is to say, they have been mentioned in a twitter hashtag at least once in the last 7 days.

# %%
## Aggregate popularity by type 
typesGrp = pd.DataFrame(types[['Type','Popular']].groupby(['Type','Popular']).size())  # group by type and program and count number of cases in each group
typesGrp = typesGrp.reset_index()   # 'ungroup' dataframe
typesGrp = typesGrp.rename(columns={0:'Count'})  # rename columns
# export resulting table to create Sankey diagram in R :)
typesGrp.to_csv('PokemonTypesPopular.csv')
typesGrp
# Out:
#         Type Popular  Count
# 0        Bug   False     46
# 1        Bug    True     19
# 2       Dark   False     31
# 3       Dark    True     13
# 4     Dragon   False     21
# 5     Dragon    True     15
# 6   Electric   False     26
# 7   Electric    True     15
# 8      Fairy   False     19
# 9      Fairy    True     14
# 10  Fighting   False     34
# 11  Fighting    True      9
# 12      Fire   False     36
# 13      Fire    True     19
# 14    Flying   False     54
# 15    Flying    True     33
# 16     Ghost   False     21
# 17     Ghost    True      9
# 18     Grass   False     56
# 19     Grass    True     24
# 20    Ground   False     39
# 21    Ground    True     19
# 22       Ice   False     24
# 23       Ice    True      9
# 24  No value   False    239
# 25  No value    True    129
# 26    Normal   False     54
# 27    Normal    True     42
# 28    Poison   False     37
# 29    Poison    True     22
# 30   Psychic   False     47
# 31   Psychic    True     23
# 32      Rock   False     39
# 33      Rock    True     16
# 34     Steel   False     34
# 35     Steel    True      6
# 36     Water   False     77
# 37     Water    True     40

# %%
# Use matplotlib.pyplot to create stacked bar chart
# https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/bar_stacked.html

# make sure libraries are loaded
import numpy as np
import matplotlib.pyplot as plt

# subset popular and unpopular Pokemon
unpopular = typesGrp[typesGrp.Popular=="False"]['Count']
unpopular = [i for i in unpopular]
popular = typesGrp[typesGrp.Popular=="True"]['Count']
popular = [i for i in popular]
# identify number of bars (i.e. groups in data set)
N = 19
ind = np.arange(N) # set index for x-axis
width=0.75  # specify width of bar
p1 =plt.bar(ind, popular, width, color = 'royalblue') # define bottom of stacked bar, popular
p2 = plt.bar(ind, unpopular, width, color = 'indianred', # define top of stacked bar, unpopular
             bottom=popular)
plt.ylabel('Count')  # label y axis
plt.title('Popularity by Pokemon Type')  # define title
# create x axis labels
xtick = []
# create list of unique type names
for index, row in typesGrp.iterrows():
    if row['Type'] not in xtick:
        xtick.append(row['Type'])
# provide x axis labels
plt.xticks(ind, xtick, rotation = 'vertical')
plt.yticks(np.arange(0,140,20))  # define y tick marks
plt.legend((p1[0], p2[0]), ('Popular', 'Unpopular'))  # define legend
# show plot
plt.show()

# %% [markdown]
# This is not too informative because it doesn't account for overall size of Pokemon Type group. Apply normalization by
# calculating/graphing percentage of Type as opposed to total number.

# %%
# In order to calculate percent popular, first identify total number of members in each group
# Aggregate list of Pokemon types and count size of each group.
typesCt = pd.DataFrame(types[['Type']].groupby(['Type']).size())  # store as Pandas Dataframe
typesCt = typesCt.reset_index()  # Reset index of resulting data frame (similar to ungroup)
typesCt = typesCt.rename(columns={0:'Count'}) # rename columns for ease of analysis
typesCt # preview list
# Out:
#         Type  Count
# 0        Bug     65
# 1       Dark     44
# 2     Dragon     36
# 3   Electric     41
# 4      Fairy     33
# 5   Fighting     43
# 6       Fire     55
# 7     Flying     87
# 8      Ghost     30
# 9      Grass     80
# 10    Ground     58
# 11       Ice     33
# 12  No value    368
# 13    Normal     96
# 14    Poison     59
# 15   Psychic     70
# 16      Rock     55
# 17     Steel     40
# 18     Water    117

# %%
# Join list of popularity by type to list of total counts per type
pctPopular = typesGrp.join(typesCt.set_index('Type'), on='Type', rsuffix='_GrpTotal')
# calculate percent popularity
pctPopular['PctPop'] = (pctPopular['Count'] / pctPopular['Count_GrpTotal'])
# preview table
pctPopular 
# preview most popular types
pctPopular[typesGrp.Popular=="True"].sort_values(by = 'PctPop',ascending=False)
# Out:
#         Type Popular  Count  Count_GrpTotal    PctPop
# 27    Normal    True     42              96  0.437500
# 9      Fairy    True     14              33  0.424242
# 5     Dragon    True     15              36  0.416667
# 15    Flying    True     33              87  0.379310
# 29    Poison    True     22              59  0.372881
# 7   Electric    True     15              41  0.365854
# 25  No value    True    129             368  0.350543
# 13      Fire    True     19              55  0.345455
# 37     Water    True     40             117  0.341880
# 31   Psychic    True     23              70  0.328571
# 21    Ground    True     19              58  0.327586
# 19     Grass    True     24              80  0.300000
# 17     Ghost    True      9              30  0.300000
# 3       Dark    True     13              44  0.295455
# 1        Bug    True     19              65  0.292308
# 33      Rock    True     16              55  0.290909
# 23       Ice    True      9              33  0.272727
# 11  Fighting    True      9              43  0.209302
# 35     Steel    True      6              40  0.150000

# %%
## Create another stacked bar plot, in which the values are percentages and add up to 1
# https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/bar_stacked.html

import numpy as np
import matplotlib.pyplot as plt

# subset popular and unpopular from new percentage list
unpopular = pctPopular[pctPopular.Popular=="False"]['PctPop']
popular = pctPopular[pctPopular.Popular=="True"]['PctPop']
# sort subset lists in order of most to least popular
unpopular = unpopular.sort_values()
popular = popular.sort_values(ascending=False)
# convert dadaframe to a list
unpopular = [i for i in unpopular]
popular = [i for i in popular]
# identify number of bars (i.e. groups in data set)
N = 19
ind = np.arange(N) # set index for x axis
width=.75  # set width of bars
p1=plt.bar(ind,popular, width, color = 'royalblue')  # plot popularity
p2 = plt.bar(ind, unpopular, width, color='indianred',  # plot unpopularity
             bottom=popular) 
plt.ylabel('Percent')    # apply labels
plt.title('Popularity by Pokemon Type')  # define title
# create x-axis labels
# create subset to generate x axis labels
xlab = pctPopular[pctPopular.Popular=="True"].sort_values('PctPop', ascending = False)
# create empty list to store labels
xtick = []
# iterate through subset to create list of x tick labels
for index, row in xlab.iterrows():
    xtick.append(row['Type'])

# set x-axis labels
plt.xticks(ind, xtick, rotation = 'vertical')
plt.yticks(np.arange(0,1.3,.2))  # set y-axis tick labels
plt.legend((p1[0], p2[0]), ('Popular', 'Unpopular'))  # format legend

plt.show() # display plot

# %%
## Iterate through list of popular and unpopular to spell out the most and least popular types
# subset popular pokemon, arranging from most to least popular
popularlist = pctPopular[typesGrp.Popular=="True"].sort_values('PctPop', ascending = False)
# reformat decimal to display as percentage
popularlist["PctPop"]=popularlist["PctPop"]*100
# Print results
print('The most popular Pokemon Types are:')
for index, row in popularlist.head(5).iterrows():
        print('{:s}: {:.1f}% were mentioned on Twitter'.format(row['Type'], row['PctPop']))

# re-iterate through list, least to most popular
unpopularlist = popularlist.sort_values('PctPop', ascending = True)
print('\nThe least popular Pokemon Types are:')
for index, row in unpopularlist.head(5).iterrows():
        print('{:s}: only {:.1f}% were mentioned on Twitter'.format(row['Type'], row['PctPop']))
# Out:
# The most popular Pokemon Types are:
# Normal: 43.8% were mentioned on Twitter
# Fairy: 42.4% were mentioned on Twitter
# Dragon: 41.7% were mentioned on Twitter
# Flying: 37.9% were mentioned on Twitter
# Poison: 37.3% were mentioned on Twitter
#
# The least popular Pokemon Types are:
# Steel: only 15.0% were mentioned on Twitter
# Fighting: only 20.9% were mentioned on Twitter
# Ice: only 27.3% were mentioned on Twitter
# Rock: only 29.1% were mentioned on Twitter
# Bug: only 29.2% were mentioned on Twitter

# %%
popularlist.sort_values('PctPop', ascending = True).head(5)
# Out:
#         Type Popular  Count  Count_GrpTotal     PctPop
# 35     Steel    True      6              40  15.000000
# 11  Fighting    True      9              43  20.930233
# 23       Ice    True      9              33  27.272727
# 33      Rock    True     16              55  29.090909
# 1        Bug    True     19              65  29.230769

# %% [markdown]
# #### Gather more information about what makes a popular pokemon

# %%
## Analyze popularity of legendary pokemon
# create new dataset, grouped by legendary, popularity and count how many in each

# Count number of legendary/non-legendary pokemon, store in dataframe
legendaryCount = pokemonDF[['Legendary']].groupby(['Legendary']).size().to_frame()
# Group by legendary and popularity, store in data frame
legendaryPopular = pokemonDF[['Legendary', 'Popular']].groupby(['Legendary', 'Popular']).size().to_frame()
# join two datasets together 
legendaryPopular = legendaryPopular.join(legendaryCount, on = 'Legendary', rsuffix='_total') 
# reset indices and rename columns for ease of analysis
legendaryPopular = legendaryPopular.reset_index()
legendaryPopular = legendaryPopular.rename(columns={'0':'Count', '0_total':'Total'})
# Calculate percentage: popularity count / group count
legendaryPopular['Pct'] = legendaryPopular['Count']/legendaryPopular['Total']
legendaryPopular
# Out:
#   Legendary Popular  Count  Total       Pct
# 0     False   False    446    667  0.668666
# 1     False    True    221    667  0.331334
# 2      True   False     21     38  0.552632
# 3      True    True     17     38  0.447368

# %%
# Print statement comparing popularity of legendary v. non-legendary Pokemon
legpop = (legendaryPopular[((legendaryPopular.Legendary=="True") & (legendaryPopular.Popular=="True"))]['Pct'])*100
legpop=[i for i in legpop]
unlegpop = (legendaryPopular[((legendaryPopular.Legendary=="False") & (legendaryPopular.Popular=="True"))]['Pct'])*100
unlegpop=[i for i in unlegpop]
if legpop > unlegpop:
    print('Legendary Pokemon are more popular than non-Legendary Pokemon. \n{:.1f}% of Legendary Pokemon were mentioned in a tweet. \nOnly {:.1f}% of non-Legendary Pokemon were mentioned.'.format(legpop[0], unlegpop[0]))
else:
    if legpop < unlegpop:
        print('Non-Legendary Pokemon are more popular than non-Legendary Pokemon. \n{:.1f}% of non-Legendary Pokemon were mentioned in a tweet. \nOnly {:.1f}% of Legendary Pokemon were mentioned.'.format(unlegpop[0], legpop[0]))
# Out:
# Legendary Pokemon are more popular than non-Legendary Pokemon.
# 44.7% of Legendary Pokemon were mentioned in a tweet.
# Only 33.1% of non-Legendary Pokemon were mentioned.

# %%
# Plot comparison of popularity of legendary v. non-legendary Pokemon

import numpy as np
import matplotlib.pyplot as plt

# subset popular and unpopular
unpopular = legendaryPopular[legendaryPopular.Popular=="False"]['Pct'].sort_values()
popular = legendaryPopular[legendaryPopular.Popular=="True"]['Pct'].sort_values(ascending=False)

# convert dadaframe to a list
unpopular = [i for i in unpopular]
popular = [i for i in popular]

N = 2 # define number of groups to plot along x axis
ind = np.arange(N) # apply indexing to x axis
width=.75 # define width of each bar
# begin plots
p1=plt.bar(ind,popular, width, color = 'royalblue')  # plot popular pokemon
p2 = plt.bar(ind, unpopular, width, color = 'indianred', # plot unpopular pokemon
             bottom=popular)
plt.ylabel('Percent') # apply label to y axis
plt.title('Popularity by Pokemon Legendary Status')  # define title
plt.xticks(ind, ('Not Legendary', 'Legendary'))  # define legend
plt.yticks(np.arange(0,1.3,.2))  # configure y axis tick marks
plt.legend((p1[0], p2[0]), ('Popular', 'Unpopular')) # define legend

plt.show()

# %%
## Analyze popularity of generations
# create new dataset, grouped by generation and popularity, and count how many are in each group

# create new dataframe containing counts of each generation
genCount = pokemonDF[['Generation']].groupby(['Generation']).size().to_frame()
genCount = genCount.reset_index()
# create new dataframe containing counts of groups of generation / popularity ind
genPopular = pokemonDF[['Generation', 'Popular']].groupby(['Generation', 'Popular']).size().to_frame()
# reset indices and rename columns for ease of analysis
genPopular = genPopular.reset_index()
genPopular = genPopular.rename(columns = {0: 'Count'})
# I could not join these dataframes together for whatever reason, so I will add a list of totals per group
ct = [] # create empty count list
for index, row in genCount.iterrows():
    ct.append(row[0]) # add count for each generation twice
    ct.append(row[0])
genPopular['Total'] = ct # store count list as total in genPopular dataframe
# calculate percent popularity
genPopular['Pct'] = (genPopular['Count']/genPopular['Total'])
# observe results
genPopular[genPopular.Popular=='True'].sort_values(by = 'Pct', ascending = False)
# Out:
#    Generation Popular  Count  Total       Pct
# 1           1    True     56    150  0.373333
# 5           3    True     47    134  0.350746
# 3           2    True     35    100  0.350000
# 9           5    True     50    150  0.333333
# 7           4    True     33    103  0.320388
# 11          6    True     17     68  0.250000

# %%
# Identify min and max popular percent
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.idxmax.html
maxix = genPopular[genPopular.Popular=='True']['Pct'].idxmax()
minix = genPopular[genPopular.Popular=='True']['Pct'].idxmin()
print('The most popular generation of Pokemon is generation {:s}: \n{:.1f}% of its Pokemon were tweeted about.'.format(genPopular['Generation'][maxix], (genPopular['Pct'][maxix]*100)))
print('The least popular generation of Pokemon is generation {:s}: \nonly {:.1f}% of its Pokemon were tweeted about.'.format(genPopular['Generation'][minix], (genPopular['Pct'][minix]*100)))
# Out:
# The most popular generation of Pokemon is generation 1:
# 37.3% of its Pokemon were tweeted about.
# The least popular generation of Pokemon is generation 6:
# only 25.0% of its Pokemon were tweeted about.

# %%
# Plot stacked bar charts
# https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/bar_stacked.html

import numpy as np
import matplotlib.pyplot as plt

# subset popular and unpopular 
unpopular = genPopular[genPopular.Popular=="False"]['Pct'].sort_values()  
popular = genPopular[genPopular.Popular=="True"]['Pct'].sort_values(ascending=False)

# convert dadaframe to a list
unpopular = [i for i in unpopular]
popular = [i for i in popular]

N = 6  # define number of groups to plot
ind = np.arange(N) # apply indexing to x axis
width=.75    # define width of each bar
# begin plots
p1=plt.bar(ind,popular, width, color = 'royalblue') # plot Popular pokemon on the bottom
p2 = plt.bar(ind, unpopular, width, color = 'indianred',  # plot unpopular Pokemon on top
             bottom=popular)
plt.ylabel('Percent') # apply label to y axis
plt.xlabel('Generation') # apply label to x axis
plt.title('Popularity by Pokemon Generation')  # Apply title
# generate x tick labels
xtick = []
for index, row in genPopular[genPopular.Popular=="True"].sort_values('Pct', ascending = False).iterrows():
    xtick.append(row['Generation'])
plt.xticks(ind, xtick)  # Define labels for x-axis tick parks
plt.yticks(np.arange(0,1.3,.2)) # define labels for y-axis tick marks
plt.legend((p1[0], p2[0]), ('Popular', 'Unpopular'))  # define legend

plt.show()  # display plot

# %%
## Examine power by type of Pokemon in our Twitter analysis subset

types['Total'] = types['Total'].astype('int')
pokeGroup = types.groupby('Type').mean()
pokeGroup = pokeGroup.sort_values('Total')
pokeGroup['total_ranked']=pokeGroup['Total'].rank(ascending=0)
# assign colors to top and bottom 5. 
# https://datatofish.com/if-condition-in-pandas-dataframe/
pokeGroup.loc[pokeGroup.total_ranked<=6, 'color']='red'  # most powerful
pokeGroup.loc[pokeGroup.total_ranked>6, 'color']='blue'  # middle
pokeGroup.loc[pokeGroup.total_ranked>=12, 'color']='gold' # least powerful
pokeGroup


import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

plt.barh(pokeGroup.index.values, pokeGroup['Total'], color = pokeGroup['color'])
plt.xlabel("Average Total Power")
plt.ylabel("Pokemon Type")
plt.title("Pokemon Twitter Subset: Power by Type");

# %%
# Rank by popularity
popularrank = pctPopular[pctPopular.Popular=="True"].copy() # subset popular
popularrank['pop_rank'] = popularrank['PctPop'].rank(ascending=0) # rank bypopularity

# %%
# Join popularity rank to power ranking dataset
popularrank = popularrank.join(pokeGroup, on = 'Type')
popularrank
# Out:
#         Type Popular  Count  Count_GrpTotal    PctPop  pop_rank       Total  \
# 1        Bug    True     19              65  0.292308      15.0  365.523077
# 3       Dark    True     13              44  0.295455      14.0  438.204545
# 5     Dragon    True     15              36  0.416667       3.0  491.222222
# 7   Electric    True     15              41  0.365854       6.0  421.878049
# 9      Fairy    True     14              33  0.424242       2.0  391.939394
# 11  Fighting    True      9              43  0.209302      18.0  437.511628
# 13      Fire    True     19              55  0.345455       8.0  445.945455
# 15    Flying    True     33              87  0.379310       4.0  428.609195
# 17     Ghost    True      9              30  0.300000      12.5  404.833333
# 19     Grass    True     24              80  0.300000      12.5  404.925000
# 21    Ground    True     19              58  0.327586      11.0  414.706897
# 23       Ice    True      9              33  0.272727      17.0  444.515152
# 25  No value    True    129             368  0.350543       7.0  402.535326
# 27    Normal    True     42              96  0.437500       1.0  390.802083
# 29    Poison    True     22              59  0.372881       5.0  388.762712
# 31   Psychic    True     23              70  0.328571      10.0  439.457143
# 33      Rock    True     16              55  0.290909      16.0  437.000000
# 35     Steel    True      6              40  0.150000      19.0  468.350000
# 37     Water    True     40             117  0.341880       9.0  415.051282
#
#     total_ranked color
# 1           19.0  gold
# 3            6.0   red
# 5            1.0   red
# 7           10.0  blue
# 9           16.0  gold
# 11           7.0  blue
# 13           3.0   red
# 15           9.0  blue
# 17          14.0  gold
# 19          13.0  gold
# 21          12.0  gold
# 23           4.0   red
# 25          15.0  gold
# 27          17.0  gold
# 29          18.0  gold
# 31           5.0   red
# 33           8.0  blue
# 35           2.0   red
# 37          11.0  blue

# %%
# Print statement comparing popularity rank and power rank
# sort by popularity rank
popularrank = popularrank.sort_values('pop_rank')
# print comparison
print('The most popular are not always the most powerful:\n')
# iterate through first 3 rows
i=0
for index, row in popularrank.iterrows():
    if i > 2: # print top 3 most popular
        continue
    print('{:s} Pokemon are ranked #{:.0f} in popularity but are #{:.0f} in power'.format(row['Type'], row['pop_rank'], row['total_ranked']))
    i+=1
popularrank = popularrank.sort_values('total_ranked')
print('\nThe most powerful are not always popular\n')
i=0
for index, row in popularrank.iterrows():
    if i> 2: # print top 3 most powerful
        continue
    print('{:s} Pokemon are ranked #{:.0f} in power but are #{:.0f} in popularity'.format(row['Type'], row['total_ranked'], row['pop_rank']))
    i+=1
# Out:
# The most popular are not always the most powerful:
#
# Normal Pokemon are ranked #1 in popularity but are #17 in power
# Fairy Pokemon are ranked #2 in popularity but are #16 in power
# Dragon Pokemon are ranked #3 in popularity but are #1 in power
#
# The most powerful are not always popular
#
# Dragon Pokemon are ranked #1 in power but are #3 in popularity
# Steel Pokemon are ranked #2 in power but are #19 in popularity
# Fire Pokemon are ranked #3 in power but are #8 in popularity
