# %% [markdown]
# # Web Scraping Wikipedia Tables using BeautifulSoup and Python
#
# Wiki:
# https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_FBS_football_stadiums

# %% [markdown]
# #### Collecting web page data

# %%
# Install requests and beautifulsoup4
# $ pip install requests
# $ pip install beautifulsoup4

# %%
# Import the installed modules
import requests
from bs4 import BeautifulSoup
from urllib import request

# %%
# To get the data from the web page we will use requests API's get() method
url = "https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_FBS_football_stadiums"
page = requests.get(url)

# %%
# page is a requests.models.Response object if we use Requests module
# page is a string object if we use urllib.Request module
type(page)
# Out:
# requests.models.Response

# %% [markdown]
# A list of the response status code:
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# %%
# It is always good to check the http response status code from Requests 
print(page.status_code)   # This should print 200
# print(page[:800])
# Out:
# 200

# %%
# Now we have collected the data from the web page by using content() method from Requests module
print(page.content[:800])
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of NCAA Division I FBS football stadiums - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XiQY6QpAAEIAAHQIpZgAAAEO","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_NCAA_Division_I_FBS_football_stadiums","wgTitle":"List of NCAA Divisi'

# %%
# create a bs4 object and use the prettify method from bs4
# This will print data in format like inspecting the web page.
soup = BeautifulSoup(page.content, 'html.parser') # the input of the BeautifulSoup should be string object or bytes
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of NCAA Division I FBS football stadiums - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XiQY6QpAAEIAAHQIpZgAAAEO","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_NCAA_Division_I_FBS_football_stadiums","wgTitle":"List of NCAA Division I FBS football stadiums","wgCurRevisionId":930475985,"wgRevisionId":930475985,"wgArticleId":9897546,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserG

# %% [markdown]
# As of now we know that our table is in tag "table" and class "wikitable".
# So, first we will extract the data in table tag using find method of bs4 object.
# This method returns a bs4 object

# %%
# find all the tables on the web
tables = soup.find_all('table', {'class':'wikitable sortable'})
# find tag, table, and class (using dictionary), wikitable

# %%
# The type of tb should be a bs4.element.Tag object for a single table
# The type of tb should be a bs4.element.Tag object for mutiple tables
type(tables)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# ####  < table > tag:
# The < table > tag defines an HTML table.
# An HTML table consists of the < table > element and one or more < tr >, < th >, and < td > elements.
# The < tr > element defines a table row,
# The < th > element defines a table header,
# and the < td > element defines a table cell.
#
# A more complex HTML table may also include < caption >, < col >, < colgroup >, < thead >, < tfoot >, and < tbody > elements.
#
# ##### Example:
# < table>
# ....< tr>
# ........< th>Month< /th>
# ........< th>Savings< /th>
# ....< / tr>
# ....< tr>
# ........< td> January< / td>
# ........< td> 100< / td>
# ....< / tr>
# ....< tr>
# ........< td>February< /td>
# ........< td> 80< /td>
# ....< /tr>
# < /table>

# %%
# Search through the tables for the one with the headings we want.
for table in tables:
    # find the '<th>' tag -- contains header
    ths = table.find_all('th')
    # store table headers for each table
    # ths is a list of <th> tags
    # iterate the <th> tags and get the text of the tag
    headings = [th.text.strip() for th in ths]
    # list the wanted table headers 
    if headings[1:7] == ['Stadium', 'City', 'State', 'Team', 
                        'Conference', 'Capacity']:
        break

# %%
headings
# Out:
# ['Image',
#  'Stadium',
#  'City',
#  'State',
#  'Team',
#  'Conference',
#  'Capacity',
#  'Record1',
#  'Built',
#  'Expanded 2',
#  'Surface']

# %%
#### Checking #### 
# Extract the columns we want 
# Use the table that we just stored from last forloop for finding the  <tr> tag: defines a table row
for trs in table.find_all('tr'):
    # find all the <td> tag: defines a table cell
    tds = trs.find_all('td')
    if not tds:     # if tds is not None
        continue
    # get the text from <td> tag and store in a tuple
    print([td.text.strip() for td in tds[1:7]])
# Out:
# ['Aggie Memorial Stadium', 'Las Cruces', 'NM', 'New Mexico State', 'Independent', '30,343[1]']
# ['Alamodome', 'San Antonio', 'TX', 'UTSA', 'C-USA', '65,000']
# ['Alaska Airlines Field at Husky Stadium', 'Seattle', 'WA', 'Washington', 'Pac-12', '70,500[2]']
# ['Albertsons Stadium', 'Boise', 'ID', 'Boise State', 'Mountain West', '36,387[3]']
# ['Allen E. Paulson Stadium', 'Statesboro', 'GA', 'Georgia Southern', 'Sun Belt', '25,000']
# ['Aloha Stadium', 'Honolulu', 'HI', 'Hawaiʻi', 'Mountain West', '50,000[5]']
# ['Alumni Stadium', 'Chestnut Hill', 'MA', 'Boston College', 'ACC', '44,500[6]']
# ['Amon G. Carter Stadium', 'Fort Worth', 'TX', 'TCU', 'Big 12', '45,000[7]']
# ['Apogee Stadium', 'Denton', 'TX', 'North Texas', 'C-USA', '30,850']
# ['Arizona Stadium', 'Tucson', 'AZ', 'Arizona', 'Pac-12', '56,029[9]']
# ['Arthur L. Williams Stadium', 'Lynchburg', 'VA', 'Liberty', 'Independent (2018)', '25,000[11]']
# ['Autzen Stadium', 'Eugene', 'OR', 'Oregon', 'Pac-12', '54,000']
# ['Bagwell Field at Dowdy–Ficklen Stadium', 'Greenville', 'NC', 'East Carolina', 'American', '50,000[13]']
# ['BB&T Field', 'Winston-Salem', 'NC', 'Wake Forest', 'ACC', '31,500']
# ['Beaver Stadium', 'University Park', 'PA', 'Penn State', 'Big Ten', '106,572[15]']
# ['Benson Field at Yulman Stadium', 'New Orleans', 'LA', 'Tulane', 'American', '30,000']
# ['Bill Snyder Family Football Stadium', 'Manhattan', 'KS', 'Kansas State', 'Big 12', '50,000[18]']
# ['Blaik Field at Michie Stadium', 'West Point', 'NY', 'Army', 'Independent', '38,000[20]']
# ['Bobby Bowden Field at Doak S. Campbell Stadium', 'Tallahassee', 'FL', 'Florida State', 'ACC', '79,560[21]']
# ['Bobby Dodd Stadium at Historic Grant Field', 'Atlanta', 'GA', 'Georgia Tech', 'ACC', '55,000[22]']
# ['Boone Pickens Stadium', 'Stillwater', 'OK', 'Oklahoma State', 'Big 12', '60,218[24]']
# ['Brigham Field at Huskie Stadium', 'DeKalb', 'IL', 'NIU', 'MAC', '23,595[25]']
# ['Brooks Field at Wallace Wade Stadium', 'Durham', 'NC', 'Duke', 'ACC', '40,000[26]']
# ['Brooks Stadium', 'Conway', 'SC', 'Coastal Carolina', 'Sun Belt', '20,000']
# ['Bryant–Denny Stadium', 'Tuscaloosa', 'AL', 'Alabama', 'SEC', '101,821[27]']
# ['Bulldog Stadium at Jim Sweeney Field', 'Fresno', 'CA', 'Fresno State', 'Mountain West', '41,031']
# ['Cajun Field', 'Lafayette', 'LA', 'Louisiana', 'Sun Belt', '41,426']
# ['California Memorial Stadium', 'Berkeley', 'CA', 'California', 'Pac-12', '62,717[30]']
# ['Camp Randall Stadium', 'Madison', 'WI', 'Wisconsin', 'Big Ten', '80,321[32]']
# ['Capital One Field at Maryland Stadium', 'College Park', 'MD', 'Maryland', 'Big Ten', '51,802[33]']
# ['Cardinal Stadium[36]', 'Louisville', 'KY', 'Louisville', 'ACC', '61,000[37]']
# ['Carl Smith Center, Home of David A. Harrison III Field at Scott Stadium', 'Charlottesville', 'VA', 'Virginia', 'ACC', '61,500']
# ['Carlisle-Faulkner Field at M.M. Roberts Stadium', 'Hattiesburg', 'MS', 'Southern Miss', 'C-USA', '36,000']
# ['Carrier Dome', 'Syracuse', 'NY', 'Syracuse', 'ACC', '49,250[40]']
# ['CEFCU Stadium', 'San Jose', 'CA', 'San Jose State', 'Mountain West', '30,456']
# ['Centennial Bank Stadium', 'Jonesboro', 'AR', 'Arkansas State', 'Sun Belt', '30,964[43]']
# ['Darrell K Royal–Texas Memorial Stadium', 'Austin', 'TX', 'Texas', 'Big 12', '100,119[44]']
# ['David Booth Kansas Memorial Stadium', 'Lawrence', 'KS', 'Kansas', 'Big 12', '50,071[47]']
# ['Davis Wade Stadium at Scott Field', 'Starkville', 'MS', 'Mississippi State', 'SEC', '61,337[49]']
# ['Dix Stadium', 'Kent', 'OH', 'Kent State', 'MAC', '25,000']
# ['Doyt L. Perry Stadium', 'Bowling Green', 'OH', 'Bowling Green', 'MAC', '24,000[52]']
# ['Dreamstyle Stadium', 'Albuquerque', 'NM', 'New Mexico', 'Mountain West', '39,224[53]']
# ['Falcon Stadium', 'Colorado Springs', 'CO', 'Air Force', 'Mountain West', '46,692[55]']
# ['FAU Stadium', 'Boca Raton', 'FL', 'Florida Atlantic', 'C-USA', '30,000']
# ['Faurot Field at Memorial Stadium', 'Columbia', 'MO', 'Missouri', 'SEC', '71,168[57]']
# ['Folsom Field', 'Boulder', 'CO', 'Colorado', 'Pac-12', '50,183[58]']
# ['Frank Howard Field at Clemson Memorial Stadium', 'Clemson', 'SC', 'Clemson', 'ACC', '81,500[59]']
# ['Fred C. Yager Stadium', 'Oxford', 'OH', 'Miami', 'MAC', '24,286[61]']
# ['Gaylord Family – Oklahoma Memorial Stadium at Owen Field', 'Norman', 'OK', 'Oklahoma', 'Big 12', '86,112[62]']
# ['Georgia State Stadium', 'Atlanta', 'GA', 'Georgia State', 'Sun Belt', '25,000']
# ['Gerald J. Ford Stadium', 'University Park', 'TX', 'SMU', 'American', '32,000[63]']
# ['Glass Bowl', 'Toledo', 'OH', 'Toledo', 'MAC', '26,248']
# ['Hard Rock Stadium', 'Miami Gardens', 'FL', 'Miami', 'ACC', '65,326[64]']
# ['Heinz Field', 'Pittsburgh', 'PA', 'Pittsburgh', 'ACC', '68,400[A 1]']
# ['Houchens Industries–L. T. Smith Stadium at Jimmy Feix Field', 'Bowling Green', 'KY', 'Western Kentucky', 'C-USA', '22,113']
# ['InfoCision Stadium–Summa Field', 'Akron', 'OH', 'Akron', 'MAC', '30,000[66]']
# ['Jack Trice Stadium', 'Ames', 'IA', 'Iowa State', 'Big 12', '61,500[68]']
# ['Jim Wacker Field at Bobcat Stadium', 'San Marcos', 'TX', 'Texas State', 'Sun Belt', '30,000[70]']
# ['Joan C. Edwards Stadium', 'Huntington', 'WV', 'Marshall', 'C-USA', '38,019']
# ['Joe Aillet Stadium', 'Ruston', 'LA', 'Louisiana Tech', 'C-USA', '28,109']
# ["John O'Quinn Field at TDECU Stadium", 'Houston', 'TX', 'Houston', 'American', '40,000']
# ['Johnny "Red" Floyd Stadium', 'Murfreesboro', 'TN', 'Middle Tennessee', 'C-USA', '31,000']
# ['Jonah Field at War Memorial Stadium', 'Laramie', 'WY', 'Wyoming', 'Mountain West', '29,181[73]']
# ['Jones AT&T Stadium', 'Lubbock', 'TX', 'Texas Tech', 'Big 12', '60,862[75]']
# ['JPS Field at Malone Stadium', 'Monroe', 'LA', 'Louisiana-Monroe', 'Sun Belt', '30,427']
# ['Kelly/Shorts Stadium', 'Mount Pleasant', 'MI', 'Central Michigan', 'MAC', '30,255']
# ['Kenan Memorial Stadium', 'Chapel Hill', 'NC', 'North Carolina', 'ACC', '51,000']
# ['Kidd Brewer Stadium', 'Boone', 'NC', 'Appalachian State', 'Sun Belt', '30,000']
# ['Kinnick Stadium', 'Iowa City', 'IA', 'Iowa', 'Big Ten', '70,585[79]']
# ['Kornblau Field at S.B. Ballard Stadium', 'Norfolk', 'VA', 'Old Dominion', 'C-USA', '22,480']
# ['Kroger Field at C.M. Newton Grounds', 'Lexington', 'KY', 'Kentucky', 'SEC', '61,000[82][A 2]']
# ['Kyle Field', 'College Station', 'TX', 'Texas A&M', 'SEC', '102,733[85]']
# ['Ladd–Peebles Stadium', 'Mobile', 'AL', 'South Alabama', 'Sun Belt', '40,000']
# ['Lane Stadium/Worsham Field', 'Blacksburg', 'VA', 'Virginia Tech', 'ACC', '66,233']
# ['LaVell Edwards Stadium', 'Provo', 'UT', 'BYU', 'Independent', '63,470[87]']
# ['Legion Field', 'Birmingham', 'AL', 'UAB', 'C-USA', '71,594']
# ['Liberty Bowl Memorial Stadium', 'Memphis', 'TN', 'Memphis', 'American', '62,380[88]']
# ['Lincoln Financial Field', 'Philadelphia', 'PA', 'Temple', 'American', '68,532']
# ['Los Angeles Memorial Coliseum', 'Los Angeles', 'CA', 'Southern California', 'Pac-12', '77,500']
# ['Mackay Stadium', 'Reno', 'NV', 'Nevada', 'Mountain West', '26,000']
# ['Martin Stadium', 'Pullman', 'WA', 'Washington State', 'Pac-12', '32,248']
# ['McColl–Richardson Field at Jerry Richardson Stadium', 'Charlotte', 'NC', 'Charlotte', 'C-USA', '15,314']
# ['McLane Stadium', 'Waco', 'TX', 'Baylor', 'Big 12', '45,140']
# ['Memorial Stadium', 'Champaign', 'IL', 'Illinois', 'Big Ten', '60,670[90]']
# ['Memorial Stadium', 'Bloomington', 'IN', 'Indiana', 'Big Ten', '52,959[93]']
# ['Memorial Stadium, Tom Osborne Field', 'Lincoln', 'NE', 'Nebraska', 'Big Ten', '86,047']
# ['Merlin Olsen Field at Maverik Stadium', 'Logan', 'UT', 'Utah State', 'Mountain West', '25,513']
# ['Michigan Stadium', 'Ann Arbor', 'MI', 'Michigan', 'Big Ten', '107,601[97]']
# ['Mountaineer Field at Milan Puskar Stadium', 'Morgantown', 'WV', 'West Virginia', 'Big 12', '60,000[99]']
# ['Navy–Marine Corps Memorial Stadium', 'Annapolis', 'MD', 'Navy', 'American', '34,000[100]']
# ['Neyland Stadium', 'Knoxville', 'TN', 'Tennessee', 'SEC', '102,455[101]']
# ['Nippert Stadium', 'Cincinnati', 'OH', 'Cincinnati', 'American', '40,000[103]']
# ['Notre Dame Stadium', 'Notre Dame', 'IN', 'Notre Dame', 'Independent', '77,622[104]']
# ['Ohio Stadium', 'Columbus', 'OH', 'Ohio State', 'Big Ten', '102,780[105]']
# ['Pat Dye Field at Jordan–Hare Stadium', 'Auburn', 'AL', 'Auburn', 'SEC', '87,451[108]']
# ['Peden Stadium', 'Athens', 'OH', 'Ohio', 'MAC', '24,000']
# ['Pratt & Whitney Stadium at Rentschler Field', 'East Hartford', 'CT', 'UConn', 'American', '40,000[110]']
# ['Raymond James Stadium', 'Tampa', 'FL', 'USF', 'American', '65,857[113]']
# ['Donald W. Reynolds Razorback Stadium, Frank Broyles Field', 'Fayetteville', 'AR', 'Arkansas', 'SEC', '80,000[115]']
# ['Reser Stadium', 'Corvallis', 'OR', 'Oregon State', 'Pac-12', '45,674']
# ['Riccardo Silva Stadium', 'Miami', 'FL', 'FIU', 'C-USA', '23,500[116]']
# ['Rice Stadium', 'Houston', 'TX', 'Rice', 'C-USA', '47,000']
# ['Rice-Eccles Stadium', 'Salt Lake City', 'UT', 'Utah', 'Pac-12', '47,825[117]']
# ['Rose Bowl Stadium', 'Pasadena', 'CA', 'UCLA', 'Pac-12', '90,888[119]']
# ['Ross–Ade Stadium', 'West Lafayette', 'IN', 'Purdue', 'Big Ten', '57,236[32]']
# ['Ryan Field', 'Evanston', 'IL', 'Northwestern', 'Big Ten', '47,130']
# ['Rynearson Stadium', 'Ypsilanti', 'MI', 'Eastern Michigan', 'MAC', '30,200[122]']
# ['Sam Boyd Stadium', 'Whitney', 'NV', 'UNLV', 'Mountain West', '36,800[123]']
# ['Sanford Stadium', 'Athens', 'GA', 'Georgia', 'SEC', '92,746[125]']
# ['Scheumann Stadium', 'Muncie', 'IN', 'Ball State', 'MAC', '22,500']
# ['SDCCU Stadium', 'San Diego', 'CA', 'San Diego State', 'Mountain West', '70,561[127]']
# ['SHI Stadium', 'Piscataway', 'NJ', 'Rutgers', 'Big Ten', '52,454[130]']
# ['Skelly Field at H. A. Chapman Stadium', 'Tulsa', 'OK', 'Tulsa', 'American', '30,000[132]']
# ['Sonny Lubick Field at Canvas Stadium', 'Fort Collins', 'CO', 'Colorado State', 'Mountain West', '41,200[133]']
# ['Spartan Stadium', 'East Lansing', 'MI', 'Michigan State', 'Big Ten', '75,005[134]']
# ['Spectrum Stadium', 'Orlando', 'FL', 'UCF', 'American', '44,206[136]']
# ['Stanford Stadium', 'Stanford', 'CA', 'Stanford', 'Pac-12', '50,424[138]']
# ['Steve Spurrier-Florida Field at Ben Hill Griffin Stadium', 'Gainesville', 'FL', 'Florida', 'SEC', '88,548[141]']
# ['Sun Bowl Stadium', 'El Paso', 'TX', 'UTEP', 'C-USA', '51,500']
# ['Sun Devil Stadium, Frank Kush Field', 'Tempe', 'AZ', 'Arizona State', 'Pac-12', '56,232[144]']
# ['TCF Bank Stadium', 'Minneapolis', 'MN', 'Minnesota', 'Big Ten', '50,805']
# ['Tiger Stadium', 'Baton Rouge', 'LA', 'LSU', 'SEC', '102,321[147]']
# ['UB Stadium', 'Amherst', 'NY', 'Buffalo', 'MAC', '29,013[150]']
# ['Vanderbilt Stadium', 'Nashville', 'TN', 'Vanderbilt', 'SEC', '40,350']
# ['Vaught–Hemingway Stadium at Hollingsworth Field', 'Oxford', 'MS', 'Mississippi', 'SEC', '64,038[152]']
# ['Veterans Memorial Stadium at Larry Blakeney Field', 'Troy', 'AL', 'Troy', 'Sun Belt', '30,402']
# ['Waldo Stadium', 'Kalamazoo', 'MI', 'Western Michigan', 'MAC', '30,200[153]']
# ['Warren McGuirk Alumni Stadium', 'Hadley', 'MA', 'UMass', 'Independent', '17,000']
# ['Wayne Day Family Field at Carter–Finley Stadium', 'Raleigh', 'NC', 'NC State', 'ACC', '57,583[155]']
# ['Williams-Brice Stadium', 'Columbia', 'SC', 'South Carolina', 'SEC', '80,250[156]']

# %%
# Create an empty list
rows=list()
# Extract the columns we want 
# Use the table that we just stored from last forloop for finding the  <tr> tag: defines a table row
for trs in table.find_all('tr'):
    # find all the <td> tag: defines a table cell
    tds = trs.find_all('td')
    if not tds:     # if tds is not None
        continue
    # get the text from <td> tag and store in variable by row
    rows.append([td.text.strip() for td in tds[1:7]])

# %%
rows
# Out:
# [['Aggie Memorial Stadium',
#   'Las Cruces',
#   'NM',
#   'New Mexico State',
#   'Independent',
#   '30,343[1]'],
#  ['Alamodome', 'San Antonio', 'TX', 'UTSA', 'C-USA', '65,000'],
#  ['Alaska Airlines Field at Husky Stadium',
#   'Seattle',
#   'WA',
#   'Washington',
#   'Pac-12',
#   '70,500[2]'],
#  ['Albertsons Stadium',
#   'Boise',
#   'ID',
#   'Boise State',
#   'Mountain West',
#   '36,387[3]'],
#  ['Allen E. Paulson Stadium',
#   'Statesboro',
#   'GA',
#   'Georgia Southern',
#   'Sun Belt',
#   '25,000'],
#  ['Aloha Stadium', 'Honolulu', 'HI', 'Hawaiʻi', 'Mountain West', '50,000[5]'],
#  ['Alumni Stadium',
#   'Chestnut Hill',
#   'MA',
#   'Boston College',
#   'ACC',
#   '44,500[6]'],
#  ['Amon G. Carter Stadium', 'Fort Worth', 'TX', 'TCU', 'Big 12', '45,000[7]'],
#  ['Apogee Stadium', 'Denton', 'TX', 'North Texas', 'C-USA', '30,850'],
#  ['Arizona Stadium', 'Tucson', 'AZ', 'Arizona', 'Pac-12', '56,029[9]'],
#  ['Arthur L. Williams Stadium',
#   'Lynchburg',
#   'VA',
#   'Liberty',
#   'Independent (2018)',
#   '25,000[11]'],
#  ['Autzen Stadium', 'Eugene', 'OR', 'Oregon', 'Pac-12', '54,000'],
#  ['Bagwell Field at Dowdy–Ficklen Stadium',
#   'Greenville',
#   'NC',
#   'East Carolina',
#   'American',
#   '50,000[13]'],
#  ['BB&T Field', 'Winston-Salem', 'NC', 'Wake Forest', 'ACC', '31,500'],
#  ['Beaver Stadium',
#   'University Park',
#   'PA',
#   'Penn State',
#   'Big Ten',
#   '106,572[15]'],
#  ['Benson Field at Yulman Stadium',
#   'New Orleans',
#   'LA',
#   'Tulane',
#   'American',
#   '30,000'],
#  ['Bill Snyder Family Football Stadium',
#   'Manhattan',
#   'KS',
#   'Kansas State',
#   'Big 12',
#   '50,000[18]'],
#  ['Blaik Field at Michie Stadium',
#   'West Point',
#   'NY',
#   'Army',
#   'Independent',
#   '38,000[20]'],
#  ['Bobby Bowden Field at Doak S. Campbell Stadium',
#   'Tallahassee',
#   'FL',
#   'Florida State',
#   'ACC',
#   '79,560[21]'],
#  ['Bobby Dodd Stadium at Historic Grant Field',
#   'Atlanta',
#   'GA',
#   'Georgia Tech',
#   'ACC',
#   '55,000[22]'],
#  ['Boone Pickens Stadium',
#   'Stillwater',
#   'OK',
#   'Oklahoma State',
#   'Big 12',
#   '60,218[24]'],
#  ['Brigham Field at Huskie Stadium',
#   'DeKalb',
#   'IL',
#   'NIU',
#   'MAC',
#   '23,595[25]'],
#  ['Brooks Field at Wallace Wade Stadium',
#   'Durham',
#   'NC',
#   'Duke',
#   'ACC',
#   '40,000[26]'],
#  ['Brooks Stadium', 'Conway', 'SC', 'Coastal Carolina', 'Sun Belt', '20,000'],
#  ['Bryant–Denny Stadium', 'Tuscaloosa', 'AL', 'Alabama', 'SEC', '101,821[27]'],
#  ['Bulldog Stadium at Jim Sweeney Field',
#   'Fresno',
#   'CA',
#   'Fresno State',
#   'Mountain West',
#   '41,031'],
#  ['Cajun Field', 'Lafayette', 'LA', 'Louisiana', 'Sun Belt', '41,426'],
#  ['California Memorial Stadium',
#   'Berkeley',
#   'CA',
#   'California',
#   'Pac-12',
#   '62,717[30]'],
#  ['Camp Randall Stadium',
#   'Madison',
#   'WI',
#   'Wisconsin',
#   'Big Ten',
#   '80,321[32]'],
#  ['Capital One Field at Maryland Stadium',
#   'College Park',
#   'MD',
#   'Maryland',
#   'Big Ten',
#   '51,802[33]'],
#  ['Cardinal Stadium[36]',
#   'Louisville',
#   'KY',
#   'Louisville',
#   'ACC',
#   '61,000[37]'],
#  ['Carl Smith Center, Home of David A. Harrison III Field at Scott Stadium',
#   'Charlottesville',
#   'VA',
#   'Virginia',
#   'ACC',
#   '61,500'],
#  ['Carlisle-Faulkner Field at M.M. Roberts Stadium',
#   'Hattiesburg',
#   'MS',
#   'Southern Miss',
#   'C-USA',
#   '36,000'],
#  ['Carrier Dome', 'Syracuse', 'NY', 'Syracuse', 'ACC', '49,250[40]'],
#  ['CEFCU Stadium',
#   'San Jose',
#   'CA',
#   'San Jose State',
#   'Mountain West',
#   '30,456'],
#  ['Centennial Bank Stadium',
#   'Jonesboro',
#   'AR',
#   'Arkansas State',
#   'Sun Belt',
#   '30,964[43]'],
#  ['Darrell K Royal–Texas Memorial Stadium',
#   'Austin',
#   'TX',
#   'Texas',
#   'Big 12',
#   '100,119[44]'],
#  ['David Booth Kansas Memorial Stadium',
#   'Lawrence',
#   'KS',
#   'Kansas',
#   'Big 12',
#   '50,071[47]'],
#  ['Davis Wade Stadium at Scott Field',
#   'Starkville',
#   'MS',
#   'Mississippi State',
#   'SEC',
#   '61,337[49]'],
#  ['Dix Stadium', 'Kent', 'OH', 'Kent State', 'MAC', '25,000'],
#  ['Doyt L. Perry Stadium',
#   'Bowling Green',
#   'OH',
#   'Bowling Green',
#   'MAC',
#   '24,000[52]'],
#  ['Dreamstyle Stadium',
#   'Albuquerque',
#   'NM',
#   'New Mexico',
#   'Mountain West',
#   '39,224[53]'],
#  ['Falcon Stadium',
#   'Colorado Springs',
#   'CO',
#   'Air Force',
#   'Mountain West',
#   '46,692[55]'],
#  ['FAU Stadium', 'Boca Raton', 'FL', 'Florida Atlantic', 'C-USA', '30,000'],
#  ['Faurot Field at Memorial Stadium',
#   'Columbia',
#   'MO',
#   'Missouri',
#   'SEC',
#   '71,168[57]'],
#  ['Folsom Field', 'Boulder', 'CO', 'Colorado', 'Pac-12', '50,183[58]'],
#  ['Frank Howard Field at Clemson Memorial Stadium',
#   'Clemson',
#   'SC',
#   'Clemson',
#   'ACC',
#   '81,500[59]'],
#  ['Fred C. Yager Stadium', 'Oxford', 'OH', 'Miami', 'MAC', '24,286[61]'],
#  ['Gaylord Family – Oklahoma Memorial Stadium at Owen Field',
#   'Norman',
#   'OK',
#   'Oklahoma',
#   'Big 12',
#   '86,112[62]'],
#  ['Georgia State Stadium',
#   'Atlanta',
#   'GA',
#   'Georgia State',
#   'Sun Belt',
#   '25,000'],
#  ['Gerald J. Ford Stadium',
#   'University Park',
#   'TX',
#   'SMU',
#   'American',
#   '32,000[63]'],
#  ['Glass Bowl', 'Toledo', 'OH', 'Toledo', 'MAC', '26,248'],
#  ['Hard Rock Stadium', 'Miami Gardens', 'FL', 'Miami', 'ACC', '65,326[64]'],
#  ['Heinz Field', 'Pittsburgh', 'PA', 'Pittsburgh', 'ACC', '68,400[A 1]'],
#  ['Houchens Industries–L. T. Smith Stadium at Jimmy Feix Field',
#   'Bowling Green',
#   'KY',
#   'Western Kentucky',
#   'C-USA',
#   '22,113'],
#  ['InfoCision Stadium–Summa Field',
#   'Akron',
#   'OH',
#   'Akron',
#   'MAC',
#   '30,000[66]'],
#  ['Jack Trice Stadium', 'Ames', 'IA', 'Iowa State', 'Big 12', '61,500[68]'],
#  ['Jim Wacker Field at Bobcat Stadium',
#   'San Marcos',
#   'TX',
#   'Texas State',
#   'Sun Belt',
#   '30,000[70]'],
#  ['Joan C. Edwards Stadium',
#   'Huntington',
#   'WV',
#   'Marshall',
#   'C-USA',
#   '38,019'],
#  ['Joe Aillet Stadium', 'Ruston', 'LA', 'Louisiana Tech', 'C-USA', '28,109'],
#  ["John O'Quinn Field at TDECU Stadium",
#   'Houston',
#   'TX',
#   'Houston',
#   'American',
#   '40,000'],
#  ['Johnny "Red" Floyd Stadium',
#   'Murfreesboro',
#   'TN',
#   'Middle Tennessee',
#   'C-USA',
#   '31,000'],
#  ['Jonah Field at War Memorial Stadium',
#   'Laramie',
#   'WY',
#   'Wyoming',
#   'Mountain West',
#   '29,181[73]'],
#  ['Jones AT&T Stadium', 'Lubbock', 'TX', 'Texas Tech', 'Big 12', '60,862[75]'],
#  ['JPS Field at Malone Stadium',
#   'Monroe',
#   'LA',
#   'Louisiana-Monroe',
#   'Sun Belt',
#   '30,427'],
#  ['Kelly/Shorts Stadium',
#   'Mount Pleasant',
#   'MI',
#   'Central Michigan',
#   'MAC',
#   '30,255'],
#  ['Kenan Memorial Stadium',
#   'Chapel Hill',
#   'NC',
#   'North Carolina',
#   'ACC',
#   '51,000'],
#  ['Kidd Brewer Stadium',
#   'Boone',
#   'NC',
#   'Appalachian State',
#   'Sun Belt',
#   '30,000'],
#  ['Kinnick Stadium', 'Iowa City', 'IA', 'Iowa', 'Big Ten', '70,585[79]'],
#  ['Kornblau Field at S.B. Ballard Stadium',
#   'Norfolk',
#   'VA',
#   'Old Dominion',
#   'C-USA',
#   '22,480'],
#  ['Kroger Field at C.M. Newton Grounds',
#   'Lexington',
#   'KY',
#   'Kentucky',
#   'SEC',
#   '61,000[82][A 2]'],
#  ['Kyle Field', 'College Station', 'TX', 'Texas A&M', 'SEC', '102,733[85]'],
#  ['Ladd–Peebles Stadium',
#   'Mobile',
#   'AL',
#   'South Alabama',
#   'Sun Belt',
#   '40,000'],
#  ['Lane Stadium/Worsham Field',
#   'Blacksburg',
#   'VA',
#   'Virginia Tech',
#   'ACC',
#   '66,233'],
#  ['LaVell Edwards Stadium', 'Provo', 'UT', 'BYU', 'Independent', '63,470[87]'],
#  ['Legion Field', 'Birmingham', 'AL', 'UAB', 'C-USA', '71,594'],
#  ['Liberty Bowl Memorial Stadium',
#   'Memphis',
#   'TN',
#   'Memphis',
#   'American',
#   '62,380[88]'],
#  ['Lincoln Financial Field',
#   'Philadelphia',
#   'PA',
#   'Temple',
#   'American',
#   '68,532'],
#  ['Los Angeles Memorial Coliseum',
#   'Los Angeles',
#   'CA',
#   'Southern California',
#   'Pac-12',
#   '77,500'],
#  ['Mackay Stadium', 'Reno', 'NV', 'Nevada', 'Mountain West', '26,000'],
#  ['Martin Stadium', 'Pullman', 'WA', 'Washington State', 'Pac-12', '32,248'],
#  ['McColl–Richardson Field at Jerry Richardson Stadium',
#   'Charlotte',
#   'NC',
#   'Charlotte',
#   'C-USA',
#   '15,314'],
#  ['McLane Stadium', 'Waco', 'TX', 'Baylor', 'Big 12', '45,140'],
#  ['Memorial Stadium', 'Champaign', 'IL', 'Illinois', 'Big Ten', '60,670[90]'],
#  ['Memorial Stadium', 'Bloomington', 'IN', 'Indiana', 'Big Ten', '52,959[93]'],
#  ['Memorial Stadium, Tom Osborne Field',
#   'Lincoln',
#   'NE',
#   'Nebraska',
#   'Big Ten',
#   '86,047'],
#  ['Merlin Olsen Field at Maverik Stadium',
#   'Logan',
#   'UT',
#   'Utah State',
#   'Mountain West',
#   '25,513'],
#  ['Michigan Stadium', 'Ann Arbor', 'MI', 'Michigan', 'Big Ten', '107,601[97]'],
#  ['Mountaineer Field at Milan Puskar Stadium',
#   'Morgantown',
#   'WV',
#   'West Virginia',
#   'Big 12',
#   '60,000[99]'],
#  ['Navy–Marine Corps Memorial Stadium',
#   'Annapolis',
#   'MD',
#   'Navy',
#   'American',
#   '34,000[100]'],
#  ['Neyland Stadium', 'Knoxville', 'TN', 'Tennessee', 'SEC', '102,455[101]'],
#  ['Nippert Stadium',
#   'Cincinnati',
#   'OH',
#   'Cincinnati',
#   'American',
#   '40,000[103]'],
#  ['Notre Dame Stadium',
#   'Notre Dame',
#   'IN',
#   'Notre Dame',
#   'Independent',
#   '77,622[104]'],
#  ['Ohio Stadium', 'Columbus', 'OH', 'Ohio State', 'Big Ten', '102,780[105]'],
#  ['Pat Dye Field at Jordan–Hare Stadium',
#   'Auburn',
#   'AL',
#   'Auburn',
#   'SEC',
#   '87,451[108]'],
#  ['Peden Stadium', 'Athens', 'OH', 'Ohio', 'MAC', '24,000'],
#  ['Pratt & Whitney Stadium at Rentschler Field',
#   'East Hartford',
#   'CT',
#   'UConn',
#   'American',
#   '40,000[110]'],
#  ['Raymond James Stadium', 'Tampa', 'FL', 'USF', 'American', '65,857[113]'],
#  ['Donald W. Reynolds Razorback Stadium, Frank Broyles Field',
#   'Fayetteville',
#   'AR',
#   'Arkansas',
#   'SEC',
#   '80,000[115]'],
#  ['Reser Stadium', 'Corvallis', 'OR', 'Oregon State', 'Pac-12', '45,674'],
#  ['Riccardo Silva Stadium', 'Miami', 'FL', 'FIU', 'C-USA', '23,500[116]'],
#  ['Rice Stadium', 'Houston', 'TX', 'Rice', 'C-USA', '47,000'],
#  ['Rice-Eccles Stadium',
#   'Salt Lake City',
#   'UT',
#   'Utah',
#   'Pac-12',
#   '47,825[117]'],
#  ['Rose Bowl Stadium', 'Pasadena', 'CA', 'UCLA', 'Pac-12', '90,888[119]'],
#  ['Ross–Ade Stadium',
#   'West Lafayette',
#   'IN',
#   'Purdue',
#   'Big Ten',
#   '57,236[32]'],
#  ['Ryan Field', 'Evanston', 'IL', 'Northwestern', 'Big Ten', '47,130'],
#  ['Rynearson Stadium',
#   'Ypsilanti',
#   'MI',
#   'Eastern Michigan',
#   'MAC',
#   '30,200[122]'],
#  ['Sam Boyd Stadium', 'Whitney', 'NV', 'UNLV', 'Mountain West', '36,800[123]'],
#  ['Sanford Stadium', 'Athens', 'GA', 'Georgia', 'SEC', '92,746[125]'],
#  ['Scheumann Stadium', 'Muncie', 'IN', 'Ball State', 'MAC', '22,500'],
#  ['SDCCU Stadium',
#   'San Diego',
#   'CA',
#   'San Diego State',
#   'Mountain West',
#   '70,561[127]'],
#  ['SHI Stadium', 'Piscataway', 'NJ', 'Rutgers', 'Big Ten', '52,454[130]'],
#  ['Skelly Field at H. A. Chapman Stadium',
#   'Tulsa',
#   'OK',
#   'Tulsa',
#   'American',
#   '30,000[132]'],
#  ['Sonny Lubick Field at Canvas Stadium',
#   'Fort Collins',
#   'CO',
#   'Colorado State',
#   'Mountain West',
#   '41,200[133]'],
#  ['Spartan Stadium',
#   'East Lansing',
#   'MI',
#   'Michigan State',
#   'Big Ten',
#   '75,005[134]'],
#  ['Spectrum Stadium', 'Orlando', 'FL', 'UCF', 'American', '44,206[136]'],
#  ['Stanford Stadium', 'Stanford', 'CA', 'Stanford', 'Pac-12', '50,424[138]'],
#  ['Steve Spurrier-Florida Field at Ben Hill Griffin Stadium',
#   'Gainesville',
#   'FL',
#   'Florida',
#   'SEC',
#   '88,548[141]'],
#  ['Sun Bowl Stadium', 'El Paso', 'TX', 'UTEP', 'C-USA', '51,500'],
#  ['Sun Devil Stadium, Frank Kush Field',
#   'Tempe',
#   'AZ',
#   'Arizona State',
#   'Pac-12',
#   '56,232[144]'],
#  ['TCF Bank Stadium', 'Minneapolis', 'MN', 'Minnesota', 'Big Ten', '50,805'],
#  ['Tiger Stadium', 'Baton Rouge', 'LA', 'LSU', 'SEC', '102,321[147]'],
#  ['UB Stadium', 'Amherst', 'NY', 'Buffalo', 'MAC', '29,013[150]'],
#  ['Vanderbilt Stadium', 'Nashville', 'TN', 'Vanderbilt', 'SEC', '40,350'],
#  ['Vaught–Hemingway Stadium at Hollingsworth Field',
#   'Oxford',
#   'MS',
#   'Mississippi',
#   'SEC',
#   '64,038[152]'],
#  ['Veterans Memorial Stadium at Larry Blakeney Field',
#   'Troy',
#   'AL',
#   'Troy',
#   'Sun Belt',
#   '30,402'],
#  ['Waldo Stadium',
#   'Kalamazoo',
#   'MI',
#   'Western Michigan',
#   'MAC',
#   '30,200[153]'],
#  ['Warren McGuirk Alumni Stadium',
#   'Hadley',
#   'MA',
#   'UMass',
#   'Independent',
#   '17,000'],
#  ['Wayne Day Family Field at Carter–Finley Stadium',
#   'Raleigh',
#   'NC',
#   'NC State',
#   'ACC',
#   '57,583[155]'],
#  ['Williams-Brice Stadium',
#   'Columbia',
#   'SC',
#   'South Carolina',
#   'SEC',
#   '80,250[156]']]

# %%
import pandas as pd
df=pd.DataFrame(rows, columns= headings[1:7])

# %%
df
# Out:
#                                                Stadium         City State  \
# 0                               Aggie Memorial Stadium   Las Cruces    NM
# 1                                            Alamodome  San Antonio    TX
# 2               Alaska Airlines Field at Husky Stadium      Seattle    WA
# 3                                   Albertsons Stadium        Boise    ID
# 4                             Allen E. Paulson Stadium   Statesboro    GA
# ..                                                 ...          ...   ...
# 125  Veterans Memorial Stadium at Larry Blakeney Field         Troy    AL
# 126                                      Waldo Stadium    Kalamazoo    MI
# 127                      Warren McGuirk Alumni Stadium       Hadley    MA
# 128    Wayne Day Family Field at Carter–Finley Stadium      Raleigh    NC
# 129                             Williams-Brice Stadium     Columbia    SC
#
#                  Team     Conference     Capacity
# 0    New Mexico State    Independent    30,343[1]
# 1                UTSA          C-USA       65,000
# 2          Washington         Pac-12    70,500[2]
# 3         Boise State  Mountain West    36,387[3]
# 4    Georgia Southern       Sun Belt       25,000
# ..                ...            ...          ...
# 125              Troy       Sun Belt       30,402
# 126  Western Michigan            MAC  30,200[153]
# 127             UMass    Independent       17,000
# 128          NC State            ACC  57,583[155]
# 129    South Carolina            SEC  80,250[156]
#
# [130 rows x 6 columns]

# %%
def normalize_string(text):
    """
    Expect: a string contain '[]'; ex: 70,500[2]
    Modifies: extract text before '[]';
    Returns: strings; ex: 70,500
    """   
    if '[' in text:
        index=text.find('[')
        result=text[:index]
    else:
        result=text
    return result

# %%
df['Capacity']=df['Capacity'].apply(normalize_string)

# %%
df
# Out:
#                                                Stadium         City State  \
# 0                               Aggie Memorial Stadium   Las Cruces    NM
# 1                                            Alamodome  San Antonio    TX
# 2               Alaska Airlines Field at Husky Stadium      Seattle    WA
# 3                                   Albertsons Stadium        Boise    ID
# 4                             Allen E. Paulson Stadium   Statesboro    GA
# ..                                                 ...          ...   ...
# 125  Veterans Memorial Stadium at Larry Blakeney Field         Troy    AL
# 126                                      Waldo Stadium    Kalamazoo    MI
# 127                      Warren McGuirk Alumni Stadium       Hadley    MA
# 128    Wayne Day Family Field at Carter–Finley Stadium      Raleigh    NC
# 129                             Williams-Brice Stadium     Columbia    SC
#
#                  Team     Conference Capacity
# 0    New Mexico State    Independent   30,343
# 1                UTSA          C-USA   65,000
# 2          Washington         Pac-12   70,500
# 3         Boise State  Mountain West   36,387
# 4    Georgia Southern       Sun Belt   25,000
# ..                ...            ...      ...
# 125              Troy       Sun Belt   30,402
# 126  Western Michigan            MAC   30,200
# 127             UMass    Independent   17,000
# 128          NC State            ACC   57,583
# 129    South Carolina            SEC   80,250
#
# [130 rows x 6 columns]

# %%
def normalize_number(strings):
    """
    Expect: a string contain '$','--', or ','
    Modifies: remove '$' and ','; convert '--' to '0'
    Returns: an integer
    """
    if ',' in strings:
        strings=strings.replace(',','')
    else:
        strings=0
    return int(strings)

# %%
df['Capacity']=df['Capacity'].apply(normalize_number)

# %%
# output a list in cells version of csv
df.to_csv('football_stadium.csv', index=False, encoding='utf-8')
