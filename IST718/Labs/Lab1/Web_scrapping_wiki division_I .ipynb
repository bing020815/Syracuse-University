# %% [markdown]
# # Web Scraping Wikipedia Tables using BeautifulSoup and Python
#
# Wiki:
# https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_FBS_football_stadiums

# %% [markdown]
# #### Collecting web page data

# %%
# Install requests and beautifulsoup4
# $ pip install requests
# $ pip install beautifulsoup4

# %%
# Import the installed modules
import requests
from bs4 import BeautifulSoup
from urllib import request

# %%
# To get the data from the web page we will use requests API's get() method
url = "https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_institutions"
page = requests.get(url)

# %%
# page is a requests.models.Response object if we use Requests module
# page is a string object if we use urllib.Request module
type(page)
# Out:
# requests.models.Response

# %% [markdown]
# A list of the response status code:
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# %%
# It is always good to check the http response status code from Requests 
print(page.status_code)   # This should print 200
# print(page[:800])
# Out:
# 200

# %%
# Now we have collected the data from the web page by using content() method from Requests module
print(page.content[:800])
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of NCAA Division I institutions - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XiM@4QpAADkAAEgmAtwAAAAE","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_NCAA_Division_I_institutions","wgTitle":"List of NCAA Division I institutions"'

# %%
# create a bs4 object and use the prettify method from bs4
# This will print data in format like inspecting the web page.
soup = BeautifulSoup(page.content, 'html.parser') # the input of the BeautifulSoup should be string object or bytes
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of NCAA Division I institutions - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XiM@4QpAADkAAEgmAtwAAAAE","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_NCAA_Division_I_institutions","wgTitle":"List of NCAA Division I institutions","wgCurRevisionId":933196664,"wgRevisionId":933196664,"wgArticleId":3604099,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories"

# %% [markdown]
# As of now we know that our table is in tag "table" and class "wikitable".
# So, first we will extract the data in table tag using find method of bs4 object.
# This method returns a bs4 object

# %%
# find all the tables on the web
tables = soup.find_all('table', {'class':'wikitable'})
# find tag, table, and class (using dictionary), wikitable

# %%
# The type of tb should be a bs4.element.Tag object for a single table
# The type of tb should be a bs4.element.Tag object for mutiple tables
type(tables)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# ####  < table > tag:
# The < table > tag defines an HTML table.
# An HTML table consists of the < table > element and one or more < tr >, < th >, and < td > elements.
# The < tr > element defines a table row,
# The < th > element defines a table header,
# and the < td > element defines a table cell.
#
# A more complex HTML table may also include < caption >, < col >, < colgroup >, < thead >, < tfoot >, and < tbody > elements.
#
# ##### Example:
# < table>
# ....< tr>
# ........< th>Month< /th>
# ........< th>Savings< /th>
# ....< / tr>
# ....< tr>
# ........< td> January< / td>
# ........< td> 100< / td>
# ....< / tr>
# ....< tr>
# ........< td>February< /td>
# ........< td> 80< /td>
# ....< /tr>
# < /table>

# %%
# Search through the tables for the one with the headings we want.
for table in tables:
    # find the '<th>' tag -- contains header
    ths = table.find_all('th')
    # store table headers for each table
    # ths is a list of <th> tags
    # iterate the <th> tags and get the text of the tag
    headings = [th.text.strip() for th in ths]
    # list the wanted table headers 
    if headings[:6] == ['School', 'Common Name', 'Team', 'City', 
                        'State', 'Type']:
        break

# %%
headings
# Out:
# ['School',
#  'Common Name',
#  'Team',
#  'City',
#  'State',
#  'Type',
#  'Primary Conference',
#  'Abilene Christian University',
#  'University of Akron',
#  'University of Alabama',
#  'Alabama Agricultural and Mechanical University',
#  'University of Alabama at Birmingham',
#  'Alabama State University',
#  'University at Albany, SUNY',
#  'Alcorn State University',
#  'American University',
#  'Appalachian State University',
#  'University of Arizona',
#  'Arizona State University',
#  'University of Arkansas',
#  'University of Arkansas at Little Rock',
#  'University of Arkansas at Pine Bluff',
#  'Arkansas State University',
#  'Auburn University',
#  'Austin Peay State University',
#  'Ball State University',
#  'Baylor University',
#  'Belmont University',
#  'Bethune-Cookman University',
#  'Binghamton University',
#  'Boise State University',
#  'Boston College',
#  'Boston University',
#  'Bowling Green State University',
#  'Bradley University',
#  'Brigham Young University',
#  'Brown University',
#  'Bryant University',
#  'Bucknell University',
#  'University at Buffalo',
#  'Butler University',
#  'University of California, Berkeley',
#  'University of California, Davis',
#  'University of California, Irvine',
#  'University of California, Los Angeles',
#  'California Polytechnic State University',
#  'University of California, Riverside',
#  'University of California, Santa Barbara',
#  'California State University, Bakersfield',
#  'California State University, Fresno',
#  'California State University, Fullerton',
#  'California State University, Long Beach',
#  'California State University, Northridge',
#  'California State University, Sacramento',
#  'Campbell University',
#  'Canisius College',
#  'University of Central Arkansas',
#  'Central Connecticut State University',
#  'University of Central Florida',
#  'Central Michigan University',
#  'College of Charleston',
#  'Charleston Southern University',
#  'Chicago State University',
#  'University of Cincinnati',
#  'The Citadel',
#  'Clemson University',
#  'Cleveland State University',
#  'Coastal Carolina University',
#  'Colgate University',
#  'University of Colorado Boulder',
#  'Colorado State University',
#  'Columbia University',
#  'University of Connecticut',
#  'Coppin State University',
#  'Cornell University',
#  'Creighton University',
#  'Dartmouth College',
#  'Davidson College',
#  'University of Dayton',
#  'University of Delaware',
#  'Delaware State University',
#  'University of Denver',
#  'DePaul University',
#  'University of Detroit Mercy',
#  'Drake University',
#  'Drexel University',
#  'Duke University',
#  'Duquesne University',
#  'East Carolina University',
#  'East Tennessee State University',
#  'Eastern Illinois University',
#  'Eastern Kentucky University',
#  'Eastern Michigan University',
#  'Eastern Washington University',
#  'Elon University',
#  'University of Evansville',
#  'Fairfield University',
#  'Fairleigh Dickinson University',
#  'University of Florida',
#  'Florida A&M University',
#  'Florida Atlantic University',
#  'Florida Gulf Coast University',
#  'Florida International University',
#  'Florida State University',
#  'Fordham University',
#  'Furman University',
#  'Gardner–Webb University',
#  'George Mason University',
#  'George Washington University',
#  'Georgetown University',
#  'University of Georgia',
#  'Georgia Institute of Technology',
#  'Georgia Southern University',
#  'Georgia State University',
#  'Gonzaga University',
#  'Grambling State University',
#  'Grand Canyon University',
#  'Hampton University',
#  'University of Hartford',
#  'Harvard University',
#  'University of Hawaii at Manoa',
#  'High Point University',
#  'Hofstra University',
#  'College of the Holy Cross',
#  'University of Houston',
#  'Houston Baptist University',
#  'Howard University',
#  'University of Idaho',
#  'Idaho State University',
#  'University of Illinois at Chicago',
#  'Illinois State University',
#  'University of Illinois at Urbana–Champaign',
#  'University of the Incarnate Word',
#  'Indiana University',
#  'Indiana State University',
#  'Indiana University – Purdue University Indianapolis',
#  'Iona College',
#  'University of Iowa',
#  'Iowa State University',
#  'Jackson State University',
#  'Jacksonville University',
#  'Jacksonville State University',
#  'James Madison University',
#  'University of Kansas',
#  'Kansas State University',
#  'Kennesaw State University',
#  'Kent State University',
#  'University of Kentucky',
#  'La Salle University',
#  'Lafayette College',
#  'Lamar University',
#  'Lehigh University',
#  'Liberty University',
#  'Lipscomb University',
#  'Long Island University',
#  'Longwood University',
#  'University of Louisiana at Lafayette',
#  'University of Louisiana at Monroe',
#  'Louisiana State University',
#  'Louisiana Tech University',
#  'University of Louisville',
#  'Loyola University Chicago',
#  'Loyola University Maryland',
#  'Loyola Marymount University',
#  'University of Maine',
#  'Manhattan College',
#  'Marist College',
#  'Marquette University',
#  'Marshall University',
#  'University of Maryland, Baltimore County',
#  'University of Maryland, College Park',
#  'University of Maryland Eastern Shore',
#  'University of Massachusetts Amherst',
#  'University of Massachusetts Lowell',
#  'McNeese State University',
#  'University of Memphis',
#  'Mercer University',
#  'University of Miami',
#  'Miami University',
#  'University of Michigan',
#  'Michigan State University',
#  'Middle Tennessee State University',
#  'University of Minnesota',
#  'University of Mississippi',
#  'Mississippi State University',
#  'Mississippi Valley State University',
#  'University of Missouri',
#  'University of Missouri–Kansas City',
#  'Missouri State University',
#  'Monmouth University',
#  'University of Montana',
#  'Montana State University',
#  'Morehead State University',
#  'Morgan State University',
#  "Mount St. Mary's University",
#  'Murray State University',
#  'University of Nebraska–Lincoln',
#  'University of Nebraska Omaha',
#  'University of Nevada, Las Vegas',
#  'University of Nevada, Reno',
#  'University of New Hampshire',
#  'New Jersey Institute of Technology',
#  'University of New Mexico',
#  'New Mexico State University',
#  'University of New Orleans',
#  'Niagara University',
#  'Nicholls State University',
#  'Norfolk State University',
#  'North Carolina Agricultural and Technical State University',
#  'University of North Carolina at Asheville',
#  'North Carolina Central University',
#  'University of North Carolina at Chapel Hill',
#  'University of North Carolina at Charlotte',
#  'University of North Carolina at Greensboro',
#  'North Carolina State University',
#  'University of North Carolina at Wilmington',
#  'University of North Dakota',
#  'North Dakota State University',
#  'University of North Florida',
#  'University of North Texas',
#  'Northeastern University',
#  'Northern Arizona University',
#  'University of Northern Colorado',
#  'Northern Illinois University',
#  'University of Northern Iowa',
#  'Northern Kentucky University',
#  'Northwestern University',
#  'Northwestern State University',
#  'University of Notre Dame',
#  'Oakland University',
#  'Ohio University',
#  'The Ohio State University',
#  'University of Oklahoma',
#  'Oklahoma State University–Stillwater',
#  'Old Dominion University',
#  'Oral Roberts University',
#  'University of Oregon',
#  'Oregon State University',
#  'University of the Pacific',
#  'University of Pennsylvania',
#  'Pennsylvania State University',
#  'Pepperdine University',
#  'University of Pittsburgh',
#  'University of Portland',
#  'Portland State University',
#  'Prairie View A&M University',
#  'Presbyterian College',
#  'Princeton University',
#  'Providence College',
#  'Purdue University',
#  'Purdue University Fort Wayne[p]',
#  'Quinnipiac University',
#  'Radford University',
#  'University of Rhode Island',
#  'Rice University',
#  'University of Richmond',
#  'Rider University',
#  'Robert Morris University',
#  'Rutgers University',
#  'Sacred Heart University',
#  'St. Bonaventure University',
#  'St. Francis College',
#  'Saint Francis University',
#  "St. John's University",
#  "Saint Joseph's University",
#  'Saint Louis University',
#  "Saint Mary's College of California",
#  "Saint Peter's University",
#  'Sam Houston State University',
#  'Samford University',
#  'University of San Diego',
#  'San Diego State University',
#  'University of San Francisco',
#  'San Jose State University',
#  'Santa Clara University',
#  'Seattle University',
#  'Seton Hall University',
#  'Siena College',
#  'University of South Alabama',
#  'University of South Carolina',
#  'South Carolina State University',
#  'University of South Carolina Upstate',
#  'University of South Dakota',
#  'South Dakota State University',
#  'University of South Florida',
#  'Southeast Missouri State University',
#  'Southeastern Louisiana University',
#  'Southern University',
#  'University of Southern California',
#  'Southern Illinois University Carbondale',
#  'Southern Illinois University Edwardsville',
#  'Southern Methodist University',
#  'University of Southern Mississippi',
#  'Southern Utah University',
#  'Stanford University',
#  'Stephen F. Austin State University',
#  'Stetson University',
#  'Stony Brook University',
#  'Syracuse University',
#  'Temple University',
#  'University of Tennessee',
#  'University of Tennessee at Chattanooga',
#  'University of Tennessee at Martin',
#  'Tennessee State University',
#  'Tennessee Technological University',
#  'Texas A&M University',
#  'Texas A&M University–Corpus Christi',
#  'University of Texas at Arlington',
#  'University of Texas at Austin',
#  'Texas Christian University',
#  'University of Texas at El Paso',
#  'University of Texas Rio Grande Valley',
#  'University of Texas at San Antonio',
#  'Texas Southern University',
#  'Texas State University',
#  'Texas Tech University',
#  'University of Toledo',
#  'Towson University',
#  'Troy University',
#  'Tulane University',
#  'University of Tulsa',
#  'United States Air Force Academy',
#  'United States Military Academy',
#  'United States Naval Academy',
#  'University of Utah',
#  'Utah State University',
#  'Utah Valley University',
#  'Valparaiso University',
#  'Vanderbilt University',
#  'University of Vermont',
#  'Villanova University',
#  'University of Virginia',
#  'Virginia Commonwealth University',
#  'Virginia Military Institute',
#  'Virginia Tech[A 52]',
#  'Wagner College',
#  'Wake Forest University',
#  'University of Washington',
#  'Washington State University',
#  'Weber State University',
#  'West Virginia University',
#  'Western Carolina University',
#  'Western Illinois University',
#  'Western Kentucky University',
#  'Western Michigan University',
#  'Wichita State University',
#  'College of William & Mary',
#  'Winthrop University',
#  'University of Wisconsin–Green Bay',
#  'University of Wisconsin–Madison',
#  'University of Wisconsin–Milwaukee',
#  'Wofford College',
#  'Wright State University',
#  'University of Wyoming',
#  'Xavier University',
#  'Yale University',
#  'Youngstown State University']

# %%
#### Checking #### 
# Extract the columns we want 
# Use the table that we just stored from last forloop for finding the  <tr> tag: defines a table row
for trs in table.find_all('tr'):
    # find all the <td> tag: defines a table cell
    tds = trs.find_all('td')
    if not tds:     # if tds is not None
        continue
    # get the text from <td> tag and store in a tuple
    print([td.text.strip() for td in tds[0:5]])
# Out:
# ['Abilene Christian', 'Wildcats', 'Abilene', 'Texas', 'Private/Churches of Christ']
# ['Akron', 'Zips', 'Akron', 'Ohio', 'State']
# ['Alabama', 'Crimson Tide', 'Tuscaloosa', 'Alabama', 'State']
# ['Alabama A&M', 'Bulldogs and Lady Bulldogs', 'Huntsville', 'Alabama', 'State']
# ['UAB', 'Blazers', 'Birmingham', 'Alabama', 'State']
# ['Alabama State', 'Hornets and Lady Hornets', 'Montgomery', 'Alabama', 'State']
# ['Albany', 'Great Danes', 'Albany', 'New York', 'State']
# ['Alcorn State', 'Braves and Lady Braves', 'Lorman', 'Mississippi', 'State']
# ['American', 'Eagles', 'Washington', 'District of Columbia', 'Private/Methodist']
# ['Appalachian State', 'Mountaineers', 'Boone', 'North Carolina', 'State']
# ['Arizona', 'Wildcats', 'Tucson', 'Arizona', 'State']
# ['Arizona State', 'Sun Devils', 'Tempe', 'Arizona', 'State']
# ['Arkansas', 'Razorbacks and Razorback women[A 1]', 'Fayetteville', 'Arkansas', 'State']
# ['Little Rock[A 2]', 'Trojans', 'Little Rock', 'Arkansas', 'State']
# ['Arkansas–Pine Bluff', 'Golden Lions and Golden Lady Lions', 'Pine Bluff', 'Arkansas', 'State']
# ['Arkansas State', 'Red Wolves', 'Jonesboro', 'Arkansas', 'State']
# ['Auburn', 'Tigers', 'Auburn', 'Alabama', 'State']
# ['Austin Peay', 'Governors and Lady Govs', 'Clarksville', 'Tennessee', 'State']
# ['Ball State', 'Cardinals', 'Muncie', 'Indiana', 'State']
# ['Baylor', 'Bears and Lady Bears', 'Waco', 'Texas', 'Private/Baptist']
# ['Belmont', 'Bruins', 'Nashville', 'Tennessee', 'Private/Christian']
# ['Bethune–Cookman', 'Wildcats', 'Daytona Beach', 'Florida', 'Private/Methodist']
# ['Binghamton', 'Bearcats', 'Vestal', 'New York', 'State']
# ['Boise State', 'Broncos', 'Boise', 'Idaho', 'State']
# ['Boston College', 'Eagles', 'Chestnut Hill', 'Massachusetts', 'Private/Catholic']
# ['Boston University', 'Terriers', 'Boston', 'Massachusetts', 'Private/Non-sectarian']
# ['Bowling Green', 'Falcons', 'Bowling Green', 'Ohio', 'State']
# ['Bradley', 'Braves', 'Peoria', 'Illinois', 'Private/Non-Sectarian']
# ['BYU', 'Cougars', 'Provo', 'Utah', 'Private/Latter-Day Saints']
# ['Brown', 'Bears', 'Providence', 'Rhode Island', 'Private/Non-Sectarian']
# ['Bryant', 'Bulldogs', 'Smithfield', 'Rhode Island', 'Private/Non-Sectarian']
# ['Bucknell', 'Bison', 'Lewisburg', 'Pennsylvania', 'Private/Non-Sectarian']
# ['Buffalo', 'Bulls', 'Buffalo', 'New York', 'State']
# ['Butler', 'Bulldogs', 'Indianapolis', 'Indiana', 'Private/Non-Sectarian']
# ['California[A 3]', 'Golden Bears', 'Berkeley', 'California', 'State']
# ['UC Davis', 'Aggies', 'Davis', 'California', 'State']
# ['UC Irvine', 'Anteaters', 'Irvine', 'California', 'State']
# ['UCLA', 'Bruins', 'Los Angeles', 'California', 'State']
# ['Cal Poly', 'Mustangs', 'San Luis Obispo', 'California', 'State']
# ['UC Riverside', 'Highlanders', 'Riverside', 'California', 'State']
# ['UC Santa Barbara', 'Gauchos', 'Santa Barbara', 'California', 'State']
# ['Cal State Bakersfield', 'Roadrunners', 'Bakersfield', 'California', 'State']
# ['Fresno State', 'Bulldogs', 'Fresno', 'California', 'State']
# ['Cal State Fullerton', 'Titans', 'Fullerton', 'California', 'State']
# ['Long Beach State', '49ers[A 4]', 'Long Beach', 'California', 'State']
# ['Cal State Northridge[A 5]', 'Matadors', 'Northridge', 'California', 'State']
# ['Sacramento State', 'Hornets', 'Sacramento', 'California', 'State']
# ['Campbell', 'Fighting Camels and Lady Camels', 'Buies Creek', 'North Carolina', 'Private/Baptist']
# ['Canisius', 'Golden Griffins', 'Buffalo', 'New York', 'Private/Catholic']
# ['Central Arkansas', 'Bears and Sugar Bears', 'Conway', 'Arkansas', 'State']
# ['Central Connecticut', 'Blue Devils', 'New Britain', 'Connecticut', 'State']
# ['UCF', 'Knights', 'Orlando', 'Florida', 'State']
# ['Central Michigan', 'Chippewas', 'Mount Pleasant', 'Michigan', 'State']
# ['College of Charleston[A 6]', 'Cougars', 'Charleston', 'South Carolina', 'State']
# ['Charleston Southern', 'Buccaneers[A 7]', 'North Charleston', 'South Carolina', 'Private/Baptist']
# ['Chicago State', 'Cougars', 'Chicago', 'Illinois', 'State']
# ['Cincinnati', 'Bearcats', 'Cincinnati', 'Ohio', 'State']
# ['The Citadel', 'Bulldogs', 'Charleston', 'South Carolina', 'State']
# ['Clemson', 'Tigers', 'Clemson', 'South Carolina', 'State']
# ['Cleveland State', 'Vikings', 'Cleveland', 'Ohio', 'State']
# ['Coastal Carolina', 'Chanticleers', 'Conway', 'South Carolina', 'State']
# ['Colgate', 'Raiders', 'Hamilton', 'New York', 'Private/Non-sectarian']
# ['Colorado', 'Buffaloes', 'Boulder', 'Colorado', 'State']
# ['Colorado State', 'Rams', 'Fort Collins', 'Colorado', 'State']
# ['Columbia', 'Lions', 'Manhattan', 'New York', 'Private/Non-sectarian']
# ['UConn', 'Huskies', 'Storrs', 'Connecticut', 'State']
# ['Coppin State', 'Eagles', 'Baltimore', 'Maryland', 'State']
# ['Cornell', 'Big Red', 'Ithaca', 'New York', 'Private/Statutory state']
# ['Creighton', 'Bluejays', 'Omaha', 'Nebraska', 'Private/Catholic']
# ['Dartmouth', 'Big Green', 'Hanover', 'New Hampshire', 'Private/Non-sectarian']
# ['Davidson', 'Wildcats', 'Davidson', 'North Carolina', 'Private/Presbyterian']
# ['Dayton', 'Flyers', 'Dayton', 'Ohio', 'Private/Catholic']
# ['Delaware', "Fightin' Blue Hens", 'Newark', 'Delaware', 'Private-state hybrid']
# ['Delaware State', 'Hornets and Lady Hornets', 'Dover', 'Delaware', 'State']
# ['Denver', 'Pioneers', 'Denver', 'Colorado', 'Private/Non-sectarian']
# ['DePaul', 'Blue Demons', 'Chicago', 'Illinois', 'Private/Catholic']
# ['Detroit[A 8]', 'Titans', 'Detroit', 'Michigan', 'Private/Catholic']
# ['Drake', 'Bulldogs', 'Des Moines', 'Iowa', 'Private/Non-sectarian']
# ['Drexel', 'Dragons', 'Philadelphia', 'Pennsylvania', 'Private/Non-sectarian']
# ['Duke', 'Blue Devils', 'Durham', 'North Carolina', 'Private/Non-sectarian']
# ['Duequesne', 'Dukes', 'Pittsburgh', 'Pennsylvania', 'Private/Catholic']
# ['East Carolina', 'Pirates and Lady Pirates', 'Greenville', 'North Carolina', 'State']
# ['East Tennessee State[A 9]', 'Buccaneers and Lady Buccaneers', 'Johnson City', 'Tennessee', 'State']
# ['Eastern Illinois', 'Panthers', 'Charleston', 'Illinois', 'State']
# ['Eastern Kentucky[A 10]', 'Colonels', 'Richmond', 'Kentucky', 'State']
# ['Eastern Michigan', 'Eagles', 'Ypsilanti', 'Michigan', 'State']
# ['Eastern Washington', 'Eagles', 'Cheney', 'Washington', 'State']
# ['Elon', 'Phoenix', 'Elon', 'North Carolina', 'Private/Non-sectarian']
# ['Evansville', 'Purple Aces', 'Evansville', 'Indiana', 'Private/Methodist']
# ['Fairfield', 'Stags', 'Fairfield', 'Connecticut', 'Private/Catholic']
# ['Fairleigh Dickinson', 'Knights', 'Hackensack', 'New Jersey', 'Private/Non-sectarian']
# ['Florida', 'Gators', 'Gainesville', 'Florida', 'State']
# ['Florida A&M', 'Rattlers and Lady Rattlers', 'Tallahassee', 'Florida', 'State']
# ['Florida Atlantic', 'Owls', 'Boca Raton', 'Florida', 'State']
# ['FGCU', 'Eagles', 'Fort Myers', 'Florida', 'State']
# ['FIU', 'Panthers', 'Miami', 'Florida', 'State']
# ['Florida State', 'Seminoles', 'Tallahassee', 'Florida', 'State']
# ['Fordham', 'Rams', 'Bronx', 'New York', 'Private/Catholic']
# ['Furman', 'Paladins and Lady Paladins', 'Greenville', 'South Carolina', 'Private/Non-sectarian']
# ['Gardner–Webb', "Runnin' Bulldogs", 'Boiling Springs', 'North Carolina', 'Private/Baptist']
# ['George Mason', 'Patriots', 'Fairfax', 'Virginia', 'State']
# ['George Washington', 'Colonials', 'Washington', 'District of Columbia', 'Private/Non-sectarian']
# ['Georgetown', 'Hoyas', 'Washington', 'District of Columbia', 'Private/Catholic']
# ['Georgia', 'Bulldogs and Lady Bulldogs[A 11]', 'Athens', 'Georgia', 'State']
# ['Georgia Tech', 'Yellow Jackets', 'Atlanta', 'Georgia', 'State']
# ['Georgia Southern', 'Eagles and Lady Eagles', 'Statesboro', 'Georgia', 'State']
# ['Georgia State', 'Panthers', 'Atlanta', 'Georgia', 'State']
# ['Gonzaga', 'Bulldogs', 'Spokane', 'Washington', 'Private/Catholic']
# ['Grambling', 'Tigers and Lady Tigers', 'Grambling', 'Louisiana', 'State']
# ['Grand Canyon', 'Antelopes', 'Phoenix', 'Arizona', 'Private/Christian']
# ['Hampton', 'Pirates and Lady Pirates', 'Hampton', 'Virginia', 'Private/Non-sectarian']
# ['Hartford', 'Hawks', 'West Hartford', 'Connecticut', 'Private/Non-sectarian']
# ['Harvard', 'Crimson', 'Cambridge[A 12]', 'Massachusetts', 'Private/Non-sectarian']
# ['Hawaii', 'Rainbow Warriors and Rainbow Wahine[A 13]', 'Honolulu', 'Hawaii', 'State']
# ['High Point', 'Panthers', 'High Point', 'North Carolina', 'Private/Methodist']
# ['Hofstra', 'Pride', 'Hempstead', 'New York', 'Private/Non-sectarian']
# ['Holy Cross', 'Crusaders', 'Worcester', 'Massachusetts', 'Private/Catholic']
# ['Houston', 'Cougars', 'Houston', 'Texas', 'State']
# ['Houston Baptist', 'Huskies', 'Houston', 'Texas', 'Private/Baptist']
# ['Howard', 'Bison and Lady Bison', 'Washington', 'District of Columbia', 'Private/Non-sectarian']
# ['Idaho', 'Vandals', 'Moscow', 'Idaho', 'State']
# ['Idaho State', 'Bengals', 'Pocatello', 'Idaho', 'State']
# ['UIC[A 14]', 'Flames', 'Chicago', 'Illinois', 'State']
# ['Illinois State', 'Redbirds', 'Normal', 'Illinois', 'State']
# ['Illinois', 'Fighting Illini', 'Urbana–Champaign', 'Illinois', 'State']
# ['Incarnate Word[A 15]', 'Cardinals', 'San Antonio', 'Texas', 'Private/Catholic']
# ['Indiana', 'Hoosiers', 'Bloomington', 'Indiana', 'State']
# ['Indiana State', 'Sycamores', 'Terre Haute', 'Indiana', 'State']
# ['IUPUI', 'Jaguars', 'Indianapolis', 'Indiana', 'State']
# ['Iona', 'Gaels', 'New Rochelle', 'New York', 'Private/Catholic']
# ['Iowa', 'Hawkeyes', 'Iowa City', 'Iowa', 'State']
# ['Iowa State', 'Cyclones', 'Ames', 'Iowa', 'State']
# ['Jackson State', 'Tigers and Lady Tigers', 'Jackson', 'Mississippi', 'State']
# ['Jacksonville', 'Dolphins', 'Jacksonville', 'Florida', 'Private/Non-Sectarian']
# ['Jacksonville State', 'Gamecocks', 'Jacksonville', 'Alabama', 'State']
# ['James Madison', 'Dukes', 'Harrisonburg', 'Virginia', 'State']
# ['Kansas', 'Jayhawks', 'Lawrence', 'Kansas', 'State']
# ['Kansas State', 'Wildcats', 'Manhattan', 'Kansas', 'State']
# ['Kennesaw State', 'Owls and Lady Owls', 'Kennesaw', 'Georgia', 'State']
# ['Kent State', 'Golden Flashes', 'Kent', 'Ohio', 'State']
# ['Kentucky', 'Wildcats', 'Lexington', 'Kentucky', 'State']
# ['La Salle', 'Explorers', 'Philadelphia', 'Pennsylvania', 'Private/Catholic']
# ['Lafayette', 'Leopards', 'Easton', 'Pennsylvania', 'Private/Presbyterian']
# ['Lamar', 'Cardinals and Lady Cardinals', 'Beaumont', 'Texas', 'State']
# ['Lehigh', 'Mountain Hawks', 'Bethlehem', 'Pennsylvania', 'Private/Non-Sectarian']
# ['Liberty', 'Flames and Lady Flames', 'Lynchburg', 'Virginia', 'Private/Christian']
# ['Lipscomb', 'Bisons and Lady Bisons', 'Nashville', 'Tennessee', 'Private/Churches of Christ']
# ['LIU[A 16]', 'Sharks', 'Brooklyn', 'New York', 'Private/Non-Sectarian']
# ['Longwood', 'Lancers', 'Farmville', 'Virginia', 'State']
# ['Louisiana[A 17]', "Ragin' Cajuns", 'Lafayette', 'Louisiana', 'State']
# ['Louisiana–Monroe', 'Warhawks', 'Monroe', 'Louisiana', 'State']
# ['LSU', 'Tigers and Lady Tigers[A 18]', 'Baton Rouge', 'Louisiana', 'State']
# ['Louisiana Tech', 'Bulldogs and Lady Techsters', 'Ruston', 'Louisiana', 'State']
# ['Louisville', 'Cardinals', 'Louisville', 'Kentucky', 'State']
# ['Loyola–Chicago[A 19]', 'Ramblers', 'Chicago', 'Illinois', 'Private/Catholic']
# ['Loyola (MD)', 'Greyhounds', 'Baltimore', 'Maryland', 'Private/Catholic']
# ['Loyola  Marymount[A 20]', 'Lions', 'Los Angeles', 'California', 'Private/Catholic']
# ['Maine', 'Black Bears', 'Orono', 'Maine', 'State']
# ['Manhattan', 'Jaspers and Lady Jaspers', 'Riverdale', 'New York', 'Private/Catholic']
# ['Marist', 'Red Foxes', 'Poughkeepsie', 'New York', 'Private/Catholic']
# ['Marquette', 'Golden Eagles', 'Milwaukee', 'Wisconsin', 'Private/Catholic']
# ['Marshall', 'Thundering Herd', 'Huntington', 'West Virginia', 'State']
# ['UMBC', 'Retrievers', 'Catonsville', 'Maryland', 'State']
# ['Maryland', 'Terrapins', 'College Park', 'Maryland', 'State']
# ['Maryland Eastern Shore', 'Hawks and Lady Hawks', 'Princess Anne', 'Maryland', 'State']
# ['UMass[A 21]', 'Minutemen and Minutewomen', 'Amherst', 'Massachusetts', 'State']
# ['UMass Lowell', 'River Hawks', 'Lowell', 'Massachusetts', 'State']
# ['McNeese State', 'Cowboys and Cowgirls', 'Lake Charles', 'Louisiana', 'State']
# ['Memphis', 'Tigers', 'Memphis', 'Tennessee', 'State']
# ['Mercer', 'Bears', 'Macon', 'Georgia', 'Private/Non-Sectarian']
# ['Miami (FL)[A 22]', 'Hurricanes', 'Coral Gables', 'Florida', 'Private/Non-Sectarian']
# ['Miami (OH)[A 23]', 'Redhawks', 'Oxford', 'Ohio', 'State']
# ['Michigan', 'Wolverines', 'Ann Arbor', 'Michigan', 'State']
# ['Michigan State', 'Spartans', 'East Lansing', 'Michigan', 'State']
# ['Middle Tennessee', 'Blue Raiders', 'Murfreesboro', 'Tennessee', 'State']
# ['Minnesota', 'Golden Gophers', 'Minneapolis–Saint Paul', 'Minnesota', 'State']
# ['Ole Miss[A 24]', 'Rebels', 'Oxford', 'Mississippi', 'State']
# ['Mississippi State', 'Bulldogs', 'Starkville', 'Mississippi', 'State']
# ['Mississippi Valley State', 'Delta Devils and Devilettes', 'Itta Bena', 'Mississippi', 'State']
# ['Missouri', 'Tigers', 'Columbia', 'Missouri', 'State']
# ['Kansas City[A 25]', 'Kangaroos', 'Kansas City', 'Missouri', 'State']
# ['Missouri State', 'Bears and Lady Bears', 'Springfield', 'Missouri', 'State']
# ['Monmouth', 'Hawks', 'West Long Branch', 'New Jersey', 'Private/Non-Sectarian']
# ['Montana', 'Grizzlies[A 26]', 'Missoula', 'Montana', 'State']
# ['Montana State', 'Bobcats', 'Bozeman', 'Montana', 'State']
# ['Morehead State', 'Eagles', 'Morehead', 'Kentucky', 'State']
# ['Morgan State', 'Bears and Lady Bears', 'Baltimore', 'Maryland', 'State']
# ["Mount St. Mary's", 'Mountaineers', 'Emmitsburg', 'Maryland', 'Private/Catholic']
# ['Murray State', 'Racers[A 27]', 'Murray', 'Kentucky', 'State']
# ['Nebraska', 'Cornhuskers', 'Lincoln', 'Nebraska', 'State']
# ['Omaha[A 28]', 'Mavericks', 'Omaha', 'Nebraska', 'State']
# ['UNLV', 'Rebels[A 29]', 'Paradise', 'Nevada', 'State']
# ['Nevada', 'Wolf Pack', 'Reno', 'Nevada', 'State']
# ['New Hampshire', 'Wildcats', 'Durham', 'New Hampshire', 'State']
# ['NJIT', 'Highlanders', 'Newark', 'New Jersey', 'State']
# ['New Mexico', 'Lobos', 'Albuquerque', 'New Mexico', 'State']
# ['New Mexico State', 'Aggies', 'Las Cruces', 'New Mexico', 'State']
# ['New Orleans', 'Privateers', 'New Orleans', 'Louisiana', 'State']
# ['Niagara', 'Purple Eagles', 'Lewiston', 'New York', 'Private/Catholic']
# ['Nicholls', 'Colonels', 'Thibodaux', 'Louisiana', 'State']
# ['Norfolk State', 'Spartans', 'Norfolk', 'Virginia', 'State']
# ['North Carolina A&T', 'Aggies', 'Greensboro', 'North Carolina', 'State']
# ['UNC Asheville', 'Bulldogs', 'Asheville', 'North Carolina', 'State']
# ['North Carolina Central', 'Eagles', 'Durham', 'North Carolina', 'State']
# ['North Carolina', 'Tar Heels', 'Chapel Hill', 'North Carolina', 'State']
# ['Charlotte', '49ers', 'Charlotte', 'North Carolina', 'State']
# ['UNC Greensboro', 'Spartans[A 30]', 'Greensboro', 'North Carolina', 'State']
# ['NC State', 'Wolfpack', 'Raleigh', 'North Carolina', 'State']
# ['UNC Wilmington', 'Seahawks', 'Wilmington', 'North Carolina', 'State']
# ['North Dakota', 'Fighting Hawks[A 31]', 'Grand Forks', 'North Dakota', 'State']
# ['North Dakota State', 'Bison', 'Fargo', 'North Dakota', 'State']
# ['North Florida', 'Ospreys and Lady Ospreys', 'Jacksonville', 'Florida', 'State']
# ['North Texas', 'Mean Green', 'Denton', 'Texas', 'State']
# ['Northeastern', 'Huskies', 'Boston', 'Massachusetts', 'Private/Non-Sectarian']
# ['Northern Arizona', 'Lumberjacks', 'Flagstaff', 'Arizona', 'State']
# ['Northern Colorado', 'Bears', 'Greeley', 'Colorado', 'State']
# ['Northern Illinois', 'Huskies', 'DeKalb', 'Illinois', 'State']
# ['Northern Iowa[A 32]', 'Panthers', 'Cedar Falls', 'Iowa', 'State']
# ['Northern Kentucky', 'Norse', 'Highland Heights', 'Kentucky', 'State']
# ['Northwestern', 'Wildcats', 'Evanston', 'Illinois', 'Private/Non-Sectarian']
# ['Northwestern State', 'Demons and Lady Demons', 'Natchitoches', 'Louisiana', 'State']
# ['Notre Dame', 'Fighting Irish', 'South Bend', 'Indiana', 'Private/Catholic']
# ['Oakland', 'Golden Grizzlies', 'Rochester', 'Michigan', 'State']
# ['Ohio', 'Bobcats', 'Athens', 'Ohio', 'State']
# ['Ohio State[A 33]', 'Buckeyes', 'Columbus', 'Ohio', 'State']
# ['Oklahoma', 'Sooners', 'Norman', 'Oklahoma', 'State']
# ['Oklahoma State', 'Cowboys and Cowgirls', 'Stillwater', 'Oklahoma', 'State']
# ['Old Dominion', 'Monarchs and Lady Monarchs', 'Norfolk', 'Virginia', 'State']
# ['Oral Roberts', 'Golden Eagles', 'Tulsa', 'Oklahoma', 'Private/Christian']
# ['Oregon', 'Ducks', 'Eugene', 'Oregon', 'State']
# ['Oregon State', 'Beavers', 'Corvallis', 'Oregon', 'State']
# ['Pacific', 'Tigers', 'Stockton', 'California', 'Private/Methodist']
# ['Penn', 'Quakers', 'Philadelphia', 'Pennsylvania', 'Private/Non-Sectarian']
# ['Penn State', 'Nittany Lions[A 34]', 'State College', 'Pennsylvania', 'State-related']
# ['Pepperdine', 'Waves', 'Malibu', 'California', 'Private/Churches of Christ']
# ['Pittsburgh[A 35]', 'Panthers', 'Pittsburgh', 'Pennsylvania', 'State-related']
# ['Portland', 'Pilots', 'Portland', 'Oregon', 'Private/Catholic']
# ['Portland State', 'Vikings', 'Portland', 'Oregon', 'State']
# ['Prairie View A&M', 'Panthers and Lady Panthers', 'Prairie View', 'Texas', 'State']
# ['Presbyterian', 'Blue Hose', 'Clinton', 'South Carolina', 'Private/Presbyterian']
# ['Princeton', 'Tigers', 'Princeton', 'New Jersey', 'Private/Non-Sectarian']
# ['Providence', 'Friars', 'Providence', 'Rhode Island', 'Private/Catholic']
# ['Purdue', 'Boilermakers', 'West Lafayette', 'Indiana', 'State']
# ['Purdue Fort Wayne', 'Mastodons', 'Fort Wayne', 'Indiana', 'State']
# ['Quinnipiac', 'Bobcats', 'Hamden', 'Connecticut', 'Private/Non-Sectarian']
# ['Radford', 'Highlanders', 'Radford', 'Virginia', 'State']
# ['Rhode Island', 'Rams', 'Kingston', 'Rhode Island', 'State']
# ['Rice', 'Owls', 'Houston', 'Texas', 'Private/Non-Sectarian']
# ['Richmond', 'Spiders', 'Richmond', 'Virginia', 'Private/Non-Sectarian']
# ['Rider', 'Broncs', 'Lawrenceville', 'New Jersey', 'Private/Non-Sectarian']
# ['Robert Morris', 'Colonials', 'Moon Township', 'Pennsylvania', 'Private/Non-Sectarian']
# ['Rutgers', 'Scarlet Knights', 'New Brunswick', 'New Jersey', 'State-private hybrid']
# ['Sacred Heart', 'Pioneers', 'Fairfield', 'Connecticut', 'Private/Catholic']
# ['St. Bonaventure', 'Bonnies', 'St. Bonaventure', 'New York', 'Private/Catholic']
# ['St. Francis Brooklyn[A 36]', 'Terriers', 'Brooklyn', 'New York', 'Private/Catholic']
# ['Saint Francis (PA)[A 37]', 'Red Flash', 'Loretto', 'Pennsylvania', 'Private/Catholic']
# ["St. John's[A 38]", 'Red Storm', 'Jamaica', 'New York', 'Private/Catholic']
# ["Saint Joseph's[A 39]", 'Hawks', 'Philadelphia', 'Pennsylvania', 'Private/Catholic']
# ['Saint Louis', 'Billikens', 'St. Louis', 'Missouri', 'Private/Catholic']
# ["Saint Mary's", 'Gaels', 'Moraga', 'California', 'Private/Catholic']
# ["Saint Peter's", 'Peacocks and Peahens', 'Jersey City', 'New Jersey', 'Private/Catholic']
# ['Sam Houston State', 'Bearkats', 'Huntsville', 'Texas', 'State']
# ['Samford', 'Bulldogs', 'Homewood', 'Alabama', 'Private/Baptist']
# ['San Diego', 'Toreros', 'San Diego', 'California', 'Private/Catholic']
# ['San Diego State', 'Aztecs', 'San Diego', 'California', 'State']
# ['San Francisco', 'Dons', 'San Francisco', 'California', 'Private/Catholic']
# ['San Jose State', 'Spartans', 'San Jose', 'California', 'State']
# ['Santa Clara', 'Broncos', 'Santa Clara', 'California', 'Private/Catholic']
# ['Seattle', 'Redhawks', 'Seattle', 'Washington', 'Private/Catholic']
# ['Seton Hall', 'Pirates', 'South Orange', 'New Jersey', 'Private/Catholic']
# ['Siena', 'Saints', 'Loudonville', 'New York', 'Private/Catholic']
# ['South Alabama', 'Jaguars', 'Mobile', 'Alabama', 'State']
# ['South Carolina', 'Gamecocks', 'Columbia', 'South Carolina', 'State']
# ['South Carolina State', 'Bulldogs and Lady Bulldogs', 'Orangeburg', 'South Carolina', 'State']
# ['USC Upstate[A 40]', 'Spartans', 'Spartanburg', 'South Carolina', 'State']
# ['South Dakota', 'Coyotes', 'Vermillion', 'South Dakota', 'State']
# ['South Dakota State', 'Jackrabbits', 'Brookings', 'South Dakota', 'State']
# ['South Florida', 'Bulls', 'Tampa', 'Florida', 'State']
# ['Southeast Missouri[A 41]', 'Redhawks', 'Cape Girardeau', 'Missouri', 'State']
# ['Southeastern Louisiana', 'Lions and Lady Lions', 'Hammond', 'Louisiana', 'State']
# ['Southern', 'Jaguars and Lady Jaguars', 'Baton Rouge', 'Louisiana', 'State']
# ['USC[A 42]', 'Trojans[A 43]', 'Los Angeles', 'California', 'Private/Non-Sectarian']
# ['Southern Illinois', 'Salukis', 'Carbondale', 'Illinois', 'State']
# ['SIU Edwardsville[A 44]', 'Cougars', 'Edwardsville', 'Illinois', 'State']
# ['SMU', 'Mustangs', 'University Park', 'Texas', 'Private/Methodist']
# ['Southern Miss', 'Golden Eagles and Lady Eagles', 'Hattiesburg', 'Mississippi', 'State']
# ['Southern Utah[A 45]', 'Thunderbirds', 'Cedar City', 'Utah', 'State']
# ['Stanford', 'Cardinal', 'Palo Alto', 'California', 'Private/Non-Sectarian']
# ['Stephen F. Austin[A 46]', 'Lumberjacks and Ladyjacks', 'Nacogdoches', 'Texas', 'State']
# ['Stetson', 'Hatters', 'DeLand', 'Florida', 'Private/Non-Sectarian']
# ['Stony Brook', 'Seawolves', 'Stony Brook', 'New York', 'State']
# ['Syracuse', 'Orange', 'Syracuse', 'New York', 'Private/Methodist']
# ['Temple', 'Owls', 'Philadelphia', 'Pennsylvania', 'State-related']
# ['Tennessee', 'Volunteers and Lady Vols[A 47]', 'Knoxville', 'Tennessee', 'State']
# ['Chattanooga', 'Mocs and Lady Mocs', 'Chattanooga', 'Tennessee', 'State']
# ['UT Martin', 'Skyhawks', 'Martin', 'Tennessee', 'State']
# ['Tennessee State', 'Tigers and Lady Tigers', 'Nashville', 'Tennessee', 'State']
# ['Tennessee Tech', 'Golden Eagles', 'Cookeville', 'Tennessee', 'State']
# ['Texas A&M', 'Aggies', 'College Station', 'Texas', 'State']
# ['Texas A&M–Corpus Christi', 'Islanders', 'Corpus Christi', 'Texas', 'State']
# ['Texas–Arlington', 'Mavericks', 'Arlington', 'Texas', 'State']
# ['Texas', 'Longhorns', 'Austin', 'Texas', 'State']
# ['TCU', 'Horned Frogs and Lady Frogs', 'Fort Worth', 'Texas', 'Private/Disciples of Christ']
# ['UTEP', 'Miners', 'El Paso', 'Texas', 'State']
# ['UTRGV', 'Vaqueros', 'Edinburg[A 48]', 'Texas', 'State']
# ['UTSA', 'Roadrunners', 'San Antonio', 'Texas', 'State']
# ['Texas Southern', 'Tigers and Lady Tigers', 'Houston', 'Texas', 'State']
# ['Texas State', 'Bobcats', 'San Marcos', 'Texas', 'State']
# ['Texas Tech', 'Red Raiders[A 49]', 'Lubbock', 'Texas', 'State']
# ['Toledo', 'Rockets', 'Toledo', 'Ohio', 'State']
# ['Towson', 'Tigers', 'Towson', 'Maryland', 'State']
# ['Troy', 'Trojans', 'Troy', 'Alabama', 'State']
# ['Tulane', 'Green Wave', 'New Orleans', 'Louisiana', 'Private/Non-Sectarian']
# ['Tulsa', 'Golden Hurricane', 'Tulsa', 'Oklahoma', 'Private/Presbyterian']
# ['Air Force', 'Falcons', 'Colorado Springs', 'Colorado', 'Federal academy']
# ['Army[A 50]', 'Black Knights', 'West Point', 'New York', 'Federal academy']
# ['Navy', 'Midshipmen', 'Annapolis', 'Maryland', 'Federal academy']
# ['Utah', 'Utes[A 51]', 'Salt Lake City', 'Utah', 'State']
# ['Utah State', 'Aggies', 'Logan', 'Utah', 'State']
# ['Utah Valley', 'Wolverines', 'Orem', 'Utah', 'State']
# ['Valpo', 'Crusaders', 'Valparaiso', 'Indiana', 'Private/Lutheran']
# ['Vanderbilt', 'Commodores', 'Nashville', 'Tennessee', 'Private/Non-Sectarian']
# ['Vermont', 'Catamounts', 'Burlington', 'Vermont', 'State']
# ['Villanova', 'Wildcats', 'Radnor Township', 'Pennsylvania', 'Private/Catholic']
# ['Virginia', 'Cavaliers', 'Charlottesville', 'Virginia', 'State']
# ['VCU', 'Rams', 'Richmond', 'Virginia', 'State']
# ['VMI', 'Keydets', 'Lexington', 'Virginia', 'State']
# ['Virginia Tech', 'Hokies', 'Blacksburg', 'Virginia', 'State']
# ['Wagner', 'Seahawks', 'Staten Island', 'New York', 'Private/Lutheran']
# ['Wake Forest', 'Demon Deacons', 'Winston-Salem', 'North Carolina', 'Private/Non-Sectarian']
# ['Washington', 'Huskies', 'Seattle', 'Washington', 'State']
# ['Washington State', 'Cougars', 'Pullman', 'Washington', 'State']
# ['Weber State', 'Wildcats', 'Ogden', 'Utah', 'State']
# ['West Virginia', 'Mountaineers', 'Morgantown', 'West Virginia', 'State']
# ['Western Carolina', 'Catamounts', 'Cullowhee', 'North Carolina', 'State']
# ['Western Illinois', 'Leathernecks', 'Macomb', 'Illinois', 'State']
# ['Western Kentucky', 'Hilltoppers and Lady Toppers', 'Bowling Green', 'Kentucky', 'State']
# ['Western Michigan', 'Broncos', 'Kalamazoo', 'Michigan', 'State']
# ['Wichita State', 'Shockers', 'Wichita', 'Kansas', 'State']
# ['William & Mary', 'Tribe', 'Williamsburg', 'Virginia', 'State']
# ['Winthrop', 'Eagles', 'Rock Hill', 'South Carolina', 'State']
# ['Green Bay[A 53]', 'Phoenix', 'Green Bay', 'Wisconsin', 'State']
# ['Wisconsin', 'Badgers', 'Madison', 'Wisconsin', 'State']
# ['Milwaukee[A 54]', 'Panthers', 'Milwaukee', 'Wisconsin', 'State']
# ['Wofford', 'Terriers', 'Spartanburg', 'South Carolina', 'Private/Methodist']
# ['Wright State', 'Raiders', 'Fairborn', 'Ohio', 'State']
# ['Wyoming', 'Cowboys and Cowgirls', 'Laramie', 'Wyoming', 'State']
# ['Xavier', 'Musketeers', 'Cincinnati', 'Ohio', 'Private/Catholic']
# ['Yale', 'Bulldogs', 'New Haven', 'Connecticut', 'Private/Non-Sectarian']
# ['Youngstown State', 'Penguins', 'Youngstown', 'Ohio', 'State']

# %%
# Create an empty list
rows=list()
# Extract the columns we want 
# Use the table that we just stored from last forloop for finding the  <tr> tag: defines a table row
for trs in table.find_all('tr'):
    # find all the <td> tag: defines a table cell
    tds = trs.find_all('td')
    if not tds:     # if tds is not None
        continue
    # get the text from <td> tag and store in variable by row
    rows.append([td.text.strip() for td in tds[0:5]])

# %%
import pandas as pd
df=pd.DataFrame(rows, columns= headings[1:6])

# %%
df
# Out:
#            Common Name                        Team        City        State  \
# 0    Abilene Christian                    Wildcats     Abilene        Texas
# 1                Akron                        Zips       Akron         Ohio
# 2              Alabama                Crimson Tide  Tuscaloosa      Alabama
# 3          Alabama A&M  Bulldogs and Lady Bulldogs  Huntsville      Alabama
# 4                  UAB                     Blazers  Birmingham      Alabama
# ..                 ...                         ...         ...          ...
# 345       Wright State                     Raiders    Fairborn         Ohio
# 346            Wyoming        Cowboys and Cowgirls     Laramie      Wyoming
# 347             Xavier                  Musketeers  Cincinnati         Ohio
# 348               Yale                    Bulldogs   New Haven  Connecticut
# 349   Youngstown State                    Penguins  Youngstown         Ohio
#
#                            Type
# 0    Private/Churches of Christ
# 1                         State
# 2                         State
# 3                         State
# 4                         State
# ..                          ...
# 345                       State
# 346                       State
# 347            Private/Catholic
# 348       Private/Non-Sectarian
# 349                       State
#
# [350 rows x 5 columns]

# %%
headings[:6]
# Out:
# ['School', 'Common Name', 'Team', 'City', 'State', 'Type']

# %%
df=df.assign(School=headings[7:])

# %%
df=df[['School', 'Common Name', 'Team', 'City', 'State', 'Type']]

# %%
df
# Out:
#                                              School        Common Name  \
# 0                      Abilene Christian University  Abilene Christian
# 1                               University of Akron              Akron
# 2                             University of Alabama            Alabama
# 3    Alabama Agricultural and Mechanical University        Alabama A&M
# 4               University of Alabama at Birmingham                UAB
# ..                                              ...                ...
# 345                         Wright State University       Wright State
# 346                           University of Wyoming            Wyoming
# 347                               Xavier University             Xavier
# 348                                 Yale University               Yale
# 349                     Youngstown State University   Youngstown State
#
#                            Team        City        State  \
# 0                      Wildcats     Abilene        Texas
# 1                          Zips       Akron         Ohio
# 2                  Crimson Tide  Tuscaloosa      Alabama
# 3    Bulldogs and Lady Bulldogs  Huntsville      Alabama
# 4                       Blazers  Birmingham      Alabama
# ..                          ...         ...          ...
# 345                     Raiders    Fairborn         Ohio
# 346        Cowboys and Cowgirls     Laramie      Wyoming
# 347                  Musketeers  Cincinnati         Ohio
# 348                    Bulldogs   New Haven  Connecticut
# 349                    Penguins  Youngstown         Ohio
#
#                            Type
# 0    Private/Churches of Christ
# 1                         State
# 2                         State
# 3                         State
# 4                         State
# ..                          ...
# 345                       State
# 346                       State
# 347            Private/Catholic
# 348       Private/Non-Sectarian
# 349                       State
#
# [350 rows x 6 columns]

# %%
def normalize_string(text):
    """
    Expect: a string contain '[]'; ex: Saint Francis (PA)[A 37]
    Modifies: extract text before '[]';
    Returns: strings; ex: Saint Francis (PA)
    """   
    if '[' in text:
        index=text.find('[')
        result=text[:index]
    else:
        result=text
    return result

# %%
df=df.applymap(normalize_string)

# %%
# output a list in cells version of csv
df.to_csv('divisionI.csv', index=False)
